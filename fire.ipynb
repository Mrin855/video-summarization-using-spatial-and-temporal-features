# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os

# %%
import cv2 
import os

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def dataset_train_processing():
    # Hardcode dataset path
    data_path =r'C:\SumMe\Frame\Fire domino'
    augmented_data_path = r'C:\SumMe\Augmentation\Augf\Aug'
    
    # Create the directory for augmented data if it doesn't exist
    if not os.path.exists(augmented_data_path):
        os.makedirs(augmented_data_path)
    
    # Process dataset
    file_names = os.listdir(data_path)
    
    # Set a datagenerator for augmentation
    train_datagen = ImageDataGenerator(rotation_range=15,
                                       shear_range=0.1,
                                       zoom_range=0.2,
                                       horizontal_flip=True,
                                       width_shift_range=0.1,
                                       height_shift_range=0.1)
    
    # Create batches of data for augmentation
    for file_name in file_names:
        image_path = os.path.join(data_path, file_name)
        img = plt.imread(image_path)
        img = img.reshape((1,) + img.shape)  # Reshape to add batch dimension
        
        # Flow the image through the generator and save augmented images
        i = 0
        for batch in train_datagen.flow(img, 
                                        batch_size=1,
                                        save_to_dir=augmented_data_path,
                                        save_prefix=f'aug_{os.path.splitext(file_name)[0]}',
                                        save_format='jpeg'):
            i += 1
            if i >= 1:  # Save 2 augmented versions of each image
                break
    
    # Sample visualization of augmented images (optional)
    example_gen = train_datagen.flow_from_directory(data_path,
                                                    target_size=(224, 224),
                                                    batch_size=1,
                                                    class_mode=None,
                                                    save_to_dir=augmented_data_path,
                                                    save_prefix='aug_example',
                                                    save_format='jpg')
    
    plt.figure(figsize=(12, 12))
    for i in range(0, 15):
        plt.subplot(5, 3, i + 1)
        for X in example_gen:
            image = X[0]
            plt.imshow(image)
            break
    plt.tight_layout()
    plt.show()

# Usage
dataset_train_processing()
# Out:
# Found 0 images belonging to 0 classes.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 58
#      55     plt.show()
#      57 # Usage
# ---> 58 dataset_train_processing()
#
# Cell In[4], line 51, in dataset_train_processing()
#      49 plt.subplot(5, 3, i + 1)
#      50 for X in example_gen:
# ---> 51     image = X[0]
#      52     plt.imshow(image)
#      53     break
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np
import os

# Load the InceptionV3 model
net = InceptionV3(include_top=True, weights='imagenet')
net.summary()

# Load images from directory using ImageDataGenerator
image_directory = r'C:\SumMe\Augmentation\Augf'
input_size = net.input_shape[1:3]  # Get the input size (height, width)

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# Create a data generator for the images
augimds = datagen.flow_from_directory(image_directory,
                                      target_size=input_size,
                                      batch_size=32,  # Adjust the batch size if needed
                                      class_mode=None,
                                      shuffle=False) 

# Create a model that outputs the activations from the specified layer
layer_name = 'predictions'  # Example layer name in InceptionV3 (change as needed)
intermediate_layer_model = tf.keras.Model(inputs=net.input,
                                          outputs=net.get_layer(layer_name).output)

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Reshape the features to ensure they are in 'rows' format (2D)
features_train = features_train.reshape(features_train.shape[0], -1)
np.save(os.path.join(image_directory, 'inceptionv3_features_train.npy'), features_train)

print(f"Features shape: {features_train.shape}")

# Print some sample features
print("Sample features (first 5 rows):")
print(features_train[:5])
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_59[0][0]']
# ...
#  conv2d_77 (Conv2D)             (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 8, 8, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,851,784
# Trainable params: 23,817,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# Found 1612 images belonging to 1 classes.
# 51/51 [==============================] - 440s 8s/step
# Features shape: (1612, 1000)
# Sample features (first 5 rows):
# [[1.61304677e-04 2.99649051e-04 1.20096127e-04 ... 1.26236091e-05
#   4.92565043e-04 9.56719916e-04]
#  [5.74631258e-07 5.49960362e-07 2.35319271e-06 ... 6.11204314e-07
#   4.61264062e-05 4.60764795e-06]
#  [8.20912817e-07 1.10308520e-06 1.28463935e-05 ... 1.28044587e-06
#   2.19889320e-04 2.00485592e-05]
#  [2.03637842e-06 4.14465512e-06 1.90133378e-05 ... 2.22018821e-06
#   2.90991709e-04 7.85439115e-05]
#  [3.10023870e-06 3.11893928e-06 2.24751329e-05 ... 3.73116609e-06
#   7.74489308e-05 2.89365780e-05]]

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os


# Load the ResNet50 model
net = ResNet50(include_top=True, weights='imagenet')
net.summary()

# Load images from directory using ImageDataGenerator
image_directory = r'C:\SumMe\Augmentation\Augf'
input_size = net.input_shape[1:3]  # Get the input size (height, width)

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# Create a data generator for the images
augimds = datagen.flow_from_directory(image_directory,
                                      target_size=input_size,
                                      batch_size=32,  # Adjust the batch size if needed
                                      class_mode=None,
                                      shuffle=False) 

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Create a model that outputs the activations from the specified layer
layer_name = 'predictions'  # Example layer name in ResNet50
intermediate_layer_model = tf.keras.Model(inputs=net.input,
                                          outputs=net.get_layer(layer_name).output)

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Reshape the features to ensure they are in 'rows' format (2D)
features_train = features_train.reshape(features_train.shape[0], -1)
np.save(os.path.join(image_directory, 'resnet50_features_train.npy'), features_train)


print(f"Features shape: {features_train.shape}")

# Print some sample features
print("Sample features (first 5 rows):")
print(features_train[:5])
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Found 1612 images belonging to 1 classes.
# 51/51 [==============================] - 236s 5s/step
# 51/51 [==============================] - 428s 8s/step
# Features shape: (1612, 1000)
# Sample features (first 5 rows):
# [[1.1148635e-07 2.4781914e-06 2.4985039e-04 ... 2.9455842e-08
#   6.5333108e-05 3.7567827e-04]
#  [4.2426901e-08 4.1423715e-07 3.5343734e-07 ... 2.7389316e-08
#   4.4765420e-05 4.5641482e-06]
#  [7.9547506e-09 2.0232709e-07 1.1224616e-07 ... 4.8029936e-09
#   1.3444244e-05 6.6269649e-06]
#  [1.7810419e-09 3.8865061e-08 3.5919993e-07 ... 4.0730586e-10
#   2.1410847e-06 1.0295512e-05]
#  [1.1783892e-08 2.9222531e-07 3.0476679e-07 ... 2.5224280e-09
#   1.8012161e-06 9.5853229e-06]]

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os


# Load the ResNet50 model
net = ResNet50(include_top=True, weights='imagenet')
net.summary()

# Load images from directory using ImageDataGenerator
image_directory = r':\SumMe\Augmentation\Augf'
input_size = net.input_shape[1:3]  # Get the input size (height, width)

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# Create a data generator for the images
augimds = datagen.flow_from_directory(image_directory,
                                      target_size=input_size,
                                      batch_size=32,  # Adjust the batch size if needed
                                      class_mode=None,
                                      shuffle=False) 

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Create a model that outputs the activations from the specified layer
layer_name = 'predictions'  # Example layer name in ResNet50
intermediate_layer_model = tf.keras.Model(inputs=net.input,
                                          outputs=net.get_layer(layer_name).output)

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Reshape the features to ensure they are in 'rows' format (2D)
features_train = features_train.reshape(features_train.shape[0], -1)
np.save(os.path.join(image_directory, 'resnet50_features_train.npy'), features_train)


print(f"Features shape: {features_train.shape}")

# Print some sample features
print("Sample features (first 5 rows):")
print(features_train[:5])
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 19
#      17 datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
#      18 # Create a data generator for the images
# ---> 19 augimds = datagen.flow_from_directory(image_directory,
#      20                                       target_size=input_size,
#      21                                       batch_size=32,  # Adjust the batch size if needed
#      22                                       class_mode=None,
#      23                                       shuffle=False)
#      25 # Generate activations
#      26 features_train = intermediate_layer_model.predict(augimds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\preprocessing\image.py:1648, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1562 def flow_from_directory(
#    1563     self,
#    1564     directory,
#    (...)
#    1578     keep_aspect_ratio=False,
#    1579 ):
#    1580     """Takes the path to a directory & generates batches of augmented data.
#    1581
#    1582     Args:
#    (...)
#    1646             and `y` is a numpy array of corresponding labels.
#    1647     """
# -> 1648     return DirectoryIterator(
#    1649         directory,
#    1650         self,
#    1651         target_size=target_size,
#    1652         color_mode=color_mode,
#    1653         keep_aspect_ratio=keep_aspect_ratio,
#    1654         classes=classes,
#    1655         class_mode=class_mode,
#    1656         data_format=self.data_format,
#    1657         batch_size=batch_size,
#    1658         shuffle=shuffle,
#    1659         seed=seed,
#    1660         save_to_dir=save_to_dir,
#    1661         save_prefix=save_prefix,
#    1662         save_format=save_format,
#    1663         follow_links=follow_links,
#    1664         subset=subset,
#    1665         interpolation=interpolation,
#    1666         dtype=self.dtype,
#    1667     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\preprocessing\image.py:563, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561 if not classes:
#     562     classes = []
# --> 563     for subdir in sorted(os.listdir(directory)):
#     564         if os.path.isdir(os.path.join(directory, subdir)):
#     565             classes.append(subdir)
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: ':\\SumMe\\Augmentation\\Augf'

# %%
import numpy as np
import os

# Define the directory where your features are saved
image_directory = r'C:\SumMe\Augmentation\Augf'

# Load the features from the saved .npy files
features_resnet = np.load(os.path.join(image_directory, 'resnet50_features_train.npy'))
features_inceptionv3 = np.load(os.path.join(image_directory, 'inceptionv3_features_train.npy'))

# Ensure both feature arrays have the same number of samples
assert features_resnet.shape[0] == features_inceptionv3.shape[0], "Number of samples must be the same in both feature arrays."

# Concatenate the features along the feature dimension (axis=1)
features_combined = np.concatenate((features_resnet, features_inceptionv3), axis=1)

# Save the combined features to a new .npy file
np.save(os.path.join(image_directory, 'combined_features_train.npy'), features_combined)

print(f"Combined features shape: {features_combined.shape}")

# Print some sample combined features
print("Sample combined features (first 5 rows):")
print(features_combined[:5])
# Out:
# Combined features shape: (1612, 2000)
# Sample combined features (first 5 rows):
# [[1.1148635e-07 2.4781914e-06 2.4985039e-04 ... 1.2623609e-05
#   4.9256504e-04 9.5671992e-04]
#  [4.2426901e-08 4.1423715e-07 3.5343734e-07 ... 6.1120431e-07
#   4.6126406e-05 4.6076480e-06]
#  [7.9547506e-09 2.0232709e-07 1.1224616e-07 ... 1.2804459e-06
#   2.1988932e-04 2.0048559e-05]
#  [1.7810419e-09 3.8865061e-08 3.5919993e-07 ... 2.2201882e-06
#   2.9099171e-04 7.8543912e-05]
#  [1.1783892e-08 2.9222531e-07 3.0476679e-07 ... 3.7311661e-06
#   7.7448931e-05 2.8936578e-05]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input

# Define the directory where your features are saved
image_directory = r'C:\SumMe\Augmentation\Augf'

# Load the features from the saved .npy files
features_combined = np.load(os.path.join(image_directory, 'combined_features_train.npy'))

# Define the number of timesteps (sequence length) and features
timesteps = 1  # Assuming each sample is treated as a sequence of length 1 for this example
input_dim = features_combined.shape[1]  # Should be 2000

# Prepare data for LSTM
# For this example, we'll use the features directly as sequences of length 1
X = features_combined
y = np.random.randint(0, 100, size=(features_combined.shape[0],))  # Example target variable, replace with your actual labels

# Reshape input to be [samples, timesteps, features]
X = X.reshape((X.shape[0], timesteps, input_dim))

# Define the LSTM model
inputs = Input(shape=(timesteps, input_dim))

# Add LSTM layers
x = LSTM(64, return_sequences=True)(inputs)
x = Dropout(0.5)(x)

x = LSTM(128, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(256, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(256, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(128, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(64, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(32)(x)
x = Dropout(0.5)(x)

# Add a Dense layer for output
outputs = Dense(100, activation='softmax')(x)  # Adjust the number of units based on your specific task

# Create the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
# For this example, we use dummy targets. Replace y with your actual labels.
model.fit(X, y, epochs=20, batch_size=32, validation_split=0.2)

# Extract features from the last LSTM layer
feature_extractor = Model(inputs=model.input, outputs=model.layers[-3].output)  # Layer before the final Dense layer

# Obtain features from the last LSTM layer
features_last_lstm = feature_extractor.predict(X)

# Save the extracted features
np.save(os.path.join(image_directory, 'features_last_lstm.npy'), features_last_lstm)

# Print the feature shape
print(f"Shape of features extracted from the last LSTM layer: {features_last_lstm.shape}")

# Print some sample features
print("Sample features from the last LSTM layer (first 5 samples):")
print(features_last_lstm[:5])
# Out:
# Epoch 1/20
# 41/41 [==============================] - 85s 552ms/step - loss: 4.6054 - accuracy: 0.0124 - val_loss: 4.6059 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 41/41 [==============================] - 5s 130ms/step - loss: 4.6038 - accuracy: 0.0147 - val_loss: 4.6062 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 41/41 [==============================] - 5s 123ms/step - loss: 4.6021 - accuracy: 0.0132 - val_loss: 4.6069 - val_accuracy: 0.0124
# Epoch 4/20
# 41/41 [==============================] - 5s 128ms/step - loss: 4.6003 - accuracy: 0.0124 - val_loss: 4.6083 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 41/41 [==============================] - 6s 135ms/step - loss: 4.5962 - accuracy: 0.0140 - val_loss: 4.6208 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 41/41 [==============================] - 5s 125ms/step - loss: 4.5915 - accuracy: 0.0124 - val_loss: 4.6231 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 41/41 [==============================] - 5s 126ms/step - loss: 4.5869 - accuracy: 0.0132 - val_loss: 4.6317 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 41/41 [==============================] - 5s 131ms/step - loss: 4.5857 - accuracy: 0.0116 - val_loss: 4.6331 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 41/41 [==============================] - 5s 123ms/step - loss: 4.5872 - accuracy: 0.0163 - val_loss: 4.6268 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 41/41 [==============================] - 5s 123ms/step - loss: 4.5883 - accuracy: 0.0132 - val_loss: 4.6254 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 41/41 [==============================] - 5s 124ms/step - loss: 4.5877 - accuracy: 0.0124 - val_loss: 4.6248 - val_accuracy: 0.0124
# Epoch 12/20
# 41/41 [==============================] - 5s 122ms/step - loss: 4.5863 - accuracy: 0.0116 - val_loss: 4.6212 - val_accuracy: 0.0093
# Epoch 13/20
# 41/41 [==============================] - 5s 121ms/step - loss: 4.5825 - accuracy: 0.0147 - val_loss: 4.6193 - val_accuracy: 0.0186
# Epoch 14/20
# 41/41 [==============================] - 5s 126ms/step - loss: 4.5755 - accuracy: 0.0132 - val_loss: 4.6177 - val_accuracy: 0.0155
# Epoch 15/20
# 41/41 [==============================] - 5s 122ms/step - loss: 4.5713 - accuracy: 0.0178 - val_loss: 4.6458 - val_accuracy: 0.0186
# Epoch 16/20
# 41/41 [==============================] - 5s 123ms/step - loss: 4.5764 - accuracy: 0.0132 - val_loss: 4.6269 - val_accuracy: 0.0124
# Epoch 17/20
# 41/41 [==============================] - 5s 126ms/step - loss: 4.5702 - accuracy: 0.0178 - val_loss: 4.6449 - val_accuracy: 0.0155
# Epoch 18/20
# 41/41 [==============================] - 5s 132ms/step - loss: 4.5679 - accuracy: 0.0116 - val_loss: 4.6302 - val_accuracy: 0.0155
# Epoch 19/20
# 41/41 [==============================] - 5s 127ms/step - loss: 4.5684 - accuracy: 0.0178 - val_loss: 4.6148 - val_accuracy: 0.0093
# Epoch 20/20
# 41/41 [==============================] - 5s 126ms/step - loss: 4.5647 - accuracy: 0.0147 - val_loss: 4.6550 - val_accuracy: 0.0124
# 51/51 [==============================] - 17s 30ms/step
# Shape of features extracted from the last LSTM layer: (1612, 32)
# Sample features from the last LSTM layer (first 5 samples):
# [[ 0.01930729  0.0291542   0.0137334  -0.02171565  0.01611891  0.00888591
#   -0.01393662  0.01456445 -0.0118538   0.00406024 -0.00918148  0.00271932
#    0.0005478  -0.00059667 -0.02200161  0.01678105  0.01932048 -0.01086316
#   -0.00202907  0.00748366 -0.01520746 -0.00134151  0.01717079 -0.01379219
#   -0.00637239  0.01517458 -0.01017391  0.00585657 -0.00280699  0.01693841
#    0.00886745  0.03625365]
#  [ 0.0388945   0.05251325  0.04178075 -0.02186151  0.03692305  0.02424862
#   -0.03320083  0.03557481 -0.01410555  0.02518602 -0.02782163  0.01181674
#    0.01955817  0.01417843 -0.04768629  0.03122847  0.03700668 -0.03728982
#   -0.00841518  0.02253378 -0.01009836  0.00362999  0.04193449 -0.03325343
#   -0.02055456  0.03610137 -0.01826867  0.02431239  0.01662677  0.04034556
#    0.02893837  0.05575297]
#  [ 0.03956061  0.05328104  0.04285589 -0.02184418  0.03768722  0.02480369
#   -0.03382409  0.0363291  -0.01418606  0.02597508 -0.02855017  0.01211967
#    0.02021697  0.01474508 -0.04857374  0.03172648  0.03756178 -0.03827064
#   -0.00868892  0.02307973 -0.00990802  0.00382344  0.04273145 -0.03396231
#   -0.02104915  0.03687818 -0.01858896  0.02504274  0.01737175  0.04117233
#    0.02968917  0.05643228]
#  [ 0.03605267  0.04921867  0.03730218 -0.0219162   0.03371375  0.02190872
#   -0.03050962  0.03238705 -0.01376523  0.02188192 -0.02480337  0.01050375
#    0.01674712  0.01181975 -0.04391767  0.02911098  0.03459311 -0.0331702
#   -0.00730279  0.02023225 -0.01090243  0.002828    0.0384893  -0.0302722
#   -0.01844796  0.03284481 -0.0169435   0.02128637  0.01351569  0.03684366
#    0.02580144  0.05287683]
#  [ 0.01633929  0.02547829  0.00995207 -0.02160412  0.01318752  0.00668816
#   -0.01090715  0.01155322 -0.01152855  0.00114487 -0.00670239  0.00138111
#   -0.00223426 -0.0025908  -0.01813838  0.01460956  0.01647321 -0.00721756
#   -0.00125567  0.00535309 -0.01588815 -0.00201152  0.01326425 -0.01102159
#   -0.00430574  0.0122602  -0.00911794  0.00345683 -0.00540011  0.01351202
#    0.00606094  0.03331952]]

# %%
import numpy as np
from sklearn.cluster import KMeans

# Load data (assuming the data is saved in a numpy array .npy file)
# Replace the path with the actual location of your data file
F = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")  # Adjust this path if necessary

# Set parameters
N = 242
np.random.seed(2)  # Setting the random seed for reproducibility

# Perform k-means clustering
kmeans = KMeans(n_clusters=N, init='k-means++', random_state=2)
kmeans.fit(F)

# Get cluster assignments (C_IDX) and cluster centroids (CC)
C_IDX = kmeans.labels_
CC = kmeans.cluster_centers_

# Initialize list to store indices of data points in each cluster
C = {i: np.where(C_IDX == i)[0] for i in range(N)}

# C now contains the indices of data points in each cluster

# %%
# Print the actual data points in the first cluster (cluster 0)
cluster_0_data_points = F[C[0], :]
print(cluster_0_data_points)
# Out:
# [[-0.00668995 -0.00408879 -0.01650906 -0.02033358 -0.00820162 -0.00943597
#    0.01315715 -0.01052002 -0.00911464 -0.0195248   0.01054327 -0.00837081
#   -0.02294643 -0.0166805   0.01170465 -0.00219561 -0.00655553  0.01853047
#    0.00373919 -0.01010326 -0.0205492  -0.00680174 -0.01779956  0.00937571
#    0.01101836 -0.00870769 -0.00196969 -0.0127983  -0.02330829 -0.01230301
#   -0.01453612  0.01048456]
#  [-0.00614266 -0.00336565 -0.01593027 -0.02037216 -0.00771827 -0.00906826
#    0.01257483 -0.01001669 -0.00917065 -0.01906896  0.01016848 -0.00815097
#   -0.02247072 -0.01637126  0.01099794 -0.00179616 -0.00599222  0.01796398
#    0.00363667 -0.00975713 -0.02045027 -0.00669373 -0.01705028  0.00891095
#    0.01066706 -0.00823865 -0.00212219 -0.01245135 -0.02292061 -0.01170171
#   -0.01406563  0.01103146]
#  [-0.00602638 -0.00321266 -0.0158075  -0.02037974 -0.00761469 -0.00899068
#    0.01245167 -0.00991003 -0.00918218 -0.0189719   0.01008895 -0.00810487
#   -0.02236937 -0.01630463  0.01084823 -0.00171102 -0.00587268  0.0178434
#    0.0036144  -0.00968304 -0.02042859 -0.00667092 -0.01689095  0.00881201
#    0.01059226 -0.0081389  -0.00215453 -0.01237771 -0.02283858 -0.01157445
#   -0.01396513  0.01114664]
#  [-0.00652474 -0.00387231 -0.01633497 -0.02034331 -0.00805539 -0.00932693
#    0.01298222 -0.01037    -0.00913163 -0.01938794  0.01042974 -0.00830422
#   -0.02280236 -0.01658626  0.01149151 -0.00207504 -0.00638652  0.01835906
#    0.00370816 -0.00999874 -0.02051807 -0.00676936 -0.01757248  0.00923587
#    0.01091216 -0.00856634 -0.00201545 -0.01269397 -0.02319061 -0.01212282
#   -0.01439366  0.01064741]
#  [-0.00584422 -0.00297199 -0.01561378 -0.02039148 -0.00745301 -0.0088681
#    0.01225771 -0.00974245 -0.00920064 -0.01881976  0.00996266 -0.00803162
#   -0.02221042 -0.01620067  0.01061235 -0.00157781 -0.00568484  0.01765365
#    0.00357969 -0.00956659 -0.02039536 -0.00663502 -0.01664094  0.00865646
#    0.01047516 -0.00798199 -0.00220545 -0.0122615  -0.02270873 -0.01137421
#   -0.01380786  0.01132832]
#  [-0.00526501 -0.00221054 -0.01499763 -0.02042784 -0.00693835 -0.00848031
#    0.01164478 -0.0092128  -0.00925958 -0.01833511  0.00956219 -0.00779892
#   -0.02170598 -0.01586828  0.00986482 -0.00115671 -0.0050917   0.01705357
#    0.00347071 -0.00919781 -0.02028799 -0.00652097 -0.01584953  0.00816318
#    0.01010387 -0.00748368 -0.00236689 -0.01189335 -0.02229602 -0.01073884
#   -0.01330888  0.01190381]]

# %%
# Print all the indices and their corresponding cluster values
for cluster_idx in range(N):
    print(f"Cluster {cluster_idx}:")
    print("Indices of data points:", C[cluster_idx])
    print("Number of data points in this cluster:", len(C[cluster_idx]))
    print()
# Out:
# Cluster 0:
# Indices of data points: [ 186  702  933  995 1055 1436]
# Number of data points in this cluster: 6
#
# Cluster 1:
# Indices of data points: [  64  417  668 1061 1558]
# Number of data points in this cluster: 5
#
# Cluster 2:
# Indices of data points: [ 885 1112 1293 1331 1528]
# Number of data points in this cluster: 5
#
# Cluster 3:
# Indices of data points: [  89  215  372 1223 1572]
# Number of data points in this cluster: 5
#
# Cluster 4:
# Indices of data points: [ 151  407  570  878 1323]
# Number of data points in this cluster: 5
#
# Cluster 5:
# Indices of data points: [  14  799  831  836  840  860  865 1265 1267 1341 1354 1364 1368 1418
#  1426 1463 1471 1491 1498 1518]
# Number of data points in this cluster: 20
#
# Cluster 6:
# Indices of data points: [ 230  347  402  406  595 1062 1135 1160]
# Number of data points in this cluster: 8
#
# Cluster 7:
# Indices of data points: [ 130  191  227  357  948  990 1024 1083 1106 1164 1538]
# Number of data points in this cluster: 11
#
# Cluster 8:
# Indices of data points: [ 171  387  524  710 1141 1251]
# Number of data points in this cluster: 6
#
# Cluster 9:
# Indices of data points: [  30   51  786  876 1175 1330]
# Number of data points in this cluster: 6
#
# Cluster 10:
# Indices of data points: [ 120  739  797  824 1355 1369 1445]
# Number of data points in this cluster: 7
#
# Cluster 11:
# Indices of data points: [ 247  488  503  697  728  731  763 1108 1176 1222 1261]
# Number of data points in this cluster: 11
#
# Cluster 12:
# Indices of data points: [ 305  342  473  495  537  663  669  997 1127 1258 1356 1578]
# Number of data points in this cluster: 12
#
# Cluster 13:
# Indices of data points: [ 18 323 548]
# Number of data points in this cluster: 3
#
# Cluster 14:
# Indices of data points: [217 272 274 346 359]
# Number of data points in this cluster: 5
#
# Cluster 15:
# Indices of data points: [ 352 1016 1201]
# Number of data points in this cluster: 3
#
# Cluster 16:
# Indices of data points: [ 441  451  612  641 1130]
# Number of data points in this cluster: 5
#
# Cluster 17:
# Indices of data points: [ 262  289  439  648 1123]
# Number of data points in this cluster: 5
#
# Cluster 18:
# Indices of data points: [  65  234  430 1114]
# Number of data points in this cluster: 4
#
# Cluster 19:
# Indices of data points: [  80  448 1207 1211]
# Number of data points in this cluster: 4
#
# Cluster 20:
# Indices of data points: [ 144  735  746  869  981 1005 1300 1446]
# Number of data points in this cluster: 8
#
# Cluster 21:
# Indices of data points: [ 390  566  673 1131 1239]
# Number of data points in this cluster: 5
#
# Cluster 22:
# Indices of data points: [ 182  285  361  393 1575]
# Number of data points in this cluster: 5
#
# Cluster 23:
# Indices of data points: [ 108  498 1284 1302 1401]
# Number of data points in this cluster: 5
#
# Cluster 24:
# Indices of data points: [ 313  388  698  713  730  965  969 1486]
# Number of data points in this cluster: 8
#
# Cluster 25:
# Indices of data points: [  71  143  355  484  527 1006 1026]
# Number of data points in this cluster: 7
#
# Cluster 26:
# Indices of data points: [ 146  282  470  603  608  689  959  973 1182 1277 1516]
# Number of data points in this cluster: 11
#
# Cluster 27:
# Indices of data points: [1165 1327 1556 1603]
# Number of data points in this cluster: 4
#
# Cluster 28:
# Indices of data points: [ 866  886 1227 1259 1515]
# Number of data points in this cluster: 5
#
# Cluster 29:
# Indices of data points: [  32   97  129  803  819 1045 1058 1065 1084 1266 1268 1275 1312 1392
#  1479 1512 1564]
# Number of data points in this cluster: 17
#
# Cluster 30:
# Indices of data points: [  17   94  127  815  826  832  864  875 1031 1318 1373 1376 1378 1381
#  1382 1397 1403 1407 1413 1419 1423 1424 1427 1442 1449 1453 1460 1483
#  1495]
# Number of data points in this cluster: 29
#
# Cluster 31:
# Indices of data points: [ 189  370  426  480  625  810 1544]
# Number of data points in this cluster: 7
#
# Cluster 32:
# Indices of data points: [  60   67   90   93  209  362 1590]
# Number of data points in this cluster: 7
#
# Cluster 33:
# Indices of data points: [ 392  422  511  533  547  563  596  622  693  787  996 1221 1554 1561]
# Number of data points in this cluster: 14
#
# Cluster 34:
# Indices of data points: [  74  235  585  656 1315 1604]
# Number of data points in this cluster: 6
#
# Cluster 35:
# Indices of data points: [ 399  471  788  804  843  859 1192 1278 1367 1467 1472]
# Number of data points in this cluster: 11
#
# Cluster 36:
# Indices of data points: [ 162  474  938 1195 1286 1360]
# Number of data points in this cluster: 6
#
# Cluster 37:
# Indices of data points: [ 125  389 1297 1304 1347]
# Number of data points in this cluster: 5
#
# Cluster 38:
# Indices of data points: [  46   50  266  379  857  906  955 1003 1059 1257 1288 1334 1345]
# Number of data points in this cluster: 13
#
# Cluster 39:
# Indices of data points: [ 505  512  593  839  970  988 1169 1545 1587]
# Number of data points in this cluster: 9
#
# Cluster 40:
# Indices of data points: [ 154  542 1200 1329 1571 1594]
# Number of data points in this cluster: 6
#
# Cluster 41:
# [   4   11   21  432  599  686  887  930  936 1002 1236 1455 1567]
# Number of data points in this cluster: 13
#
# Cluster 42:
# Indices of data points: [ 418  564 1014 1126 1197]
# Number of data points in this cluster: 5
#
# Cluster 43:
# Indices of data points: [  23  260  706  769 1060 1246 1524]
# Number of data points in this cluster: 7
#
# Cluster 44:
# Indices of data points: [  16  111  493 1299 1519 1569]
# Number of data points in this cluster: 6
#
# Cluster 45:
# Indices of data points: [ 371  949 1172 1560]
# Number of data points in this cluster: 4
#
# Cluster 46:
# Indices of data points: [ 326  411  472  616  737  900 1389]
# Number of data points in this cluster: 7
#
# Cluster 47:
# Indices of data points: [223 337 340 853]
# Number of data points in this cluster: 4
#
# Cluster 48:
# Indices of data points: [ 37 181 281 301]
# Number of data points in this cluster: 4
#
# Cluster 49:
# Indices of data points: [ 187  192  291  297  348  452  662 1081 1082 1220 1326]
# Number of data points in this cluster: 11
#
# Cluster 50:
# Indices of data points: [ 463  760  989 1042]
# Number of data points in this cluster: 4
#
# Cluster 51:
# Indices of data points: [104 116 486 695 745 800 823 891]
# Number of data points in this cluster: 8
#
# Cluster 52:
# Indices of data points: [ 168  703  984 1281]
# Number of data points in this cluster: 4
#
# Cluster 53:
# Indices of data points: [ 206  882 1015]
# Number of data points in this cluster: 3
#
# Cluster 54:
# Indices of data points: [ 81 540 964]
# Number of data points in this cluster: 3
#
# Cluster 55:
# Indices of data points: [  19  167  221  530  753  845  889  890 1346]
# Number of data points in this cluster: 9
#
# Cluster 56:
# Indices of data points: [791 793 795]
# Number of data points in this cluster: 3
#
# Cluster 57:
# Indices of data points: [ 368  449  482 1191]
# Number of data points in this cluster: 4
#
# Cluster 58:
# Indices of data points: [  96  207  575  578  784 1072 1110 1514]
# Number of data points in this cluster: 8
#
# Cluster 59:
# Indices of data points: [  63  204  240  336  394  453 1107 1542]
# Number of data points in this cluster: 8
#
# Cluster 60:
# Indices of data points: [  12  683  827 1133 1282 1488]
# Number of data points in this cluster: 6
#
# Cluster 61:
# Indices of data points: [ 250  302  667 1098 1121 1134]
# Number of data points in this cluster: 6
#
# Cluster 62:
# Indices of data points: [ 708 1137]
# Number of data points in this cluster: 2
#
# Cluster 63:
# Indices of data points: [  41   45  101  103  114  847  868  905  982 1383 1386 1435 1448 1550
#  1606]
# Number of data points in this cluster: 15
#
# Cluster 64:
# Indices of data points: [   0   15  704  794  802  841  877  895  939 1235 1348 1398 1469 1602]
# Number of data points in this cluster: 14
#
# Cluster 65:
# Indices of data points: [  92  140  180  427  466  954  962 1147]
# Number of data points in this cluster: 8
#
# Cluster 66:
# Indices of data points: [ 214  259  619  644  661  971 1198 1205 1224]
# Number of data points in this cluster: 9
#
# Cluster 67:
# Indices of data points: [ 172  584  607 1036 1202 1237 1536]
# Number of data points in this cluster: 7
#
# Cluster 68:
# Indices of data points: [  61  467  605  705 1038 1228]
# Number of data points in this cluster: 6
#
# Cluster 69:
# Indices of data points: [  87  152  825  828  892  909  915  937  952 1305 1404 1429 1452 1521
#  1543]
# Number of data points in this cluster: 15
#
# Cluster 70:
# Indices of data points: [  13  175  729  838 1049 1328 1374 1466]
# Number of data points in this cluster: 8
#
# Cluster 71:
# Indices of data points: [ 79 265 280]
# Number of data points in this cluster: 3
#
# Cluster 72:
# Indices of data points: [ 163  303  322  635  680 1162 1216 1274]
# Number of data points in this cluster: 8
#
# Cluster 73:
# Indices of data points: [ 213  363  446  606  646 1109 1290]
# Number of data points in this cluster: 7
#
# Cluster 74:
# Indices of data points: [  44  110  220  429  444  477  515  538  610 1254 1287 1476]
# Number of data points in this cluster: 12
#
# Cluster 75:
# Indices of data points: [ 142  159  211  457  991 1064]
# Number of data points in this cluster: 6
#
# Cluster 76:
# Indices of data points: [  91  226  263  275  334 1159]
# Number of data points in this cluster: 6
#
# Cluster 77:
# Indices of data points: [ 276  456  476  980 1158 1371]
# Number of data points in this cluster: 6
#
# Cluster 78:
# Indices of data points: [   5   95  200  293  382  386  443  598 1294]
# Number of data points in this cluster: 9
#
# Cluster 79:
# Indices of data points: [ 184  205  295  550  627  636  966 1028 1088 1272 1591]
# Number of data points in this cluster: 11
#
# Cluster 80:
# Indices of data points: [ 677  776  822  920 1069 1194 1247 1529]
# Number of data points in this cluster: 8
#
# Cluster 81:
# Indices of data points: [  52   56  483  659  690  727  767  918 1001 1596]
# Number of data points in this cluster: 10
#
# Cluster 82:
# Indices of data points: [ 454  502 1047 1177 1180]
# Number of data points in this cluster: 5
#
# Cluster 83:
# Indices of data points: [ 231  634  687  752  993 1085 1145 1146]
# Number of data points in this cluster: 8
#
# Cluster 84:
# Indices of data points: [ 319 1052 1566]
# Number of data points in this cluster: 3
#
# Cluster 85:
# Indices of data points: [ 256  558  676  679 1148 1170]
# Number of data points in this cluster: 6
#
# Cluster 86:
# Indices of data points: [ 121  555 1048 1280 1292 1308 1477 1523]
# Number of data points in this cluster: 8
#
# Cluster 87:
# Indices of data points: [   2   20  796  809  851  898  950 1296 1416 1458 1485 1490 1493 1505
#  1601 1608]
# Number of data points in this cluster: 16
#
# Cluster 88:
# Indices of data points: [513 573 574 650 734]
# Number of data points in this cluster: 5
#
# Cluster 89:
# Indices of data points: [  22   77  100  105  681  901 1096 1256 1402 1484]
# Number of data points in this cluster: 10
#
# Cluster 90:
# Indices of data points: [   8 1189 1244 1549 1605]
# Number of data points in this cluster: 5
#
# Cluster 91:
# Indices of data points: [  42  497  718  757  947 1033]
# Number of data points in this cluster: 6
#
# Cluster 92:
# Indices of data points: [  24  126  201  396  740 1013 1311 1353]
# Number of data points in this cluster: 8
#
# Cluster 93:
# Indices of data points: [ 248  621  911  929  974 1215]
# Number of data points in this cluster: 6
#
# Cluster 94:
# Indices of data points: [ 421  534  601 1611]
# Number of data points in this cluster: 4
#
# Cluster 95:
# Indices of data points: [ 165  237  287  335 1593]
# Number of data points in this cluster: 5
#
# Cluster 96:
# Indices of data points: [ 339  459  500  623  633  678 1025 1342]
# Number of data points in this cluster: 8
#
# Cluster 97:
# Indices of data points: [ 532  553  554  643  682  881  940 1000 1027 1044 1241 1301 1303 1344]
# Number of data points in this cluster: 14
#
# Cluster 98:
# Indices of data points: [ 329 1183 1225 1532]
# Number of data points in this cluster: 4
#
# Cluster 99:
# Indices of data points: [255 377 779]
# Number of data points in this cluster: 3
#
# Cluster 100:
# Indices of data points: [  33  212  597 1017 1242 1409]
# Number of data points in this cluster: 6
#
# Cluster 101:
# Indices of data points: [158 160 672]
# Number of data points in this cluster: 3
#
# Cluster 102:
# Indices of data points: [131 133 145 316 994]
# Number of data points in this cluster: 5
#
# Cluster 103:
# Indices of data points: [ 307  535 1139 1548]
# Number of data points in this cluster: 4
#
# Cluster 104:
# Indices of data points: [ 203  501  519  583 1037 1074 1128 1144 1174]
# Number of data points in this cluster: 9
#
# Cluster 105:
# Indices of data points: [1553]
# Number of data points in this cluster: 1
#
# Cluster 106:
# Indices of data points: [ 222  296  543  572  979 1335 1443 1559]
# Number of data points in this cluster: 8
#
# Cluster 107:
# Indices of data points: [  83  343  345  440  557 1080 1285 1562 1592]
# Number of data points in this cluster: 9
#
# Cluster 108:
# Indices of data points: [ 107  124  324  700  749 1511 1565]
# Number of data points in this cluster: 7
#
# Cluster 109:
# Indices of data points: [  85  157  188  332  344 1043 1525]
# Number of data points in this cluster: 7
#
# Cluster 110:
# Indices of data points: [   9  135  252  288  516  561  725 1030 1322]
# Number of data points in this cluster: 9
#
# Cluster 111:
# Indices of data points: [ 741  744 1019 1022 1101 1167 1317 1530]
# Number of data points in this cluster: 8
#
# Cluster 112:
# Indices of data points: [ 400  408  560  773 1366]
# Number of data points in this cluster: 5
#
# Cluster 113:
# Indices of data points: [ 70 861 946]
# Number of data points in this cluster: 3
#
# Cluster 114:
# Indices of data points: [  66  155  225 1097 1113 1551]
# Number of data points in this cluster: 6
#
# Cluster 115:
# Indices of data points: [ 31 415 424 545 837]
# Number of data points in this cluster: 5
#
# Cluster 116:
# Indices of data points: [770 780 792]
# Number of data points in this cluster: 3
#
# Cluster 117:
# Indices of data points: [ 86 261 267 317 358]
# Number of data points in this cluster: 5
#
# Cluster 118:
# Indices of data points: [ 196  229  383  419  509  651 1004]
# Number of data points in this cluster: 7
#
# Cluster 119:
# Indices of data points: [ 311  367  413  600 1377]
# Number of data points in this cluster: 5
#
# Cluster 120:
# Indices of data points: [ 254  269  270  365 1598]
# Number of data points in this cluster: 5
#
# Cluster 121:
# Indices of data points: [  28  179  588  629  655 1156]
# Number of data points in this cluster: 6
#
# Cluster 122:
# Indices of data points: [  40  816  957 1234 1243 1351 1363 1394 1400 1440 1513 1531]
# Number of data points in this cluster: 12
#
# Cluster 123:
# Indices of data points: [ 170  183  268  279  290  738 1140]
# Number of data points in this cluster: 7
#
# Cluster 124:
# Indices of data points: [238]
# Number of data points in this cluster: 1
#
# Cluster 125:
# Indices of data points: [ 304  314  437 1138 1179 1231 1350]
# Number of data points in this cluster: 7
#
# Cluster 126:
# Indices of data points: [148 174 814]
# Number of data points in this cluster: 3
#
# Cluster 127:
# Indices of data points: [403 521 526 691]
# Number of data points in this cluster: 4
#
# Cluster 128:
# Indices of data points: [  27  198  374  397  433  435  782 1009 1115 1209 1574]
# Number of data points in this cluster: 11
#
# Cluster 129:
# Indices of data points: [173 692 721 777]
# Number of data points in this cluster: 4
#
# Cluster 130:
# Indices of data points: [  35   38  850  917  958 1070 1316 1406 1410 1420 1439 1450 1468 1473
#  1541]
# Number of data points in this cluster: 15
#
# Cluster 131:
# [ 153  218  508  617  624 1041 1153 1204 1557 1580]
# Number of data points in this cluster: 10
#
# Cluster 132:
# Indices of data points: [ 277  910  919  976 1067 1444 1582 1588]
# Number of data points in this cluster: 8
#
# Cluster 133:
# Indices of data points: [ 327  478  654  742  747  801 1021 1120 1496]
# Number of data points in this cluster: 9
#
# Cluster 134:
# Indices of data points: [ 251  284  434  442 1093 1095 1273 1581]
# Number of data points in this cluster: 8
#
# Cluster 135:
# Indices of data points: [ 113  122  258  736  772 1255 1306 1361 1430 1465]
# Number of data points in this cluster: 10
#
# Cluster 136:
# Indices of data points: [  43  147  161  450  587  631  732 1125 1502]
# Number of data points in this cluster: 9
#
# Cluster 137:
# Indices of data points: [ 378  455  768  778  975 1279 1589]
# Number of data points in this cluster: 7
#
# Cluster 138:
# Indices of data points: [ 808  912  931 1063 1352 1362 1384 1415 1441 1481 1547 1600]
# Number of data points in this cluster: 12
#
# Cluster 139:
# Indices of data points: [  58   62  292  351  431  649 1008 1118 1157]
# Number of data points in this cluster: 9
#
# Cluster 140:
# Indices of data points: [210 609 701 751 762 977]
# Number of data points in this cluster: 6
#
# Cluster 141:
# Indices of data points: [ 249  592  756  789  985 1035 1178]
# Number of data points in this cluster: 7
#
# Cluster 142:
# Indices of data points: [  75  177  632  723 1068 1269 1508]
# Number of data points in this cluster: 7
#
# Cluster 143:
# Indices of data points: [ 333  914  941  998 1573]
# Number of data points in this cluster: 5
#
# Cluster 144:
# Indices of data points: [  68  178  414  576  999 1232]
# Number of data points in this cluster: 6
#
# Cluster 145:
# Indices of data points: [ 611  640 1474 1597]
# Number of data points in this cluster: 4
#
# Cluster 146:
# Indices of data points: [  29  299  499  765  812  888 1166 1510 1555]
# Number of data points in this cluster: 9
#
# Cluster 147:
# Indices of data points: [  69  460  630  660  983 1238]
# Number of data points in this cluster: 6
#
# Cluster 148:
# Indices of data points: [ 136  835  926 1078 1230 1233 1310 1372 1501]
# Number of data points in this cluster: 9
#
# Cluster 149:
# Indices of data points: [ 169  666 1075 1150 1313]
# Number of data points in this cluster: 5
#
# Cluster 150:
# Indices of data points: [   6  375  645 1023 1053 1124]
# Number of data points in this cluster: 6
#
# Cluster 151:
# Indices of data points: [ 464  562  568  571  774  863 1391]
# Number of data points in this cluster: 7
#
# Cluster 152:
# Indices of data points: [ 199  310  510 1210 1213 1307 1500 1570]
# Number of data points in this cluster: 8
#
# Cluster 153:
# Indices of data points: [416 487 522 719 842 874 978]
# Number of data points in this cluster: 7
#
# Cluster 154:
# Indices of data points: [ 112  294  489  549  944 1132 1186 1607]
# Number of data points in this cluster: 8
#
# Cluster 155:
# Indices of data points: [ 465 1240 1262]
# Number of data points in this cluster: 3
#
# Cluster 156:
# Indices of data points: [ 236  468  469  479  614 1168 1337]
# Number of data points in this cluster: 7
#
# Cluster 157:
# Indices of data points: [  98  507 1007 1181 1250 1388 1539]
# Number of data points in this cluster: 7
#
# Cluster 158:
# Indices of data points: [ 604  758  951 1499]
# Number of data points in this cluster: 4
#
# Cluster 159:
# Indices of data points: [   7   25  134  582  894 1142 1412]
# Number of data points in this cluster: 7
#
# Cluster 160:
# Indices of data points: [ 115  119  244  318  338  813  870  897 1012 1517 1609]
# Number of data points in this cluster: 11
#
# Cluster 161:
# Indices of data points: [380 391 544 830]
# Number of data points in this cluster: 4
#
# Cluster 162:
# Indices of data points: [ 190  420  602  674 1196 1264 1537]
# Number of data points in this cluster: 7
#
# Cluster 163:
# Indices of data points: [  34  321  665  716  871  928  960 1100 1212 1399 1461 1527 1546 1579]
# Number of data points in this cluster: 14
#
# Cluster 164:
# Indices of data points: [1092 1171 1583]
# Number of data points in this cluster: 3
#
# Cluster 165:
# Indices of data points: [ 150  219  423  425  783 1149 1568]
# Number of data points in this cluster: 7
#
# Cluster 166:
# Indices of data points: [ 149  481  520  771  781 1117]
# Number of data points in this cluster: 6
#
# Cluster 167:
# Indices of data points: [  82  264 1585]
# Number of data points in this cluster: 3
#
# Cluster 168:
# Indices of data points: [  55  118  300  805  807  902 1073 1520]
# Number of data points in this cluster: 8
#
# Cluster 169:
# Indices of data points: [194 401 496 821]
# Number of data points in this cluster: 4
#
# Cluster 170:
# Indices of data points: [ 811 1203]
# Number of data points in this cluster: 2
#
# Cluster 171:
# Indices of data points: [ 176  356  369  647  653  664 1214 1226]
# Number of data points in this cluster: 8
#
# Cluster 172:
# Indices of data points: [241 257 271 330]
# Number of data points in this cluster: 4
#
# Cluster 173:
# Indices of data points: [  76  353  956  972 1190]
# Number of data points in this cluster: 5
#
# Cluster 174:
# Indices of data points: [ 117  577  726 1173]
# Number of data points in this cluster: 4
#
# Cluster 175:
# Indices of data points: [  72  197  856 1252 1309 1336 1599]
# Number of data points in this cluster: 7
#
# Cluster 176:
# Indices of data points: [  54  506 1076]
# Number of data points in this cluster: 3
#
# Cluster 177:
# Indices of data points: [ 59  99 546 639 699]
# Number of data points in this cluster: 5
#
# Cluster 178:
# Indices of data points: [ 754  896  932 1208 1325 1422 1475 1482 1506]
# Number of data points in this cluster: 9
#
# Cluster 179:
# Indices of data points: [ 541  759 1018 1099 1119 1154 1217]
# Number of data points in this cluster: 7
#
# Cluster 180:
# Indices of data points: [ 312  445 1526]
# Number of data points in this cluster: 3
#
# Cluster 181:
# Indices of data points: [ 987 1143 1151 1206 1586]
# Number of data points in this cluster: 5
#
# Cluster 182:
# Indices of data points: [ 766  798  806  817  820  855  858  923 1032]
# Number of data points in this cluster: 9
#
# Cluster 183:
# Indices of data points: [ 899  961  967 1040 1122 1187]
# Number of data points in this cluster: 6
#
# Cluster 184:
# Indices of data points: [ 492  525  589  764  921  934 1056 1577]
# Number of data points in this cluster: 8
#
# Cluster 185:
# Indices of data points: [ 712  717 1094 1509]
# Number of data points in this cluster: 4
#
# Cluster 186:
# Indices of data points: [   3   47  775  790  862  893  907  925 1029 1071 1086 1276 1298 1387
#  1390 1434 1456 1478]
# Number of data points in this cluster: 18
#
# Cluster 187:
# Indices of data points: [ 137  315  428  552 1193 1199]
# Number of data points in this cluster: 6
#
# Cluster 188:
# Indices of data points: [ 208  232  320  652  670 1079 1289 1319]
# Number of data points in this cluster: 8
#
# Cluster 189:
# Indices of data points: [ 404  514  517 1185 1533]
# Number of data points in this cluster: 5
#
# Cluster 190:
# Indices of data points: [ 366  879  968 1357]
# Number of data points in this cluster: 4
#
# Cluster 191:
# Indices of data points: [ 618  696 1324 1610]
# Number of data points in this cluster: 4
#
# Cluster 192:
# Indices of data points: [1102 1249 1503]
# Number of data points in this cluster: 3
#
# Cluster 193:
# Indices of data points: [ 384  485  528  580  586 1263]
# Number of data points in this cluster: 6
#
# Cluster 194:
# Indices of data points: [ 106  761  986 1253]
# Number of data points in this cluster: 4
#
# Cluster 195:
# Indices of data points: [  84  559  671  849 1161 1260]
# Number of data points in this cluster: 6
#
# Cluster 196:
# Indices of data points: [  57  688  720 1136 1338]
# Number of data points in this cluster: 5
#
# Cluster 197:
# Indices of data points: [164 325 354]
# Number of data points in this cluster: 3
#
# Cluster 198:
# Indices of data points: [ 490  523  834 1010 1395]
# Number of data points in this cluster: 5
#
# Cluster 199:
# Indices of data points: [195 242 245 278 349 373 376]
# Number of data points in this cluster: 7
#
# Cluster 200:
# Indices of data points: [ 239  594 1576]
# Number of data points in this cluster: 3
#
# Cluster 201:
# Indices of data points: [ 590  963 1219]
# Number of data points in this cluster: 3
#
# Cluster 202:
# Indices of data points: [243 328 398]
# Number of data points in this cluster: 3
#
# Cluster 203:
# Indices of data points: [ 405  591  638  715 1090 1188]
# Number of data points in this cluster: 6
#
# Cluster 204:
# Indices of data points: [286 381 556 626]
# Number of data points in this cluster: 4
#
# Cluster 205:
# Indices of data points: [ 409  884  924 1270 1522]
# Number of data points in this cluster: 5
#
# Cluster 206:
# Indices of data points: [216 253 298 360]
# Number of data points in this cluster: 4
#
# Cluster 207:
# Indices of data points: [  26  395  880  953 1020 1271]
# Number of data points in this cluster: 6
#
# Cluster 208:
# Indices of data points: [  53  867  922 1340]
# Number of data points in this cluster: 4
#
# Cluster 209:
# Indices of data points: [ 846  848  904 1039 1046 1057 1111 1375 1504]
# Number of data points in this cluster: 9
#
# Cluster 210:
# Indices of data points: [ 306  927  945 1050 1155 1470]
# Number of data points in this cluster: 6
#
# Cluster 211:
# Indices of data points: [246 283 364]
# Number of data points in this cluster: 3
#
# Cluster 212:
# Indices of data points: [ 412  628  714 1332]
# Number of data points in this cluster: 4
#
# Cluster 213:
# Indices of data points: [ 709  942 1087 1358 1540]
# Number of data points in this cluster: 5
#
# Cluster 214:
# Indices of data points: [1034 1103 1245 1507]
# Number of data points in this cluster: 4
#
# Cluster 215:
# Indices of data points: [193 385 436 637]
# Number of data points in this cluster: 4
#
# Cluster 216:
# Indices of data points: [   1   36   49  132  818  829  852  908 1349 1385 1393 1396 1405 1425
#  1464 1489 1534]
# Number of data points in this cluster: 17
#
# Cluster 217:
# Indices of data points: [567 658 833]
# Number of data points in this cluster: 3
#
# Cluster 218:
# Indices of data points: [ 458  531  539  657  748 1105]
# Number of data points in this cluster: 6
#
# Cluster 219:
# Indices of data points: [ 684 1414 1462]
# Number of data points in this cluster: 3
#
# Cluster 220:
# Indices of data points: [  39  102  138  724  785  854  873 1321 1370]
# Number of data points in this cluster: 9
#
# Cluster 221:
# Indices of data points: [  78  331  475  551  675  733 1104]
# Number of data points in this cluster: 7
#
# Cluster 222:
# Indices of data points: [  73  139  166  711  935 1291 1487]
# Number of data points in this cluster: 7
#
# Cluster 223:
# Indices of data points: [ 128  943 1320 1411 1437]
# Number of data points in this cluster: 5
#
# Cluster 224:
# Indices of data points: [ 228 1584]
# Number of data points in this cluster: 2
#
# Cluster 225:
# Indices of data points: [  88  447  620 1077 1184]
# Number of data points in this cluster: 5
#
# Cluster 226:
# Indices of data points: [  48  185 1408 1535 1595]
# Number of data points in this cluster: 5
#
# Cluster 227:
# Indices of data points: [309 518 685 883]
# Number of data points in this cluster: 4
#
# Cluster 228:
# Indices of data points: [141 461]
# Number of data points in this cluster: 2
#
# Cluster 229:
# Indices of data points: [ 462  491  494  569 1152 1218 1283]
# Number of data points in this cluster: 7
#
# Cluster 230:
# Indices of data points: [224 308 350 438 581 613]
# Number of data points in this cluster: 6
#
# Cluster 231:
# Indices of data points: [903]
# Number of data points in this cluster: 1
#
# Cluster 232:
# Indices of data points: [ 410  743 1091 1333]
# Number of data points in this cluster: 4
#
# Cluster 233:
# Indices of data points: [ 123  722  916 1089 1295 1314 1380 1497]
# Number of data points in this cluster: 8
#
# Cluster 234:
# Indices of data points: [ 233  844  992 1011 1433 1480]
# Number of data points in this cluster: 6
#
# Cluster 235:
# Indices of data points: [694 755 872]
# Number of data points in this cluster: 3
#
# Cluster 236:
# [ 156  273  529  565  615 1248]
# Number of data points in this cluster: 6
#
# Cluster 237:
# Indices of data points: [ 504  579 1552]
# Number of data points in this cluster: 3
#
# Cluster 238:
# Indices of data points: [ 341  536  642 1116 1129 1163]
# Number of data points in this cluster: 6
#
# Cluster 239:
# Indices of data points: [ 202 1229 1563]
# Number of data points in this cluster: 3
#
# Cluster 240:
# Indices of data points: [  10  109  913 1051 1066 1339 1343 1359 1365 1379 1417 1421 1428 1431
#  1432 1438 1447 1451 1454 1457 1459 1492 1494]
# Number of data points in this cluster: 23
#
# Cluster 241:
# Indices of data points: [ 707  750 1054]
# Number of data points in this cluster: 3

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# Load data (assuming the data is saved in a numpy array .npy file)
try:
    F = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")  # Adjust this path if necessary
except FileNotFoundError:
    print("Error: The specified file was not found.")
    exit(1)

# Set parameters
N = 242  # Number of clusters
num_samples = F.shape[0]  # Number of data points (950)
np.random.seed(2)  # Setting the random seed for reproducibility

# Perform k-means clustering
kmeans = KMeans(n_clusters=N, init='k-means++', random_state=2)
kmeans.fit(F)

# Get cluster assignments (C_IDX) and cluster centroids (CC)
C_IDX = kmeans.labels_
CC = kmeans.cluster_centers_

# Initialize binary matrix (950 x 143) with zeros
keyframe_matrix = np.zeros((num_samples, N), dtype=int)

# Loop through each cluster and find the closest data point to the centroid
for cluster_idx in range(N):
    # Get the indices of the data points in the current cluster
    cluster_indices = np.where(C_IDX == cluster_idx)[0]
    
    # Skip empty clusters (if any)
    if len(cluster_indices) == 0:
        print(f"Cluster {cluster_idx} is empty, skipping.")
        continue
    
    # Get the feature vectors for the data points in this cluster
    cluster_features = F[cluster_indices, :]
    
    # Get the centroid of this cluster
    centroid = CC[cluster_idx]
    
    # Compute the Euclidean distance between each point in the cluster and the centroid
    distances = cdist(cluster_features, centroid.reshape(1, -1), metric='euclidean')
    
    # Get the index of the closest data point to the centroid
    closest_point_idx = cluster_indices[np.argmin(distances)]
    
    # Set the corresponding entry in the binary matrix to 1 (keyframe)
    keyframe_matrix[closest_point_idx, cluster_idx] = 1

    # Optionally, print the keyframe index for each cluster
    print(f"Cluster {cluster_idx}: Keyframe index: {closest_point_idx}")
# keyframe_matrix is now a 950 x 143 binary matrix
# You can use it for further analysis or saving to a file
# Out:
# Cluster 0: Keyframe index: 933
# Cluster 1: Keyframe index: 417
# Cluster 2: Keyframe index: 885
# Cluster 3: Keyframe index: 1572
# Cluster 4: Keyframe index: 151
# Cluster 5: Keyframe index: 831
# Cluster 6: Keyframe index: 230
# Cluster 7: Keyframe index: 1083
# Cluster 8: Keyframe index: 387
# Cluster 9: Keyframe index: 1175
# Cluster 10: Keyframe index: 1445
# Cluster 11: Keyframe index: 1176
# Cluster 12: Keyframe index: 663
# Cluster 13: Keyframe index: 548
# Cluster 14: Keyframe index: 272
# Cluster 15: Keyframe index: 1016
# Cluster 16: Keyframe index: 441
# Cluster 17: Keyframe index: 439
# Cluster 18: Keyframe index: 430
# Cluster 19: Keyframe index: 1207
# Cluster 20: Keyframe index: 746
# Cluster 21: Keyframe index: 1131
# Cluster 22: Keyframe index: 182
# Cluster 23: Keyframe index: 1302
# Cluster 24: Keyframe index: 969
# Cluster 25: Keyframe index: 1026
# Cluster 26: Keyframe index: 689
# Cluster 27: Keyframe index: 1327
# Cluster 28: Keyframe index: 886
# Cluster 29: Keyframe index: 803
# Cluster 30: Keyframe index: 17
# Cluster 31: Keyframe index: 189
# Cluster 32: Keyframe index: 209
# Cluster 33: Keyframe index: 392
# Cluster 34: Keyframe index: 585
# Cluster 35: Keyframe index: 1192
# Cluster 36: Keyframe index: 1286
# Cluster 37: Keyframe index: 1347
# Cluster 38: Keyframe index: 906
# Cluster 39: Keyframe index: 839
# Cluster 40: Keyframe index: 1200
# Cluster 41: Keyframe index: 887
# Cluster 42: Keyframe index: 564
# Cluster 43: Keyframe index: 769
# Cluster 44: Keyframe index: 493
# Cluster 45: Keyframe index: 371
# Cluster 46: Keyframe index: 737
# Cluster 47: Keyframe index: 337
# Cluster 48: Keyframe index: 301
# Cluster 49: Keyframe index: 662
# Cluster 50: Keyframe index: 463
# Cluster 51: Keyframe index: 695
# Cluster 52: Keyframe index: 984
# Cluster 53: Keyframe index: 206
# Cluster 54: Keyframe index: 81
# Cluster 55: Keyframe index: 753
# Cluster 56: Keyframe index: 795
# Cluster 57: Keyframe index: 1191
# Cluster 58: Keyframe index: 1110
# Cluster 59: Keyframe index: 204
# Cluster 60: Keyframe index: 683
# Cluster 61: Keyframe index: 1134
# Cluster 62: Keyframe index: 708
# Cluster 63: Keyframe index: 103
# Cluster 64: Keyframe index: 1235
# Cluster 65: Keyframe index: 92
# Cluster 66: Keyframe index: 971
# Cluster 67: Keyframe index: 1202
# Cluster 68: Keyframe index: 605
# Cluster 69: Keyframe index: 1452
# Cluster 70: Keyframe index: 838
# Cluster 71: Keyframe index: 280
# Cluster 72: Keyframe index: 322
# Cluster 73: Keyframe index: 606
# Cluster 74: Keyframe index: 429
# Cluster 75: Keyframe index: 142
# Cluster 76: Keyframe index: 226
# Cluster 77: Keyframe index: 276
# Cluster 78: Keyframe index: 5
# Cluster 79: Keyframe index: 1272
# Cluster 80: Keyframe index: 1529
# Cluster 81: Keyframe index: 659
# Cluster 82: Keyframe index: 454
# Cluster 83: Keyframe index: 1085
# Cluster 84: Keyframe index: 1566
# Cluster 85: Keyframe index: 676
# Cluster 86: Keyframe index: 1280
# Cluster 87: Keyframe index: 1416
# Cluster 88: Keyframe index: 574
# Cluster 89: Keyframe index: 100
# Cluster 90: Keyframe index: 8
# Cluster 91: Keyframe index: 1033
# Cluster 92: Keyframe index: 1013
# Cluster 93: Keyframe index: 248
# Cluster 94: Keyframe index: 534
# Cluster 95: Keyframe index: 1593
# Cluster 96: Keyframe index: 339
# Cluster 97: Keyframe index: 643
# Cluster 98: Keyframe index: 329
# Cluster 99: Keyframe index: 377
# Cluster 100: Keyframe index: 33
# Cluster 101: Keyframe index: 158
# Cluster 102: Keyframe index: 316
# Cluster 103: Keyframe index: 535
# Cluster 104: Keyframe index: 519
# Cluster 105: Keyframe index: 1553
# Cluster 106: Keyframe index: 1335
# Cluster 107: Keyframe index: 440
# Cluster 108: Keyframe index: 700
# Cluster 109: Keyframe index: 157
# Cluster 110: Keyframe index: 1030
# Cluster 111: Keyframe index: 1101
# Cluster 112: Keyframe index: 400
# Cluster 113: Keyframe index: 861
# Cluster 114: Keyframe index: 66
# Cluster 115: Keyframe index: 837
# Cluster 116: Keyframe index: 780
# Cluster 117: Keyframe index: 358
# Cluster 118: Keyframe index: 651
# Cluster 119: Keyframe index: 1377
# Cluster 120: Keyframe index: 1598
# Cluster 121: Keyframe index: 655
# Cluster 122: Keyframe index: 1351
# Cluster 123: Keyframe index: 170
# Cluster 124: Keyframe index: 238
# Cluster 125: Keyframe index: 1350
# Cluster 126: Keyframe index: 814
# Cluster 127: Keyframe index: 403
# Cluster 128: Keyframe index: 1009
# Cluster 129: Keyframe index: 692
# Cluster 130: Keyframe index: 1410
# Cluster 131: Keyframe index: 1580
# Cluster 132: Keyframe index: 919
# Cluster 133: Keyframe index: 1120
# Cluster 134: Keyframe index: 251
# Cluster 135: Keyframe index: 772
# Cluster 136: Keyframe index: 147
# Cluster 137: Keyframe index: 778
# Cluster 138: Keyframe index: 1362
# Cluster 139: Keyframe index: 351
# Cluster 140: Keyframe index: 210
# Cluster 141: Keyframe index: 249
# Cluster 142: Keyframe index: 1068
# Cluster 143: Keyframe index: 941
# Cluster 144: Keyframe index: 178
# Cluster 145: Keyframe index: 640
# Cluster 146: Keyframe index: 29
# Cluster 147: Keyframe index: 630
# Cluster 148: Keyframe index: 926
# Cluster 149: Keyframe index: 169
# Cluster 150: Keyframe index: 375
# Cluster 151: Keyframe index: 863
# Cluster 152: Keyframe index: 1307
# Cluster 153: Keyframe index: 416
# Cluster 154: Keyframe index: 489
# Cluster 155: Keyframe index: 1240
# Cluster 156: Keyframe index: 614
# Cluster 157: Keyframe index: 1181
# Cluster 158: Keyframe index: 951
# Cluster 159: Keyframe index: 7
# Cluster 160: Keyframe index: 115
# Cluster 161: Keyframe index: 830
# Cluster 162: Keyframe index: 190
# Cluster 163: Keyframe index: 960
# Cluster 164: Keyframe index: 1583
# Cluster 165: Keyframe index: 1149
# Cluster 166: Keyframe index: 149
# Cluster 167: Keyframe index: 1585
# Cluster 168: Keyframe index: 1520
# Cluster 169: Keyframe index: 401
# Cluster 170: Keyframe index: 811
# Cluster 171: Keyframe index: 356
# Cluster 172: Keyframe index: 330
# Cluster 173: Keyframe index: 956
# Cluster 174: Keyframe index: 1173
# Cluster 175: Keyframe index: 1252
# Cluster 176: Keyframe index: 54
# Cluster 177: Keyframe index: 59
# Cluster 178: Keyframe index: 1325
# Cluster 179: Keyframe index: 1154
# Cluster 180: Keyframe index: 312
# Cluster 181: Keyframe index: 1586
# Cluster 182: Keyframe index: 855
# Cluster 183: Keyframe index: 1040
# Cluster 184: Keyframe index: 492
# Cluster 185: Keyframe index: 1509
# Cluster 186: Keyframe index: 893
# Cluster 187: Keyframe index: 1199
# Cluster 188: Keyframe index: 652
# Cluster 189: Keyframe index: 517
# Cluster 190: Keyframe index: 879
# Cluster 191: Keyframe index: 1610
# Cluster 192: Keyframe index: 1249
# Cluster 193: Keyframe index: 384
# Cluster 194: Keyframe index: 106
# Cluster 195: Keyframe index: 1161
# Cluster 196: Keyframe index: 688
# Cluster 197: Keyframe index: 164
# Cluster 198: Keyframe index: 490
# Cluster 199: Keyframe index: 278
# Cluster 200: Keyframe index: 239
# Cluster 201: Keyframe index: 1219
# Cluster 202: Keyframe index: 328
# Cluster 203: Keyframe index: 1090
# Cluster 204: Keyframe index: 556
# Cluster 205: Keyframe index: 1270
# Cluster 206: Keyframe index: 298
# Cluster 207: Keyframe index: 395
# Cluster 208: Keyframe index: 867
# Cluster 209: Keyframe index: 846
# Cluster 210: Keyframe index: 945
# Cluster 211: Keyframe index: 283
# Cluster 212: Keyframe index: 714
# Cluster 213: Keyframe index: 1358
# Cluster 214: Keyframe index: 1245
# Cluster 215: Keyframe index: 385
# Cluster 216: Keyframe index: 1405
# Cluster 217: Keyframe index: 833
# Cluster 218: Keyframe index: 458
# Cluster 219: Keyframe index: 1462
# Cluster 220: Keyframe index: 785
# Cluster 221: Keyframe index: 331
# Cluster 222: Keyframe index: 711
# Cluster 223: Keyframe index: 1411
# Cluster 224: Keyframe index: 1584
# Cluster 225: Keyframe index: 620
# Cluster 226: Keyframe index: 1408
# Cluster 227: Keyframe index: 309
# Cluster 228: Keyframe index: 141
# Cluster 229: Keyframe index: 494
# Cluster 230: Keyframe index: 581
# Cluster 231: Keyframe index: 903
# Cluster 232: Keyframe index: 1091
# Cluster 233: Keyframe index: 1380
# Cluster 234: Keyframe index: 844
# Cluster 235: Keyframe index: 694
# Cluster 236: Keyframe index: 615
# Cluster 237: Keyframe index: 1552
# Cluster 238: Keyframe index: 536
# Cluster 239: Keyframe index: 1229
# Cluster 240: Keyframe index: 1447
# Cluster 241: Keyframe index: 750

# %%
# Save the keyframe binary matrix
np.save(r'C:\SumMe\Augmentation\Augf\keyframe', keyframe_matrix)

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from scipy.io import savemat

# Load data (assuming the data is saved in a numpy array .npy file)
try:
    F = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")  # Adjust this path if necessary
except FileNotFoundError:
    print("Error: The specified file was not found.")
    exit(1)

# Check shape of input data
print("Shape of input data F:", F.shape)

# Set parameters
N = 242  # Number of clusters
num_samples = F.shape[0]  # Number of data points (should be 950)
np.random.seed(2)  # Setting the random seed for reproducibility

# Perform k-means clustering
kmeans = KMeans(n_clusters=N, init='k-means++', n_init=50, random_state=2)
kmeans.fit(F)

# Get cluster assignments (C_IDX) and cluster centroids (CC)
C_IDX = kmeans.labels_
CC = kmeans.cluster_centers_

# Check cluster assignments
unique, counts = np.unique(C_IDX, return_counts=True)
cluster_sizes = dict(zip(unique, counts))
print("Cluster sizes:", cluster_sizes)

# Initialize binary matrix (950 x 143) with zeros
keyframe_matrix = np.zeros((num_samples, N), dtype=int)

# Loop through each cluster and find the closest data point to the centroid
for cluster_idx in range(N):
    # Get the indices of the data points in the current cluster
    cluster_indices = np.where(C_IDX == cluster_idx)[0]
    
    # Skip empty clusters (if any)
    if len(cluster_indices) == 0:
        print(f"Warning: Cluster {cluster_idx} is empty, skipping.")
        continue
    
    # Get the feature vectors for the data points in this cluster
    cluster_features = F[cluster_indices, :]
    
    # Get the centroid of this cluster
    centroid = CC[cluster_idx]
    
    # Compute the Euclidean distance between each point in the cluster and the centroid
    distances = cdist(cluster_features, centroid.reshape(1, -1), metric='euclidean')
    
    # Get the index of the closest data point to the centroid
    closest_point_idx = cluster_indices[np.argmin(distances)]
    
    # Set the corresponding entry in the binary matrix to 1 (keyframe)
    keyframe_matrix[closest_point_idx, cluster_idx] = 1

# Check the shape of the keyframe matrix
print("Shape of keyframe matrix:", keyframe_matrix.shape)

# Save the matrix as a .mat file
savemat(r'C:\SumMe\Augmentation\Augf', {'keyframe_matrix': keyframe_matrix})

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Step 1: Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")

# Step 2: (Optional) Preprocess the data if needed
# For example, you might want to scale the features to ensure the clustering works well
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 3: Perform Agglomerative Clustering
# You can specify the number of clusters or other hyperparameters here
n_clusters = 242  # Example, set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model to the feature matrix
clustering_labels = clustering.fit_predict(features_scaled)

# Step 4: (Optional) Visualize the results if the features are 2D (or use dimensionality reduction)
if features_scaled.shape[1] == 2:  # If your features are 2D, you can visualize them
    plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=clustering_labels, cmap='viridis')
    plt.title("Agglomerative Clustering Results")
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# If you have higher-dimensional features, consider using PCA to reduce to 2D for visualization
# For example:
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# features_2d = pca.fit_transform(features_scaled)
# plt.scatter(features_2d[:, 0], features_2d[:, 1], c=clustering_labels, cmap='viridis')
# plt.show()

# Step 5: View the labels assigned to each data point
print("Cluster Labels:", clustering_labels)
# Out:
# Cluster Labels: [ 64  15 204 ...  94 126 100]

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters =242  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Display the clusters in the desired format
for cluster_label, indices in cluster_dict.items():
    print(f"Cluster {cluster_label}:")
    print(f"Indices of data points: {indices}")
    print(f"Number of data points in this cluster: {len(indices)}\n")
# Out:
# Cluster 64:
# Indices of data points: [0, 15, 704, 794, 802, 841, 895, 939, 1073, 1235, 1348, 1398, 1602]
# Number of data points in this cluster: 13
#
# Cluster 15:
# Indices of data points: [1, 36, 49, 132, 818, 829, 852, 908, 950, 1296, 1349, 1385, 1393, 1396, 1405, 1425, 1464, 1489, 1534, 1601]
# Number of data points in this cluster: 20
#
# Cluster 204:
# Indices of data points: [2, 20, 796, 809, 851, 898, 1416, 1431, 1458, 1485, 1490, 1493, 1505, 1608]
# Number of data points in this cluster: 14
#
# Cluster 127:
# Indices of data points: [3, 47, 775, 790, 862, 893, 925, 1029, 1071, 1086, 1298, 1390, 1434, 1456, 1478]
# Number of data points in this cluster: 15
#
# Cluster 25:
# Indices of data points: [4, 11, 21, 599, 686, 887, 936, 1002, 1236, 1455, 1567]
# Number of data points in this cluster: 11
#
# Cluster 8:
# Indices of data points: [5, 95, 200, 293, 382, 386, 443, 598, 1294]
# Number of data points in this cluster: 9
#
# Cluster 9:
# Indices of data points: [6, 205, 375, 645, 1023, 1053, 1124]
# Number of data points in this cluster: 7
#
# Cluster 34:
# Indices of data points: [7, 25, 134, 582, 894, 1142, 1412]
# Number of data points in this cluster: 7
#
# Cluster 46:
# Indices of data points: [8, 48, 185, 1189, 1244, 1408, 1535, 1549, 1595, 1605]
# Number of data points in this cluster: 10
#
# Cluster 130:
# Indices of data points: [9, 135, 252, 288, 516, 561, 725, 1030, 1322]
# Number of data points in this cluster: 9
#
# Cluster 54:
# Indices of data points: [10, 109, 913, 1051, 1066, 1339, 1343, 1359, 1365, 1379, 1417, 1421, 1428, 1432, 1438, 1447, 1451, 1454, 1457, 1459, 1492, 1494]
# Number of data points in this cluster: 22
#
# Cluster 191:
# Indices of data points: [12, 683, 827, 1133, 1282, 1488]
# Number of data points in this cluster: 6
#
# Cluster 45:
# Indices of data points: [13, 175, 694, 729, 838, 872, 1328, 1466]
# Number of data points in this cluster: 8
#
# Cluster 104:
# Indices of data points: [14, 831, 840, 865, 1265, 1267, 1341, 1354, 1364, 1368, 1463, 1471, 1498, 1518]
# Number of data points in this cluster: 14
#
# Cluster 145:
# Indices of data points: [16, 493, 1299, 1519, 1569]
# Number of data points in this cluster: 5
#
# Cluster 6:
# Indices of data points: [17, 94, 127, 815, 826, 832, 864, 875, 1031, 1318, 1373, 1376, 1378, 1381, 1382, 1397, 1403, 1407, 1413, 1419, 1423, 1424, 1427, 1442, 1449, 1453, 1460, 1483, 1495]
# Number of data points in this cluster: 29
#
# Cluster 60:
# Indices of data points: [18, 232, 320, 323, 548, 652, 670, 1079, 1319]
# Number of data points in this cluster: 9
#
# Cluster 209:
# Indices of data points: [19, 530, 753, 889, 1346]
# Number of data points in this cluster: 5
#
# Cluster 188:
# Indices of data points: [22, 77, 100, 105, 681, 901, 1402, 1484]
# Number of data points in this cluster: 8
#
# Cluster 67:
# Indices of data points: [23, 260, 706, 769, 1060, 1246, 1524]
# Number of data points in this cluster: 7
#
# Cluster 14:
# Indices of data points: [24, 126, 201, 396, 740, 1013, 1311, 1353]
# Number of data points in this cluster: 8
#
# Cluster 38:
# Indices of data points: [26, 248, 621, 911, 929, 974, 1215]
# Number of data points in this cluster: 7
#
# Cluster 176:
# Indices of data points: [27, 208, 433, 1289, 1574]
# Number of data points in this cluster: 5
#
# Cluster 32:
# Indices of data points: [28, 179, 588, 629, 655, 1156]
# Number of data points in this cluster: 6
#
# Cluster 173:
# Indices of data points: [29, 299, 499, 765, 888, 1166, 1510, 1555]
# Number of data points in this cluster: 8
#
# Cluster 215:
# Indices of data points: [30, 786, 1175]
# Number of data points in this cluster: 3
#
# Cluster 221:
# Indices of data points: [31, 415, 424, 837]
# Number of data points in this cluster: 4
#
# Cluster 165:
# Indices of data points: [32, 97, 803, 819, 1065, 1084, 1268, 1275, 1312, 1512, 1564]
# Number of data points in this cluster: 11
#
# Cluster 11:
# Indices of data points: [33, 504, 579, 1017, 1242, 1409, 1552]
# Number of data points in this cluster: 7
#
# Cluster 198:
# Indices of data points: [34, 432, 930, 1461]
# Number of data points in this cluster: 4
#
# Cluster 136:
# Indices of data points: [35, 799, 1316, 1406, 1418, 1426, 1468, 1473]
# Number of data points in this cluster: 8
#
# Cluster 59:
# Indices of data points: [37, 181, 281, 301, 360]
# Number of data points in this cluster: 5
#
# Cluster 208:
# Indices of data points: [38, 850, 917, 958, 1070, 1410, 1420, 1439, 1450, 1541]
# Number of data points in this cluster: 10
#
# Cluster 2:
# Indices of data points: [39, 46, 102, 138, 785, 854, 857, 873, 906, 955, 1288, 1321, 1345, 1370]
# Number of data points in this cluster: 14
#
# Cluster 233:
# Indices of data points: [40, 1243, 1363]
# Number of data points in this cluster: 3
#
# Cluster 214:
# Indices of data points: [41, 45, 101, 103, 847, 868, 905, 1383, 1435, 1448, 1550, 1606]
# Number of data points in this cluster: 12
#
# Cluster 98:
# Indices of data points: [42, 497, 718, 757, 947, 1033]
# Number of data points in this cluster: 6
#
# Cluster 28:
# Indices of data points: [43, 147, 161, 450, 587, 631, 732, 1125, 1502]
# Number of data points in this cluster: 9
#
# Cluster 44:
# Indices of data points: [44, 110, 220, 429, 444, 477, 515, 538, 610, 1254, 1287, 1476]
# Number of data points in this cluster: 12
#
# Cluster 239:
# Indices of data points: [50, 266, 379, 1003, 1059, 1257, 1334]
# Number of data points in this cluster: 7
#
# Cluster 142:
# Indices of data points: [51, 876, 985, 1330]
# Number of data points in this cluster: 4
#
# Cluster 48:
# Indices of data points: [52, 56, 483, 659, 690, 767, 918, 1001]
# Number of data points in this cluster: 8
#
# Cluster 153:
# Indices of data points: [53, 867, 922, 1340]
# Number of data points in this cluster: 4
#
# Cluster 159:
# Indices of data points: [54, 506, 1076]
# Number of data points in this cluster: 3
#
# Cluster 185:
# Indices of data points: [55, 118, 300, 805, 807, 902, 1520]
# Number of data points in this cluster: 7
#
# Cluster 195:
# Indices of data points: [57, 688, 1136, 1338]
# Number of data points in this cluster: 4
#
# Cluster 149:
# Indices of data points: [58, 62, 292, 351, 431, 649, 1008, 1118, 1157]
# Number of data points in this cluster: 9
#
# Cluster 119:
# Indices of data points: [59, 99, 546, 639, 699]
# Number of data points in this cluster: 5
#
# Cluster 162:
# Indices of data points: [60, 67, 90, 93, 209, 362, 1590]
# Number of data points in this cluster: 7
#
# Cluster 138:
# Indices of data points: [61, 467, 605, 705, 1038, 1228]
# Number of data points in this cluster: 6
#
# Cluster 36:
# Indices of data points: [63, 204, 240, 336, 394, 453, 1107, 1542]
# Number of data points in this cluster: 8
#
# Cluster 124:
# Indices of data points: [64, 417, 811, 1061, 1203, 1558]
# Number of data points in this cluster: 6
#
# Cluster 172:
# Indices of data points: [65, 234, 430, 963]
# Number of data points in this cluster: 4
#
# Cluster 122:
# Indices of data points: [66, 78, 155, 225, 331, 475, 551, 675, 733, 1104, 1113]
# Number of data points in this cluster: 11
#
# Cluster 156:
# Indices of data points: [68, 178, 414, 576, 999, 1232]
# Number of data points in this cluster: 6
#
# Cluster 151:
# Indices of data points: [69, 460, 630, 660, 983, 1238]
# Number of data points in this cluster: 6
#
# Cluster 137:
# Indices of data points: [70, 861, 946]
# Number of data points in this cluster: 3
#
# Cluster 61:
# Indices of data points: [71, 143, 355, 484, 527, 1006, 1026]
# Number of data points in this cluster: 7
#
# Cluster 72:
# Indices of data points: [72, 197, 1252, 1309, 1336]
# Number of data points in this cluster: 5
#
# Cluster 167:
# Indices of data points: [73, 139, 166, 711, 935, 1291, 1487]
# Number of data points in this cluster: 7
#
# Cluster 31:
# Indices of data points: [74, 987, 1143, 1151, 1206, 1315, 1586]
# Number of data points in this cluster: 7
#
# Cluster 13:
# Indices of data points: [75, 177, 632, 723, 1068, 1269, 1508]
# Number of data points in this cluster: 7
#
# Cluster 91:
# Indices of data points: [76, 353, 720, 956, 972, 1190]
# Number of data points in this cluster: 6
#
# Cluster 131:
# Indices of data points: [79, 265, 280]
# Number of data points in this cluster: 3
#
# Cluster 178:
# Indices of data points: [80, 448, 1207, 1211]
# Number of data points in this cluster: 4
#
# Cluster 203:
# Indices of data points: [81, 540, 964]
# Number of data points in this cluster: 3
#
# Cluster 29:
# Indices of data points: [82, 264, 359, 1585]
# Number of data points in this cluster: 4
#
# Cluster 70:
# Indices of data points: [83, 345, 440, 557, 1080, 1285, 1562, 1592]
# Number of data points in this cluster: 8
#
# Cluster 205:
# Indices of data points: [84, 559, 671, 849, 1161, 1260]
# Number of data points in this cluster: 6
#
# Cluster 16:
# Indices of data points: [85, 111, 157, 188, 332, 344, 1043, 1525]
# Number of data points in this cluster: 8
#
# Cluster 186:
# Indices of data points: [86, 261, 267, 317, 358]
# Number of data points in this cluster: 5
#
# Cluster 75:
# Indices of data points: [87, 152, 754, 828, 892, 952, 1305, 1404, 1429, 1452, 1521, 1543]
# Number of data points in this cluster: 12
#
# Cluster 24:
# Indices of data points: [88, 162, 474, 620, 1077, 1184]
# Number of data points in this cluster: 6
#
# Cluster 22:
# Indices of data points: [89, 195, 242, 245, 278, 349, 372, 373, 376, 1223, 1572]
# Number of data points in this cluster: 11
#
# Cluster 51:
# Indices of data points: [91, 216, 253, 298, 1159]
# Number of data points in this cluster: 5
#
# Cluster 106:
# Indices of data points: [92, 427, 466, 590, 954, 1147, 1219]
# Number of data points in this cluster: 7
#
# Cluster 87:
# Indices of data points: [96, 207, 529, 575, 578, 784, 1072, 1110, 1514]
# Number of data points in this cluster: 9
#
# Cluster 144:
# Indices of data points: [98, 507, 1007, 1181, 1250, 1388, 1539]
# Number of data points in this cluster: 7
#
# Cluster 78:
# Indices of data points: [104, 116, 486, 695, 745, 800, 823, 891]
# Number of data points in this cluster: 8
#
# Cluster 30:
# Indices of data points: [106, 761, 986, 1052, 1253, 1566]
# Number of data points in this cluster: 6
#
# Cluster 103:
# Indices of data points: [107, 324, 856, 1599]
# Number of data points in this cluster: 4
#
# Cluster 39:
# Indices of data points: [108, 410, 743, 1091, 1284, 1333]
# Number of data points in this cluster: 6
#
# Cluster 128:
# Indices of data points: [112, 294, 489, 549, 944, 1132, 1186, 1544, 1607]
# Number of data points in this cluster: 9
#
# Cluster 65:
# Indices of data points: [113, 122, 258, 409, 736, 772, 1255, 1306, 1361, 1430, 1465]
# Number of data points in this cluster: 11
#
# Cluster 196:
# Indices of data points: [114, 123, 722, 982, 1295, 1314, 1386]
# Number of data points in this cluster: 7
#
# Cluster 94:
# Indices of data points: [115, 318, 813, 870, 1012, 1609]
# Number of data points in this cluster: 6
#
# Cluster 26:
# Indices of data points: [117, 498, 577, 726, 1173, 1302, 1401]
# Number of data points in this cluster: 7
#
# Cluster 179:
# Indices of data points: [119, 244, 338, 897, 1517]
# Number of data points in this cluster: 5
#
# Cluster 93:
# Indices of data points: [120, 136, 739, 797, 824, 1230, 1233, 1355, 1445]
# Number of data points in this cluster: 9
#
# Cluster 33:
# Indices of data points: [121, 555, 1048, 1280, 1292, 1308, 1477, 1523]
# Number of data points in this cluster: 8
#
# Cluster 225:
# Indices of data points: [124, 700, 749, 1511, 1565]
# Number of data points in this cluster: 5
#
# Cluster 115:
# Indices of data points: [125, 389, 1297, 1304, 1347]
# Number of data points in this cluster: 5
#
# Cluster 161:
# Indices of data points: [128, 943, 1411, 1437, 1446]
# Number of data points in this cluster: 5
#
# Cluster 194:
# Indices of data points: [129, 1045, 1058, 1266, 1392, 1479, 1506]
# Number of data points in this cluster: 7
#
# Cluster 187:
# Indices of data points: [130, 191, 343, 990]
# Number of data points in this cluster: 4
#
# Cluster 62:
# Indices of data points: [131, 316, 568, 774, 994]
# Number of data points in this cluster: 5
#
# Cluster 150:
# Indices of data points: [133, 145, 1571]
# Number of data points in this cluster: 3
#
# Cluster 200:
# Indices of data points: [137, 428, 552, 1199]
# Number of data points in this cluster: 4
#
# Cluster 152:
# Indices of data points: [140, 180, 586, 962]
# Number of data points in this cluster: 4
#
# Cluster 125:
# Indices of data points: [141, 206, 461, 882, 1015]
# Number of data points in this cluster: 5
#
# Cluster 53:
# Indices of data points: [142, 159, 457, 567, 658, 833, 991, 1064]
# Number of data points in this cluster: 8
#
# Cluster 238:
# Indices of data points: [144, 735, 746, 869, 981, 1005, 1300]
# Number of data points in this cluster: 7
#
# Cluster 66:
# Indices of data points: [146, 282, 470, 603, 608, 689, 959, 973, 1182, 1277, 1516]
# Number of data points in this cluster: 11
#
# Cluster 10:
# Indices of data points: [148, 174, 239, 594, 814, 1576]
# Number of data points in this cluster: 6
#
# Cluster 174:
# Indices of data points: [149, 481, 520, 771, 781, 1117]
# Number of data points in this cluster: 6
#
# Cluster 147:
# Indices of data points: [150, 219, 425, 545, 783, 1149]
# Number of data points in this cluster: 6
#
# Cluster 0:
# Indices of data points: [151, 407, 570, 684, 878, 1323, 1414, 1462]
# Number of data points in this cluster: 8
#
# Cluster 63:
# Indices of data points: [153, 218, 315, 508, 617, 624, 1041, 1153, 1204, 1557, 1580]
# Number of data points in this cluster: 11
#
# Cluster 237:
# Indices of data points: [154, 542, 1200, 1329, 1594]
# Number of data points in this cluster: 5
#
# Cluster 226:
# Indices of data points: [156, 273, 565, 615, 1248]
# Number of data points in this cluster: 5
#
# Cluster 114:
# Indices of data points: [158, 160, 672, 1034, 1103, 1245, 1507]
# Number of data points in this cluster: 7
#
# Cluster 21:
# Indices of data points: [163, 303, 322, 613, 635, 680, 1162, 1193, 1216, 1274]
# Number of data points in this cluster: 10
#
# Cluster 193:
# Indices of data points: [164, 325, 354]
# Number of data points in this cluster: 3
#
# Cluster 171:
# Indices of data points: [165, 237, 287, 335, 1593]
# Number of data points in this cluster: 5
#
# Cluster 96:
# Indices of data points: [167, 221, 845, 890, 910, 1444]
# Number of data points in this cluster: 6
#
# Cluster 210:
# Indices of data points: [168, 703, 984, 1281]
# Number of data points in this cluster: 4
#
# Cluster 23:
# Indices of data points: [169, 666, 707, 750, 1075, 1150, 1313]
# Number of data points in this cluster: 7
#
# Cluster 4:
# Indices of data points: [170, 183, 268, 279, 289, 290, 738, 1140]
# Number of data points in this cluster: 8
#
# Cluster 40:
# Indices of data points: [171, 387, 524, 710, 1141, 1251]
# Number of data points in this cluster: 6
#
# Cluster 73:
# Indices of data points: [172, 584, 607, 1036, 1202, 1237, 1536]
# Number of data points in this cluster: 7
#
# Cluster 180:
# Indices of data points: [173, 692, 721, 777, 1049, 1374]
# Number of data points in this cluster: 6
#
# Cluster 143:
# Indices of data points: [176, 356, 369, 647, 653, 664, 1214, 1226]
# Number of data points in this cluster: 8
#
# Cluster 219:
# Indices of data points: [182, 285, 361, 393, 1575]
# Number of data points in this cluster: 5
#
# Cluster 133:
# Indices of data points: [184, 295, 550, 627, 636, 966, 1028, 1088, 1272, 1591]
# Number of data points in this cluster: 10
#
# Cluster 50:
# Indices of data points: [186, 702, 812, 933, 995, 1055, 1436]
# Number of data points in this cluster: 7
#
# Cluster 229:
# Indices of data points: [187, 1081, 1082, 1220]
# Number of data points in this cluster: 4
#
# Cluster 184:
# Indices of data points: [189, 370, 426, 480, 625, 810]
# Number of data points in this cluster: 6
#
# Cluster 224:
# Indices of data points: [190, 602, 674, 1196, 1264]
# Number of data points in this cluster: 5
#
# Cluster 111:
# Indices of data points: [192, 291, 297, 348, 452, 662, 1326]
# Number of data points in this cluster: 7
#
# Cluster 42:
# Indices of data points: [193, 385, 436, 564, 637, 1014, 1126]
# Number of data points in this cluster: 7
#
# Cluster 212:
# Indices of data points: [194, 401, 496, 821]
# Number of data points in this cluster: 4
#
# Cluster 58:
# Indices of data points: [196, 229, 383, 419, 509, 651, 1004]
# Number of data points in this cluster: 7
#
# Cluster 223:
# Indices of data points: [198, 374, 397, 435, 782, 1009, 1115, 1209]
# Number of data points in this cluster: 8
#
# Cluster 202:
# Indices of data points: [199, 310, 510, 1210, 1213, 1307, 1500]
# Number of data points in this cluster: 7
#
# Cluster 177:
# Indices of data points: [202, 1229, 1563]
# Number of data points in this cluster: 3
#
# Cluster 56:
# Indices of data points: [203, 501, 519, 583, 1037, 1074, 1128, 1144, 1174]
# Number of data points in this cluster: 9
#
# Cluster 89:
# Indices of data points: [210, 609, 701, 751, 762, 977]
# Number of data points in this cluster: 6
#
# Cluster 37:
# Indices of data points: [211, 327, 478, 654, 742, 747, 801, 1021, 1120, 1496]
# Number of data points in this cluster: 10
#
# Cluster 123:
# Indices of data points: [212, 420, 597, 1537]
# Number of data points in this cluster: 4
#
# Cluster 35:
# Indices of data points: [213, 363, 445, 446, 606, 646, 1109, 1290]
# Number of data points in this cluster: 8
#
# Cluster 49:
# Indices of data points: [214, 259, 391, 619, 644, 661, 971, 1198, 1205, 1224]
# Number of data points in this cluster: 10
#
# Cluster 69:
# Indices of data points: [215, 246, 283, 364]
# Number of data points in this cluster: 4
#
# Cluster 160:
# Indices of data points: [217, 272, 274, 346]
# Number of data points in this cluster: 4
#
# Cluster 86:
# Indices of data points: [222, 296, 543, 572, 979, 1335, 1443, 1559]
# Number of data points in this cluster: 8
#
# Cluster 20:
# Indices of data points: [223, 228, 337, 340, 853, 1584]
# Number of data points in this cluster: 6
#
# Cluster 80:
# Indices of data points: [224, 308, 350, 418, 438, 581, 1197]
# Number of data points in this cluster: 7
#
# Cluster 207:
# Indices of data points: [226, 263, 275, 334]
# Number of data points in this cluster: 4
#
# Cluster 71:
# Indices of data points: [227, 357, 423, 948, 1024, 1083, 1106, 1164, 1538, 1568]
# Number of data points in this cluster: 10
#
# Cluster 5:
# Indices of data points: [230, 347, 402, 406, 595, 611, 1062, 1135, 1160, 1597]
# Number of data points in this cluster: 10
#
# Cluster 90:
# Indices of data points: [231, 634, 687, 752, 993, 1085, 1145, 1146]
# Number of data points in this cluster: 8
#
# Cluster 140:
# Indices of data points: [233, 844, 992, 1011, 1433, 1480]
# Number of data points in this cluster: 6
#
# Cluster 206:
# Indices of data points: [235, 585, 656, 1604]
# Number of data points in this cluster: 4
#
# Cluster 189:
# Indices of data points: [236, 468, 469, 614, 1168]
# Number of data points in this cluster: 5
#
# Cluster 241:
# Indices of data points: [238]
# Number of data points in this cluster: 1
#
# Cluster 19:
# Indices of data points: [241, 257, 271, 330]
# Number of data points in this cluster: 4
#
# Cluster 1:
# Indices of data points: [243, 328, 398, 405, 591, 638, 715, 1090, 1188]
# Number of data points in this cluster: 9
#
# Cluster 57:
# Indices of data points: [247, 503, 697, 728, 731, 763, 1176, 1261]
# Number of data points in this cluster: 8
#
# Cluster 222:
# Indices of data points: [249, 592, 756, 789, 1035, 1178]
# Number of data points in this cluster: 6
#
# Cluster 43:
# Indices of data points: [250, 302, 447, 667, 1098, 1121, 1134]
# Number of data points in this cluster: 7
#
# Cluster 227:
# Indices of data points: [251, 284, 434, 442, 1093, 1095, 1273, 1581]
# Number of data points in this cluster: 8
#
# Cluster 112:
# Indices of data points: [254, 269, 270, 365, 1598]
# Number of data points in this cluster: 5
#
# Cluster 182:
# Indices of data points: [255, 377, 779]
# Number of data points in this cluster: 3
#
# Cluster 18:
# Indices of data points: [256, 341, 536, 558, 642, 676, 679, 1116, 1129, 1148, 1163, 1170]
# Number of data points in this cluster: 12
#
# Cluster 155:
# Indices of data points: [262, 439, 648, 1123]
# Number of data points in this cluster: 4
#
# Cluster 154:
# Indices of data points: [276, 456, 476, 980, 1158, 1371]
# Number of data points in this cluster: 6
#
# Cluster 183:
# Indices of data points: [277, 919, 976, 1067, 1582, 1588]
# Number of data points in this cluster: 6
#
# Cluster 12:
# Indices of data points: [286, 381, 441, 451, 612, 641, 1130]
# Number of data points in this cluster: 7
#
# Cluster 77:
# Indices of data points: [304, 314, 437, 1138, 1179, 1231, 1350]
# Number of data points in this cluster: 7
#
# Cluster 116:
# Indices of data points: [305, 342, 473, 495, 537, 663, 669, 997, 1127, 1258, 1356, 1578]
# Number of data points in this cluster: 12
#
# Cluster 101:
# Indices of data points: [306, 927, 945, 1050, 1155, 1470]
# Number of data points in this cluster: 6
#
# Cluster 139:
# Indices of data points: [307, 535, 1139, 1548]
# Number of data points in this cluster: 4
#
# Cluster 74:
# Indices of data points: [309, 421, 518, 685, 883]
# Number of data points in this cluster: 5
#
# Cluster 213:
# Indices of data points: [311, 367, 413, 600, 657, 1377]
# Number of data points in this cluster: 6
#
# Cluster 199:
# Indices of data points: [312, 1526]
# Number of data points in this cluster: 2
#
# Cluster 113:
# Indices of data points: [313, 388, 698, 713, 730, 965, 969, 1486]
# Number of data points in this cluster: 8
#
# Cluster 76:
# Indices of data points: [319, 556, 626]
# Number of data points in this cluster: 3
#
# Cluster 47:
# Indices of data points: [321, 665, 716, 871, 877, 928, 960, 1100, 1212, 1399, 1469, 1527, 1546, 1579]
# Number of data points in this cluster: 14
#
# Cluster 68:
# Indices of data points: [326, 411, 472, 616, 737, 900, 1054, 1389]
# Number of data points in this cluster: 8
#
# Cluster 129:
# Indices of data points: [329, 1183, 1225, 1532]
# Number of data points in this cluster: 4
#
# Cluster 134:
# Indices of data points: [333, 914, 941, 998, 1320, 1573]
# Number of data points in this cluster: 6
#
# Cluster 55:
# Indices of data points: [339, 449, 459, 500, 623, 633, 678, 1025, 1342]
# Number of data points in this cluster: 9
#
# Cluster 211:
# Indices of data points: [352, 1016, 1201]
# Number of data points in this cluster: 3
#
# Cluster 135:
# Indices of data points: [366, 879, 968, 1357]
# Number of data points in this cluster: 4
#
# Cluster 216:
# Indices of data points: [368, 482, 1191]
# Number of data points in this cluster: 3
#
# Cluster 168:
# Indices of data points: [371, 709, 949, 1087, 1172, 1560]
# Number of data points in this cluster: 6
#
# Cluster 83:
# Indices of data points: [378, 455, 768, 778, 975, 1279, 1589]
# Number of data points in this cluster: 7
#
# Cluster 105:
# Indices of data points: [380, 544, 668, 830]
# Number of data points in this cluster: 4
#
# Cluster 218:
# Indices of data points: [384, 485, 528, 580, 1263]
# Number of data points in this cluster: 5
#
# Cluster 169:
# Indices of data points: [390, 566, 673, 1131, 1239]
# Number of data points in this cluster: 5
#
# Cluster 3:
# Indices of data points: [392, 422, 511, 533, 547, 563, 596, 622, 693, 787, 996, 1097, 1221, 1551, 1554, 1561]
# Number of data points in this cluster: 16
#
# Cluster 217:
# Indices of data points: [395, 880, 953, 1271]
# Number of data points in this cluster: 4
#
# Cluster 17:
# Indices of data points: [399, 471, 788, 804, 843, 859, 1192, 1278, 1367, 1467, 1472, 1570]
# Number of data points in this cluster: 12
#
# Cluster 235:
# Indices of data points: [400, 408, 560, 773, 1366]
# Number of data points in this cluster: 5
#
# Cluster 141:
# Indices of data points: [403, 521, 526, 691]
# Number of data points in this cluster: 4
#
# Cluster 148:
# Indices of data points: [404, 708, 1137, 1533]
# Number of data points in this cluster: 4
#
# Cluster 192:
# Indices of data points: [412, 628, 714, 1332]
# Number of data points in this cluster: 4
#
# Cluster 157:
# Indices of data points: [416, 487, 522, 719, 842, 874, 978]
# Number of data points in this cluster: 7
#
# Cluster 92:
# Indices of data points: [454, 502, 1047, 1177, 1180]
# Number of data points in this cluster: 5
#
# Cluster 197:
# Indices of data points: [458, 531, 539, 748, 1105]
# Number of data points in this cluster: 5
#
# Cluster 121:
# Indices of data points: [462, 491, 494, 569, 1152, 1218, 1283, 1327, 1556]
# Number of data points in this cluster: 9
#
# Cluster 7:
# Indices of data points: [463, 760, 989, 1020, 1042]
# Number of data points in this cluster: 5
#
# Cluster 107:
# Indices of data points: [464, 562, 571, 863, 1114, 1391]
# Number of data points in this cluster: 6
#
# Cluster 234:
# Indices of data points: [465, 1240, 1262]
# Number of data points in this cluster: 3
#
# Cluster 95:
# Indices of data points: [479, 885, 1112, 1293, 1331, 1337, 1528]
# Number of data points in this cluster: 7
#
# Cluster 110:
# Indices of data points: [488, 755, 1108, 1222]
# Number of data points in this cluster: 4
#
# Cluster 231:
# Indices of data points: [490, 523, 834]
# Number of data points in this cluster: 3
#
# Cluster 108:
# Indices of data points: [492, 525, 589, 764, 921, 934, 1577]
# Number of data points in this cluster: 7
#
# Cluster 79:
# Indices of data points: [505, 512, 593, 839, 970, 988, 1169, 1545, 1587]
# Number of data points in this cluster: 9
#
# Cluster 164:
# Indices of data points: [513, 573, 574, 650, 734]
# Number of data points in this cluster: 5
#
# Cluster 228:
# Indices of data points: [514, 517, 1185]
# Number of data points in this cluster: 3
#
# Cluster 52:
# Indices of data points: [532, 553, 554, 643, 682, 881, 940, 1000, 1027, 1044, 1241, 1301, 1303, 1344]
# Number of data points in this cluster: 14
#
# Cluster 100:
# Indices of data points: [534, 601, 1611]
# Number of data points in this cluster: 3
#
# Cluster 81:
# Indices of data points: [541, 759, 1018, 1099, 1119, 1154, 1217]
# Number of data points in this cluster: 7
#
# Cluster 99:
# Indices of data points: [604, 758, 951, 1499]
# Number of data points in this cluster: 4
#
# Cluster 126:
# Indices of data points: [618, 696, 1324, 1610]
# Number of data points in this cluster: 4
#
# Cluster 97:
# Indices of data points: [640, 942, 1358, 1474, 1540]
# Number of data points in this cluster: 5
#
# Cluster 109:
# Indices of data points: [677, 776, 822, 1194, 1247, 1529]
# Number of data points in this cluster: 6
#
# Cluster 181:
# Indices of data points: [712, 717, 1094, 1509]
# Number of data points in this cluster: 4
#
# Cluster 102:
# Indices of data points: [724, 816, 957, 1234, 1351, 1394, 1400, 1440, 1513, 1531]
# Number of data points in this cluster: 10
#
# Cluster 201:
# Indices of data points: [727, 1056, 1596]
# Number of data points in this cluster: 3
#
# Cluster 84:
# Indices of data points: [741, 744, 1019, 1022, 1101, 1167, 1317, 1530]
# Number of data points in this cluster: 8
#
# Cluster 146:
# Indices of data points: [766, 806, 820, 855, 858, 923]
# Number of data points in this cluster: 6
#
# Cluster 132:
# Indices of data points: [770, 780, 792]
# Number of data points in this cluster: 3
#
# Cluster 27:
# Indices of data points: [791, 793, 795]
# Number of data points in this cluster: 3
#
# Cluster 232:
# Indices of data points: [798, 817, 1032]
# Number of data points in this cluster: 3
#
# Cluster 230:
# Indices of data points: [808, 907, 931, 1063, 1415, 1547]
# Number of data points in this cluster: 6
#
# Cluster 82:
# Indices of data points: [825, 909, 912, 915, 937, 1352, 1362, 1384, 1441, 1481, 1600]
# Number of data points in this cluster: 11
#
# Cluster 220:
# Indices of data points: [835, 926, 1078, 1310, 1372, 1501]
# Number of data points in this cluster: 6
#
# Cluster 236:
# Indices of data points: [836, 860, 1276, 1387, 1491]
# Number of data points in this cluster: 5
#
# Cluster 41:
# Indices of data points: [846, 848, 904, 1039, 1046, 1057, 1111, 1369, 1375, 1504]
# Number of data points in this cluster: 10
#
# Cluster 117:
# Indices of data points: [866, 886, 1227, 1259, 1515]
# Number of data points in this cluster: 5
#
# Cluster 88:
# Indices of data points: [884, 924, 1096, 1256, 1270, 1522]
# Number of data points in this cluster: 6
#
# Cluster 166:
# Indices of data points: [896, 932, 1208, 1325, 1422, 1475, 1482]
# Number of data points in this cluster: 7
#
# Cluster 170:
# Indices of data points: [899, 961, 967, 1040, 1122, 1187]
# Number of data points in this cluster: 6
#
# Cluster 190:
# Indices of data points: [903]
# Number of data points in this cluster: 1
#
# Cluster 158:
# Indices of data points: [916, 1089, 1380, 1497]
# Number of data points in this cluster: 4
#
# Cluster 163:
# Indices of data points: [920, 1010, 1069, 1395]
# Number of data points in this cluster: 4
#
# Cluster 85:
# Indices of data points: [938, 1195, 1286, 1360]
# Number of data points in this cluster: 4
#
# Cluster 118:
# Indices of data points: [1092, 1171, 1583]
# Number of data points in this cluster: 3
#
# Cluster 175:
# Indices of data points: [1102, 1249, 1503]
# Number of data points in this cluster: 3
#
# Cluster 240:
# Indices of data points: [1165, 1603]
# Number of data points in this cluster: 2
#
# Cluster 120:
# Indices of data points: [1553]
# Number of data points in this cluster: 1

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Step 1: Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")

# Step 2: (Optional) Preprocess the data if needed
# For example, you might want to scale the features to ensure the clustering works well
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 3: Perform Agglomerative Clustering
# You can specify the number of clusters or other hyperparameters here
n_clusters = 242  # Example, set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model to the feature matrix
clustering_labels = clustering.fit_predict(features_scaled)

# Step 4: (Optional) Visualize the results if the features are 2D (or use dimensionality reduction)
if features_scaled.shape[1] == 2:  # If your features are 2D, you can visualize them
    plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=clustering_labels, cmap='viridis')
    plt.title("Agglomerative Clustering Results")
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# If you have higher-dimensional features, consider using PCA to reduce to 2D for visualization
# For example:
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# features_2d = pca.fit_transform(features_scaled)
# plt.scatter(features_2d[:, 0], features_2d[:, 1], c=clustering_labels, cmap='viridis')
# plt.show()

# Step 5: View the labels assigned to each data point
print("Cluster Labels:", clustering_labels)
# Out:
# Cluster Labels: [ 64  15 204 ...  94 126 100]

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters =242  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Display the clusters in the desired format
for cluster_label, indices in cluster_dict.items():
    print(f"Cluster {cluster_label}:")
    print(f"Indices of data points: {indices}")
    print(f"Number of data points in this cluster: {len(indices)}\n")
# Out:
# Cluster 64:
# Indices of data points: [0, 15, 704, 794, 802, 841, 895, 939, 1073, 1235, 1348, 1398, 1602]
# Number of data points in this cluster: 13
#
# Cluster 15:
# Indices of data points: [1, 36, 49, 132, 818, 829, 852, 908, 950, 1296, 1349, 1385, 1393, 1396, 1405, 1425, 1464, 1489, 1534, 1601]
# Number of data points in this cluster: 20
#
# Cluster 204:
# Indices of data points: [2, 20, 796, 809, 851, 898, 1416, 1431, 1458, 1485, 1490, 1493, 1505, 1608]
# Number of data points in this cluster: 14
#
# Cluster 127:
# Indices of data points: [3, 47, 775, 790, 862, 893, 925, 1029, 1071, 1086, 1298, 1390, 1434, 1456, 1478]
# Number of data points in this cluster: 15
#
# Cluster 25:
# Indices of data points: [4, 11, 21, 599, 686, 887, 936, 1002, 1236, 1455, 1567]
# Number of data points in this cluster: 11
#
# Cluster 8:
# Indices of data points: [5, 95, 200, 293, 382, 386, 443, 598, 1294]
# Number of data points in this cluster: 9
#
# Cluster 9:
# Indices of data points: [6, 205, 375, 645, 1023, 1053, 1124]
# Number of data points in this cluster: 7
#
# Cluster 34:
# Indices of data points: [7, 25, 134, 582, 894, 1142, 1412]
# Number of data points in this cluster: 7
#
# Cluster 46:
# Indices of data points: [8, 48, 185, 1189, 1244, 1408, 1535, 1549, 1595, 1605]
# Number of data points in this cluster: 10
#
# Cluster 130:
# Indices of data points: [9, 135, 252, 288, 516, 561, 725, 1030, 1322]
# Number of data points in this cluster: 9
#
# Cluster 54:
# Indices of data points: [10, 109, 913, 1051, 1066, 1339, 1343, 1359, 1365, 1379, 1417, 1421, 1428, 1432, 1438, 1447, 1451, 1454, 1457, 1459, 1492, 1494]
# Number of data points in this cluster: 22
#
# Cluster 191:
# Indices of data points: [12, 683, 827, 1133, 1282, 1488]
# Number of data points in this cluster: 6
#
# Cluster 45:
# Indices of data points: [13, 175, 694, 729, 838, 872, 1328, 1466]
# Number of data points in this cluster: 8
#
# Cluster 104:
# Indices of data points: [14, 831, 840, 865, 1265, 1267, 1341, 1354, 1364, 1368, 1463, 1471, 1498, 1518]
# Number of data points in this cluster: 14
#
# Cluster 145:
# Indices of data points: [16, 493, 1299, 1519, 1569]
# Number of data points in this cluster: 5
#
# Cluster 6:
# Indices of data points: [17, 94, 127, 815, 826, 832, 864, 875, 1031, 1318, 1373, 1376, 1378, 1381, 1382, 1397, 1403, 1407, 1413, 1419, 1423, 1424, 1427, 1442, 1449, 1453, 1460, 1483, 1495]
# Number of data points in this cluster: 29
#
# Cluster 60:
# Indices of data points: [18, 232, 320, 323, 548, 652, 670, 1079, 1319]
# Number of data points in this cluster: 9
#
# Cluster 209:
# Indices of data points: [19, 530, 753, 889, 1346]
# Number of data points in this cluster: 5
#
# Cluster 188:
# Indices of data points: [22, 77, 100, 105, 681, 901, 1402, 1484]
# Number of data points in this cluster: 8
#
# Cluster 67:
# Indices of data points: [23, 260, 706, 769, 1060, 1246, 1524]
# Number of data points in this cluster: 7
#
# Cluster 14:
# Indices of data points: [24, 126, 201, 396, 740, 1013, 1311, 1353]
# Number of data points in this cluster: 8
#
# Cluster 38:
# Indices of data points: [26, 248, 621, 911, 929, 974, 1215]
# Number of data points in this cluster: 7
#
# Cluster 176:
# Indices of data points: [27, 208, 433, 1289, 1574]
# Number of data points in this cluster: 5
#
# Cluster 32:
# Indices of data points: [28, 179, 588, 629, 655, 1156]
# Number of data points in this cluster: 6
#
# Cluster 173:
# Indices of data points: [29, 299, 499, 765, 888, 1166, 1510, 1555]
# Number of data points in this cluster: 8
#
# Cluster 215:
# Indices of data points: [30, 786, 1175]
# Number of data points in this cluster: 3
#
# Cluster 221:
# Indices of data points: [31, 415, 424, 837]
# Number of data points in this cluster: 4
#
# Cluster 165:
# Indices of data points: [32, 97, 803, 819, 1065, 1084, 1268, 1275, 1312, 1512, 1564]
# Number of data points in this cluster: 11
#
# Cluster 11:
# Indices of data points: [33, 504, 579, 1017, 1242, 1409, 1552]
# Number of data points in this cluster: 7
#
# Cluster 198:
# Indices of data points: [34, 432, 930, 1461]
# Number of data points in this cluster: 4
#
# Cluster 136:
# Indices of data points: [35, 799, 1316, 1406, 1418, 1426, 1468, 1473]
# Number of data points in this cluster: 8
#
# Cluster 59:
# Indices of data points: [37, 181, 281, 301, 360]
# Number of data points in this cluster: 5
#
# Cluster 208:
# Indices of data points: [38, 850, 917, 958, 1070, 1410, 1420, 1439, 1450, 1541]
# Number of data points in this cluster: 10
#
# Cluster 2:
# Indices of data points: [39, 46, 102, 138, 785, 854, 857, 873, 906, 955, 1288, 1321, 1345, 1370]
# Number of data points in this cluster: 14
#
# Cluster 233:
# Indices of data points: [40, 1243, 1363]
# Number of data points in this cluster: 3
#
# Cluster 214:
# Indices of data points: [41, 45, 101, 103, 847, 868, 905, 1383, 1435, 1448, 1550, 1606]
# Number of data points in this cluster: 12
#
# Cluster 98:
# Indices of data points: [42, 497, 718, 757, 947, 1033]
# Number of data points in this cluster: 6
#
# Cluster 28:
# Indices of data points: [43, 147, 161, 450, 587, 631, 732, 1125, 1502]
# Number of data points in this cluster: 9
#
# Cluster 44:
# Indices of data points: [44, 110, 220, 429, 444, 477, 515, 538, 610, 1254, 1287, 1476]
# Number of data points in this cluster: 12
#
# Cluster 239:
# Indices of data points: [50, 266, 379, 1003, 1059, 1257, 1334]
# Number of data points in this cluster: 7
#
# Cluster 142:
# Indices of data points: [51, 876, 985, 1330]
# Number of data points in this cluster: 4
#
# Cluster 48:
# Indices of data points: [52, 56, 483, 659, 690, 767, 918, 1001]
# Number of data points in this cluster: 8
#
# Cluster 153:
# Indices of data points: [53, 867, 922, 1340]
# Number of data points in this cluster: 4
#
# Cluster 159:
# Indices of data points: [54, 506, 1076]
# Number of data points in this cluster: 3
#
# Cluster 185:
# Indices of data points: [55, 118, 300, 805, 807, 902, 1520]
# Number of data points in this cluster: 7
#
# Cluster 195:
# Indices of data points: [57, 688, 1136, 1338]
# Number of data points in this cluster: 4
#
# Cluster 149:
# Indices of data points: [58, 62, 292, 351, 431, 649, 1008, 1118, 1157]
# Number of data points in this cluster: 9
#
# Cluster 119:
# Indices of data points: [59, 99, 546, 639, 699]
# Number of data points in this cluster: 5
#
# Cluster 162:
# Indices of data points: [60, 67, 90, 93, 209, 362, 1590]
# Number of data points in this cluster: 7
#
# Cluster 138:
# Indices of data points: [61, 467, 605, 705, 1038, 1228]
# Number of data points in this cluster: 6
#
# Cluster 36:
# Indices of data points: [63, 204, 240, 336, 394, 453, 1107, 1542]
# Number of data points in this cluster: 8
#
# Cluster 124:
# Indices of data points: [64, 417, 811, 1061, 1203, 1558]
# Number of data points in this cluster: 6
#
# Cluster 172:
# Indices of data points: [65, 234, 430, 963]
# Number of data points in this cluster: 4
#
# Cluster 122:
# Indices of data points: [66, 78, 155, 225, 331, 475, 551, 675, 733, 1104, 1113]
# Number of data points in this cluster: 11
#
# Cluster 156:
# Indices of data points: [68, 178, 414, 576, 999, 1232]
# Number of data points in this cluster: 6
#
# Cluster 151:
# Indices of data points: [69, 460, 630, 660, 983, 1238]
# Number of data points in this cluster: 6
#
# Cluster 137:
# Indices of data points: [70, 861, 946]
# Number of data points in this cluster: 3
#
# Cluster 61:
# Indices of data points: [71, 143, 355, 484, 527, 1006, 1026]
# Number of data points in this cluster: 7
#
# Cluster 72:
# Indices of data points: [72, 197, 1252, 1309, 1336]
# Number of data points in this cluster: 5
#
# Cluster 167:
# Indices of data points: [73, 139, 166, 711, 935, 1291, 1487]
# Number of data points in this cluster: 7
#
# Cluster 31:
# Indices of data points: [74, 987, 1143, 1151, 1206, 1315, 1586]
# Number of data points in this cluster: 7
#
# Cluster 13:
# Indices of data points: [75, 177, 632, 723, 1068, 1269, 1508]
# Number of data points in this cluster: 7
#
# Cluster 91:
# Indices of data points: [76, 353, 720, 956, 972, 1190]
# Number of data points in this cluster: 6
#
# Cluster 131:
# Indices of data points: [79, 265, 280]
# Number of data points in this cluster: 3
#
# Cluster 178:
# Indices of data points: [80, 448, 1207, 1211]
# Number of data points in this cluster: 4
#
# Cluster 203:
# Indices of data points: [81, 540, 964]
# Number of data points in this cluster: 3
#
# Cluster 29:
# Indices of data points: [82, 264, 359, 1585]
# Number of data points in this cluster: 4
#
# Cluster 70:
# Indices of data points: [83, 345, 440, 557, 1080, 1285, 1562, 1592]
# Number of data points in this cluster: 8
#
# Cluster 205:
# Indices of data points: [84, 559, 671, 849, 1161, 1260]
# Number of data points in this cluster: 6
#
# Cluster 16:
# Indices of data points: [85, 111, 157, 188, 332, 344, 1043, 1525]
# Number of data points in this cluster: 8
#
# Cluster 186:
# Indices of data points: [86, 261, 267, 317, 358]
# Number of data points in this cluster: 5
#
# Cluster 75:
# Indices of data points: [87, 152, 754, 828, 892, 952, 1305, 1404, 1429, 1452, 1521, 1543]
# Number of data points in this cluster: 12
#
# Cluster 24:
# Indices of data points: [88, 162, 474, 620, 1077, 1184]
# Number of data points in this cluster: 6
#
# Cluster 22:
# Indices of data points: [89, 195, 242, 245, 278, 349, 372, 373, 376, 1223, 1572]
# Number of data points in this cluster: 11
#
# Cluster 51:
# Indices of data points: [91, 216, 253, 298, 1159]
# Number of data points in this cluster: 5
#
# Cluster 106:
# Indices of data points: [92, 427, 466, 590, 954, 1147, 1219]
# Number of data points in this cluster: 7
#
# Cluster 87:
# Indices of data points: [96, 207, 529, 575, 578, 784, 1072, 1110, 1514]
# Number of data points in this cluster: 9
#
# Cluster 144:
# Indices of data points: [98, 507, 1007, 1181, 1250, 1388, 1539]
# Number of data points in this cluster: 7
#
# Cluster 78:
# Indices of data points: [104, 116, 486, 695, 745, 800, 823, 891]
# Number of data points in this cluster: 8
#
# Cluster 30:
# Indices of data points: [106, 761, 986, 1052, 1253, 1566]
# Number of data points in this cluster: 6
#
# Cluster 103:
# Indices of data points: [107, 324, 856, 1599]
# Number of data points in this cluster: 4
#
# Cluster 39:
# Indices of data points: [108, 410, 743, 1091, 1284, 1333]
# Number of data points in this cluster: 6
#
# Cluster 128:
# Indices of data points: [112, 294, 489, 549, 944, 1132, 1186, 1544, 1607]
# Number of data points in this cluster: 9
#
# Cluster 65:
# Indices of data points: [113, 122, 258, 409, 736, 772, 1255, 1306, 1361, 1430, 1465]
# Number of data points in this cluster: 11
#
# Cluster 196:
# Indices of data points: [114, 123, 722, 982, 1295, 1314, 1386]
# Number of data points in this cluster: 7
#
# Cluster 94:
# Indices of data points: [115, 318, 813, 870, 1012, 1609]
# Number of data points in this cluster: 6
#
# Cluster 26:
# Indices of data points: [117, 498, 577, 726, 1173, 1302, 1401]
# Number of data points in this cluster: 7
#
# Cluster 179:
# Indices of data points: [119, 244, 338, 897, 1517]
# Number of data points in this cluster: 5
#
# Cluster 93:
# Indices of data points: [120, 136, 739, 797, 824, 1230, 1233, 1355, 1445]
# Number of data points in this cluster: 9
#
# Cluster 33:
# Indices of data points: [121, 555, 1048, 1280, 1292, 1308, 1477, 1523]
# Number of data points in this cluster: 8
#
# Cluster 225:
# Indices of data points: [124, 700, 749, 1511, 1565]
# Number of data points in this cluster: 5
#
# Cluster 115:
# Indices of data points: [125, 389, 1297, 1304, 1347]
# Number of data points in this cluster: 5
#
# Cluster 161:
# Indices of data points: [128, 943, 1411, 1437, 1446]
# Number of data points in this cluster: 5
#
# Cluster 194:
# Indices of data points: [129, 1045, 1058, 1266, 1392, 1479, 1506]
# Number of data points in this cluster: 7
#
# Cluster 187:
# Indices of data points: [130, 191, 343, 990]
# Number of data points in this cluster: 4
#
# Cluster 62:
# Indices of data points: [131, 316, 568, 774, 994]
# Number of data points in this cluster: 5
#
# Cluster 150:
# Indices of data points: [133, 145, 1571]
# Number of data points in this cluster: 3
#
# Cluster 200:
# Indices of data points: [137, 428, 552, 1199]
# Number of data points in this cluster: 4
#
# Cluster 152:
# Indices of data points: [140, 180, 586, 962]
# Number of data points in this cluster: 4
#
# Cluster 125:
# Indices of data points: [141, 206, 461, 882, 1015]
# Number of data points in this cluster: 5
#
# Cluster 53:
# Indices of data points: [142, 159, 457, 567, 658, 833, 991, 1064]
# Number of data points in this cluster: 8
#
# Cluster 238:
# Indices of data points: [144, 735, 746, 869, 981, 1005, 1300]
# Number of data points in this cluster: 7
#
# Cluster 66:
# Indices of data points: [146, 282, 470, 603, 608, 689, 959, 973, 1182, 1277, 1516]
# Number of data points in this cluster: 11
#
# Cluster 10:
# Indices of data points: [148, 174, 239, 594, 814, 1576]
# Number of data points in this cluster: 6
#
# Cluster 174:
# Indices of data points: [149, 481, 520, 771, 781, 1117]
# Number of data points in this cluster: 6
#
# Cluster 147:
# Indices of data points: [150, 219, 425, 545, 783, 1149]
# Number of data points in this cluster: 6
#
# Cluster 0:
# Indices of data points: [151, 407, 570, 684, 878, 1323, 1414, 1462]
# Number of data points in this cluster: 8
#
# Cluster 63:
# Indices of data points: [153, 218, 315, 508, 617, 624, 1041, 1153, 1204, 1557, 1580]
# Number of data points in this cluster: 11
#
# Cluster 237:
# Indices of data points: [154, 542, 1200, 1329, 1594]
# Number of data points in this cluster: 5
#
# Cluster 226:
# Indices of data points: [156, 273, 565, 615, 1248]
# Number of data points in this cluster: 5
#
# Cluster 114:
# Indices of data points: [158, 160, 672, 1034, 1103, 1245, 1507]
# Number of data points in this cluster: 7
#
# Cluster 21:
# Indices of data points: [163, 303, 322, 613, 635, 680, 1162, 1193, 1216, 1274]
# Number of data points in this cluster: 10
#
# Cluster 193:
# Indices of data points: [164, 325, 354]
# Number of data points in this cluster: 3
#
# Cluster 171:
# Indices of data points: [165, 237, 287, 335, 1593]
# Number of data points in this cluster: 5
#
# Cluster 96:
# Indices of data points: [167, 221, 845, 890, 910, 1444]
# Number of data points in this cluster: 6
#
# Cluster 210:
# Indices of data points: [168, 703, 984, 1281]
# Number of data points in this cluster: 4
#
# Cluster 23:
# Indices of data points: [169, 666, 707, 750, 1075, 1150, 1313]
# Number of data points in this cluster: 7
#
# Cluster 4:
# Indices of data points: [170, 183, 268, 279, 289, 290, 738, 1140]
# Number of data points in this cluster: 8
#
# Cluster 40:
# Indices of data points: [171, 387, 524, 710, 1141, 1251]
# Number of data points in this cluster: 6
#
# Cluster 73:
# Indices of data points: [172, 584, 607, 1036, 1202, 1237, 1536]
# Number of data points in this cluster: 7
#
# Cluster 180:
# Indices of data points: [173, 692, 721, 777, 1049, 1374]
# Number of data points in this cluster: 6
#
# Cluster 143:
# Indices of data points: [176, 356, 369, 647, 653, 664, 1214, 1226]
# Number of data points in this cluster: 8
#
# Cluster 219:
# Indices of data points: [182, 285, 361, 393, 1575]
# Number of data points in this cluster: 5
#
# Cluster 133:
# Indices of data points: [184, 295, 550, 627, 636, 966, 1028, 1088, 1272, 1591]
# Number of data points in this cluster: 10
#
# Cluster 50:
# Indices of data points: [186, 702, 812, 933, 995, 1055, 1436]
# Number of data points in this cluster: 7
#
# Cluster 229:
# Indices of data points: [187, 1081, 1082, 1220]
# Number of data points in this cluster: 4
#
# Cluster 184:
# Indices of data points: [189, 370, 426, 480, 625, 810]
# Number of data points in this cluster: 6
#
# Cluster 224:
# Indices of data points: [190, 602, 674, 1196, 1264]
# Number of data points in this cluster: 5
#
# Cluster 111:
# Indices of data points: [192, 291, 297, 348, 452, 662, 1326]
# Number of data points in this cluster: 7
#
# Cluster 42:
# Indices of data points: [193, 385, 436, 564, 637, 1014, 1126]
# Number of data points in this cluster: 7
#
# Cluster 212:
# Indices of data points: [194, 401, 496, 821]
# Number of data points in this cluster: 4
#
# Cluster 58:
# Indices of data points: [196, 229, 383, 419, 509, 651, 1004]
# Number of data points in this cluster: 7
#
# Cluster 223:
# Indices of data points: [198, 374, 397, 435, 782, 1009, 1115, 1209]
# Number of data points in this cluster: 8
#
# Cluster 202:
# Indices of data points: [199, 310, 510, 1210, 1213, 1307, 1500]
# Number of data points in this cluster: 7
#
# Cluster 177:
# Indices of data points: [202, 1229, 1563]
# Number of data points in this cluster: 3
#
# Cluster 56:
# Indices of data points: [203, 501, 519, 583, 1037, 1074, 1128, 1144, 1174]
# Number of data points in this cluster: 9
#
# Cluster 89:
# Indices of data points: [210, 609, 701, 751, 762, 977]
# Number of data points in this cluster: 6
#
# Cluster 37:
# Indices of data points: [211, 327, 478, 654, 742, 747, 801, 1021, 1120, 1496]
# Number of data points in this cluster: 10
#
# Cluster 123:
# Indices of data points: [212, 420, 597, 1537]
# Number of data points in this cluster: 4
#
# Cluster 35:
# Indices of data points: [213, 363, 445, 446, 606, 646, 1109, 1290]
# Number of data points in this cluster: 8
#
# Cluster 49:
# Indices of data points: [214, 259, 391, 619, 644, 661, 971, 1198, 1205, 1224]
# Number of data points in this cluster: 10
#
# Cluster 69:
# Indices of data points: [215, 246, 283, 364]
# Number of data points in this cluster: 4
#
# Cluster 160:
# Indices of data points: [217, 272, 274, 346]
# Number of data points in this cluster: 4
#
# Cluster 86:
# Indices of data points: [222, 296, 543, 572, 979, 1335, 1443, 1559]
# Number of data points in this cluster: 8
#
# Cluster 20:
# Indices of data points: [223, 228, 337, 340, 853, 1584]
# Number of data points in this cluster: 6
#
# Cluster 80:
# Indices of data points: [224, 308, 350, 418, 438, 581, 1197]
# Number of data points in this cluster: 7
#
# Cluster 207:
# Indices of data points: [226, 263, 275, 334]
# Number of data points in this cluster: 4
#
# Cluster 71:
# Indices of data points: [227, 357, 423, 948, 1024, 1083, 1106, 1164, 1538, 1568]
# Number of data points in this cluster: 10
#
# Cluster 5:
# Indices of data points: [230, 347, 402, 406, 595, 611, 1062, 1135, 1160, 1597]
# Number of data points in this cluster: 10
#
# Cluster 90:
# Indices of data points: [231, 634, 687, 752, 993, 1085, 1145, 1146]
# Number of data points in this cluster: 8
#
# Cluster 140:
# Indices of data points: [233, 844, 992, 1011, 1433, 1480]
# Number of data points in this cluster: 6
#
# Cluster 206:
# Indices of data points: [235, 585, 656, 1604]
# Number of data points in this cluster: 4
#
# Cluster 189:
# Indices of data points: [236, 468, 469, 614, 1168]
# Number of data points in this cluster: 5
#
# Cluster 241:
# Indices of data points: [238]
# Number of data points in this cluster: 1
#
# Cluster 19:
# Indices of data points: [241, 257, 271, 330]
# Number of data points in this cluster: 4
#
# Cluster 1:
# Indices of data points: [243, 328, 398, 405, 591, 638, 715, 1090, 1188]
# Number of data points in this cluster: 9
#
# Cluster 57:
# Indices of data points: [247, 503, 697, 728, 731, 763, 1176, 1261]
# Number of data points in this cluster: 8
#
# Cluster 222:
# Indices of data points: [249, 592, 756, 789, 1035, 1178]
# Number of data points in this cluster: 6
#
# Cluster 43:
# Indices of data points: [250, 302, 447, 667, 1098, 1121, 1134]
# Number of data points in this cluster: 7
#
# Cluster 227:
# Indices of data points: [251, 284, 434, 442, 1093, 1095, 1273, 1581]
# Number of data points in this cluster: 8
#
# Cluster 112:
# Indices of data points: [254, 269, 270, 365, 1598]
# Number of data points in this cluster: 5
#
# Cluster 182:
# Indices of data points: [255, 377, 779]
# Number of data points in this cluster: 3
#
# Cluster 18:
# Indices of data points: [256, 341, 536, 558, 642, 676, 679, 1116, 1129, 1148, 1163, 1170]
# Number of data points in this cluster: 12
#
# Cluster 155:
# Indices of data points: [262, 439, 648, 1123]
# Number of data points in this cluster: 4
#
# Cluster 154:
# Indices of data points: [276, 456, 476, 980, 1158, 1371]
# Number of data points in this cluster: 6
#
# Cluster 183:
# Indices of data points: [277, 919, 976, 1067, 1582, 1588]
# Number of data points in this cluster: 6
#
# Cluster 12:
# Indices of data points: [286, 381, 441, 451, 612, 641, 1130]
# Number of data points in this cluster: 7
#
# Cluster 77:
# Indices of data points: [304, 314, 437, 1138, 1179, 1231, 1350]
# Number of data points in this cluster: 7
#
# Cluster 116:
# Indices of data points: [305, 342, 473, 495, 537, 663, 669, 997, 1127, 1258, 1356, 1578]
# Number of data points in this cluster: 12
#
# Cluster 101:
# Indices of data points: [306, 927, 945, 1050, 1155, 1470]
# Number of data points in this cluster: 6
#
# Cluster 139:
# Indices of data points: [307, 535, 1139, 1548]
# Number of data points in this cluster: 4
#
# Cluster 74:
# Indices of data points: [309, 421, 518, 685, 883]
# Number of data points in this cluster: 5
#
# Cluster 213:
# Indices of data points: [311, 367, 413, 600, 657, 1377]
# Number of data points in this cluster: 6
#
# Cluster 199:
# Indices of data points: [312, 1526]
# Number of data points in this cluster: 2
#
# Cluster 113:
# Indices of data points: [313, 388, 698, 713, 730, 965, 969, 1486]
# Number of data points in this cluster: 8
#
# Cluster 76:
# Indices of data points: [319, 556, 626]
# Number of data points in this cluster: 3
#
# Cluster 47:
# Indices of data points: [321, 665, 716, 871, 877, 928, 960, 1100, 1212, 1399, 1469, 1527, 1546, 1579]
# Number of data points in this cluster: 14
#
# Cluster 68:
# Indices of data points: [326, 411, 472, 616, 737, 900, 1054, 1389]
# Number of data points in this cluster: 8
#
# Cluster 129:
# Indices of data points: [329, 1183, 1225, 1532]
# Number of data points in this cluster: 4
#
# Cluster 134:
# Indices of data points: [333, 914, 941, 998, 1320, 1573]
# Number of data points in this cluster: 6
#
# Cluster 55:
# Indices of data points: [339, 449, 459, 500, 623, 633, 678, 1025, 1342]
# Number of data points in this cluster: 9
#
# Cluster 211:
# Indices of data points: [352, 1016, 1201]
# Number of data points in this cluster: 3
#
# Cluster 135:
# Indices of data points: [366, 879, 968, 1357]
# Number of data points in this cluster: 4
#
# Cluster 216:
# Indices of data points: [368, 482, 1191]
# Number of data points in this cluster: 3
#
# Cluster 168:
# Indices of data points: [371, 709, 949, 1087, 1172, 1560]
# Number of data points in this cluster: 6
#
# Cluster 83:
# Indices of data points: [378, 455, 768, 778, 975, 1279, 1589]
# Number of data points in this cluster: 7
#
# Cluster 105:
# Indices of data points: [380, 544, 668, 830]
# Number of data points in this cluster: 4
#
# Cluster 218:
# Indices of data points: [384, 485, 528, 580, 1263]
# Number of data points in this cluster: 5
#
# Cluster 169:
# Indices of data points: [390, 566, 673, 1131, 1239]
# Number of data points in this cluster: 5
#
# Cluster 3:
# Indices of data points: [392, 422, 511, 533, 547, 563, 596, 622, 693, 787, 996, 1097, 1221, 1551, 1554, 1561]
# Number of data points in this cluster: 16
#
# Cluster 217:
# Indices of data points: [395, 880, 953, 1271]
# Number of data points in this cluster: 4
#
# Cluster 17:
# Indices of data points: [399, 471, 788, 804, 843, 859, 1192, 1278, 1367, 1467, 1472, 1570]
# Number of data points in this cluster: 12
#
# Cluster 235:
# Indices of data points: [400, 408, 560, 773, 1366]
# Number of data points in this cluster: 5
#
# Cluster 141:
# Indices of data points: [403, 521, 526, 691]
# Number of data points in this cluster: 4
#
# Cluster 148:
# Indices of data points: [404, 708, 1137, 1533]
# Number of data points in this cluster: 4
#
# Cluster 192:
# Indices of data points: [412, 628, 714, 1332]
# Number of data points in this cluster: 4
#
# Cluster 157:
# Indices of data points: [416, 487, 522, 719, 842, 874, 978]
# Number of data points in this cluster: 7
#
# Cluster 92:
# Indices of data points: [454, 502, 1047, 1177, 1180]
# Number of data points in this cluster: 5
#
# Cluster 197:
# Indices of data points: [458, 531, 539, 748, 1105]
# Number of data points in this cluster: 5
#
# Cluster 121:
# Indices of data points: [462, 491, 494, 569, 1152, 1218, 1283, 1327, 1556]
# Number of data points in this cluster: 9
#
# Cluster 7:
# Indices of data points: [463, 760, 989, 1020, 1042]
# Number of data points in this cluster: 5
#
# Cluster 107:
# Indices of data points: [464, 562, 571, 863, 1114, 1391]
# Number of data points in this cluster: 6
#
# Cluster 234:
# Indices of data points: [465, 1240, 1262]
# Number of data points in this cluster: 3
#
# Cluster 95:
# Indices of data points: [479, 885, 1112, 1293, 1331, 1337, 1528]
# Number of data points in this cluster: 7
#
# Cluster 110:
# Indices of data points: [488, 755, 1108, 1222]
# Number of data points in this cluster: 4
#
# Cluster 231:
# Indices of data points: [490, 523, 834]
# Number of data points in this cluster: 3
#
# Cluster 108:
# Indices of data points: [492, 525, 589, 764, 921, 934, 1577]
# Number of data points in this cluster: 7
#
# Cluster 79:
# Indices of data points: [505, 512, 593, 839, 970, 988, 1169, 1545, 1587]
# Number of data points in this cluster: 9
#
# Cluster 164:
# Indices of data points: [513, 573, 574, 650, 734]
# Number of data points in this cluster: 5
#
# Cluster 228:
# Indices of data points: [514, 517, 1185]
# Number of data points in this cluster: 3
#
# Cluster 52:
# Indices of data points: [532, 553, 554, 643, 682, 881, 940, 1000, 1027, 1044, 1241, 1301, 1303, 1344]
# Number of data points in this cluster: 14
#
# Cluster 100:
# Indices of data points: [534, 601, 1611]
# Number of data points in this cluster: 3
#
# Cluster 81:
# Indices of data points: [541, 759, 1018, 1099, 1119, 1154, 1217]
# Number of data points in this cluster: 7
#
# Cluster 99:
# Indices of data points: [604, 758, 951, 1499]
# Number of data points in this cluster: 4
#
# Cluster 126:
# Indices of data points: [618, 696, 1324, 1610]
# Number of data points in this cluster: 4
#
# Cluster 97:
# Indices of data points: [640, 942, 1358, 1474, 1540]
# Number of data points in this cluster: 5
#
# Cluster 109:
# Indices of data points: [677, 776, 822, 1194, 1247, 1529]
# Number of data points in this cluster: 6
#
# Cluster 181:
# Indices of data points: [712, 717, 1094, 1509]
# Number of data points in this cluster: 4
#
# Cluster 102:
# Indices of data points: [724, 816, 957, 1234, 1351, 1394, 1400, 1440, 1513, 1531]
# Number of data points in this cluster: 10
#
# Cluster 201:
# Indices of data points: [727, 1056, 1596]
# Number of data points in this cluster: 3
#
# Cluster 84:
# Indices of data points: [741, 744, 1019, 1022, 1101, 1167, 1317, 1530]
# Number of data points in this cluster: 8
#
# Cluster 146:
# Indices of data points: [766, 806, 820, 855, 858, 923]
# Number of data points in this cluster: 6
#
# Cluster 132:
# Indices of data points: [770, 780, 792]
# Number of data points in this cluster: 3
#
# Cluster 27:
# Indices of data points: [791, 793, 795]
# Number of data points in this cluster: 3
#
# Cluster 232:
# Indices of data points: [798, 817, 1032]
# Number of data points in this cluster: 3
#
# Cluster 230:
# Indices of data points: [808, 907, 931, 1063, 1415, 1547]
# Number of data points in this cluster: 6
#
# Cluster 82:
# Indices of data points: [825, 909, 912, 915, 937, 1352, 1362, 1384, 1441, 1481, 1600]
# Number of data points in this cluster: 11
#
# Cluster 220:
# Indices of data points: [835, 926, 1078, 1310, 1372, 1501]
# Number of data points in this cluster: 6
#
# Cluster 236:
# Indices of data points: [836, 860, 1276, 1387, 1491]
# Number of data points in this cluster: 5
#
# Cluster 41:
# Indices of data points: [846, 848, 904, 1039, 1046, 1057, 1111, 1369, 1375, 1504]
# Number of data points in this cluster: 10
#
# Cluster 117:
# Indices of data points: [866, 886, 1227, 1259, 1515]
# Number of data points in this cluster: 5
#
# Cluster 88:
# Indices of data points: [884, 924, 1096, 1256, 1270, 1522]
# Number of data points in this cluster: 6
#
# Cluster 166:
# Indices of data points: [896, 932, 1208, 1325, 1422, 1475, 1482]
# Number of data points in this cluster: 7
#
# Cluster 170:
# Indices of data points: [899, 961, 967, 1040, 1122, 1187]
# Number of data points in this cluster: 6
#
# Cluster 190:
# Indices of data points: [903]
# Number of data points in this cluster: 1
#
# Cluster 158:
# Indices of data points: [916, 1089, 1380, 1497]
# Number of data points in this cluster: 4
#
# Cluster 163:
# Indices of data points: [920, 1010, 1069, 1395]
# Number of data points in this cluster: 4
#
# Cluster 85:
# Indices of data points: [938, 1195, 1286, 1360]
# Number of data points in this cluster: 4
#
# Cluster 118:
# Indices of data points: [1092, 1171, 1583]
# Number of data points in this cluster: 3
#
# Cluster 175:
# Indices of data points: [1102, 1249, 1503]
# Number of data points in this cluster: 3
#
# Cluster 240:
# Indices of data points: [1165, 1603]
# Number of data points in this cluster: 2
#
# Cluster 120:
# Indices of data points: [1553]
# Number of data points in this cluster: 1

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters = 242  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Function to get the keyframe index (centroid-based approach)
def get_keyframe_for_cluster(cluster_indices):
    # Extract the features for the current cluster
    cluster_features = features_scaled[cluster_indices]
    
    # Compute the centroid of the cluster (mean of the features)
    centroid = np.mean(cluster_features, axis=0)
    
    # Calculate the distance from each point to the centroid
    distances = cdist([centroid], cluster_features)
    
    # Get the index of the point closest to the centroid
    keyframe_index = cluster_indices[np.argmin(distances)]
    return keyframe_index

# Generate and display the sequence of keyframe indices for each cluster
keyframe_sequence = []

for cluster_label, indices in cluster_dict.items():
    keyframe_index = get_keyframe_for_cluster(indices)
    keyframe_sequence.append((cluster_label, keyframe_index))

# Print the sequence of keyframes in the desired format
for cluster_label, keyframe_index in keyframe_sequence:
    print(f"Cluster {cluster_label}: Keyframe index: {keyframe_index}")
# Out:
# Cluster 64: Keyframe index: 0
# Cluster 15: Keyframe index: 1405
# Cluster 204: Keyframe index: 796
# Cluster 127: Keyframe index: 893
# Cluster 25: Keyframe index: 1567
# Cluster 8: Keyframe index: 5
# Cluster 9: Keyframe index: 375
# Cluster 34: Keyframe index: 7
# Cluster 46: Keyframe index: 185
# Cluster 130: Keyframe index: 1030
# Cluster 54: Keyframe index: 1447
# Cluster 191: Keyframe index: 683
# Cluster 45: Keyframe index: 175
# Cluster 104: Keyframe index: 831
# Cluster 145: Keyframe index: 16
# Cluster 6: Keyframe index: 17
# Cluster 60: Keyframe index: 670
# Cluster 209: Keyframe index: 1346
# Cluster 188: Keyframe index: 901
# Cluster 67: Keyframe index: 769
# Cluster 14: Keyframe index: 1013
# Cluster 38: Keyframe index: 621
# Cluster 176: Keyframe index: 1574
# Cluster 32: Keyframe index: 655
# Cluster 173: Keyframe index: 29
# Cluster 215: Keyframe index: 786
# Cluster 221: Keyframe index: 31
# Cluster 165: Keyframe index: 1268
# Cluster 11: Keyframe index: 579
# Cluster 198: Keyframe index: 34
# Cluster 136: Keyframe index: 1468
# Cluster 59: Keyframe index: 301
# Cluster 208: Keyframe index: 1070
# Cluster 2: Keyframe index: 138
# Cluster 233: Keyframe index: 1363
# Cluster 214: Keyframe index: 45
# Cluster 98: Keyframe index: 1033
# Cluster 28: Keyframe index: 147
# Cluster 44: Keyframe index: 429
# Cluster 239: Keyframe index: 1257
# Cluster 142: Keyframe index: 1330
# Cluster 48: Keyframe index: 690
# Cluster 153: Keyframe index: 867
# Cluster 159: Keyframe index: 54
# Cluster 185: Keyframe index: 118
# Cluster 195: Keyframe index: 57
# Cluster 149: Keyframe index: 351
# Cluster 119: Keyframe index: 59
# Cluster 162: Keyframe index: 209
# Cluster 138: Keyframe index: 605
# Cluster 36: Keyframe index: 204
# Cluster 124: Keyframe index: 1558
# Cluster 172: Keyframe index: 65
# Cluster 122: Keyframe index: 551
# Cluster 156: Keyframe index: 178
# Cluster 151: Keyframe index: 630
# Cluster 137: Keyframe index: 861
# Cluster 61: Keyframe index: 1026
# Cluster 72: Keyframe index: 1309
# Cluster 167: Keyframe index: 711
# Cluster 31: Keyframe index: 1206
# Cluster 13: Keyframe index: 1068
# Cluster 91: Keyframe index: 956
# Cluster 131: Keyframe index: 280
# Cluster 178: Keyframe index: 1207
# Cluster 203: Keyframe index: 81
# Cluster 29: Keyframe index: 264
# Cluster 70: Keyframe index: 1080
# Cluster 205: Keyframe index: 1161
# Cluster 16: Keyframe index: 157
# Cluster 186: Keyframe index: 358
# Cluster 75: Keyframe index: 1521
# Cluster 24: Keyframe index: 1077
# Cluster 22: Keyframe index: 376
# Cluster 51: Keyframe index: 216
# Cluster 106: Keyframe index: 466
# Cluster 87: Keyframe index: 575
# Cluster 144: Keyframe index: 1181
# Cluster 78: Keyframe index: 695
# Cluster 30: Keyframe index: 761
# Cluster 103: Keyframe index: 856
# Cluster 39: Keyframe index: 743
# Cluster 128: Keyframe index: 1607
# Cluster 65: Keyframe index: 1361
# Cluster 196: Keyframe index: 123
# Cluster 94: Keyframe index: 1609
# Cluster 26: Keyframe index: 726
# Cluster 179: Keyframe index: 897
# Cluster 93: Keyframe index: 120
# Cluster 33: Keyframe index: 1280
# Cluster 225: Keyframe index: 749
# Cluster 115: Keyframe index: 1347
# Cluster 161: Keyframe index: 1437
# Cluster 194: Keyframe index: 1058
# Cluster 187: Keyframe index: 990
# Cluster 62: Keyframe index: 131
# Cluster 150: Keyframe index: 133
# Cluster 200: Keyframe index: 1199
# Cluster 152: Keyframe index: 962
# Cluster 125: Keyframe index: 1015
# Cluster 53: Keyframe index: 159
# Cluster 238: Keyframe index: 746
# Cluster 66: Keyframe index: 689
# Cluster 10: Keyframe index: 148
# Cluster 174: Keyframe index: 149
# Cluster 147: Keyframe index: 219
# Cluster 0: Keyframe index: 570
# Cluster 63: Keyframe index: 1580
# Cluster 237: Keyframe index: 154
# Cluster 226: Keyframe index: 1248
# Cluster 114: Keyframe index: 1103
# Cluster 21: Keyframe index: 303
# Cluster 193: Keyframe index: 164
# Cluster 171: Keyframe index: 1593
# Cluster 96: Keyframe index: 890
# Cluster 210: Keyframe index: 984
# Cluster 23: Keyframe index: 1150
# Cluster 4: Keyframe index: 268
# Cluster 40: Keyframe index: 387
# Cluster 73: Keyframe index: 1202
# Cluster 180: Keyframe index: 721
# Cluster 143: Keyframe index: 356
# Cluster 219: Keyframe index: 182
# Cluster 133: Keyframe index: 550
# Cluster 50: Keyframe index: 702
# Cluster 229: Keyframe index: 1220
# Cluster 184: Keyframe index: 370
# Cluster 224: Keyframe index: 1264
# Cluster 111: Keyframe index: 1326
# Cluster 42: Keyframe index: 193
# Cluster 212: Keyframe index: 401
# Cluster 58: Keyframe index: 651
# Cluster 223: Keyframe index: 198
# Cluster 202: Keyframe index: 510
# Cluster 177: Keyframe index: 1229
# Cluster 56: Keyframe index: 519
# Cluster 89: Keyframe index: 210
# Cluster 37: Keyframe index: 747
# Cluster 123: Keyframe index: 420
# Cluster 35: Keyframe index: 363
# Cluster 49: Keyframe index: 971
# Cluster 69: Keyframe index: 364
# Cluster 160: Keyframe index: 346
# Cluster 86: Keyframe index: 1335
# Cluster 20: Keyframe index: 340
# Cluster 80: Keyframe index: 350
# Cluster 207: Keyframe index: 275
# Cluster 71: Keyframe index: 357
# Cluster 5: Keyframe index: 347
# Cluster 90: Keyframe index: 1085
# Cluster 140: Keyframe index: 844
# Cluster 206: Keyframe index: 1604
# Cluster 189: Keyframe index: 468
# Cluster 241: Keyframe index: 238
# Cluster 19: Keyframe index: 330
# Cluster 1: Keyframe index: 1188
# Cluster 57: Keyframe index: 728
# Cluster 222: Keyframe index: 1035
# Cluster 43: Keyframe index: 1134
# Cluster 227: Keyframe index: 251
# Cluster 112: Keyframe index: 1598
# Cluster 182: Keyframe index: 377
# Cluster 18: Keyframe index: 679
# Cluster 155: Keyframe index: 439
# Cluster 154: Keyframe index: 276
# Cluster 183: Keyframe index: 976
# Cluster 12: Keyframe index: 612
# Cluster 77: Keyframe index: 1350
# Cluster 116: Keyframe index: 663
# Cluster 101: Keyframe index: 945
# Cluster 139: Keyframe index: 535
# Cluster 74: Keyframe index: 309
# Cluster 213: Keyframe index: 367
# Cluster 199: Keyframe index: 1526
# Cluster 113: Keyframe index: 969
# Cluster 76: Keyframe index: 626
# Cluster 47: Keyframe index: 1527
# Cluster 68: Keyframe index: 737
# Cluster 129: Keyframe index: 329
# Cluster 134: Keyframe index: 941
# Cluster 55: Keyframe index: 1025
# Cluster 211: Keyframe index: 1016
# Cluster 135: Keyframe index: 879
# Cluster 216: Keyframe index: 368
# Cluster 168: Keyframe index: 949
# Cluster 83: Keyframe index: 778
# Cluster 105: Keyframe index: 380
# Cluster 218: Keyframe index: 384
# Cluster 169: Keyframe index: 1131
# Cluster 3: Keyframe index: 533
# Cluster 217: Keyframe index: 1271
# Cluster 17: Keyframe index: 843
# Cluster 235: Keyframe index: 400
# Cluster 141: Keyframe index: 403
# Cluster 148: Keyframe index: 708
# Cluster 192: Keyframe index: 714
# Cluster 157: Keyframe index: 416
# Cluster 92: Keyframe index: 454
# Cluster 197: Keyframe index: 539
# Cluster 121: Keyframe index: 491
# Cluster 7: Keyframe index: 463
# Cluster 107: Keyframe index: 464
# Cluster 234: Keyframe index: 1240
# Cluster 95: Keyframe index: 1293
# Cluster 110: Keyframe index: 1108
# Cluster 231: Keyframe index: 834
# Cluster 108: Keyframe index: 525
# Cluster 79: Keyframe index: 839
# Cluster 164: Keyframe index: 574
# Cluster 228: Keyframe index: 1185
# Cluster 52: Keyframe index: 643
# Cluster 100: Keyframe index: 534
# Cluster 81: Keyframe index: 1154
# Cluster 99: Keyframe index: 951
# Cluster 126: Keyframe index: 1610
# Cluster 97: Keyframe index: 1540
# Cluster 109: Keyframe index: 1247
# Cluster 181: Keyframe index: 1509
# Cluster 102: Keyframe index: 1531
# Cluster 201: Keyframe index: 1596
# Cluster 84: Keyframe index: 1101
# Cluster 146: Keyframe index: 923
# Cluster 132: Keyframe index: 780
# Cluster 27: Keyframe index: 795
# Cluster 232: Keyframe index: 798
# Cluster 230: Keyframe index: 931
# Cluster 82: Keyframe index: 912
# Cluster 220: Keyframe index: 835
# Cluster 236: Keyframe index: 1387
# Cluster 41: Keyframe index: 1375
# Cluster 117: Keyframe index: 886
# Cluster 88: Keyframe index: 924
# Cluster 166: Keyframe index: 1325
# Cluster 170: Keyframe index: 1040
# Cluster 190: Keyframe index: 903
# Cluster 158: Keyframe index: 1497
# Cluster 163: Keyframe index: 920
# Cluster 85: Keyframe index: 938
# Cluster 118: Keyframe index: 1583
# Cluster 175: Keyframe index: 1249
# Cluster 240: Keyframe index: 1165
# Cluster 120: Keyframe index: 1553

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist
from scipy.io import savemat  # Import savemat to save in .mat format
import pandas as pd  # Import pandas for CSV file export

# Load the LSTM features from the .npy file
lstm_features = np.load(r"C:\SumMe\Augmentation\Augf\features_last_lstm.npy")

# Flatten LSTM features for clustering (if necessary)
n_samples = lstm_features.shape[0]  # Define the number of samples
n_clusters = 242  # Set the number of clusters
lstm_features_flattened = lstm_features.reshape(n_samples, -1)

# Standardizing the data before clustering
scaler = StandardScaler()
lstm_features_scaled = scaler.fit_transform(lstm_features_flattened)

# Apply Agglomerative Clustering with 'ward' linkage (no need to specify affinity)
agg_clustering = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
labels = agg_clustering.fit_predict(lstm_features_scaled)

# Group data points by cluster
clustered_data = {}

for idx, label in enumerate(labels):
    if label not in clustered_data:
        clustered_data[label] = []
    clustered_data[label].append(idx)

# Find keyframe for each cluster
keyframes = {}

for cluster_id, indices in clustered_data.items():
    # Get the feature vectors for the data points in this cluster
    cluster_features = lstm_features_scaled[indices]
    
    # Compute the centroid of the cluster (average of all feature vectors in the cluster)
    centroid = np.mean(cluster_features, axis=0)
    
    # Compute the Euclidean distance from each data point to the centroid
    distances = cdist(cluster_features, [centroid], metric='euclidean')
    
    # Find the index of the closest data point (keyframe)
    keyframe_idx = indices[np.argmin(distances)]
    
    # Store the keyframe index for the cluster
    keyframes[cluster_id] = keyframe_idx

# Create a binary matrix of shape (n_samples, n_clusters)
keyframe_matrix = np.zeros((n_samples, n_clusters), dtype=int)

# Mark the keyframes (set the corresponding index to 1)
for cluster_id, keyframe_idx in keyframes.items():
    keyframe_matrix[keyframe_idx, cluster_id] = 1

# Save the keyframe binary matrix as a .mat file
keyframe_data = {'keyframe_matrix': keyframe_matrix}  # Create a dictionary to save in .mat format
savemat(r'C:\SumMe\Augmentation\Augf\features_last_lstm1.mat', keyframe_data)

# Print confirmation for .mat file
print(f"Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.mat")
print(f"Dimensions of the keyframe binary matrix: {keyframe_matrix.shape}")

# Save the keyframe binary matrix as a .csv file
keyframe_matrix_df = pd.DataFrame(keyframe_matrix)  # Convert matrix to DataFrame
keyframe_matrix_df.to_csv(r'C:\SumMe\Augmentation\Augf\features_last_lstm1.csv', index=False)

# Print confirmation for .csv file
print(f"Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.csv")

# Print the sequence of keyframe indices in order of cluster numbers (Cluster 0, Cluster 1, ..., Cluster n)
print("\nKeyframe indices for each cluster:")
for cluster_id in range(n_clusters):
    if cluster_id in keyframes:
        print(f"Cluster {cluster_id}: Keyframe Index {keyframes[cluster_id]}")
    else:
        print(f"Cluster {cluster_id}: No keyframe found")
# Out:
# Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.mat
# Dimensions of the keyframe binary matrix: (1612, 242)
# Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.csv
#
# Keyframe indices for each cluster:
# Cluster 0: Keyframe Index 570
# Cluster 1: Keyframe Index 1188
# Cluster 2: Keyframe Index 138
# Cluster 3: Keyframe Index 533
# Cluster 4: Keyframe Index 268
# Cluster 5: Keyframe Index 347
# Cluster 6: Keyframe Index 17
# Cluster 7: Keyframe Index 463
# Cluster 8: Keyframe Index 5
# Cluster 9: Keyframe Index 375
# Cluster 10: Keyframe Index 148
# Cluster 11: Keyframe Index 579
# Cluster 12: Keyframe Index 612
# Cluster 13: Keyframe Index 1068
# Cluster 14: Keyframe Index 1013
# Cluster 15: Keyframe Index 1405
# Cluster 16: Keyframe Index 157
# Cluster 17: Keyframe Index 843
# Cluster 18: Keyframe Index 679
# Cluster 19: Keyframe Index 330
# Cluster 20: Keyframe Index 340
# Cluster 21: Keyframe Index 303
# Cluster 22: Keyframe Index 376
# Cluster 23: Keyframe Index 1150
# Cluster 24: Keyframe Index 1077
# Cluster 25: Keyframe Index 1567
# Cluster 26: Keyframe Index 726
# Cluster 27: Keyframe Index 795
# Cluster 28: Keyframe Index 147
# Cluster 29: Keyframe Index 264
# Cluster 30: Keyframe Index 761
# Cluster 31: Keyframe Index 1206
# Cluster 32: Keyframe Index 655
# Cluster 33: Keyframe Index 1280
# Cluster 34: Keyframe Index 7
# Cluster 35: Keyframe Index 363
# Cluster 36: Keyframe Index 204
# Cluster 37: Keyframe Index 747
# Cluster 38: Keyframe Index 621
# Cluster 39: Keyframe Index 743
# Cluster 40: Keyframe Index 387
# Cluster 41: Keyframe Index 1375
# Cluster 42: Keyframe Index 193
# Cluster 43: Keyframe Index 1134
# Cluster 44: Keyframe Index 429
# Cluster 45: Keyframe Index 175
# Cluster 46: Keyframe Index 185
# Cluster 47: Keyframe Index 1527
# Cluster 48: Keyframe Index 690
# Cluster 49: Keyframe Index 971
# Cluster 50: Keyframe Index 702
# Cluster 51: Keyframe Index 216
# Cluster 52: Keyframe Index 643
# Cluster 53: Keyframe Index 159
# Cluster 54: Keyframe Index 1447
# Cluster 55: Keyframe Index 1025
# Cluster 56: Keyframe Index 519
# Cluster 57: Keyframe Index 728
# Cluster 58: Keyframe Index 651
# Cluster 59: Keyframe Index 301
# Cluster 60: Keyframe Index 670
# Cluster 61: Keyframe Index 1026
# Cluster 62: Keyframe Index 131
# Cluster 63: Keyframe Index 1580
# Cluster 64: Keyframe Index 0
# Cluster 65: Keyframe Index 1361
# Cluster 66: Keyframe Index 689
# Cluster 67: Keyframe Index 769
# Cluster 68: Keyframe Index 737
# Cluster 69: Keyframe Index 364
# Cluster 70: Keyframe Index 1080
# Cluster 71: Keyframe Index 357
# Cluster 72: Keyframe Index 1309
# Cluster 73: Keyframe Index 1202
# Cluster 74: Keyframe Index 309
# Cluster 75: Keyframe Index 1521
# Cluster 76: Keyframe Index 626
# Cluster 77: Keyframe Index 1350
# Cluster 78: Keyframe Index 695
# Cluster 79: Keyframe Index 839
# Cluster 80: Keyframe Index 350
# Cluster 81: Keyframe Index 1154
# Cluster 82: Keyframe Index 912
# Cluster 83: Keyframe Index 778
# Cluster 84: Keyframe Index 1101
# Cluster 85: Keyframe Index 938
# Cluster 86: Keyframe Index 1335
# Cluster 87: Keyframe Index 575
# Cluster 88: Keyframe Index 924
# Cluster 89: Keyframe Index 210
# Cluster 90: Keyframe Index 1085
# Cluster 91: Keyframe Index 956
# Cluster 92: Keyframe Index 454
# Cluster 93: Keyframe Index 120
# Cluster 94: Keyframe Index 1609
# Cluster 95: Keyframe Index 1293
# Cluster 96: Keyframe Index 890
# Cluster 97: Keyframe Index 1540
# Cluster 98: Keyframe Index 1033
# Cluster 99: Keyframe Index 951
# Cluster 100: Keyframe Index 534
# Cluster 101: Keyframe Index 945
# Cluster 102: Keyframe Index 1531
# Cluster 103: Keyframe Index 856
# Cluster 104: Keyframe Index 831
# Cluster 105: Keyframe Index 380
# Cluster 106: Keyframe Index 466
# Cluster 107: Keyframe Index 464
# Cluster 108: Keyframe Index 525
# Cluster 109: Keyframe Index 1247
# Cluster 110: Keyframe Index 1108
# Cluster 111: Keyframe Index 1326
# Cluster 112: Keyframe Index 1598
# Cluster 113: Keyframe Index 969
# Cluster 114: Keyframe Index 1103
# Cluster 115: Keyframe Index 1347
# Cluster 116: Keyframe Index 663
# Cluster 117: Keyframe Index 886
# Cluster 118: Keyframe Index 1583
# Cluster 119: Keyframe Index 59
# Cluster 120: Keyframe Index 1553
# Cluster 121: Keyframe Index 491
# Cluster 122: Keyframe Index 551
# Cluster 123: Keyframe Index 420
# Cluster 124: Keyframe Index 1558
# Cluster 125: Keyframe Index 1015
# Cluster 126: Keyframe Index 1610
# Cluster 127: Keyframe Index 893
# Cluster 128: Keyframe Index 1607
# Cluster 129: Keyframe Index 329
# Cluster 130: Keyframe Index 1030
# Cluster 131: Keyframe Index 280
# Cluster 132: Keyframe Index 780
# Cluster 133: Keyframe Index 550
# Cluster 134: Keyframe Index 941
# Cluster 135: Keyframe Index 879
# Cluster 136: Keyframe Index 1468
# Cluster 137: Keyframe Index 861
# Cluster 138: Keyframe Index 605
# Cluster 139: Keyframe Index 535
# Cluster 140: Keyframe Index 844
# Cluster 141: Keyframe Index 403
# Cluster 142: Keyframe Index 1330
# Cluster 143: Keyframe Index 356
# Cluster 144: Keyframe Index 1181
# Cluster 145: Keyframe Index 16
# Cluster 146: Keyframe Index 923
# Cluster 147: Keyframe Index 219
# Cluster 148: Keyframe Index 708
# Cluster 149: Keyframe Index 351
# Cluster 150: Keyframe Index 133
# Cluster 151: Keyframe Index 630
# Cluster 152: Keyframe Index 962
# Cluster 153: Keyframe Index 867
# Cluster 154: Keyframe Index 276
# Cluster 155: Keyframe Index 439
# Cluster 156: Keyframe Index 178
# Cluster 157: Keyframe Index 416
# Cluster 158: Keyframe Index 1497
# Cluster 159: Keyframe Index 54
# Cluster 160: Keyframe Index 346
# Cluster 161: Keyframe Index 1437
# Cluster 162: Keyframe Index 209
# Cluster 163: Keyframe Index 920
# Cluster 164: Keyframe Index 574
# Cluster 165: Keyframe Index 1268
# Cluster 166: Keyframe Index 1325
# Cluster 167: Keyframe Index 711
# Cluster 168: Keyframe Index 949
# Cluster 169: Keyframe Index 1131
# Cluster 170: Keyframe Index 1040
# Cluster 171: Keyframe Index 1593
# Cluster 172: Keyframe Index 65
# Cluster 173: Keyframe Index 29
# Cluster 174: Keyframe Index 149
# Cluster 175: Keyframe Index 1249
# Cluster 176: Keyframe Index 1574
# Cluster 177: Keyframe Index 1229
# Cluster 178: Keyframe Index 1207
# Cluster 179: Keyframe Index 897
# Cluster 180: Keyframe Index 721
# Cluster 181: Keyframe Index 1509
# Cluster 182: Keyframe Index 377
# Cluster 183: Keyframe Index 976
# Cluster 184: Keyframe Index 370
# Cluster 185: Keyframe Index 118
# Cluster 186: Keyframe Index 358
# Cluster 187: Keyframe Index 990
# Cluster 188: Keyframe Index 901
# Cluster 189: Keyframe Index 468
# Cluster 190: Keyframe Index 903
# Cluster 191: Keyframe Index 683
# Cluster 192: Keyframe Index 714
# Cluster 193: Keyframe Index 164
# Cluster 194: Keyframe Index 1058
# Cluster 195: Keyframe Index 57
# Cluster 196: Keyframe Index 123
# Cluster 197: Keyframe Index 539
# Cluster 198: Keyframe Index 34
# Cluster 199: Keyframe Index 1526
# Cluster 200: Keyframe Index 1199
# Cluster 201: Keyframe Index 1596
# Cluster 202: Keyframe Index 510
# Cluster 203: Keyframe Index 81
# Cluster 204: Keyframe Index 796
# Cluster 205: Keyframe Index 1161
# Cluster 206: Keyframe Index 1604
# Cluster 207: Keyframe Index 275
# Cluster 208: Keyframe Index 1070
# Cluster 209: Keyframe Index 1346
# Cluster 210: Keyframe Index 984
# Cluster 211: Keyframe Index 1016
# Cluster 212: Keyframe Index 401
# Cluster 213: Keyframe Index 367
# Cluster 214: Keyframe Index 45
# Cluster 215: Keyframe Index 786
# Cluster 216: Keyframe Index 368
# Cluster 217: Keyframe Index 1271
# Cluster 218: Keyframe Index 384
# Cluster 219: Keyframe Index 182
# Cluster 220: Keyframe Index 835
# Cluster 221: Keyframe Index 31
# Cluster 222: Keyframe Index 1035
# Cluster 223: Keyframe Index 198
# Cluster 224: Keyframe Index 1264
# Cluster 225: Keyframe Index 749
# Cluster 226: Keyframe Index 1248
# Cluster 227: Keyframe Index 251
# Cluster 228: Keyframe Index 1185
# Cluster 229: Keyframe Index 1220
# Cluster 230: Keyframe Index 931
# Cluster 231: Keyframe Index 834
# Cluster 232: Keyframe Index 798
# Cluster 233: Keyframe Index 1363
# Cluster 234: Keyframe Index 1240
# Cluster 235: Keyframe Index 400
# Cluster 236: Keyframe Index 1387
# Cluster 237: Keyframe Index 154
# Cluster 238: Keyframe Index 746
# Cluster 239: Keyframe Index 1257
# Cluster 240: Keyframe Index 1165
# Cluster 241: Keyframe Index 238

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import scipy.io

# Step 1: Load the annotator labels from the .mat file
annotator_path = r"C:\SumMe\GT\Fire Domino.mat" # Path to the .mat file
mat_data = scipy.io.loadmat(annotator_path)

# Check the keys in the .mat file
print("Keys in the .mat file:", mat_data.keys())


user_scores = mat_data['user_score']  
print(f"Shape of user_score: {user_scores.shape}")

# Step 2: Load our model's predictions from the .csv file
our_path = r"C:\SumMe\Augmentation\Augf\features_last_lstm1.csv" # Path to the CSV file
u1 = pd.read_csv(our_path, header=None).values.flatten()  # Our model's predictions (binary array)


print(f"Shape of model's predictions (u1): {u1.shape}")

# Ensure that the length of u1 matches the number of rows in user_scores
if u1.shape[0] != user_scores.shape[0]:
    print(f"Warning: Mismatched lengths. Adjusting the data...")
    u1 = u1[:user_scores.shape[0]]  # Truncate u1 to match the number of rows in user_scores

# Step 3: Ensure both u1 and user_scores are binary (logical values, 0 or 1)
u1 = u1.astype(bool)

# Step 4: Compute the F1-Score for each of the 15 datasets (columns in user_scores)
f1_scores = []  # List to store F1 scores for each dataset

for i in range(user_scores.shape[1]):  # Loop through the 15 columns
    u2 = user_scores[:, i]  # Extract the i-th column (ground truth labels for the i-th dataset)
    
    # Ensure u2 is a boolean array
    u2 = u2.astype(bool)
    
    # Step 5: Compute the confusion matrix
    cm = confusion_matrix(u2, u1)
    
    # Extract the confusion matrix components
    tn, fp, fn, tp = cm.ravel()  # Unpack the confusion matrix
    
    # Debugging step: Print confusion matrix for the 4th column
    if i == 3:  # Checking the 4th column
        print(f"Confusion Matrix for user_score column {i+1} (4th column):")
        print(f"TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")
    
    # Check for zero denominators and calculate Precision, Recall, and F1-Score safely
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    
    # F1 Score is calculated if both precision and recall are non-zero, otherwise it's 0 or nan
    if precision + recall > 0:
        fscore = 2 * (precision * recall) / (precision + recall)
    else:
        fscore = 0.0  # F1 score is 0 if either precision or recall is zero
    
    f1_scores.append(fscore)  # Append F1 score for this dataset
    
    # Print the F1 Score for this dataset
    print(f"\nF1-Score for user_score column {i+1}: {fscore:.4f}")

# Step 6: Output all the F1 scores for the 15 datasets
print("\nAll F1 Scores:")
for i, score in enumerate(f1_scores, 1):
    print(f"F1 Score for user_score column {i}: {score:.4f}")
# Out:
# Keys in the .mat file: dict_keys(['__header__', '__version__', '__globals__', 'all_userIDs', 'segments', 'nFrames', 'video_duration', 'FPS', 'gt_score', 'user_score'])
# Shape of user_score: (1612, 15)
# Shape of model's predictions (u1): (390346,)
# Warning: Mismatched lengths. Adjusting the data...
#
# F1-Score for user_score column 1: 0.0000
#
# F1-Score for user_score column 2: 0.0464
#
# F1-Score for user_score column 3: 0.0000
# Confusion Matrix for user_score column 4 (4th column):
# TN: 1132, FP: 242, FN: 237, TP: 1
#
# F1-Score for user_score column 4: 0.0042
#
# F1-Score for user_score column 5: 0.0000
#
# F1-Score for user_score column 6: 0.0042
#
# F1-Score for user_score column 7: 0.0041
#
# F1-Score for user_score column 8: 0.0042
#
# F1-Score for user_score column 9: 0.0041
#
# F1-Score for user_score column 10: 0.0043
#
# F1-Score for user_score column 11: 0.0041
#
# F1-Score for user_score column 12: 0.0041
#
# F1-Score for user_score column 13: 0.0000
#
# F1-Score for user_score column 14: 0.0205
#
# F1-Score for user_score column 15: 0.0042
#
# All F1 Scores:
# F1 Score for user_score column 1: 0.0000
# F1 Score for user_score column 2: 0.0464
# F1 Score for user_score column 3: 0.0000
# F1 Score for user_score column 4: 0.0042
# F1 Score for user_score column 5: 0.0000
# F1 Score for user_score column 6: 0.0042
# F1 Score for user_score column 7: 0.0041
# F1 Score for user_score column 8: 0.0042
# F1 Score for user_score column 9: 0.0041
# F1 Score for user_score column 10: 0.0043
# F1 Score for user_score column 11: 0.0041
# F1 Score for user_score column 12: 0.0041
# F1 Score for user_score column 13: 0.0000
# F1 Score for user_score column 14: 0.0205
# F1 Score for user_score column 15: 0.0042
