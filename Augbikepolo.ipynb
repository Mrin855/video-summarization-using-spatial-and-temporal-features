# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os

# %%
import cv2 
import os

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def dataset_train_processing():
    # Hardcode dataset path
    data_path =r'C:\SumMe\Frame\Bike polo'
    augmented_data_path = r'C:\SumMe\Augmentation\AugBp\Aug'
    
    # Create the directory for augmented data if it doesn't exist
    if not os.path.exists(augmented_data_path):
        os.makedirs(augmented_data_path)
    
    # Process dataset
    file_names = os.listdir(data_path)
    
    # Set a datagenerator for augmentation
    train_datagen = ImageDataGenerator(rotation_range=15,
                                       shear_range=0.1,
                                       zoom_range=0.2,
                                       horizontal_flip=True,
                                       width_shift_range=0.1,
                                       height_shift_range=0.1)
    
    # Create batches of data for augmentation
    for file_name in file_names:
        image_path = os.path.join(data_path, file_name)
        img = plt.imread(image_path)
        img = img.reshape((1,) + img.shape)  # Reshape to add batch dimension
        
        # Flow the image through the generator and save augmented images
        i = 0
        for batch in train_datagen.flow(img, 
                                        batch_size=1,
                                        save_to_dir=augmented_data_path,
                                        save_prefix=f'aug_{os.path.splitext(file_name)[0]}',
                                        save_format='jpeg'):
            i += 1
            if i >= 1:  # Save 2 augmented versions of each image
                break
    
    # Sample visualization of augmented images (optional)
    example_gen = train_datagen.flow_from_directory(data_path,
                                                    target_size=(224, 224),
                                                    batch_size=1,
                                                    class_mode=None,
                                                    save_to_dir=augmented_data_path,
                                                    save_prefix='aug_example',
                                                    save_format='jpg')
    
    plt.figure(figsize=(12, 12))
    for i in range(0, 15):
        plt.subplot(5, 3, i + 1)
        for X in example_gen:
            image = X[0]
            plt.imshow(image)
            break
    plt.tight_layout()
    plt.show()

# Usage
dataset_train_processing()
# Out:
# Found 0 images belonging to 0 classes.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 58
#      55     plt.show()
#      57 # Usage
# ---> 58 dataset_train_processing()
#
# Cell In[4], line 51, in dataset_train_processing()
#      49 plt.subplot(5, 3, i + 1)
#      50 for X in example_gen:
# ---> 51     image = X[0]
#      52     plt.imshow(image)
#      53     break
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np
import os

# Load the InceptionV3 model
net = InceptionV3(include_top=True, weights='imagenet')
net.summary()

# Load images from directory using ImageDataGenerator
image_directory = r'C:\SumMe\Augmentation\AugBp'
input_size = net.input_shape[1:3]  # Get the input size (height, width)

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# Create a data generator for the images
augimds = datagen.flow_from_directory(image_directory,
                                      target_size=input_size,
                                      batch_size=32,  # Adjust the batch size if needed
                                      class_mode=None,
                                      shuffle=False) 

# Create a model that outputs the activations from the specified layer
layer_name = 'predictions'  # Example layer name in InceptionV3 (change as needed)
intermediate_layer_model = tf.keras.Model(inputs=net.input,
                                          outputs=net.get_layer(layer_name).output)

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Reshape the features to ensure they are in 'rows' format (2D)
features_train = features_train.reshape(features_train.shape[0], -1)
np.save(os.path.join(image_directory, 'inceptionv3_features_train.npy'), features_train)

print(f"Features shape: {features_train.shape}")

# Print some sample features
print("Sample features (first 5 rows):")
print(features_train[:5])
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_59[0][0]']
# ...
#  conv2d_77 (Conv2D)             (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 8, 8, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,851,784
# Trainable params: 23,817,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# Found 3064 images belonging to 1 classes.
# 96/96 [==============================] - 1151s 12s/step
# Features shape: (3064, 1000)
# Sample features (first 5 rows):
# [[1.00920768e-03 4.27961873e-04 1.08850724e-03 ... 1.56858601e-04
#   2.40773807e-04 8.70176475e-04]
#  [1.16452604e-04 1.31605440e-04 1.22265308e-04 ... 7.18086449e-05
#   5.53950435e-04 5.87393355e-04]
#  [7.35991198e-05 1.16421237e-04 7.07004510e-05 ... 1.96007968e-05
#   3.17039696e-04 7.06390187e-04]
#  [2.34282590e-04 3.19799699e-04 1.83641139e-04 ... 1.09110617e-04
#   5.06415381e-04 1.69779244e-03]
#  [1.12824047e-04 9.91819106e-05 1.54702997e-04 ... 4.08736232e-05
#   1.55255475e-04 2.28786070e-04]]

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os


# Load the ResNet50 model
net = ResNet50(include_top=True, weights='imagenet')
net.summary()

# Load images from directory using ImageDataGenerator
image_directory = r'C:\SumMe\Augmentation\AugBp'
input_size = net.input_shape[1:3]  # Get the input size (height, width)

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# Create a data generator for the images
augimds = datagen.flow_from_directory(image_directory,
                                      target_size=input_size,
                                      batch_size=32,  # Adjust the batch size if needed
                                      class_mode=None,
                                      shuffle=False) 

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Create a model that outputs the activations from the specified layer
layer_name = 'predictions'  # Example layer name in ResNet50
intermediate_layer_model = tf.keras.Model(inputs=net.input,
                                          outputs=net.get_layer(layer_name).output)

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Reshape the features to ensure they are in 'rows' format (2D)
features_train = features_train.reshape(features_train.shape[0], -1)
np.save(os.path.join(image_directory, 'resnet50_features_train.npy'), features_train)


print(f"Features shape: {features_train.shape}")

# Print some sample features
print("Sample features (first 5 rows):")
print(features_train[:5])
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Found 3064 images belonging to 1 classes.
# 96/96 [==============================] - 19360s 204s/step
# 96/96 [==============================] - 339s 3s/step
# Features shape: (3064, 1000)
# Sample features (first 5 rows):
# [[5.80247979e-05 1.65998117e-05 3.21139960e-05 ... 2.79213396e-06
#   1.14734168e-04 7.32517947e-05]
#  [1.88158640e-06 8.52340145e-06 4.71532712e-06 ... 8.09574794e-06
#   6.76640557e-05 1.30230198e-02]
#  [2.59439616e-06 1.94960035e-06 1.84941182e-05 ... 1.43291470e-06
#   1.15228504e-04 2.19049235e-03]
#  [9.29648832e-06 1.04901910e-05 1.98469243e-05 ... 1.14964541e-06
#   2.21639988e-04 7.10189459e-04]
#  [1.49840059e-06 5.81169206e-06 3.97069743e-06 ... 2.59875287e-06
#   5.79892803e-05 2.44989584e-04]]

# %%
import numpy as np
import os

# Define the directory where your features are saved
image_directory = r'C:\SumMe\Augmentation\AugBp'

# Load the features from the saved .npy files
features_resnet = np.load(os.path.join(image_directory, 'resnet50_features_train.npy'))
features_inceptionv3 = np.load(os.path.join(image_directory, 'inceptionv3_features_train.npy'))

# Ensure both feature arrays have the same number of samples
assert features_resnet.shape[0] == features_inceptionv3.shape[0], "Number of samples must be the same in both feature arrays."

# Concatenate the features along the feature dimension (axis=1)
features_combined = np.concatenate((features_resnet, features_inceptionv3), axis=1)

# Save the combined features to a new .npy file
np.save(os.path.join(image_directory, 'combined_features_train.npy'), features_combined)

print(f"Combined features shape: {features_combined.shape}")

# Print some sample combined features
print("Sample combined features (first 5 rows):")
print(features_combined[:5])
# Out:
# Combined features shape: (3064, 2000)
# Sample combined features (first 5 rows):
# [[5.8024798e-05 1.6599812e-05 3.2113996e-05 ... 1.5685860e-04
#   2.4077381e-04 8.7017647e-04]
#  [1.8815864e-06 8.5234014e-06 4.7153271e-06 ... 7.1808645e-05
#   5.5395043e-04 5.8739336e-04]
#  [2.5943962e-06 1.9496003e-06 1.8494118e-05 ... 1.9600797e-05
#   3.1703970e-04 7.0639019e-04]
#  [9.2964883e-06 1.0490191e-05 1.9846924e-05 ... 1.0911062e-04
#   5.0641538e-04 1.6977924e-03]
#  [1.4984006e-06 5.8116921e-06 3.9706974e-06 ... 4.0873623e-05
#   1.5525547e-04 2.2878607e-04]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input

# Define the directory where your features are saved
image_directory = r'C:\SumMe\Augmentation\AugBp'

# Load the features from the saved .npy files
features_combined = np.load(os.path.join(image_directory, 'combined_features_train.npy'))

# Define the number of timesteps (sequence length) and features
timesteps = 1  # Assuming each sample is treated as a sequence of length 1 for this example
input_dim = features_combined.shape[1]  # Should be 2000

# Prepare data for LSTM
# For this example, we'll use the features directly as sequences of length 1
X = features_combined
y = np.random.randint(0, 100, size=(features_combined.shape[0],))  # Example target variable, replace with your actual labels

# Reshape input to be [samples, timesteps, features]
X = X.reshape((X.shape[0], timesteps, input_dim))

# Define the LSTM model
inputs = Input(shape=(timesteps, input_dim))

# Add LSTM layers
x = LSTM(64, return_sequences=True)(inputs)
x = Dropout(0.5)(x)

x = LSTM(128, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(256, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(256, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(128, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(64, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(32)(x)
x = Dropout(0.5)(x)

# Add a Dense layer for output
outputs = Dense(100, activation='softmax')(x)  # Adjust the number of units based on your specific task

# Create the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
# For this example, we use dummy targets. Replace y with your actual labels.
model.fit(X, y, epochs=20, batch_size=32, validation_split=0.2)

# Extract features from the last LSTM layer
feature_extractor = Model(inputs=model.input, outputs=model.layers[-3].output)  # Layer before the final Dense layer

# Obtain features from the last LSTM layer
features_last_lstm = feature_extractor.predict(X)

# Save the extracted features
np.save(os.path.join(image_directory, 'features_last_lstm.npy'), features_last_lstm)

# Print the feature shape
print(f"Shape of features extracted from the last LSTM layer: {features_last_lstm.shape}")

# Print some sample features
print("Sample features from the last LSTM layer (first 5 samples):")
print(features_last_lstm[:5])
# Out:
# Epoch 1/20
# 77/77 [==============================] - 114s 350ms/step - loss: 4.6052 - accuracy: 0.0082 - val_loss: 4.6060 - val_accuracy: 0.0114
# Epoch 2/20
# 77/77 [==============================] - 15s 193ms/step - loss: 4.6027 - accuracy: 0.0090 - val_loss: 4.6078 - val_accuracy: 0.0179
# Epoch 3/20
# 77/77 [==============================] - 15s 192ms/step - loss: 4.6003 - accuracy: 0.0135 - val_loss: 4.6111 - val_accuracy: 0.0065
# Epoch 4/20
# 77/77 [==============================] - 18s 231ms/step - loss: 4.5956 - accuracy: 0.0143 - val_loss: 4.6189 - val_accuracy: 0.0065
# Epoch 5/20
# 77/77 [==============================] - 15s 196ms/step - loss: 4.5935 - accuracy: 0.0122 - val_loss: 4.6229 - val_accuracy: 0.0065
# Epoch 6/20
# 77/77 [==============================] - 14s 182ms/step - loss: 4.5911 - accuracy: 0.0147 - val_loss: 4.6261 - val_accuracy: 0.0065
# Epoch 7/20
# 77/77 [==============================] - 15s 189ms/step - loss: 4.5881 - accuracy: 0.0094 - val_loss: 4.6252 - val_accuracy: 0.0049
# Epoch 8/20
# 77/77 [==============================] - 13s 173ms/step - loss: 4.5854 - accuracy: 0.0139 - val_loss: 4.6277 - val_accuracy: 0.0049
# Epoch 9/20
#   -0.10966571 -0.13164037  0.22332525 -0.13358243  0.12886696  0.17413796
#   -0.09410737  0.08538549 -0.12081443 -0.2111584  -0.11961984  0.17743601
#    0.00765236 -0.12813967  0.15601344  0.1937493   0.12674849  0.16821295
#    0.11932451 -0.06494175]
#  [ 0.08825034 -0.07484888 -0.05850783 -0.0401703  -0.03524097  0.06738111
#    0.04390936 -0.09332935 -0.14963055  0.07330894 -0.08907516  0.04530115
#    0.02681659  0.05103873 -0.16763876  0.07862452 -0.04489684 -0.04935057
#    0.08708546 -0.13412228  0.19867413  0.14774048  0.03089797 -0.11817931
#    0.03995431  0.04604072 -0.09360819 -0.05272549 -0.08100584 -0.06726965
#   -0.08634073  0.11381988]
#  [-0.4159703   0.45124155  0.39446658  0.5547591   0.57246697 -0.5644216
#   -0.09365665  0.12394216  0.27403036 -0.00523752  0.32429454 -0.45593435
#   -0.48099858 -0.48115778  0.3698612  -0.49686673  0.4759026   0.6190553
#   -0.10110302  0.17453188 -0.03850007 -0.40038452 -0.4925702   0.31915474
#   -0.086914   -0.508306    0.42672098  0.58924985  0.52176803  0.559729
#    0.36881572 -0.0266633 ]]

# %%
import numpy as np
from sklearn.cluster import KMeans

# Load data (assuming the data is saved in a numpy array .npy file)
# Replace the path with the actual location of your data file
F = np.load(r"C:\SumMe\Augmentation\AugBp\features_last_lstm.npy")  # Adjust this path if necessary

# Set parameters
N = 460
np.random.seed(2)  # Setting the random seed for reproducibility

# Perform k-means clustering
kmeans = KMeans(n_clusters=N, init='k-means++', random_state=2)
kmeans.fit(F)

# Get cluster assignments (C_IDX) and cluster centroids (CC)
C_IDX = kmeans.labels_
CC = kmeans.cluster_centers_

# Initialize list to store indices of data points in each cluster
C = {i: np.where(C_IDX == i)[0] for i in range(N)}

# C now contains the indices of data points in each cluster

# %%
# Print the actual data points in the first cluster (cluster 0)
cluster_0_data_points = F[C[0], :]
print(cluster_0_data_points)
# Out:
# [[ 0.00279926 -0.00647155 -0.01378398 -0.00649148  0.00742329 -0.00636293
#   -0.01599819  0.0211964  -0.00330335  0.02344405  0.00160751 -0.00629756
#   -0.01288879 -0.00155564 -0.01644314  0.01903698  0.00491916  0.00077506
#   -0.00770748 -0.0327435   0.02022691  0.02472631 -0.01216053 -0.02132367
#    0.01869876  0.00739084 -0.01293687 -0.00655056 -0.01648066 -0.00435454
#   -0.01654795 -0.00933461]
#  [ 0.00232635 -0.00613488 -0.01346374 -0.0062433   0.0076893  -0.00688503
#   -0.01621766  0.02167031 -0.00249048  0.02328642  0.00210675 -0.00658526
#   -0.01309757 -0.00185554 -0.0156013   0.01869181  0.00521662  0.00112694
#   -0.00806807 -0.03232839  0.01948833  0.02398907 -0.01240167 -0.02071455
#    0.0186472   0.0071071  -0.01248712 -0.00616849 -0.01613699 -0.00395397
#   -0.01617552 -0.00968479]
#  [ 0.00235012 -0.00614912 -0.01347824 -0.00625435  0.00767789 -0.00685915
#   -0.01620669  0.0216455  -0.00252977  0.02329358  0.00208345 -0.00656994
#   -0.01308858 -0.00183944 -0.01564099  0.01870868  0.00520332  0.00111136
#   -0.00805215 -0.03234997  0.01952662  0.02402266 -0.0123903  -0.02074479
#    0.01864737  0.00712217 -0.01250817 -0.00618655 -0.01615454 -0.0039737
#   -0.01619427 -0.00966912]
#  [ 0.00252502 -0.00626814 -0.01360043 -0.00635094  0.00758149 -0.00666395
#   -0.01612542  0.02146521 -0.00283383  0.02335113  0.00189392 -0.00646263
#   -0.01301126 -0.00172439 -0.01595479  0.0188351   0.0050929   0.00098017
#   -0.00791937 -0.03250035  0.01980094  0.02429456 -0.01229881 -0.02097271
#    0.0186585   0.00723002 -0.01267754 -0.00632914 -0.01628087 -0.00412353
#   -0.01632833 -0.0095385 ]
#  [ 0.00228109 -0.00610465 -0.01343679 -0.00622061  0.00771393 -0.00692427
#   -0.01623672  0.02171523 -0.00241919  0.02327007  0.00214907 -0.00661176
#   -0.01311638 -0.00188006 -0.01552426  0.01866304  0.00524572  0.00115971
#   -0.00810118 -0.03229462  0.01942337  0.02392592 -0.0124283  -0.0206629
#    0.01864212  0.00708725 -0.01244764 -0.00614    -0.01610733 -0.00391737
#   -0.01614331 -0.00971714]
#  [ 0.00199784 -0.00589548 -0.01323912 -0.00607067  0.00787771 -0.00724613
#   -0.01637057  0.02199301 -0.00192528  0.02317234  0.00245294 -0.00678535
#   -0.01324242 -0.00206023 -0.01500921  0.01844648  0.00542496  0.00137453
#   -0.00832087 -0.03203827  0.01897825  0.02347069 -0.01256873 -0.02029185
#    0.01860518  0.00691288 -0.01217236 -0.00590073 -0.01589835 -0.00367354
#   -0.01591555 -0.00992967]]

# %%
# Print all the indices and their corresponding cluster values
for cluster_idx in range(N):
    print(f"Cluster {cluster_idx}:")
    print("Indices of data points:", C[cluster_idx])
    print("Number of data points in this cluster:", len(C[cluster_idx]))
    print()
# Out:
# Cluster 0:
# Indices of data points: [ 511 1335 2006 2046 2854 2932]
# Number of data points in this cluster: 6
#
# Cluster 1:
# Indices of data points: [ 725 1310 1370 1512 1732]
# Number of data points in this cluster: 5
#
# Cluster 2:
# Indices of data points: [ 420  478  686  958 1898 2395 2704 2738 2829 2955 2993 3025]
# Number of data points in this cluster: 12
#
# Cluster 3:
# Indices of data points: [1371 1446 2319]
# Number of data points in this cluster: 3
#
# Cluster 4:
# Indices of data points: [ 271  291  563  873 1444 1570 1727 2065]
# Number of data points in this cluster: 8
#
# Cluster 5:
# Indices of data points: [   0 1405 1747 2116]
# Number of data points in this cluster: 4
#
# Cluster 6:
# Indices of data points: [ 270  421  708  761 1008 1011 1125 1272 1445 1903 1907 2592 2670 2715
#  2743 2802 2867 2876 2892]
# Number of data points in this cluster: 19
#
# Cluster 7:
# Indices of data points: [ 102  544  624  905 1980 2387 2565 2671]
# Number of data points in this cluster: 8
#
# Cluster 8:
# Indices of data points: [1102 1246 1645 1707 2037 2217 2530 2760 2981]
# Number of data points in this cluster: 9
#
# Cluster 9:
# Indices of data points: [ 727  806 1544 1595 1604]
# Number of data points in this cluster: 5
#
# Cluster 10:
# Indices of data points: [2150]
# Number of data points in this cluster: 1
#
# Cluster 11:
# Indices of data points: [ 700  833  861  973 1036 1143 1650 1812 2178 2347 2358 2432 2466 2578
#  2740 2884]
# Number of data points in this cluster: 16
#
# Cluster 12:
# Indices of data points: [ 134 2060 2141]
# Number of data points in this cluster: 3
#
# Cluster 13:
# Indices of data points: [ 115 1099 1636 1664 1714 1883 1995 2162 2749 2896]
# Number of data points in this cluster: 10
#
# Cluster 14:
# Indices of data points: [ 742 1072 1124 1314 1552 2247 2836]
# Number of data points in this cluster: 7
#
# Cluster 15:
# Indices of data points: [ 113  396  723  790 1568 1931 2756]
# Number of data points in this cluster: 7
#
# Cluster 16:
# Indices of data points: [1699 2044 2984]
# Number of data points in this cluster: 3
#
# Cluster 17:
# Indices of data points: [   5  884 1738]
# Number of data points in this cluster: 3
#
# Cluster 18:
# Indices of data points: [ 315  340  401 1759]
# Number of data points in this cluster: 4
#
# Cluster 19:
# Indices of data points: [  85  157  429  569  840  847  872 1074 1282 1313 1800 1835 2555 2580
#  2606 2611 2625 2654 2666 2678 2795 2817]
# Number of data points in this cluster: 22
#
# Cluster 20:
# Indices of data points: [ 146  154  453  492 1957 1986 2013 2185 2721 2735 2797 2936 3053]
# Number of data points in this cluster: 13
#
# Cluster 21:
# Indices of data points: [ 520  919 1530 1533 1770 2262 2861 2961]
# Number of data points in this cluster: 8
#
# Cluster 22:
# Indices of data points: [ 393  523 1647]
# Number of data points in this cluster: 3
#
# Cluster 23:
# Indices of data points: [2132 2977]
# Number of data points in this cluster: 2
#
# Cluster 24:
# Indices of data points: [ 311  594  789 1147 1253 1325 1360 1441 2603 2741 2750]
# Number of data points in this cluster: 11
#
# Cluster 25:
# Indices of data points: [ 230  484  640 1309 1498 1549 1675 1919 1934 1951 2008 2499 2620 2839
#  2871 2974 3024 3063]
# Number of data points in this cluster: 18
#
# Cluster 26:
# Indices of data points: [ 155  889 1502 1838 2640]
# Number of data points in this cluster: 5
#
# Cluster 27:
# Indices of data points: [  30  360  394 2430 2941]
# Number of data points in this cluster: 5
#
# Cluster 28:
# Indices of data points: [ 121  141  169  431  996 1058 1063 1539 1682 1690 1906 1942 2326 2327
#  2476 2700]
# Number of data points in this cluster: 16
#
# Cluster 29:
# Indices of data points: [ 535  975 1481]
# Number of data points in this cluster: 3
#
# Cluster 30:
# Indices of data points: [ 907 1461 1576 1585 1791 2273 2701]
# Number of data points in this cluster: 7
#
# Cluster 31:
# Indices of data points: [1030 1406]
# Number of data points in this cluster: 2
#
# Cluster 32:
# Indices of data points: [ 543  633  696  762  940 1342 1386 1464 1613 2428]
# Number of data points in this cluster: 10
#
# Cluster 33:
# Indices of data points: [ 316  444 2456]
# Number of data points in this cluster: 3
#
# Cluster 34:
# Indices of data points: [ 371  518 1031 2158 2258]
# Number of data points in this cluster: 5
#
# Cluster 35:
# Indices of data points: [ 205  244  623  835 1018 1111 1196 1224 1237 1269 2009 2377 2438 2462
#  2703 2903]
# Number of data points in this cluster: 16
#
# Cluster 36:
# Indices of data points: [  17  163  179  842 1219 1809 1890 2401 2453 2601 2621 2628 2847]
# Number of data points in this cluster: 13
#
# Cluster 37:
# Indices of data points: [2728]
# Number of data points in this cluster: 1
#
# Cluster 38:
# Indices of data points: [ 541  663 1742]
# Number of data points in this cluster: 3
#
# Cluster 39:
# Indices of data points: [ 216 1164 2087 2187 2537]
# Number of data points in this cluster: 5
#
# Cluster 40:
# Indices of data points: [ 295 1065]
# Number of data points in this cluster: 2
#
# Cluster 41:
# Indices of data points: [1609]
# Number of data points in this cluster: 1
#
# Cluster 42:
# Indices of data points: [  26   73  412  583  648  784  969 1081 1575 1712 1831 1977 2002 2239
#  2307 2413 2534 2812]
# Number of data points in this cluster: 18
#
# Cluster 43:
# Indices of data points: [1367 1528 2925]
# Number of data points in this cluster: 3
#
# Cluster 44:
# Indices of data points: [ 674  679  792  856 1119 1623 1689 2020 2090 2755 2787 2844 2909 3041]
# Number of data points in this cluster: 14
#
# Cluster 45:
# Indices of data points: [  27  109  185  186  376  417  483  554  643  687  703  732  851 1591
#  1651 1688 1808 1830 1918 2808 2931 2934]
# Number of data points in this cluster: 22
#
# Cluster 46:
# Indices of data points: [  54   81  604  897 1276 1470 1941 2056 2417 2635 2644]
# Number of data points in this cluster: 11
#
# Cluster 47:
# Indices of data points: [ 787 1048 1810 2250 2590 2732 2754 2782 2845]
# Number of data points in this cluster: 9
#
# Cluster 48:
# Indices of data points: [1559 1612 2298]
# Number of data points in this cluster: 3
#
# Cluster 49:
# Indices of data points: [ 223  344  388  413  697  722  972 1181 1469 1489 1760 1868 2039 2075
#  2783 2864]
# Number of data points in this cluster: 16
#
# Cluster 50:
# Indices of data points: [ 435  764 1667]
# Number of data points in this cluster: 3
#
# Cluster 51:
# Indices of data points: [ 922 2341]
# Number of data points in this cluster: 2
#
# Cluster 52:
# Indices of data points: [ 503  588 1633 1733 2290 2869]
# Number of data points in this cluster: 6
#
# Cluster 53:
# Indices of data points: [  10  268  374 1420 2142 2810]
# Number of data points in this cluster: 6
#
# Cluster 54:
# Indices of data points: [ 221 2040 2345 2425 2503 2564 2589]
# Number of data points in this cluster: 7
#
# Cluster 55:
# Indices of data points: [1220 1578 2128]
# Number of data points in this cluster: 3
#
# Cluster 56:
# Indices of data points: [ 481  862  988 1087 1582 2007 2058 2135 2447 2508 2838 2994 3006]
# Number of data points in this cluster: 13
#
# Cluster 57:
# Indices of data points: [ 888 1349 1997]
# Number of data points in this cluster: 3
#
# Cluster 58:
# Indices of data points: [1107 1150 1207 1264 2405 2525 2546 2600 2709]
# Number of data points in this cluster: 9
#
# Cluster 59:
# Indices of data points: [ 979 1317 1418]
# Number of data points in this cluster: 3
#
# Cluster 60:
# Indices of data points: [ 297  927 1353 1426 2221 2449]
# Number of data points in this cluster: 6
#
# Cluster 61:
# Indices of data points: [ 129  521 1483 1861 2102]
# Number of data points in this cluster: 5
#
# Cluster 62:
# Indices of data points: [ 807 2067]
# Number of data points in this cluster: 2
#
# Cluster 63:
# Indices of data points: [  16  564 1593 2293 3015]
# Number of data points in this cluster: 5
#
# Cluster 64:
# Indices of data points: [ 217  447 1238 1343 1668 2226 2912]
# Number of data points in this cluster: 7
#
# Cluster 65:
# Indices of data points: [362]
# Number of data points in this cluster: 1
#
# Cluster 66:
# Indices of data points: [   4 2010]
# Number of data points in this cluster: 2
#
# Cluster 67:
# Indices of data points: [ 314  871 1572 2188 2225]
# Number of data points in this cluster: 5
#
# Cluster 68:
# Indices of data points: [   2  338 2131]
# Number of data points in this cluster: 3
#
# Cluster 69:
# Indices of data points: [  52  929 1283 2140 2477]
# Number of data points in this cluster: 5
#
# Cluster 70:
# Indices of data points: [  45  250  692  848 1326 1652 1887 2180 2303 2310 2427 2463 2653 2902]
# Number of data points in this cluster: 14
#
# Cluster 71:
# Indices of data points: [  35  192  381  424  570  707  710 1229 1475 1586 1659 2194 2719]
# Number of data points in this cluster: 13
#
# Cluster 72:
# Indices of data points: [ 292  744  804 1096 1100 1225 1392 1692 1794 1824 2105 2471 2818]
# Number of data points in this cluster: 13
#
# Cluster 73:
# Indices of data points: [ 387  515  628  751 1145 2176 2213 2415 2751]
# Number of data points in this cluster: 9
#
# Cluster 74:
# Indices of data points: [ 298  915 1395]
# Number of data points in this cluster: 3
#
# Cluster 75:
# Indices of data points: [3035]
# Number of data points in this cluster: 1
#
# Cluster 76:
# Indices of data points: [ 367 2109 2269 3012]
# Number of data points in this cluster: 4
#
# Cluster 77:
# Indices of data points: [1175 1389 1956 2218 2261]
# Number of data points in this cluster: 5
#
# Cluster 78:
# Indices of data points: [ 105  182  653  678  791 1069 1189 1857 1990 2027 2295 2362 2489 2638
#  2712 2822]
# Number of data points in this cluster: 16
#
# Cluster 79:
# Indices of data points: [ 926  959 1597 1973 2238 2285 2801 2976]
# Number of data points in this cluster: 8
#
# Cluster 80:
# Indices of data points: [ 886 1509]
# Number of data points in this cluster: 2
#
# Cluster 81:
# Indices of data points: [ 785  876 1695 2071 2346 2397]
# Number of data points in this cluster: 6
#
# Cluster 82:
# Indices of data points: [ 550  582  671 2019]
# Number of data points in this cluster: 4
#
# Cluster 83:
# Indices of data points: [  88  242  472  499  900  953 1129 1194 2038 2047 2885 2937]
# Number of data points in this cluster: 12
#
# Cluster 84:
# Indices of data points: [ 863 1455 1589 1640 2228 2235 2834 2979]
# Number of data points in this cluster: 8
#
# Cluster 85:
# Indices of data points: [1566 2915]
# Number of data points in this cluster: 2
#
# Cluster 86:
# Indices of data points: [ 232  337  445  660  754  892  956 1033 1045 1139 1318 1329 1331 1379
#  1854 1897 2108 2206 2237 2272 2306 2443 2457 2702 2849]
# Number of data points in this cluster: 25
#
# Cluster 87:
# Indices of data points: [  41 1267]
# Number of data points in this cluster: 2
#
# Cluster 88:
# Indices of data points: [ 34 293 411]
# Number of data points in this cluster: 3
#
# Cluster 89:
# Indices of data points: [  67 1097 1491 1629 1878 1912 1916]
# Number of data points in this cluster: 7
#
# Cluster 90:
# Indices of data points: [  25   43  621  829 1103 1626 1987 2781 2842]
# Number of data points in this cluster: 9
#
# Cluster 91:
# Indices of data points: [ 341  533  602 1203 1457 1619 2846]
# Number of data points in this cluster: 7
#
# Cluster 92:
# Indices of data points: [ 400  565  828 1278 1301 1382 1412 2133 2325 2343 2349 2557 2699]
# Number of data points in this cluster: 13
#
# Cluster 93:
# Indices of data points: [ 880 1359 1563 2923]
# Number of data points in this cluster: 4
#
# Cluster 94:
# Indices of data points: [ 191 3023]
# Number of data points in this cluster: 2
#
# Cluster 95:
# Indices of data points: [1034 1516 1877]
# Number of data points in this cluster: 3
#
# Cluster 96:
# Indices of data points: [ 331 1784 3011]
# Number of data points in this cluster: 3
#
# Cluster 97:
# Indices of data points: [ 465  899 1419 1472 1813 1876 2193 2263 2891]
# Number of data points in this cluster: 9
#
# Cluster 98:
# Indices of data points: [ 277  348  875 1200 1286 2083 2085 2646]
# Number of data points in this cluster: 8
#
# Cluster 99:
# Indices of data points: [ 426  430  585 1171 1211 1280 1300 1540 2029 2988]
# Number of data points in this cluster: 10
#
# Cluster 100:
# Indices of data points: [1598 1720 1863 2123 2454]
# Number of data points in this cluster: 5
#
# Cluster 101:
# Indices of data points: [ 140  728  778 1059 1178 1191 1208 1259 1816 2315 2339 2374 2491 2539
#  2553 2599 2777 2935]
# Number of data points in this cluster: 18
#
# Cluster 102:
# Indices of data points: [  83  458  516  832  970 1303 1320 1495 2875]
# Number of data points in this cluster: 9
#
# Cluster 103:
# Indices of data points: [356 924]
# Number of data points in this cluster: 2
#
# Cluster 104:
# Indices of data points: [  47  798 1064 1950]
# Number of data points in this cluster: 4
#
# Cluster 105:
# Indices of data points: [  61  215 1357 1387 2138]
# Number of data points in this cluster: 5
#
# Cluster 106:
# Indices of data points: [  32  224  932 1005 1490 2245]
# Number of data points in this cluster: 6
#
# Cluster 107:
# Indices of data points: [1670 1988]
# Number of data points in this cluster: 2
#
# Cluster 108:
# Indices of data points: [ 542  620 1193 1519 1538 2630]
# Number of data points in this cluster: 6
#
# Cluster 109:
# Indices of data points: [1043 1607 1939 1958 2208]
# Number of data points in this cluster: 5
#
# Cluster 110:
# Indices of data points: [ 233  869 1197 1323 1700 1874 1884 1984 2081 2156 2189]
# Number of data points in this cluster: 11
#
# Cluster 111:
# Indices of data points: [1409 1527 1543 1653 1665 1729 2805]
# Number of data points in this cluster: 7
#
# Cluster 112:
# Indices of data points: [  20  258  269 2778]
# Number of data points in this cluster: 4
#
# Cluster 113:
# Indices of data points: [2841]
# Number of data points in this cluster: 1
#
# Cluster 114:
# Indices of data points: [ 234  955 1242 1438]
# Number of data points in this cluster: 4
#
# Cluster 115:
# Indices of data points: [ 390  470  714 1086 1140 2088 2361 2790]
# Number of data points in this cluster: 8
#
# Cluster 116:
# Indices of data points: [ 963 1762 1778 2986]
# Number of data points in this cluster: 4
#
# Cluster 117:
# Indices of data points: [ 317 1510 2146]
# Number of data points in this cluster: 3
#
# Cluster 118:
# Indices of data points: [ 282  294  981 2973]
# Number of data points in this cluster: 4
#
# Cluster 119:
# Indices of data points: [   1  144  183  333  416  423  768 1079 1254 1634 1885 1948 1965 2198
#  2394 2422 2593 2748 2830 2940]
# Number of data points in this cluster: 20
#
# Cluster 120:
# Indices of data points: [  42   92  100  354  370  636  805  815  841  860 1070 1709 1715 1904
#  1913 2127 2426 2504 2531 2708]
# Number of data points in this cluster: 20
#
# Cluster 121:
# Indices of data points: [1190 1432 1494 1686 1949 2280 2924]
# Number of data points in this cluster: 7
#
# Cluster 122:
# Indices of data points: [  86   98  506  508  630  669 1002 1123 1271 1777 1996 2017 2061 2064
#  2338 2433 2956]
# Number of data points in this cluster: 17
#
# Cluster 123:
# Indices of data points: [ 267 2792]
# Number of data points in this cluster: 2
#
# Cluster 124:
# Indices of data points: [ 118  591  615 1970 2016 2095 2216]
# Number of data points in this cluster: 7
#
# Cluster 125:
# Indices of data points: [1388 2036]
# Number of data points in this cluster: 2
#
# Cluster 126:
# Indices of data points: [ 156  212  617  619  735  813  858 1024 1722 2552 2588]
# Number of data points in this cluster: 11
#
# Cluster 127:
# Indices of data points: [ 673 1146 1204 1304]
# Number of data points in this cluster: 4
#
# Cluster 128:
# Indices of data points: [  19  843  967 1346 2079 2435]
# Number of data points in this cluster: 6
#
# Cluster 129:
# Indices of data points: [ 574 1796 1833 2656 2664]
# Number of data points in this cluster: 5
#
# Cluster 130:
# Indices of data points: [ 206  220  318 1153 1263 1281 1347 1867 2041 2563 2893 2970]
# Number of data points in this cluster: 12
#
# Cluster 131:
# Indices of data points: [ 324 1355 2173]
# Number of data points in this cluster: 3
#
# Cluster 132:
# Indices of data points: [1734 1832]
# Number of data points in this cluster: 2
#
# Cluster 133:
# Indices of data points: [   3   29   84  409  571  616 1118 1232 2734 2860]
# Number of data points in this cluster: 10
#
# Cluster 134:
# Indices of data points: [ 776 1557 2149 2744 2911]
# Number of data points in this cluster: 5
#
# Cluster 135:
# Indices of data points: [ 175  184  425  456  838 1209 1631 1735 1922 2501 2523 2532 2535 2684
#  2714 2992 3014 3037]
# Number of data points in this cluster: 18
#
# Cluster 136:
# Indices of data points: [ 262  877 1098 1424 1511 1790]
# Number of data points in this cluster: 6
#
# Cluster 137:
# Indices of data points: [ 606 2055]
# Number of data points in this cluster: 2
#
# Cluster 138:
# Indices of data points: [ 406 1930 2014]
# Number of data points in this cluster: 3
#
# Cluster 139:
# Indices of data points: [160 881]
# Number of data points in this cluster: 2
#
# Cluster 140:
# Indices of data points: [2618 2933]
# Number of data points in this cluster: 2
#
# Cluster 141:
# Indices of data points: [ 284 2803 2835]
# Number of data points in this cluster: 3
#
# Cluster 142:
# Indices of data points: [ 151  213  403  597  680  893 1055 1154 1236 1274 1971 2199 2200 2328
#  2388 2680 3055]
# Number of data points in this cluster: 17
#
# Cluster 143:
# Indices of data points: [ 600  935 1615]
# Number of data points in this cluster: 3
#
# Cluster 144:
# Indices of data points: [ 194  299  440  690  694 1020 1187 1774 2115 2304 2498 2583 2637 2643
#  2769 2927 2965]
# Number of data points in this cluster: 17
#
# Cluster 145:
# Indices of data points: [ 986 1954]
# Number of data points in this cluster: 2
#
# Cluster 146:
# Indices of data points: [ 320  773  964 1010 1186 1307 1596 1818 2130 2203]
# Number of data points in this cluster: 10
#
# Cluster 147:
# Indices of data points: [539]
# Number of data points in this cluster: 1
#
# Cluster 148:
# Indices of data points: [ 323 1012 1756 2137 2145 2274 2975]
# Number of data points in this cluster: 7
#
# Cluster 149:
# Indices of data points: [ 529 1423 1782]
# Number of data points in this cluster: 3
#
# Cluster 150:
# Indices of data points: [ 112  380 1244 1312 1417 1561 1975 1992 2833 2958]
# Number of data points in this cluster: 10
#
# Cluster 151:
# Indices of data points: [ 702 1025 1202 1482 1814 2068]
# Number of data points in this cluster: 6
#
# Cluster 152:
# Indices of data points: [1799 2155 2939]
# Number of data points in this cluster: 3
#
# Cluster 153:
# Indices of data points: [ 664 1369 1558 1702 2015 2710]
# Number of data points in this cluster: 6
#
# Cluster 154:
# Indices of data points: [2764]
# Number of data points in this cluster: 1
#
# Cluster 155:
# Indices of data points: [ 609 1844 2104 2381 2384 2686]
# Number of data points in this cluster: 6
#
# Cluster 156:
# Indices of data points: [  18 1316 1767]
# Number of data points in this cluster: 3
#
# Cluster 157:
# Indices of data points: [1660 2080 2227 2758]
# Number of data points in this cluster: 4
#
# Cluster 158:
# Indices of data points: [  64   77  641  750 1121 3028]
# Number of data points in this cluster: 6
#
# Cluster 159:
# Indices of data points: [ 319 1114 1614 1937 2167 2220]
# Number of data points in this cluster: 6
#
# Cluster 160:
# Indices of data points: [ 286 1233 1676]
# Number of data points in this cluster: 3
#
# Cluster 161:
# Indices of data points: [  60  236  248  459 1050 1518 1546 1630 1637 1839 2342 2473 2579 2828
#  2951]
# Number of data points in this cluster: 15
#
# Cluster 162:
# Indices of data points: [208 350 990]
# Number of data points in this cluster: 3
#
# Cluster 163:
# Indices of data points: [  91  355  738  757 1083 1182 1231 1248 1450 1717 2380 2452 2745 3018]
# Number of data points in this cluster: 14
#
# Cluster 164:
# Indices of data points: [  66   71  195  252  846 1017 1039 1155 1327 1669 1769 2204 2461 2519
#  2558 2604 2629 2647 2772 2840 2913]
# Number of data points in this cluster: 21
#
# Cluster 165:
# Indices of data points: [ 274  328  534 2267 2815]
# Number of data points in this cluster: 5
#
# Cluster 166:
# Indices of data points: [ 342 1400 2114 2233]
# Number of data points in this cluster: 4
#
# Cluster 167:
# Indices of data points: [ 928  960 1042 1479 1625 1711 2478 2627 2791 2942 3022]
# Number of data points in this cluster: 11
#
# Cluster 168:
# Indices of data points: [2887]
# Number of data points in this cluster: 1
#
# Cluster 169:
# Indices of data points: [  58  802 1724]
# Number of data points in this cluster: 3
#
# Cluster 170:
# Indices of data points: [  74  137  461 1258 1265 1401 2567 2866 2954]
# Number of data points in this cluster: 9
#
# Cluster 171:
# Indices of data points: [ 993 1477]
# Number of data points in this cluster: 2
#
# Cluster 172:
# Indices of data points: [ 110 1110 1198 1448 1571 1658]
# Number of data points in this cluster: 6
#
# Cluster 173:
# Indices of data points: [1391 2223 2284]
# Number of data points in this cluster: 3
#
# Cluster 174:
# Indices of data points: [  36  166  260  488  689 1041 1067 1084 1685 1858 1928 2318 2375 2398
#  2434 2492 2605 2631 2682 2718 2929]
# Number of data points in this cluster: 21
#
# Cluster 175:
# Indices of data points: [ 301 1514 3047]
# Number of data points in this cluster: 3
#
# Cluster 176:
# Indices of data points: [ 165  896 2279 2529]
# Number of data points in this cluster: 4
#
# Cluster 177:
# Indices of data points: [  40  153  901 1587 1662 1899 1964 2078 2761]
# Number of data points in this cluster: 9
#
# Cluster 178:
# Indices of data points: [ 766  931 1273 1328 2025 2241 2874]
# Number of data points in this cluster: 7
#
# Cluster 179:
# Indices of data points: [ 279  479 1000]
# Number of data points in this cluster: 3
#
# Cluster 180:
# Indices of data points: [ 557  586 1240 1680 1989 2003 2042 2231 2281 2695]
# Number of data points in this cluster: 10
#
# Cluster 181:
# Indices of data points: [ 257  493  865 1865]
# Number of data points in this cluster: 4
#
# Cluster 182:
# Indices of data points: [  21  474  944 1864 2246 2582 2616 2675 2780]
# Number of data points in this cluster: 9
#
# Cluster 183:
# Indices of data points: [ 313  326  327 2507 2972]
# Number of data points in this cluster: 5
#
# Cluster 184:
# Indices of data points: [1167 1611 2890]
# Number of data points in this cluster: 3
#
# Cluster 185:
# Indices of data points: [ 760 1938 2171]
# Number of data points in this cluster: 3
#
# Cluster 186:
# Indices of data points: [ 225  480  859 1003 1348 1415 2181 2390 2459 2642 2843]
# Number of data points in this cluster: 11
#
# Cluster 187:
# Indices of data points: [ 726  756 2028 2479]
# Number of data points in this cluster: 4
#
# Cluster 188:
# Indices of data points: [1522]
# Number of data points in this cluster: 1
#
# Cluster 189:
# Indices of data points: [  55  170  174  226  473  849  906 1023 1090 1411 1451 1648 1701 1811
#  2097 2437 2481 2482 2679 2774]
# Number of data points in this cluster: 20
#
# Cluster 190:
# Indices of data points: [ 198  363  739 1133 1199 1393 1484 1574 1886 2073 2177 2330 2442 3016]
# Number of data points in this cluster: 14
#
# Cluster 191:
# Indices of data points: [ 222  579 1120 1534]
# Number of data points in this cluster: 4
#
# Cluster 192:
# Indices of data points: [ 818 1163 1383 1819 2633 2742 2785 2950]
# Number of data points in this cluster: 8
#
# Cluster 193:
# Indices of data points: [   9  119  498  546  612  718  720 1101 1172 1206 1289 1397 2120 2121
#  2313 2403 2404 2436 2497 2549 2632]
# Number of data points in this cluster: 21
#
# Cluster 194:
# Indices of data points: [  97  902 1060 1062 1297 1537 1649 1666 2356 2391 2412 2511 2667 2826
#  3036 3043]
# Number of data points in this cluster: 16
#
# Cluster 195:
# Indices of data points: [ 418  827 1262 2502]
# Number of data points in this cluster: 4
#
# Cluster 196:
# Indices of data points: [ 538  701 1044 1077 1829 1947 2506 2608 2624 2650 2698]
# Number of data points in this cluster: 11
#
# Cluster 197:
# Indices of data points: [   8  128  253 1366 2271]
# Number of data points in this cluster: 5
#
# Cluster 198:
# Indices of data points: [ 136  814 1311 1622 2035 2063 2286 2657 2786 2969 3039]
# Number of data points in this cluster: 11
#
# Cluster 199:
# Indices of data points: [ 228 1447]
# Number of data points in this cluster: 2
#
# Cluster 200:
# Indices of data points: [  79  343  446 1183 1806 1849 2379 2543 2571 2584 2688 2706 2711 2832]
# Number of data points in this cluster: 14
#
# Cluster 201:
# Indices of data points: [280]
# Number of data points in this cluster: 1
#
# Cluster 202:
# Indices of data points: [1646 2514]
# Number of data points in this cluster: 2
#
# Cluster 203:
# Indices of data points: [ 266  404  864 1029 1076 1532 1873 2118 2260]
# Number of data points in this cluster: 9
#
# Cluster 204:
# Indices of data points: [ 432  471  638  721  763  991 1004 1014 1324 1442]
# Number of data points in this cluster: 10
#
# Cluster 205:
# Indices of data points: [1351 1721 1889 2652 3058]
# Number of data points in this cluster: 5
#
# Cluster 206:
# Indices of data points: [ 476  644  925 1521 1638 1654 2464 2716]
# Number of data points in this cluster: 8
#
# Cluster 207:
# Indices of data points: [ 307  536 1555 1588]
# Number of data points in this cluster: 4
#
# Cluster 208:
# Indices of data points: [1332 1350 1616]
# Number of data points in this cluster: 3
#
# Cluster 209:
# Indices of data points: [ 334 1255 1821 2207]
# Number of data points in this cluster: 4
#
# Cluster 210:
# Indices of data points: [ 605  712 1128 1136 1148]
# Number of data points in this cluster: 5
#
# Cluster 211:
# Indices of data points: [1639 1657 2098 2222]
# Number of data points in this cluster: 4
#
# Cluster 212:
# Indices of data points: [ 161 1719 1793 2082 2321 2837 2962]
# Number of data points in this cluster: 7
#
# Cluster 213:
# Indices of data points: [ 998 1632 1820 2110]
# Number of data points in this cluster: 4
#
# Cluster 214:
# Indices of data points: [ 106  556  737  997 1905 1915 2134 2152 2474 2526 2880 2908 3057]
# Number of data points in this cluster: 13
#
# Cluster 215:
# Indices of data points: [3010]
# Number of data points in this cluster: 1
#
# Cluster 216:
# Indices of data points: [ 439 1116 1678 1888 2212 2275 2788 2920]
# Number of data points in this cluster: 8
#
# Cluster 217:
# Indices of data points: [ 451  614 1106 2100 2354 2681]
# Number of data points in this cluster: 6
#
# Cluster 218:
# Indices of data points: [1594 1771]
# Number of data points in this cluster: 2
#
# Cluster 219:
# Indices of data points: [  87   93  505  525  951 1170 2201 2541 2724 2968 3013 3046]
# Number of data points in this cluster: 12
#
# Cluster 220:
# Indices of data points: [ 358 1407 1535]
# Number of data points in this cluster: 3
#
# Cluster 221:
# Indices of data points: [1776 2136 2597 2883]
# Number of data points in this cluster: 4
#
# Cluster 222:
# Indices of data points: [  50   75  147  172  495  717  783  811  942 1239 1321 2004 2018 2033
#  2648 2660 2663 2796 2991]
# Number of data points in this cluster: 19
#
# Cluster 223:
# Indices of data points: [ 836 1188 2739 2816]
# Number of data points in this cluster: 4
#
# Cluster 224:
# Indices of data points: [ 243  346  675  810 1910 2139 2850]
# Number of data points in this cluster: 7
#
# Cluster 225:
# Indices of data points: [  62   68  407  699  715 1109 1285 1768 2048 2547]
# Number of data points in this cluster: 10
#
# Cluster 226:
# Indices of data points: [2922]
# Number of data points in this cluster: 1
#
# Cluster 227:
# Indices of data points: [ 448  558  752  883 1049 1592 1696 1978 2024 2053 2214 2585]
# Number of data points in this cluster: 12
#
# Cluster 228:
# Indices of data points: [ 143  524  736  796 1414 1679 1757 1993 2074 2202 2316 2515 2658 2857
#  2888]
# Number of data points in this cluster: 15
#
# Cluster 229:
# Indices of data points: [  89 2971]
# Number of data points in this cluster: 2
#
# Cluster 230:
# Indices of data points: [ 332  386  528 2254 2287]
# Number of data points in this cluster: 5
#
# Cluster 231:
# Indices of data points: [ 148  276 1051 1358 1439 1601 1750 1895 1923 2252 2766]
# Number of data points in this cluster: 11
#
# Cluster 232:
# Indices of data points: [ 296 2982]
# Number of data points in this cluster: 2
#
# Cluster 233:
# Indices of data points: [ 672  954 1627 2299 2352 2746 2824]
# Number of data points in this cluster: 7
#
# Cluster 234:
# Indices of data points: [ 167  468  593  650  852 1981 2333 2668 2773 2831 2907 2944]
# Number of data points in this cluster: 12
#
# Cluster 235:
# Indices of data points: [ 666 2166 2853]
# Number of data points in this cluster: 3
#
# Cluster 236:
# Indices of data points: [281 322]
# Number of data points in this cluster: 2
#
# Cluster 237:
# Indices of data points: [ 634 1287 1506 1565 2096 2566 2672]
# Number of data points in this cluster: 7
#
# Cluster 238:
# Indices of data points: [ 178  436 2868]
# Number of data points in this cluster: 3
#
# Cluster 239:
# Indices of data points: [ 365  930 1515]
# Number of data points in this cluster: 3
#
# Cluster 240:
# Indices of data points: [ 349  980 1761]
# Number of data points in this cluster: 3
#
# Cluster 241:
# Indices of data points: [ 442  494  733  982 1431 1433 1466 1497 1755 2011 2296 2451]
# Number of data points in this cluster: 12
#
# Cluster 242:
# Indices of data points: [  23  730 1159 1376 1550 1795 2322]
# Number of data points in this cluster: 7
#
# Cluster 243:
# Indices of data points: [ 377  450  464  627  824  903 1560 1674 1834 2930 3001]
# Number of data points in this cluster: 11
#
# Cluster 244:
# Indices of data points: [1040 1783 2229]
# Number of data points in this cluster: 3
#
# Cluster 245:
# Indices of data points: [  53  921  999 1697 1866]
# Number of data points in this cluster: 5
#
# Cluster 246:
# Indices of data points: [ 410  777  817  952 1214 1430 1911 1999 2731 2747 2881 2926 3034 3059]
# Number of data points in this cluster: 14
#
# Cluster 247:
#  [1567 2168 2619 3050]:
# Number of data points in this cluster: 4
#
# Cluster 248:
# Indices of data points: [ 131  197  642  934 1165 1354]
# Number of data points in this cluster: 6
#
# Cluster 249:
# Indices of data points: [1243 1322]
# Number of data points in this cluster: 2
#
# Cluster 250:
# Indices of data points: [ 308  948 1748 2757 2800]
# Number of data points in this cluster: 5
#
# Cluster 251:
# Indices of data points: [ 469  882 1092 1901 2122 2125 2598 2776]
# Number of data points in this cluster: 8
#
# Cluster 252:
# Indices of data points: [ 193  414  698  794  995 1001 1710 2439 2669 2946]
# Number of data points in this cluster: 10
#
# Cluster 253:
# Indices of data points: [ 490  914  987 1152 1480 1677 2183 2819]
# Number of data points in this cluster: 8
#
# Cluster 254:
# Indices of data points: [ 304  526 1488 2301]
# Number of data points in this cluster: 4
#
# Cluster 255:
# Indices of data points: [ 339  415 2113 2276 2283]
# Number of data points in this cluster: 5
#
# Cluster 256:
# Indices of data points: [2255 2737]
# Number of data points in this cluster: 2
#
# Cluster 257:
# Indices of data points: [  90  649 2043 2848]
# Number of data points in this cluster: 4
#
# Cluster 258:
# Indices of data points: [ 159  176  547  626  753  912 1112 1416 2594 2904]
# Number of data points in this cluster: 10
#
# Cluster 259:
# Indices of data points: [ 555  936 1779]
# Number of data points in this cluster: 3
#
# Cluster 260:
# Indices of data points: [ 933 1378 1723 1731 1955 2278 2917]
# Number of data points in this cluster: 7
#
# Cluster 261:
# Indices of data points: [1377 2294]
# Number of data points in this cluster: 2
#
# Cluster 262:
# Indices of data points: [  22  203  477  519  587  590  759  895 1503 1706 1817 1836 2195 2324
#  2334 2372 2446 2516 2538]
# Number of data points in this cluster: 19
#
# Cluster 263:
# Indices of data points: [1218 1584 2174 2251 2945 2949]
# Number of data points in this cluster: 6
#
# Cluster 264:
# Indices of data points: [ 397  405  795  857 1009 1460 1924]
# Number of data points in this cluster: 7
#
# Cluster 265:
# Indices of data points: [  33  114  383  904 1526 2317 2359 2505 2560 2634]
# Number of data points in this cluster: 10
#
# Cluster 266:
# Indices of data points: [ 287  300 1403 1621 1743 1754]
# Number of data points in this cluster: 6
#
# Cluster 267:
# Indices of data points: [  65  171  513  637  850 1022 1293 1785 2291 2392 2685 2717 2858]
# Number of data points in this cluster: 13
#
# Cluster 268:
# Indices of data points: [ 190  229  255  433 1485 1553 1804 1979 2163 2191 2779]
# Number of data points in this cluster: 11
#
# Cluster 269:
# Indices of data points: [ 373 1643]
# Number of data points in this cluster: 2
#
# Cluster 270:
# Indices of data points: [ 290 1749 1843 3019]
# Number of data points in this cluster: 4
#
# Cluster 271:
# Indices of data points: [1728 2297]
# Number of data points in this cluster: 2
#
# Cluster 272:
# Indices of data points: [ 111  135  639  755 1235 2062 2070 2144 2170 2897]
# Number of data points in this cluster: 10
#
# Cluster 273:
# Indices of data points: [ 384  885 1882 2901]
# Number of data points in this cluster: 4
#
# Cluster 274:
# Indices of data points: [1972 2160]
# Number of data points in this cluster: 2
#
# Cluster 275:
# Indices of data points: [  69  123  142  527 1179 1256 1275 1306 1635 1850 1853 2323 2337 2378
#  2570]
# Number of data points in this cluster: 15
#
# Cluster 276:
# Indices of data points: [ 522  578  580 1085 1250 2360 2468 2483 2521 2694 2794]
# Number of data points in this cluster: 11
#
# Cluster 277:
# Indices of data points: [ 275  302  357  803  985 3002]
# Number of data points in this cluster: 6
#
# Cluster 278:
# Indices of data points: [  39  288  632  741  855 1982 2022 3062]
# Number of data points in this cluster: 8
#
# Cluster 279:
# Indices of data points: [1605 1606 1713 1758 2376]
# Number of data points in this cluster: 5
#
# Cluster 280:
# Indices of data points: [1822]
# Number of data points in this cluster: 1
#
# Cluster 281:
# Indices of data points: [ 240  249  743 1021 1375 1399 1583 2879 2906 3040]
# Number of data points in this cluster: 10
#
# Cluster 282:
# Indices of data points: [ 359  774  966 1744 2999]
# Number of data points in this cluster: 5
#
# Cluster 283:
# Indices of data points: [ 246  263  369  531  845 2032 2386 2900 3027]
# Number of data points in this cluster: 9
#
# Cluster 284:
# Indices of data points: [2253]
# Number of data points in this cluster: 1
#
# Cluster 285:
# Indices of data points: [ 189  345 1053 1075 1144 1173 1226 1425 1862 2054 2072 2309 2722 2996]
# Number of data points in this cluster: 14
#
# Cluster 286:
# Indices of data points: [  38  608 1837 1945 3045]
# Number of data points in this cluster: 5
#
# Cluster 287:
# Indices of data points: [ 353 1507]
# Number of data points in this cluster: 2
#
# Cluster 288:
# Indices of data points: [ 989 1427]
# Number of data points in this cluster: 2
#
# Cluster 289:
# Indices of data points: [ 568 1827 2111 2382]
# Number of data points in this cluster: 4
#
# Cluster 290:
# Indices of data points: [ 711 2799]
# Number of data points in this cluster: 2
#
# Cluster 291:
# Indices of data points: [ 532  695  705  788 1726 1851 1943 1953 2106 3003]
# Number of data points in this cluster: 10
#
# Cluster 292:
# Indices of data points: [ 879 1279 1524 1541 2129 2418 2542 2581]
# Number of data points in this cluster: 8
#
# Cluster 293:
# Indices of data points: [1963]
# Number of data points in this cluster: 1
#
# Cluster 294:
# Indices of data points: [   7  239  364  839  971 1094 1536 1741 1841 1872 1917 2057 2101 2793]
# Number of data points in this cluster: 14
#
# Cluster 295:
# Indices of data points: [ 125  668 2148 2266]
# Number of data points in this cluster: 4
#
# Cluster 296:
# Indices of data points: [ 196  507  566  654  793  812 1290 1340 2852 2960 3032]
# Number of data points in this cluster: 11
#
# Cluster 297:
# Indices of data points: [ 132  321  517  920 1038 1068 1234 1453 2012 2350 2469 2550 2767]
# Number of data points in this cluster: 13
#
# Cluster 298:
# Indices of data points: [1333 3044]
# Number of data points in this cluster: 2
#
# Cluster 299:
# Indices of data points: [ 978 1437]
# Number of data points in this cluster: 2
#
# Cluster 300:
# Indices of data points: [1007 2164]
# Number of data points in this cluster: 2
#
# Cluster 301:
# Indices of data points: [ 782 1157 1459 2268 3000]
# Number of data points in this cluster: 5
#
# Cluster 302:
# Indices of data points: [ 187  231  501  502  716  957 1296 1683 2302 2348 2465 2639]
# Number of data points in this cluster: 12
#
# Cluster 303:
# Indices of data points: [ 398  898 1035]
# Number of data points in this cluster: 3
#
# Cluster 304:
# Indices of data points: [ 911 1765 2363]
# Number of data points in this cluster: 3
#
# Cluster 305:
# Indices of data points: [ 375  559  799  945 1468 1672 2804]
# Number of data points in this cluster: 7
#
# Cluster 306:
# Indices of data points: [ 138  395  661  693  825  938  941  992 1026 1138 1786 1991 2182 2809
#  2918]
# Number of data points in this cluster: 15
#
# Cluster 307:
# Indices of data points: [ 820  887 1134 1505 2045]
# Number of data points in this cluster: 5
#
# Cluster 308:
# Indices of data points: [  63  127  219  238  823 1673 1900 1908 2107 2364 2400 2493 2540 2596
#  2602]
# Number of data points in this cluster: 15
#
# Cluster 309:
# Indices of data points: [ 402 1542]
# Number of data points in this cluster: 2
#
# Cluster 310:
# Indices of data points: [1394 1410 1764 2966]
# Number of data points in this cluster: 4
#
# Cluster 311:
# Indices of data points: [1361 1385 1486 1891]
# Number of data points in this cluster: 4
#
# Cluster 312:
# Indices of data points: [  24  199 1015 1130 1149 1501 1875 1881 2084 2513 2763 2895]
# Number of data points in this cluster: 12
#
# Cluster 313:
# Indices of data points: [ 389 1463]
# Number of data points in this cluster: 2
#
# Cluster 314:
# Indices of data points: [  56   57  122  188  745 1961 2094 2827]
# Number of data points in this cluster: 8
#
# Cluster 315:
# Indices of data points: [ 576  618  645  685  779 1341 2076 2312 2355 2429 2475 2496 2889 3033]
# Number of data points in this cluster: 14
#
# Cluster 316:
# Indices of data points: [ 259  613  682  746 1037 1161 2765 2784 2855 2870 2873]
# Number of data points in this cluster: 11
#
# Cluster 317:
# Indices of data points: [  95  704  771 1260 1368 1624 2112 2366 2490 2528 2554]
# Number of data points in this cluster: 11
#
# Cluster 318:
# Indices of data points: [1422 1525 2031 2759]
# Number of data points in this cluster: 4
#
# Cluster 319:
# Indices of data points: [  59  462  486  819 1027 1095 1160 1195 1531 1893 1952 2383 2577]
# Number of data points in this cluster: 13
#
# Cluster 320:
# Indices of data points: [  46  101  210  305 1221 1554 1628 2440 2573 2856 2898]
# Number of data points in this cluster: 11
#
# Cluster 321:
# Indices of data points: [1223 1428 1545 1581 1708 1739 1787]
# Number of data points in this cluster: 7
#
# Cluster 322:
# Indices of data points: [ 434 2169 2408 2921]
# Number of data points in this cluster: 4
#
# Cluster 323:
# Indices of data points: [ 391  918  968 1277 1500 2086 2209 2242]
# Number of data points in this cluster: 8
#
# Cluster 324:
# Indices of data points: [ 452  561  868 1080 2196 2215]
# Number of data points in this cluster: 6
#
# Cluster 325:
# Indices of data points: [ 372  454  950  983 2151 2219 2707 3004]
# Number of data points in this cluster: 8
#
# Cluster 326:
# Indices of data points: [1344 1499]
# Number of data points in this cluster: 2
#
# Cluster 327:
# Indices of data points: [  49  310  443  740  984 1028 1205 1217 1471 1716 1746 1825 2205 2406
#  2509]
# Number of data points in this cluster: 15
#
# Cluster 328:
# Indices of data points: [1365 1929 2030 2172]
# Number of data points in this cluster: 4
#
# Cluster 329:
# Indices of data points: [2154 3048]
# Number of data points in this cluster: 2
#
# Cluster 330:
# Indices of data points: [1363 1798 2059 2259 2617 2948]
# Number of data points in this cluster: 6
#
# Cluster 331:
# Indices of data points: [1617 2197 2987]
# Number of data points in this cluster: 3
#
# Cluster 332:
# Indices of data points: [1860]
# Number of data points in this cluster: 1
#
# Cluster 333:
# Indices of data points: [ 441  482  713  729  816 1373 1380 1492 2049 2444 2720 3061]
# Number of data points in this cluster: 12
#
# Cluster 334:
# Indices of data points: [ 303 1127 1137 1177]
# Number of data points in this cluster: 4
#
# Cluster 335:
# Indices of data points: [  44  108  466  510  683 1298 1456 1921 2455 2859 2952]
# Number of data points in this cluster: 11
#
# Cluster 336:
# Indices of data points: [ 107  422  572 2445]
# Number of data points in this cluster: 4
#
# Cluster 337:
# Indices of data points: [1946]
# Number of data points in this cluster: 1
#
# Cluster 338:
# Indices of data points: [  15   37 1548]
# Number of data points in this cluster: 3
#
# Cluster 339:
# Indices of data points: [ 164  567  611 1894 2480 2495 2518 2556]
# Number of data points in this cluster: 8
#
# Cluster 340:
# Indices of data points: [ 540 1435 1909]
# Number of data points in this cluster: 3
#
# Cluster 341:
# Indices of data points: [   6   94  145  610 1268 1308 1374 1556 1600 1745 1892 1944 2093 2186
#  2311 2365 2964]
# Number of data points in this cluster: 17
#
# Cluster 342:
# Indices of data points: [ 734  786 1166 1478 2052 2938]
# Number of data points in this cluster: 6
#
# Cluster 343:
# Indices of data points: [  14  177 2091 2905]
# Number of data points in this cluster: 4
#
# Cluster 344:
# Indices of data points: [ 487 1452 1869 2419]
# Number of data points in this cluster: 4
#
# Cluster 345:
# Indices of data points: [ 126  336  866 1372 1529 1815 2175 2192 2320 2985]
# Number of data points in this cluster: 10
#
# Cluster 346:
# Indices of data points: [1352]
# Number of data points in this cluster: 1
#
# Cluster 347:
# Indices of data points: [551]
# Number of data points in this cluster: 1
#
# Cluster 348:
# Indices of data points: [ 245 3017]
# Number of data points in this cluster: 2
#
# Cluster 349:
# Indices of data points: [ 514  854 1780 1847 2147 2224 2813 2914 2947]
# Number of data points in this cluster: 9
#
# Cluster 350:
# Indices of data points: [ 595  656  837 1705 1803 2963]
# Number of data points in this cluster: 6
#
# Cluster 351:
# Indices of data points: [3049]
# Number of data points in this cluster: 1
#
# Cluster 352:
# Indices of data points: [ 261  657  910 1158 1694 1775 1966 1983 2232 2723]
# Number of data points in this cluster: 10
#
# Cluster 353:
# Indices of data points: [278 285 379 724]
# Number of data points in this cluster: 4
#
# Cluster 354:
# Indices of data points: [ 592  780 2697 3007]
# Number of data points in this cluster: 4
#
# Cluster 355:
# Indices of data points: [1141 1228 1319 1547 1608 1656 2077 2512 2807 2998]
# Number of data points in this cluster: 10
#
# Cluster 356:
# Indices of data points: [ 676  769  909 1082 1493 2370 2488 2568 2613 2705]
# Number of data points in this cluster: 10
#
# Cluster 357:
# Indices of data points: [ 747  770 2023 2248 2265 2385 2775 2851]
# Number of data points in this cluster: 8
#
# Cluster 358:
# Indices of data points: [312]
# Number of data points in this cluster: 1
#
# Cluster 359:
# Indices of data points: [1210]
# Number of data points in this cluster: 1
#
# Cluster 360:
# Indices of data points: [ 283 1725 2983]
# Number of data points in this cluster: 3
#
# Cluster 361:
# Indices of data points: [2244 2270]
# Number of data points in this cluster: 2
#
# Cluster 362:
# Indices of data points: [ 237  497  599  607  658  665  917 1057 1213 1251 1807 2486 2676 3031]
# Number of data points in this cluster: 14
#
# Cluster 363:
# Indices of data points: [2725]
# Number of data points in this cluster: 1
#
# Cluster 364:
# Indices of data points: [ 368  577  629  670  961 1088 1684 1920 1976 2421 2527]
# Number of data points in this cluster: 11
#
# Cluster 365:
# Indices of data points: [2989]
# Number of data points in this cluster: 1
#
# Cluster 366:
# Indices of data points: [1305 1384 1449 1661 1766 2282 2607 2823]
# Number of data points in this cluster: 8
#
# Cluster 367:
# Indices of data points: [ 124  254 1126 1284 1294 1985 1998 2510 2753]
# Number of data points in this cluster: 9
#
# Cluster 368:
# Indices of data points: [ 831 1054 1520]
# Number of data points in this cluster: 3
#
# Cluster 369:
# Indices of data points: [ 181  265  419  913 1113 1168 1270 1845 2119 2402 2536 2576 2689 2995]
# Number of data points in this cluster: 14
#
# Cluster 370:
# Indices of data points: [  11   13  329  485  748  949 1184 1573 1932 2572 2882]
# Number of data points in this cluster: 11
#
# Cluster 371:
# Indices of data points: [894]
# Number of data points in this cluster: 1
#
# Cluster 372:
# Indices of data points: [ 385  625  908 1066 1261 1687 2367]
# Number of data points in this cluster: 7
#
# Cluster 373:
# Indices of data points: [ 460  719 1108 1247 1823 2517 2551 2614 2825]
# Number of data points in this cluster: 9
#
# Cluster 374:
# Indices of data points: [ 241  596  662  962 1052 1429 1927 1960 2026 2050 2424 2713 2736 2770]
# Number of data points in this cluster: 14
#
# Cluster 375:
# Indices of data points: [ 775  809 1763]
# Number of data points in this cluster: 3
#
# Cluster 376:
# Indices of data points: [ 545  822  874 1093 1117 2407 2692]
# Number of data points in this cluster: 7
#
# Cluster 377:
# Indices of data points: [1753]
# Number of data points in this cluster: 1
#
# Cluster 378:
# Indices of data points: [ 651 1006 1413 1962 2066 2990]
# Number of data points in this cluster: 6
#
# Cluster 379:
# Indices of data points: [ 149  202  549 1227 1508 1801 2353 2645 2659 2798 3042]
# Number of data points in this cluster: 11
#
# Cluster 380:
# Indices of data points: [ 976 1169 1288 1789 1940]
# Number of data points in this cluster: 5
#
# Cluster 381:
# Indices of data points: [ 589  834 1454 1880 2485]
# Number of data points in this cluster: 5
#
# Cluster 382:
# Indices of data points: [1788 1926 2243]
# Number of data points in this cluster: 3
#
# Cluster 383:
# Indices of data points: [1773]
# Number of data points in this cluster: 1
#
# Cluster 384:
# Indices of data points: [ 264  392  826  923 1019 1826 2340 2458 2587 2595]
# Number of data points in this cluster: 10
#
# Cluster 385:
# Indices of data points: [ 509  560 1047 1580 1936 2179 2249]
# Number of data points in this cluster: 7
#
# Cluster 386:
# Indices of data points: [ 977 2910]
# Number of data points in this cluster: 2
#
# Cluster 387:
# Indices of data points: [272 562]
# Number of data points in this cluster: 2
#
# Cluster 388:
# Indices of data points: [ 209  631  706  709  749 1115 1681 1871 2161 2288 2626 2662 2806]
# Number of data points in this cluster: 13
#
# Cluster 389:
# Indices of data points: [ 659  830 2126]
# Number of data points in this cluster: 3
#
# Cluster 390:
# Indices of data points: [  12   31  152  537 1215 2289 2336 2467 2562 2569 2612 2623 2661]
# Number of data points in this cluster: 13
#
# Cluster 391:
# Indices of data points: [ 428  581  601 1523 1698 1736 2001 2236 2441 2470 2472 2575 2610]
# Number of data points in this cluster: 13
#
# Cluster 392:
# Indices of data points: [ 247 1078 1201 1473 1504 2771]
# Number of data points in this cluster: 6
#
# Cluster 393:
# Indices of data points: [309]
# Number of data points in this cluster: 1
#
# Cluster 394:
# Indices of data points: [  78  351  449  455 1032 1345 1671 1828 1994 2230 2821]
# Number of data points in this cluster: 11
#
# Cluster 395:
# Indices of data points: [ 378  553  647  655 1056 1142 2420]
# Number of data points in this cluster: 7
#
# Cluster 396:
# Indices of data points: [ 103  150  207  251  438 1230 1291 1336 1914 1969 2411 2693 2696]
# Number of data points in this cluster: 13
#
# Cluster 397:
# Indices of data points: [  76   80  158  437 1302 1925 1959 2005 2099 2351 2416 2431 2494 2544
#  2559 2591 2752]
# Number of data points in this cluster: 17
#
# Cluster 398:
# Indices of data points: [  70  943 1751 2069 2308 2789]
# Number of data points in this cluster: 6
#
# Cluster 399:
# Indices of data points: [ 162  173  201  767 1105 1855 2329 2373 2520 2665 2899]
# Number of data points in this cluster: 11
#
# Cluster 400:
# Indices of data points: [ 965  994 1421 1458 1896]
# Number of data points in this cluster: 5
#
# Cluster 401:
# Indices of data points: [ 204  646  890 1073 1174 1737 1879 2641 3056]
# Number of data points in this cluster: 9
#
# Cluster 402:
# Indices of data points: [3020]
# Number of data points in this cluster: 1
#
# Cluster 403:
# Indices of data points: [1016]
# Number of data points in this cluster: 1
#
# Cluster 404:
# Indices of data points: [ 104  667 1603 1663 1974 2092 2165 2727 2729]
# Number of data points in this cluster: 9
#
# Cluster 405:
# Indices of data points: [2730]
# Number of data points in this cluster: 1
#
# Cluster 406:
# Indices of data points: [ 361 1266 2157]
# Number of data points in this cluster: 3
#
# Cluster 407:
# Indices of data points: [ 325 1122 1752 1870 2234]
# Number of data points in this cluster: 5
#
# Cluster 408:
# Indices of data points: [ 427  598  684  781  891  916 1330 1562 1644 2862 2894]
# Number of data points in this cluster: 11
#
# Cluster 409:
# Indices of data points: [ 256 2034]
# Number of data points in this cluster: 2
#
# Cluster 410:
# Indices of data points: [ 330 1362]
# Number of data points in this cluster: 2
#
# Cluster 411:
# Indices of data points: [2153]
# Number of data points in this cluster: 1
#
# Cluster 412:
# Indices of data points: [  99 1135 1487 1935]
# Number of data points in this cluster: 4
#
# Cluster 413:
# Indices of data points: [ 677 1176 1212 1933 2877 2878 2886]
# Number of data points in this cluster: 7
#
# Cluster 414:
# Indices of data points: [  51  130  273 1071 1156 1356 2959]
# Number of data points in this cluster: 7
#
# Cluster 415:
# Indices of data points: [ 801 1252 1390 2184 2331 2393 2636 2865 3029]
# Number of data points in this cluster: 9
#
# Cluster 416:
# Indices of data points: [ 289 2726]
# Number of data points in this cluster: 2
#
# Cluster 417:
# Indices of data points: [1364 1436 3008]
# Number of data points in this cluster: 3
#
# Cluster 418:
# Indices of data points: [  82 2103 2240]
# Number of data points in this cluster: 3
#
# Cluster 419:
# Indices of data points: [ 352 2159]
# Number of data points in this cluster: 2
#
# Cluster 420:
# Indices of data points: [2980]
# Number of data points in this cluster: 1
#
# Cluster 421:
# Indices of data points: [ 133 1513 1781 2124 2545]
# Number of data points in this cluster: 5
#
# Cluster 422:
# Indices of data points: [2117 2256 2264]
# Number of data points in this cluster: 3
#
# Cluster 423:
# Indices of data points: [ 765 1222 1396 1465 1802 2409 2450 2524 2673 2691]
# Number of data points in this cluster: 10
#
# Cluster 424:
# Indices of data points: [ 211  399  844 1443]
# Number of data points in this cluster: 4
#
# Cluster 425:
# Indices of data points: [  48  491  584 1852 2021 2368 2690]
# Number of data points in this cluster: 7
#
# Cluster 426:
# Indices of data points: [ 808 1517]
# Number of data points in this cluster: 2
#
# Cluster 427:
# Indices of data points: [ 200 1151 1398 1496 1703 2399 2410 2622 2655 3054]
# Number of data points in this cluster: 10
#
# Cluster 428:
# Indices of data points: [ 408 1131 1295 1551 2357 2423 2460 2609 2649 2677 2687 3051]
# Number of data points in this cluster: 12
#
# Cluster 429:
# Indices of data points: [1089 1792 1859 2257 2574]
# Number of data points in this cluster: 5
#
# Cluster 430:
# Indices of data points: [  28 1599 2814 3009]
# Number of data points in this cluster: 4
#
# Cluster 431:
# Indices of data points: [  72   96  463 1091 1292 1620 1693 2051 2916 3021]
# Number of data points in this cluster: 10
#
# Cluster 432:
# Indices of data points: [ 947 1610]
# Number of data points in this cluster: 2
#
# Cluster 433:
# Indices of data points: [1339 1440 2190]
# Number of data points in this cluster: 3
#
# Cluster 434:
# Indices of data points: [1404 2277]
# Number of data points in this cluster: 2
#
# Cluster 435:
# Indices of data points: [ 946 1132 1602 2919]
# Number of data points in this cluster: 4
#
# Cluster 436:
# Indices of data points: [2978]
# Number of data points in this cluster: 1
#
# Cluster 437:
# Indices of data points: [ 575 2210 2211 2522 2997]
# Number of data points in this cluster: 5
#
# Cluster 438:
# Indices of data points: [1315 1474 1590 2332 2414 2548 2863 2967 3005]
# Number of data points in this cluster: 9
#
# Cluster 439:
# Indices of data points: [ 496  797 1192 1245 1718 2811 2820]
# Number of data points in this cluster: 7
#
# Cluster 440:
# Indices of data points: [ 489 1013 1579 1641 2586 2674 2762 3030 3052]
# Number of data points in this cluster: 9
#
# Cluster 441:
# Indices of data points: [1185 1805 2305]
# Number of data points in this cluster: 3
#
# Cluster 442:
# Indices of data points: [ 218  347  457  691 1434 1967 2389 2396]
# Number of data points in this cluster: 8
#
# Cluster 443:
# [ 500  552 1249 1299 1334 1402 1467 1848 2369 2448 2615 2957 3038]
# Number of data points in this cluster: 13
#
# Cluster 444:
# Indices of data points: [1856]
# Number of data points in this cluster: 1
#
# Cluster 445:
# Indices of data points: [1408]
# Number of data points in this cluster: 1
#
# Cluster 446:
# Indices of data points: [ 475  622  635  937 1337 1730 2500 2872]
# Number of data points in this cluster: 8
#
# Cluster 447:
# Indices of data points: [ 681 1104 1577 2928]
# Number of data points in this cluster: 4
#
# Cluster 448:
# Indices of data points: [1476]
# Number of data points in this cluster: 1
#
# Cluster 449:
# Indices of data points: [ 573  688  853  867 1216 1257 1462 2314 2335]
# Number of data points in this cluster: 9
#
# Cluster 450:
# Indices of data points: [530]
# Number of data points in this cluster: 1
#
# Cluster 451:
# Indices of data points: [ 116  139  168  548 1061 1642 2344 2484 2533 2651 2683 2733 3026]
# Number of data points in this cluster: 13
#
# Cluster 452:
# Indices of data points: [2943]
# Number of data points in this cluster: 1
#
# Cluster 453:
# Indices of data points: [ 120  227  306  382  731  758  878 1046 1338 1655 1772 1840 1842 1846
#  2371 2768]
# Number of data points in this cluster: 16
#
# Cluster 454:
# Indices of data points: [ 504  939 1241]
# Number of data points in this cluster: 3
#
# Cluster 455:
# Indices of data points: [ 512  974 1162 1381 1564 1740 2000 2089 2143 2300]
# Number of data points in this cluster: 10
#
# Cluster 456:
# Indices of data points: [ 117  180  467  652  800 1691 1797 1968 2292 2561 3060]
# Number of data points in this cluster: 11
#
# Cluster 457:
# Indices of data points: [ 235  603 1704]
# Number of data points in this cluster: 3
#
# Cluster 458:
# Indices of data points: [ 335  870 1180 1902]
# Number of data points in this cluster: 4
#
# Cluster 459:
# Indices of data points: [ 214  366  772  821 1569 1618 2487 2953]
# Number of data points in this cluster: 8

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# Load data (assuming the data is saved in a numpy array .npy file)
try:
    F = np.load(r"C:\SumMe\Augmentation\AugBp\features_last_lstm.npy")  # Adjust this path if necessary
except FileNotFoundError:
    print("Error: The specified file was not found.")
    exit(1)

# Set parameters
N = 460  # Number of clusters
num_samples = F.shape[0]  # Number of data points (950)
np.random.seed(2)  # Setting the random seed for reproducibility

# Perform k-means clustering
kmeans = KMeans(n_clusters=N, init='k-means++', random_state=2)
kmeans.fit(F)

# Get cluster assignments (C_IDX) and cluster centroids (CC)
C_IDX = kmeans.labels_
CC = kmeans.cluster_centers_

# Initialize binary matrix (950 x 143) with zeros
keyframe_matrix = np.zeros((num_samples, N), dtype=int)

# Loop through each cluster and find the closest data point to the centroid
for cluster_idx in range(N):
    # Get the indices of the data points in the current cluster
    cluster_indices = np.where(C_IDX == cluster_idx)[0]
    
    # Skip empty clusters (if any)
    if len(cluster_indices) == 0:
        print(f"Cluster {cluster_idx} is empty, skipping.")
        continue
    
    # Get the feature vectors for the data points in this cluster
    cluster_features = F[cluster_indices, :]
    
    # Get the centroid of this cluster
    centroid = CC[cluster_idx]
    
    # Compute the Euclidean distance between each point in the cluster and the centroid
    distances = cdist(cluster_features, centroid.reshape(1, -1), metric='euclidean')
    
    # Get the index of the closest data point to the centroid
    closest_point_idx = cluster_indices[np.argmin(distances)]
    
    # Set the corresponding entry in the binary matrix to 1 (keyframe)
    keyframe_matrix[closest_point_idx, cluster_idx] = 1

    # Optionally, print the keyframe index for each cluster
    print(f"Cluster {cluster_idx}: Keyframe index: {closest_point_idx}")
# keyframe_matrix is now a 950 x 143 binary matrix
# You can use it for further analysis or saving to a file
# Out:
# Cluster 0: Keyframe index: 2006
# Cluster 1: Keyframe index: 1310
# Cluster 2: Keyframe index: 2829
# Cluster 3: Keyframe index: 1371
# Cluster 4: Keyframe index: 291
# Cluster 5: Keyframe index: 1747
# Cluster 6: Keyframe index: 1011
# Cluster 7: Keyframe index: 1980
# Cluster 8: Keyframe index: 1707
# Cluster 9: Keyframe index: 806
# Cluster 10: Keyframe index: 2150
# Cluster 11: Keyframe index: 1812
# Cluster 12: Keyframe index: 134
# Cluster 13: Keyframe index: 1636
# Cluster 14: Keyframe index: 742
# Cluster 15: Keyframe index: 1568
# Cluster 16: Keyframe index: 1699
# Cluster 17: Keyframe index: 5
# Cluster 18: Keyframe index: 1759
# Cluster 19: Keyframe index: 1282
# Cluster 20: Keyframe index: 1957
# Cluster 21: Keyframe index: 1770
# Cluster 22: Keyframe index: 1647
# Cluster 23: Keyframe index: 2977
# Cluster 24: Keyframe index: 1441
# Cluster 25: Keyframe index: 2871
# Cluster 26: Keyframe index: 2640
# Cluster 441: Keyframe index: 1805
# Cluster 442: Keyframe index: 1434
# Cluster 443: Keyframe index: 1848
# Cluster 444: Keyframe index: 1856
# Cluster 445: Keyframe index: 1408
# Cluster 446: Keyframe index: 937
# Cluster 447: Keyframe index: 2928
# Cluster 448: Keyframe index: 1476
# Cluster 449: Keyframe index: 688
# Cluster 450: Keyframe index: 530
# Cluster 451: Keyframe index: 1061
# Cluster 452: Keyframe index: 2943
# Cluster 453: Keyframe index: 382
# Cluster 454: Keyframe index: 504
# Cluster 455: Keyframe index: 2000
# Cluster 456: Keyframe index: 117
# Cluster 457: Keyframe index: 1704
# Cluster 458: Keyframe index: 1902
# Cluster 459: Keyframe index: 366

# %%
# Save the keyframe binary matrix
np.save(r'C:\SumMe\Augmentation\AugBp\keyframe', keyframe_matrix)

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Step 1: Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBp\features_last_lstm.npy")

# Step 2: (Optional) Preprocess the data if needed
# For example, you might want to scale the features to ensure the clustering works well
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 3: Perform Agglomerative Clustering
# You can specify the number of clusters or other hyperparameters here
n_clusters = 460  # Example, set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model to the feature matrix
clustering_labels = clustering.fit_predict(features_scaled)

# Step 4: (Optional) Visualize the results if the features are 2D (or use dimensionality reduction)
if features_scaled.shape[1] == 2:  # If your features are 2D, you can visualize them
    plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=clustering_labels, cmap='viridis')
    plt.title("Agglomerative Clustering Results")
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# If you have higher-dimensional features, consider using PCA to reduce to 2D for visualization
# For example:
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# features_2d = pca.fit_transform(features_scaled)
# plt.scatter(features_2d[:, 0], features_2d[:, 1], c=clustering_labels, cmap='viridis')
# plt.show()

# Step 5: View the labels assigned to each data point
print("Cluster Labels:", clustering_labels)
# Out:
# Cluster Labels: [131 101 275 ... 122  62 290]

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBp\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters =460  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Display the clusters in the desired format
for cluster_label, indices in cluster_dict.items():
    print(f"Cluster {cluster_label}:")
    print(f"Indices of data points: {indices}")
    print(f"Number of data points in this cluster: {len(indices)}\n")
# Out:
# Cluster 131:
# Indices of data points: [0, 1405, 1747, 2116]
# Number of data points in this cluster: 4
#
# Cluster 101:
# Indices of data points: [1, 144, 183, 333, 416, 423, 768, 1079, 1254, 1634, 1948, 1965, 2198, 2394, 2422, 2830, 2940]
# Number of data points in this cluster: 17
#
# Cluster 275:
# Indices of data points: [2, 338, 2131]
# Number of data points in this cluster: 3
#
# Cluster 348:
# Indices of data points: [3, 29, 84, 409, 571, 616, 1118, 2860]
# Number of data points in this cluster: 8
#
# Cluster 283:
# Indices of data points: [4, 2010]
# Number of data points in this cluster: 2
#
# Cluster 69:
# Indices of data points: [5, 884, 1738, 2117]
# Number of data points in this cluster: 4
#
# Cluster 57:
# Indices of data points: [6, 94, 145, 605, 610, 1308, 1556, 1600, 1745, 1892, 1944, 2093, 2186, 2964]
# Number of data points in this cluster: 14
#
# Cluster 124:
# Indices of data points: [7, 239, 364, 641, 750, 839, 971, 1094, 1536, 1741, 1841, 1872, 1917, 2057, 2101, 2793]
# Number of data points in this cluster: 16
#
# Cluster 135:
# Indices of data points: [8, 128, 253, 1366, 2271]
# Number of data points in this cluster: 5
#
# Cluster 150:
# Indices of data points: [9, 119, 498, 718, 720, 1101, 1172, 1289, 1306, 1397, 2120, 2313, 2403, 2404, 2436, 2497]
# Number of data points in this cluster: 16
#
# Cluster 136:
# Indices of data points: [10, 268, 374, 1420, 2142, 2810]
# Number of data points in this cluster: 6
#
# Cluster 89:
# Indices of data points: [11, 13, 329, 485, 748, 949, 1184, 1573, 1932, 2572, 2882]
# Number of data points in this cluster: 11
#
# Cluster 140:
# Indices of data points: [12, 31, 152, 537, 1215, 2289, 2336, 2467, 2562, 2569, 2612, 2623, 2661]
# Number of data points in this cluster: 13
#
# Cluster 435:
# Indices of data points: [14, 177, 2091, 2905]
# Number of data points in this cluster: 4
#
# Cluster 280:
# Indices of data points: [15, 37, 1548]
# Number of data points in this cluster: 3
#
# Cluster 105:
# Indices of data points: [16, 352, 564, 2159]
# Number of data points in this cluster: 4
#
# Cluster 71:
# Indices of data points: [17, 163, 179, 842, 1219, 1809, 1890, 2401, 2453, 2601, 2621, 2628, 2847]
# Number of data points in this cluster: 13
#
# Cluster 4:
# Indices of data points: [18, 1316, 1339, 1440, 1767, 2190]
# Number of data points in this cluster: 6
#
# Cluster 126:
# Indices of data points: [19, 799, 843, 2804]
# Number of data points in this cluster: 4
#
# Cluster 165:
# Indices of data points: [20, 258, 269, 2778]
# Number of data points in this cluster: 4
#
# Cluster 237:
# Indices of data points: [21, 474, 944, 1864, 2246, 2582, 2616, 2675, 2780]
# Number of data points in this cluster: 9
#
# Cluster 119:
# Indices of data points: [22, 203, 477, 519, 587, 590, 759, 895, 1503, 1706, 1817, 1836, 2195, 2324, 2334, 2372, 2446, 2516, 2538]
# Number of data points in this cluster: 19
#
# Cluster 215:
# Indices of data points: [23, 730, 1159, 1376, 1550, 1795, 2322]
# Number of data points in this cluster: 7
#
# Cluster 230:
# Indices of data points: [24, 390, 470, 714, 1086, 1140, 2084, 2088, 2361, 2790]
# Number of data points in this cluster: 10
#
# Cluster 121:
# Indices of data points: [25, 43, 621, 829, 1103, 1626, 1987, 2781, 2842, 2857]
# Number of data points in this cluster: 10
#
# Cluster 207:
# Indices of data points: [26, 412, 657, 969, 1081, 1575, 1694, 1712, 1977, 2239, 2307]
# Number of data points in this cluster: 11
#
# Cluster 23:
# Indices of data points: [27, 109, 185, 186, 376, 417, 483, 554, 643, 687, 703, 732, 851, 1591, 1651, 1688, 1808, 1830, 1918, 2808, 2931, 2934]
# Number of data points in this cluster: 22
#
# Cluster 192:
# Indices of data points: [28, 1599, 2814, 3009, 3023]
# Number of data points in this cluster: 5
#
# Cluster 408:
# Indices of data points: [30, 360, 394, 2430, 2941]
# Number of data points in this cluster: 5
#
# Cluster 209:
# Indices of data points: [32, 224, 932, 1005, 1490, 2245]
# Number of data points in this cluster: 6
#
# Cluster 147:
# Indices of data points: [33, 114, 200, 904, 1151, 1526, 1703, 2505, 2634]
# Number of data points in this cluster: 9
#
# Cluster 242:
# Indices of data points: [34, 293, 411]
# Number of data points in this cluster: 3
#
# Cluster 15:
# Indices of data points: [35, 192, 381, 424, 570, 707, 710, 1229, 1475, 1586, 1659, 2194, 2719]
# Number of data points in this cluster: 13
#
# Cluster 385:
# Indices of data points: [36, 488, 1041, 1858, 1928, 2375, 2492, 2605, 2682, 2718]
# Number of data points in this cluster: 10
#
# Cluster 99:
# Indices of data points: [38, 1938, 3045]
# Number of data points in this cluster: 3
#
# Cluster 62:
# Indices of data points: [39, 230, 288, 632, 741, 855, 1675, 1951, 1982, 2022, 3024, 3062]
# Number of data points in this cluster: 12
#
# Cluster 364:
# Indices of data points: [40, 153, 901, 1587, 1662, 1899, 1964, 2761]
# Number of data points in this cluster: 8
#
# Cluster 373:
# Indices of data points: [41, 1267]
# Number of data points in this cluster: 2
#
# Cluster 200:
# Indices of data points: [42, 92, 100, 370, 805, 841, 1268, 1374, 1904, 1913, 2127, 2311, 2365, 2426, 2531]
# Number of data points in this cluster: 15
#
# Cluster 7:
# Indices of data points: [44, 108, 466, 1298, 1335, 1456, 1921, 2006, 2046, 2455, 2854, 2859, 2932, 2952]
# Number of data points in this cluster: 14
#
# Cluster 19:
# Indices of data points: [45, 106, 250, 692, 848, 1326, 1652, 1887, 2134, 2180, 2303, 2310, 2427, 2463, 2653, 2902, 2908, 3057]
# Number of data points in this cluster: 18
#
# Cluster 117:
# Indices of data points: [46, 101, 210, 305, 1221, 1554, 1628, 2440, 2573, 2856, 2898]
# Number of data points in this cluster: 11
#
# Cluster 70:
# Indices of data points: [47, 798, 874, 1950, 2407]
# Number of data points in this cluster: 5
#
# Cluster 416:
# Indices of data points: [48, 491, 584, 1852, 2021, 2690]
# Number of data points in this cluster: 6
#
# Cluster 115:
# Indices of data points: [49, 310, 443, 740, 984, 1028, 1205, 1217, 1471, 1716, 1746, 1825, 2205, 2406, 2509]
# Number of data points in this cluster: 15
#
# Cluster 58:
# Indices of data points: [50, 172, 623, 942, 1269, 2462, 2660, 2703, 2903]
# Number of data points in this cluster: 9
#
# Cluster 17:
# Indices of data points: [51, 130, 156, 212, 273, 617, 619, 735, 813, 858, 1071, 1156, 1356, 1722, 2552, 2959]
# Number of data points in this cluster: 16
#
# Cluster 152:
# Indices of data points: [52, 652, 800, 1283, 1797, 1968, 2140, 2292, 2477, 2561]
# Number of data points in this cluster: 10
#
# Cluster 113:
# Indices of data points: [53, 921, 974, 999, 1697, 1866, 2089, 2143, 2300]
# Number of data points in this cluster: 9
#
# Cluster 311:
# Indices of data points: [54, 81, 604, 897, 1470, 1941, 2056]
# Number of data points in this cluster: 7
#
# Cluster 199:
# Indices of data points: [55, 226, 473, 1023, 1411, 1451, 1648, 1811, 2097, 2437, 2481, 2482, 2679]
# Number of data points in this cluster: 13
#
# Cluster 68:
# Indices of data points: [56, 57, 122, 188, 745, 925, 1961, 2094, 2827]
# Number of data points in this cluster: 9
#
# Cluster 271:
# Indices of data points: [58, 802, 1724]
# Number of data points in this cluster: 3
#
# Cluster 224:
# Indices of data points: [59, 462, 486, 819, 1027, 1095, 1160, 1195, 1232, 1531, 1893, 1952, 2383, 2577, 2734]
# Number of data points in this cluster: 15
#
# Cluster 248:
# Indices of data points: [60, 236, 248, 395, 459, 661, 1050, 1518, 1546, 1630, 1637, 1839, 2342, 2473, 2579, 2828, 2951]
# Number of data points in this cluster: 17
#
# Cluster 56:
# Indices of data points: [61, 215, 1357, 1387, 2138]
# Number of data points in this cluster: 5
#
# Cluster 51:
# Indices of data points: [62, 68, 407, 699, 715, 1109, 1285, 1768, 2048, 2547]
# Number of data points in this cluster: 10
#
# Cluster 430:
# Indices of data points: [63, 127, 219, 823, 1900, 1908, 2364, 2400, 2602]
# Number of data points in this cluster: 9
#
# Cluster 55:
# Indices of data points: [64, 77, 377, 450, 824, 903, 1121, 1560, 1674, 2930, 3001, 3028]
# Number of data points in this cluster: 12
#
# Cluster 158:
# Indices of data points: [65, 171, 306, 513, 637, 758, 850, 1022, 1293, 1785, 2291, 2392, 2685, 2717, 2858]
# Number of data points in this cluster: 15
#
# Cluster 309:
# Indices of data points: [66, 195, 252, 846, 1039, 1327, 1669, 1769, 2519, 2558, 2629, 2647, 2840, 2913]
# Number of data points in this cluster: 14
#
# Cluster 375:
# Indices of data points: [67, 259, 682, 1097, 1161, 1629, 2765, 2870, 2873]
# Number of data points in this cluster: 9
#
# Cluster 39:
# Indices of data points: [69, 123, 142, 527, 1179, 1256, 1275, 1635, 1850, 1853, 2323, 2337, 2368, 2378, 2570]
# Number of data points in this cluster: 15
#
# Cluster 421:
# Indices of data points: [70, 943, 1751, 2069, 2308, 2789]
# Number of data points in this cluster: 6
#
# Cluster 97:
# Indices of data points: [71, 182, 653, 678, 1017, 1155, 1990, 2204, 2461, 2604, 2712, 2772]
# Number of data points in this cluster: 12
#
# Cluster 370:
# Indices of data points: [72, 96, 1091, 1292, 1620, 2051, 2916, 3021]
# Number of data points in this cluster: 8
#
# Cluster 144:
# Indices of data points: [73, 463, 583, 648, 784, 1693, 1831, 2002, 2413, 2534, 2812]
# Number of data points in this cluster: 11
#
# Cluster 359:
# Indices of data points: [74, 137, 461, 1258, 1265, 1401, 2866, 2954]
# Number of data points in this cluster: 8
#
# Cluster 227:
# Indices of data points: [75, 147, 495, 717, 783, 811, 1239, 1321, 2004, 2018, 2033, 2648, 2663, 2796, 2991]
# Number of data points in this cluster: 15
#
# Cluster 396:
# Indices of data points: [76, 80, 437, 2005, 2099, 2351, 2416, 2752, 2904]
# Number of data points in this cluster: 9
#
# Cluster 342:
# Indices of data points: [78, 351, 449, 455, 1671, 1828, 2821]
# Number of data points in this cluster: 7
#
# Cluster 2:
# Indices of data points: [79, 343, 446, 601, 1183, 1806, 1849, 2001, 2379, 2470, 2472, 2543, 2571, 2584, 2610, 2688, 2706, 2711, 2832]
# Number of data points in this cluster: 19
#
# Cluster 82:
# Indices of data points: [82, 673, 1146, 1204, 1304, 2103, 2240]
# Number of data points in this cluster: 7
#
# Cluster 278:
# Indices of data points: [83, 928, 960, 1042, 1479, 1625, 2478, 2627, 2942, 3022]
# Number of data points in this cluster: 10
#
# Cluster 22:
# Indices of data points: [85, 429, 569, 840, 1074, 1282, 1313, 2580, 2606, 2625, 2654, 2666, 2678, 2817]
# Number of data points in this cluster: 14
#
# Cluster 284:
# Indices of data points: [86, 506, 508, 669, 1002, 1271, 1777, 2017, 2064, 2338, 2433]
# Number of data points in this cluster: 11
#
# Cluster 132:
# Indices of data points: [87, 93, 505, 525, 951, 1170, 2201, 2541, 2724, 2968, 3013, 3046]
# Number of data points in this cluster: 12
#
# Cluster 296:
# Indices of data points: [88, 242, 472, 499, 900, 953, 1129, 1194, 2038, 2047, 2885, 2937]
# Number of data points in this cluster: 12
#
# Cluster 84:
# Indices of data points: [89, 1753, 2971]
# Number of data points in this cluster: 3
#
# Cluster 254:
# Indices of data points: [90, 603, 2043, 2848]
# Number of data points in this cluster: 4
#
# Cluster 241:
# Indices of data points: [91, 355, 738, 1182, 1248, 1717, 2380, 2452, 2745, 3018]
# Number of data points in this cluster: 10
#
# Cluster 185:
# Indices of data points: [95, 771, 1260, 1368, 1624, 2112]
# Number of data points in this cluster: 6
#
# Cluster 8:
# Indices of data points: [97, 902, 1060, 1062, 1297, 1537, 1649, 1666, 2356, 2391, 2412, 2511, 2667, 2826, 3036, 3043]
# Number of data points in this cluster: 16
#
# Cluster 72:
# Indices of data points: [98, 630, 700, 833, 861, 1036, 1143, 1996, 2178, 2956]
# Number of data points in this cluster: 10
#
# Cluster 181:
# Indices of data points: [99, 1135, 1487, 1935]
# Number of data points in this cluster: 4
#
# Cluster 157:
# Indices of data points: [102, 544, 624, 905, 1108, 1980, 2387, 2551, 2565, 2614, 2671]
# Number of data points in this cluster: 11
#
# Cluster 295:
# Indices of data points: [103, 150, 207, 251, 438, 1230, 1291, 1336, 1914, 1969, 2411, 2693, 2696]
# Number of data points in this cluster: 13
#
# Cluster 102:
# Indices of data points: [104, 476, 644, 667, 1521, 1638, 1654, 2464, 2716, 2727]
# Number of data points in this cluster: 10
#
# Cluster 198:
# Indices of data points: [105, 791, 1069, 1189, 1857, 2027, 2295, 2362, 2489, 2638, 2822]
# Number of data points in this cluster: 11
#
# Cluster 37:
# Indices of data points: [107, 879, 1279, 1524, 1541, 2129, 2418, 2542, 2581]
# Number of data points in this cluster: 9
#
# Cluster 276:
# Indices of data points: [110, 1110, 1198, 1448, 1571, 1658]
# Number of data points in this cluster: 6
#
# Cluster 94:
# Indices of data points: [111, 135, 1235, 2062, 2070, 2144, 2170, 2897]
# Number of data points in this cluster: 8
#
# Cluster 112:
# Indices of data points: [112, 380, 1032, 1244, 1312, 1345, 1417, 1561, 1975, 1992, 1994, 2230, 2833, 2958]
# Number of data points in this cluster: 14
#
# Cluster 172:
# Indices of data points: [113, 263, 723, 790]
# Number of data points in this cluster: 4
#
# Cluster 240:
# Indices of data points: [115, 1099, 1636, 1664, 1714, 1883, 1995, 2162, 2749, 2896]
# Number of data points in this cluster: 10
#
# Cluster 123:
# Indices of data points: [116, 139, 168, 548, 1061, 1642, 2344, 2484, 2533, 2651, 2683, 2733, 3026]
# Number of data points in this cluster: 13
#
# Cluster 197:
# Indices of data points: [117, 180, 467, 469, 882, 1092, 1691, 2122, 2598, 3060]
# Number of data points in this cluster: 10
#
# Cluster 260:
# Indices of data points: [118, 591, 677, 1933, 2016, 2216]
# Number of data points in this cluster: 6
#
# Cluster 263:
# Indices of data points: [120, 227, 382, 731, 878, 1046, 1338, 1655, 1772, 1840, 1842, 1846, 2371, 2768]
# Number of data points in this cluster: 14
#
# Cluster 447:
# Indices of data points: [121, 538, 1058, 1077, 2506]
# Number of data points in this cluster: 5
#
# Cluster 162:
# Indices of data points: [124, 254, 516, 1126, 1284, 1294, 1985, 1998, 2510, 2753]
# Number of data points in this cluster: 10
#
# Cluster 40:
# Indices of data points: [125, 668, 2148, 2266]
# Number of data points in this cluster: 4
#
# Cluster 351:
# Indices of data points: [126, 336, 866, 1372, 1815, 2175, 2192, 2985]
# Number of data points in this cluster: 8
#
# Cluster 383:
# Indices of data points: [129, 521, 1483, 1861, 2102]
# Number of data points in this cluster: 5
#
# Cluster 257:
# Indices of data points: [131, 197, 247, 934, 1078, 1165, 1201, 1473, 2771]
# Number of data points in this cluster: 9
#
# Cluster 47:
# Indices of data points: [132, 321, 517, 920, 1038, 1068, 1234, 1453, 2012, 2350, 2469, 2550, 2767]
# Number of data points in this cluster: 13
#
# Cluster 355:
# Indices of data points: [133, 1513, 1781, 2124, 2545]
# Number of data points in this cluster: 5
#
# Cluster 272:
# Indices of data points: [134, 2060, 2141]
# Number of data points in this cluster: 3
#
# Cluster 114:
# Indices of data points: [136, 814, 1311, 1622, 2035, 2063, 2286, 2657, 2786, 2969, 3039]
# Number of data points in this cluster: 11
#
# Cluster 143:
# Indices of data points: [138, 693, 825, 938, 941, 992, 1026, 1138, 1786, 1991, 2182, 2809, 2918]
# Number of data points in this cluster: 13
#
# Cluster 399:
# Indices of data points: [140, 704, 1208, 2366, 2490, 2491, 2528, 2539, 2554, 2935]
# Number of data points in this cluster: 10
#
# Cluster 149:
# Indices of data points: [141, 169, 431, 996, 1063, 1539, 1682, 1690, 1906, 1942, 2326, 2327, 2476, 2700]
# Number of data points in this cluster: 14
#
# Cluster 48:
# Indices of data points: [143, 524, 736, 796, 1414, 1679, 1757, 1993, 2074, 2202, 2316, 2515, 2658, 2888]
# Number of data points in this cluster: 14
#
# Cluster 356:
# Indices of data points: [146, 154, 453, 492, 1957, 1986, 2013, 2185, 2721, 2735, 2797, 2936, 3053]
# Number of data points in this cluster: 13
#
# Cluster 218:
# Indices of data points: [148, 1439, 1750, 2252]
# Number of data points in this cluster: 4
#
# Cluster 450:
# Indices of data points: [149, 202, 549, 1227, 2353, 2645, 2659]
# Number of data points in this cluster: 7
#
# Cluster 20:
# Indices of data points: [151, 213, 403, 478, 597, 680, 893, 1055, 1154, 1236, 1274, 1971, 2199, 2200, 2328, 2388, 2680, 2993, 3025, 3055]
# Number of data points in this cluster: 20
#
# Cluster 202:
# Indices of data points: [155, 889, 1502, 1838, 2640]
# Number of data points in this cluster: 5
#
# Cluster 380:
# Indices of data points: [157, 847, 872, 1800, 1835, 2468, 2555, 2611, 2795]
# Number of data points in this cluster: 9
#
# Cluster 86:
# Indices of data points: [158, 838, 1302, 1735, 1925, 1959, 2431, 2494, 2544, 2559, 2591, 2684, 3014]
# Number of data points in this cluster: 13
#
# Cluster 415:
# Indices of data points: [159, 176, 547, 626, 753, 912, 1112, 1416, 2594]
# Number of data points in this cluster: 9
#
# Cluster 118:
# Indices of data points: [160, 881]
# Number of data points in this cluster: 2
#
# Cluster 34:
# Indices of data points: [161, 510, 683, 1719, 1793, 2082, 2321, 2837, 2962]
# Number of data points in this cluster: 9
#
# Cluster 78:
# Indices of data points: [162, 173, 201, 767, 1105, 1855, 2329, 2373, 2520, 2665, 2899]
# Number of data points in this cluster: 11
#
# Cluster 211:
# Indices of data points: [164, 611, 2480, 2495, 2556]
# Number of data points in this cluster: 5
#
# Cluster 67:
# Indices of data points: [165, 896, 2256, 2264, 2279, 2529]
# Number of data points in this cluster: 6
#
# Cluster 155:
# Indices of data points: [166, 260, 689, 1067, 1084, 1685, 1845, 2318, 2398, 2434, 2631, 2689, 2929]
# Number of data points in this cluster: 13
#
# Cluster 133:
# Indices of data points: [167, 468, 593, 650, 852, 1981, 2333, 2668, 2773, 2831, 2907, 2944]
# Number of data points in this cluster: 12
#
# Cluster 360:
# Indices of data points: [170, 174, 849, 906, 1090, 1701, 2774]
# Number of data points in this cluster: 7
#
# Cluster 245:
# Indices of data points: [175, 184, 425, 456, 1209, 1631, 1922, 2501, 2523, 2532, 2535, 2714, 2992, 3037]
# Number of data points in this cluster: 14
#
# Cluster 95:
# Indices of data points: [178, 436, 2868]
# Number of data points in this cluster: 3
#
# Cluster 29:
# Indices of data points: [181, 265, 419, 913, 1113, 1168, 1270, 2119, 2402, 2536, 2576, 2995]
# Number of data points in this cluster: 12
#
# Cluster 127:
# Indices of data points: [187, 231, 501, 502, 716, 957, 1296, 1683, 2302, 2348, 2465, 2639]
# Number of data points in this cluster: 12
#
# Cluster 12:
# Indices of data points: [189, 198, 345, 363, 739, 1133, 1199, 1393, 1484, 1574, 1886, 2073, 2177, 2330, 2442, 2722, 3016]
# Number of data points in this cluster: 17
#
# Cluster 223:
# Indices of data points: [190, 229, 255, 433, 1485, 1553, 1804, 1979, 2163, 2191, 2779]
# Number of data points in this cluster: 11
#
# Cluster 282:
# Indices of data points: [191, 328]
# Number of data points in this cluster: 2
#
# Cluster 203:
# Indices of data points: [193, 414, 698, 794, 995, 1001, 1710, 2439, 2669, 2946]
# Number of data points in this cluster: 10
#
# Cluster 76:
# Indices of data points: [194, 631, 690, 709, 1187, 1774, 1871, 2161, 2304, 2498, 2583, 2643, 2662, 2927, 2965]
# Number of data points in this cluster: 15
#
# Cluster 423:
# Indices of data points: [196, 507, 566, 654, 793, 2852, 2960, 3032]
# Number of data points in this cluster: 8
#
# Cluster 335:
# Indices of data points: [199, 1015, 1130, 1149, 1501, 1875, 1881, 2513, 2763, 2895]
# Number of data points in this cluster: 10
#
# Cluster 41:
# Indices of data points: [204, 503, 588, 646, 777, 890, 1174, 1633, 1733, 1879, 2290, 2869, 3056]
# Number of data points in this cluster: 13
#
# Cluster 369:
# Indices of data points: [205, 244, 835, 1018, 1111, 1196, 1224, 1237, 2009, 2377, 2438]
# Number of data points in this cluster: 11
#
# Cluster 301:
# Indices of data points: [206, 220, 918, 1153, 1263, 1347, 2563, 2970]
# Number of data points in this cluster: 8
#
# Cluster 42:
# Indices of data points: [208, 350, 353, 990]
# Number of data points in this cluster: 4
#
# Cluster 372:
# Indices of data points: [209, 706, 749, 1115, 1681, 2288, 2626, 2806]
# Number of data points in this cluster: 8
#
# Cluster 446:
# Indices of data points: [211, 1102, 2037, 2217, 2530]
# Number of data points in this cluster: 5
#
# Cluster 163:
# Indices of data points: [214, 366, 772, 821, 1569, 1618, 2487, 2953]
# Number of data points in this cluster: 8
#
# Cluster 377:
# Indices of data points: [216, 1164, 2087, 2187, 2537]
# Number of data points in this cluster: 5
#
# Cluster 169:
# Indices of data points: [217, 447, 1238, 1343, 1668, 2169, 2226, 2912]
# Number of data points in this cluster: 8
#
# Cluster 324:
# Indices of data points: [218, 347, 457, 691, 1434, 1967, 2389, 2396]
# Number of data points in this cluster: 8
#
# Cluster 322:
# Indices of data points: [221, 2040, 2345, 2425, 2503, 2564, 2589]
# Number of data points in this cluster: 7
#
# Cluster 100:
# Indices of data points: [222, 579, 649, 1120, 1534]
# Number of data points in this cluster: 5
#
# Cluster 54:
# Indices of data points: [223, 344, 388, 413, 697, 722, 972, 1181, 1469, 1489, 1760, 1868, 2039, 2075, 2783, 2864]
# Number of data points in this cluster: 16
#
# Cluster 74:
# Indices of data points: [225, 480, 719, 859, 1003, 1415, 2181, 2459, 2843]
# Number of data points in this cluster: 9
#
# Cluster 326:
# Indices of data points: [228, 1447]
# Number of data points in this cluster: 2
#
# Cluster 145:
# Indices of data points: [232, 445, 660, 754, 892, 1033, 1045, 1318, 1329, 1331, 1379, 1897, 2108, 2206, 2272, 2306, 2443, 2702]
# Number of data points in this cluster: 18
#
# Cluster 323:
# Indices of data points: [233, 869, 1197, 1323, 1700, 1874, 1884, 1984, 2081, 2156, 2189]
# Number of data points in this cluster: 11
#
# Cluster 9:
# Indices of data points: [234, 266, 404, 864, 955, 1029, 1076, 1242, 1438, 1532, 1873, 2118, 2260]
# Number of data points in this cluster: 13
#
# Cluster 456:
# Indices of data points: [235, 1704]
# Number of data points in this cluster: 2
#
# Cluster 310:
# Indices of data points: [237, 497, 599, 658, 665, 917, 1213, 1807, 2486, 2676]
# Number of data points in this cluster: 10
#
# Cluster 336:
# Indices of data points: [238, 1885, 2493, 2540, 2593, 2596, 2748]
# Number of data points in this cluster: 7
#
# Cluster 109:
# Indices of data points: [240, 249, 743, 1021, 1375, 1399, 1583, 2879, 2906, 3040]
# Number of data points in this cluster: 10
#
# Cluster 120:
# Indices of data points: [241, 596, 662, 962, 1052, 1429, 1927, 1960, 2026, 2050, 2078, 2424, 2713, 2736, 2770]
# Number of data points in this cluster: 15
#
# Cluster 444:
# Indices of data points: [243, 346, 675, 810, 1910, 2139]
# Number of data points in this cluster: 6
#
# Cluster 111:
# Indices of data points: [245, 2728, 3017]
# Number of data points in this cluster: 3
#
# Cluster 235:
# Indices of data points: [246, 369, 531, 845, 2032, 2386, 2900, 3027]
# Number of data points in this cluster: 8
#
# Cluster 18:
# Indices of data points: [256, 606, 2034, 2055]
# Number of data points in this cluster: 4
#
# Cluster 195:
# Indices of data points: [257, 493, 865, 1865]
# Number of data points in this cluster: 4
#
# Cluster 170:
# Indices of data points: [261, 910, 1158, 1383, 1775, 1966, 1983, 2232, 2723]
# Number of data points in this cluster: 9
#
# Cluster 279:
# Indices of data points: [262, 877, 1098, 1424, 1511, 1790]
# Number of data points in this cluster: 6
#
# Cluster 75:
# Indices of data points: [264, 392, 826, 923, 1019, 1826, 2340, 2458, 2587, 2595]
# Number of data points in this cluster: 10
#
# Cluster 270:
# Indices of data points: [267, 2792]
# Number of data points in this cluster: 2
#
# Cluster 63:
# Indices of data points: [270, 421, 708, 761, 1008, 1011, 1125, 1272, 1324, 1442, 1445, 1903, 1907, 2592, 2670, 2715, 2743, 2802, 2867, 2876, 2892]
# Number of data points in this cluster: 21
#
# Cluster 43:
# Indices of data points: [271, 291, 563, 1570, 1727, 2065]
# Number of data points in this cluster: 6
#
# Cluster 38:
# Indices of data points: [272, 286, 562, 1233, 1676]
# Number of data points in this cluster: 5
#
# Cluster 167:
# Indices of data points: [274, 534, 2267, 2815]
# Number of data points in this cluster: 4
#
# Cluster 59:
# Indices of data points: [275, 302, 357, 803, 985, 3002]
# Number of data points in this cluster: 6
#
# Cluster 238:
# Indices of data points: [276, 1051, 1358, 1589, 1601, 1640, 1895, 1923, 2766]
# Number of data points in this cluster: 9
#
# Cluster 274:
# Indices of data points: [277, 348, 875, 1200, 1286, 2083, 2085, 2646]
# Number of data points in this cluster: 8
#
# Cluster 432:
# Indices of data points: [278, 379, 724]
# Number of data points in this cluster: 3
#
# Cluster 220:
# Indices of data points: [279, 479, 1000]
# Number of data points in this cluster: 3
#
# Cluster 146:
# Indices of data points: [280, 1725]
# Number of data points in this cluster: 2
#
# Cluster 194:
# Indices of data points: [281, 322]
# Number of data points in this cluster: 2
#
# Cluster 210:
# Indices of data points: [282, 981]
# Number of data points in this cluster: 2
#
# Cluster 79:
# Indices of data points: [283, 294, 2973, 2983]
# Number of data points in this cluster: 4
#
# Cluster 332:
# Indices of data points: [284, 2803, 2835]
# Number of data points in this cluster: 3
#
# Cluster 252:
# Indices of data points: [285, 287, 300, 1403, 1621, 1743, 1754]
# Number of data points in this cluster: 7
#
# Cluster 434:
# Indices of data points: [289, 2726]
# Number of data points in this cluster: 2
#
# Cluster 219:
# Indices of data points: [290, 1749, 1843, 3019]
# Number of data points in this cluster: 4
#
# Cluster 28:
# Indices of data points: [292, 618, 744, 804, 1096, 1100, 1225, 1392, 1692, 1794, 1824, 2076, 2105, 2471, 2818]
# Number of data points in this cluster: 15
#
# Cluster 445:
# Indices of data points: [295, 1065]
# Number of data points in this cluster: 2
#
# Cluster 437:
# Indices of data points: [296, 2982]
# Number of data points in this cluster: 2
#
# Cluster 367:
# Indices of data points: [297, 927, 1353, 1426, 2221, 2449]
# Number of data points in this cluster: 6
#
# Cluster 431:
# Indices of data points: [298]
# Number of data points in this cluster: 1
#
# Cluster 96:
# Indices of data points: [299, 440, 694, 812, 1020, 1290, 1340, 2115, 2637, 2769]
# Number of data points in this cluster: 10
#
# Cluster 98:
# Indices of data points: [301, 1514, 3047]
# Number of data points in this cluster: 3
#
# Cluster 180:
# Indices of data points: [303, 1127, 1137, 1177]
# Number of data points in this cluster: 4
#
# Cluster 31:
# Indices of data points: [304, 526, 1488, 2301]
# Number of data points in this cluster: 4
#
# Cluster 44:
# Indices of data points: [307, 1559, 1612, 2298]
# Number of data points in this cluster: 4
#
# Cluster 328:
# Indices of data points: [308, 948, 1748, 2757, 2800]
# Number of data points in this cluster: 5
#
# Cluster 334:
# Indices of data points: [309]
# Number of data points in this cluster: 1
#
# Cluster 166:
# Indices of data points: [311, 594, 789, 1147, 1253, 1325, 1360, 1441, 2603, 2741, 2750]
# Number of data points in this cluster: 11
#
# Cluster 368:
# Indices of data points: [312]
# Number of data points in this cluster: 1
#
# Cluster 307:
# Indices of data points: [313, 326, 2507, 2972]
# Number of data points in this cluster: 4
#
# Cluster 26:
# Indices of data points: [314, 871, 1572, 1788, 2188, 2225]
# Number of data points in this cluster: 6
#
# Cluster 261:
# Indices of data points: [315, 340, 401, 1759]
# Number of data points in this cluster: 4
#
# Cluster 65:
# Indices of data points: [316, 444, 2456, 2619]
# Number of data points in this cluster: 4
#
# Cluster 32:
# Indices of data points: [317, 1016, 1510, 2146]
# Number of data points in this cluster: 4
#
# Cluster 141:
# Indices of data points: [318, 1281, 1530, 1533, 1867, 2041, 2861, 2893]
# Number of data points in this cluster: 8
#
# Cluster 106:
# Indices of data points: [319, 1114, 1614, 1937, 2167, 2220]
# Number of data points in this cluster: 6
#
# Cluster 30:
# Indices of data points: [320, 439, 1116, 1678, 1888, 2212, 2275, 2788, 2920]
# Number of data points in this cluster: 9
#
# Cluster 204:
# Indices of data points: [323, 1012, 1756, 2145, 2274, 2975]
# Number of data points in this cluster: 6
#
# Cluster 358:
# Indices of data points: [324, 1355, 2173]
# Number of data points in this cluster: 3
#
# Cluster 36:
# Indices of data points: [325, 1122, 1752, 1870, 2166, 2234, 2853]
# Number of data points in this cluster: 7
#
# Cluster 81:
# Indices of data points: [327, 873, 1444]
# Number of data points in this cluster: 3
#
# Cluster 49:
# Indices of data points: [330, 1362, 3010]
# Number of data points in this cluster: 3
#
# Cluster 255:
# Indices of data points: [331, 1784, 3011]
# Number of data points in this cluster: 3
#
# Cluster 161:
# Indices of data points: [332, 386, 406, 528, 1930, 2014, 2254, 2287]
# Number of data points in this cluster: 8
#
# Cluster 449:
# Indices of data points: [334, 1255, 1821, 2207]
# Number of data points in this cluster: 4
#
# Cluster 110:
# Indices of data points: [335, 870, 1180, 1371, 1446, 1902, 2319]
# Number of data points in this cluster: 7
#
# Cluster 386:
# Indices of data points: [337, 765, 956, 1139, 1802, 1854, 2237, 2457, 2849]
# Number of data points in this cluster: 9
#
# Cluster 314:
# Indices of data points: [339, 415, 2113, 2283]
# Number of data points in this cluster: 4
#
# Cluster 268:
# Indices of data points: [341, 448, 533, 602, 752, 883, 1203, 1457, 1619, 2846]
# Number of data points in this cluster: 10
#
# Cluster 187:
# Indices of data points: [342, 2114, 2233]
# Number of data points in this cluster: 3
#
# Cluster 246:
# Indices of data points: [349, 980, 1761]
# Number of data points in this cluster: 3
#
# Cluster 345:
# Indices of data points: [354, 636, 815, 860, 929, 1070, 1709, 1715, 2504, 2708]
# Number of data points in this cluster: 10
#
# Cluster 374:
# Indices of data points: [356, 924]
# Number of data points in this cluster: 2
#
# Cluster 410:
# Indices of data points: [358, 1407, 1535]
# Number of data points in this cluster: 3
#
# Cluster 35:
# Indices of data points: [359, 774, 876, 966, 1744, 2999]
# Number of data points in this cluster: 6
#
# Cluster 129:
# Indices of data points: [361, 1266, 1333, 2157, 3044]
# Number of data points in this cluster: 5
#
# Cluster 46:
# Indices of data points: [362, 490, 914, 1152, 1677]
# Number of data points in this cluster: 5
#
# Cluster 250:
# Indices of data points: [365, 930, 1515]
# Number of data points in this cluster: 3
#
# Cluster 308:
# Indices of data points: [367, 2109, 2269, 3012]
# Number of data points in this cluster: 4
#
# Cluster 10:
# Indices of data points: [368, 577, 629, 670, 961, 1088, 1540, 1684, 1920, 1976, 2421, 2527]
# Number of data points in this cluster: 12
#
# Cluster 173:
# Indices of data points: [371, 518, 1031, 2158, 2258]
# Number of data points in this cluster: 5
#
# Cluster 339:
# Indices of data points: [372, 454, 950, 983, 2151, 2219, 2707, 3004]
# Number of data points in this cluster: 8
#
# Cluster 289:
# Indices of data points: [373, 1643]
# Number of data points in this cluster: 2
#
# Cluster 83:
# Indices of data points: [375, 559, 945, 959, 1468, 1597, 1672, 2238, 2801, 2976]
# Number of data points in this cluster: 10
#
# Cluster 361:
# Indices of data points: [378, 553, 647, 655, 1056, 1142, 2420]
# Number of data points in this cluster: 7
#
# Cluster 414:
# Indices of data points: [383, 1150, 2317, 2359, 2560]
# Number of data points in this cluster: 5
#
# Cluster 286:
# Indices of data points: [384, 885, 1882, 2901]
# Number of data points in this cluster: 4
#
# Cluster 50:
# Indices of data points: [385, 625, 908, 1066, 1261, 1687, 2367]
# Number of data points in this cluster: 7
#
# Cluster 125:
# Indices of data points: [387, 496, 515, 628, 751, 797, 1145, 1192, 1245, 1718, 2176, 2213, 2415, 2751, 2811, 2820]
# Number of data points in this cluster: 16
#
# Cluster 405:
# Indices of data points: [389, 1463]
# Number of data points in this cluster: 2
#
# Cluster 441:
# Indices of data points: [391, 968, 1277, 1500, 2086, 2209, 2242]
# Number of data points in this cluster: 7
#
# Cluster 381:
# Indices of data points: [393, 523, 1647]
# Number of data points in this cluster: 3
#
# Cluster 208:
# Indices of data points: [396, 994, 1568, 1931, 2756]
# Number of data points in this cluster: 5
#
# Cluster 243:
# Indices of data points: [397, 405, 615, 795, 857, 1009, 1460, 1924, 1970, 2095]
# Number of data points in this cluster: 10
#
# Cluster 264:
# Indices of data points: [398, 898, 1035]
# Number of data points in this cluster: 3
#
# Cluster 130:
# Indices of data points: [399, 844, 1218, 1443, 1584, 2174, 2251, 2945, 2949]
# Number of data points in this cluster: 9
#
# Cluster 371:
# Indices of data points: [400, 1301, 1382, 1412, 2349, 2557, 2699]
# Number of data points in this cluster: 7
#
# Cluster 401:
# Indices of data points: [402, 1542]
# Number of data points in this cluster: 2
#
# Cluster 52:
# Indices of data points: [408, 1131, 1295, 1551, 2357, 2423, 2460, 2609, 2649, 2677, 2687, 3051]
# Number of data points in this cluster: 12
#
# Cluster 265:
# Indices of data points: [410, 573, 688, 853, 867, 1216, 1257, 1462, 2314, 2335, 3034, 3059]
# Number of data points in this cluster: 12
#
# Cluster 312:
# Indices of data points: [418, 1262, 2502]
# Number of data points in this cluster: 3
#
# Cluster 137:
# Indices of data points: [420, 686, 958, 1673, 1898, 2107, 2395, 2704, 2738, 2829, 2955]
# Number of data points in this cluster: 11
#
# Cluster 253:
# Indices of data points: [422, 572, 801, 2445]
# Number of data points in this cluster: 4
#
# Cluster 319:
# Indices of data points: [426, 430, 585, 1171, 1211, 1280, 1300, 2029, 2988]
# Number of data points in this cluster: 9
#
# Cluster 426:
# Indices of data points: [427, 891, 1562, 1901, 2125, 2776, 2862]
# Number of data points in this cluster: 7
#
# Cluster 325:
# Indices of data points: [428, 581, 1523, 1698, 1736, 2236, 2441, 2575]
# Number of data points in this cluster: 8
#
# Cluster 453:
# Indices of data points: [432, 471, 638, 721, 763, 991, 1004, 1014]
# Number of data points in this cluster: 8
#
# Cluster 413:
# Indices of data points: [434, 2408, 2921]
# Number of data points in this cluster: 3
#
# Cluster 287:
# Indices of data points: [435, 764, 1667]
# Number of data points in this cluster: 3
#
# Cluster 122:
# Indices of data points: [441, 482, 713, 729, 816, 1373, 1380, 1492, 2049, 2444, 2720, 3061]
# Number of data points in this cluster: 12
#
# Cluster 73:
# Indices of data points: [442, 494, 733, 982, 1431, 1433, 1466, 1497, 1755, 2011, 2296, 2451]
# Number of data points in this cluster: 12
#
# Cluster 236:
# Indices of data points: [451, 614, 1106, 2100]
# Number of data points in this cluster: 4
#
# Cluster 226:
# Indices of data points: [452, 561, 868, 1080, 2196, 2215]
# Number of data points in this cluster: 6
#
# Cluster 402:
# Indices of data points: [458, 832, 970, 1303, 1320, 1495, 2875]
# Number of data points in this cluster: 7
#
# Cluster 425:
# Indices of data points: [460, 1247, 1823, 2517, 2825]
# Number of data points in this cluster: 5
#
# Cluster 299:
# Indices of data points: [464, 627, 1073, 1737, 1834, 2641]
# Number of data points in this cluster: 6
#
# Cluster 142:
# Indices of data points: [465, 899, 1419, 1472, 1813, 1876, 2193, 2263, 2891]
# Number of data points in this cluster: 9
#
# Cluster 292:
# Indices of data points: [475, 937, 1337, 1529, 1730, 2320]
# Number of data points in this cluster: 6
#
# Cluster 178:
# Indices of data points: [481, 862, 988, 1582, 2135, 2994, 3006]
# Number of data points in this cluster: 7
#
# Cluster 290:
# Indices of data points: [484, 640, 1309, 1498, 1549, 1919, 1934, 2008, 2499, 2620, 2839, 2871, 2974, 3063]
# Number of data points in this cluster: 14
#
# Cluster 438:
# Indices of data points: [487, 1869]
# Number of data points in this cluster: 2
#
# Cluster 217:
# Indices of data points: [489, 1013, 1579, 1641, 1711, 2586, 2674, 2762, 2791, 3030, 3052]
# Number of data points in this cluster: 11
#
# Cluster 164:
# Indices of data points: [500, 552, 1249, 1299, 1334, 1402, 1467, 1848, 2369, 2448, 2615, 2957, 3038]
# Number of data points in this cluster: 13
#
# Cluster 422:
# Indices of data points: [504, 939, 1241]
# Number of data points in this cluster: 3
#
# Cluster 256:
# Indices of data points: [509, 560, 1047, 1580, 1936, 2179, 2249]
# Number of data points in this cluster: 7
#
# Cluster 107:
# Indices of data points: [511, 514, 854, 1780, 1847, 2147, 2224, 2813, 2914, 2947]
# Number of data points in this cluster: 10
#
# Cluster 306:
# Indices of data points: [512, 1162, 1381, 1491, 1564, 1740, 1878, 1912, 1916, 2000]
# Number of data points in this cluster: 10
#
# Cluster 420:
# Indices of data points: [520, 919, 1770, 2262, 2961]
# Number of data points in this cluster: 5
#
# Cluster 251:
# Indices of data points: [522, 578, 580, 1085, 1250, 1801, 2360, 2483, 2521, 2694, 2794]
# Number of data points in this cluster: 11
#
# Cluster 128:
# Indices of data points: [529, 1423, 1782]
# Number of data points in this cluster: 3
#
# Cluster 77:
# Indices of data points: [530, 1243, 1322]
# Number of data points in this cluster: 3
#
# Cluster 148:
# Indices of data points: [532, 695, 705, 788, 1726, 1851, 1943, 1953, 2106, 3003]
# Number of data points in this cluster: 10
#
# Cluster 88:
# Indices of data points: [535, 975, 1481]
# Number of data points in this cluster: 3
#
# Cluster 186:
# Indices of data points: [536, 1555, 1588]
# Number of data points in this cluster: 3
#
# Cluster 303:
# Indices of data points: [539]
# Number of data points in this cluster: 1
#
# Cluster 349:
# Indices of data points: [540, 1435, 1909]
# Number of data points in this cluster: 3
#
# Cluster 429:
# Indices of data points: [541, 663, 1742]
# Number of data points in this cluster: 3
#
# Cluster 269:
# Indices of data points: [542, 620, 1193, 1538, 3007]
# Number of data points in this cluster: 5
#
# Cluster 188:
# Indices of data points: [543, 633, 940, 1342, 1386, 1464, 1613, 2428]
# Number of data points in this cluster: 8
#
# Cluster 14:
# Indices of data points: [545, 574, 822, 1093, 1117, 2656, 2664, 2692]
# Number of data points in this cluster: 8
#
# Cluster 428:
# Indices of data points: [546, 612, 1123, 1206, 2061, 2121, 2549, 2632]
# Number of data points in this cluster: 8
#
# Cluster 156:
# Indices of data points: [550, 582, 671, 2019]
# Number of data points in this cluster: 4
#
# Cluster 409:
# Indices of data points: [551]
# Number of data points in this cluster: 1
#
# Cluster 411:
# Indices of data points: [555, 936, 1779]
# Number of data points in this cluster: 3
#
# Cluster 397:
# Indices of data points: [556, 737, 997, 1905, 1915, 2152, 2474, 2526, 2880]
# Number of data points in this cluster: 9
#
# Cluster 60:
# Indices of data points: [557, 586, 1240, 1680, 1989, 2003, 2042, 2231, 2281, 2695]
# Number of data points in this cluster: 10
#
# Cluster 394:
# Indices of data points: [558, 1049, 1592, 1696, 1978, 2024, 2053, 2214, 2585]
# Number of data points in this cluster: 9
#
# Cluster 247:
# Indices of data points: [565, 828, 1278, 1508, 2133, 2325, 2343, 2798, 3042]
# Number of data points in this cluster: 9
#
# Cluster 343:
# Indices of data points: [567, 1348, 1894, 2390, 2518, 2642]
# Number of data points in this cluster: 6
#
# Cluster 27:
# Indices of data points: [568, 1827, 2111, 2382]
# Number of data points in this cluster: 4
#
# Cluster 337:
# Indices of data points: [575, 2210, 2211, 2522, 2997]
# Number of data points in this cluster: 5
#
# Cluster 305:
# Indices of data points: [576, 645, 685, 779, 1341, 2312, 2355, 2429, 2475, 2496, 2889, 3033]
# Number of data points in this cluster: 12
#
# Cluster 222:
# Indices of data points: [589, 834, 1454, 1880, 2485]
# Number of data points in this cluster: 5
#
# Cluster 213:
# Indices of data points: [592, 780, 2697]
# Number of data points in this cluster: 3
#
# Cluster 168:
# Indices of data points: [595, 656, 827, 837, 1803]
# Number of data points in this cluster: 5
#
# Cluster 293:
# Indices of data points: [598, 684, 781, 916, 1024, 1330, 1644, 2588, 2894]
# Number of data points in this cluster: 9
#
# Cluster 436:
# Indices of data points: [600, 935, 1615]
# Number of data points in this cluster: 3
#
# Cluster 25:
# Indices of data points: [607, 676, 769, 909, 1057, 1082, 1251, 1493, 2370, 2488, 2568, 2613, 2705, 3031]
# Number of data points in this cluster: 14
#
# Cluster 262:
# Indices of data points: [608, 1837, 1945]
# Number of data points in this cluster: 3
#
# Cluster 267:
# Indices of data points: [609, 1844, 2104, 2381, 2384, 2686]
# Number of data points in this cluster: 6
#
# Cluster 221:
# Indices of data points: [613, 746, 757, 1037, 1083, 1231, 1450, 2784, 2855]
# Number of data points in this cluster: 9
#
# Cluster 228:
# Indices of data points: [622, 635, 2500, 2567, 2872]
# Number of data points in this cluster: 5
#
# Cluster 318:
# Indices of data points: [634, 1287, 1506, 1565, 2096, 2566, 2672]
# Number of data points in this cluster: 7
#
# Cluster 205:
# Indices of data points: [639, 696, 755, 762]
# Number of data points in this cluster: 4
#
# Cluster 201:
# Indices of data points: [642, 776, 1354, 1557, 2149, 2744, 2911]
# Number of data points in this cluster: 7
#
# Cluster 233:
# Indices of data points: [651, 1006, 1413, 1962, 2066, 2990]
# Number of data points in this cluster: 6
#
# Cluster 6:
# Indices of data points: [659, 830, 1799, 2126, 2155, 2939]
# Number of data points in this cluster: 6
#
# Cluster 352:
# Indices of data points: [664, 1369, 1558, 1702, 2015, 2710]
# Number of data points in this cluster: 6
#
# Cluster 134:
# Indices of data points: [666, 727, 806, 1544, 1604]
# Number of data points in this cluster: 5
#
# Cluster 184:
# Indices of data points: [672, 954, 1627, 2299, 2352, 2746, 2824]
# Number of data points in this cluster: 7
#
# Cluster 85:
# Indices of data points: [674, 679, 792, 856, 1119, 1623, 1689, 2020, 2090, 2755, 2787, 2844, 2909, 3041]
# Number of data points in this cluster: 14
#
# Cluster 384:
# Indices of data points: [681, 1104, 1577, 2928]
# Number of data points in this cluster: 4
#
# Cluster 21:
# Indices of data points: [701, 1044, 1315, 1474, 1590, 1829, 1947, 2332, 2414, 2548, 2608, 2624, 2650, 2698, 2863, 2967, 3005]
# Number of data points in this cluster: 17
#
# Cluster 182:
# Indices of data points: [702, 1025, 1202, 1482, 1814, 2068]
# Number of data points in this cluster: 6
#
# Cluster 212:
# Indices of data points: [711, 2799]
# Number of data points in this cluster: 2
#
# Cluster 331:
# Indices of data points: [712, 1128, 1136, 1148]
# Number of data points in this cluster: 4
#
# Cluster 91:
# Indices of data points: [725, 1310, 1370, 1512, 1732]
# Number of data points in this cluster: 5
#
# Cluster 116:
# Indices of data points: [726, 734, 756, 786, 1166, 1478, 2028, 2052, 2479, 2938]
# Number of data points in this cluster: 10
#
# Cluster 231:
# Indices of data points: [728, 778, 1059, 1178, 1191, 1259, 1816, 2315, 2339, 2374, 2553, 2599, 2777]
# Number of data points in this cluster: 13
#
# Cluster 61:
# Indices of data points: [742, 1072, 1124, 1314, 1504, 1552, 2077, 2247, 2807, 2836]
# Number of data points in this cluster: 10
#
# Cluster 104:
# Indices of data points: [747, 770, 2023, 2248, 2265, 2385, 2775, 2851]
# Number of data points in this cluster: 8
#
# Cluster 362:
# Indices of data points: [760, 2171]
# Number of data points in this cluster: 2
#
# Cluster 177:
# Indices of data points: [766, 931, 1273, 1328, 2025, 2241, 2874]
# Number of data points in this cluster: 7
#
# Cluster 340:
# Indices of data points: [773, 964, 1010, 1186, 1307, 1596, 1818, 2130, 2203]
# Number of data points in this cluster: 9
#
# Cluster 440:
# Indices of data points: [775, 809, 1763]
# Number of data points in this cluster: 3
#
# Cluster 196:
# Indices of data points: [782, 1157, 1459, 2268, 3000]
# Number of data points in this cluster: 5
#
# Cluster 11:
# Indices of data points: [785, 1605, 1606, 1695, 1713, 1758, 2071, 2346, 2376, 2397]
# Number of data points in this cluster: 10
#
# Cluster 189:
# Indices of data points: [787, 1048, 1810, 2250, 2590, 2732, 2754, 2782, 2845]
# Number of data points in this cluster: 9
#
# Cluster 298:
# Indices of data points: [807, 2067]
# Number of data points in this cluster: 2
#
# Cluster 92:
# Indices of data points: [808, 1517]
# Number of data points in this cluster: 2
#
# Cluster 366:
# Indices of data points: [817, 952, 1214, 1430, 1911, 1999, 2731, 2747, 2881, 2926]
# Number of data points in this cluster: 10
#
# Cluster 315:
# Indices of data points: [818, 1163, 1819, 2633, 2742, 2785, 2950]
# Number of data points in this cluster: 7
#
# Cluster 346:
# Indices of data points: [820, 887, 1134, 1505, 2045]
# Number of data points in this cluster: 5
#
# Cluster 347:
# Indices of data points: [831, 1054, 1520]
# Number of data points in this cluster: 3
#
# Cluster 304:
# Indices of data points: [836, 1188, 2739, 2816]
# Number of data points in this cluster: 4
#
# Cluster 391:
# Indices of data points: [863, 1455, 2228, 2235, 2834, 2979]
# Number of data points in this cluster: 6
#
# Cluster 249:
# Indices of data points: [880, 1359, 1563, 2923]
# Number of data points in this cluster: 4
#
# Cluster 379:
# Indices of data points: [886, 1509]
# Number of data points in this cluster: 2
#
# Cluster 406:
# Indices of data points: [888]
# Number of data points in this cluster: 1
#
# Cluster 417:
# Indices of data points: [894]
# Number of data points in this cluster: 1
#
# Cluster 87:
# Indices of data points: [907, 1461, 1585, 1791, 2273, 2701]
# Number of data points in this cluster: 6
#
# Cluster 317:
# Indices of data points: [911, 1765, 2363]
# Number of data points in this cluster: 3
#
# Cluster 412:
# Indices of data points: [915, 1395]
# Number of data points in this cluster: 2
#
# Cluster 13:
# Indices of data points: [922, 2341, 3020]
# Number of data points in this cluster: 3
#
# Cluster 302:
# Indices of data points: [926, 1891, 1973, 2285]
# Number of data points in this cluster: 4
#
# Cluster 191:
# Indices of data points: [933, 1378, 1389, 1731, 2218, 2917]
# Number of data points in this cluster: 6
#
# Cluster 183:
# Indices of data points: [946, 1132, 1602, 2919]
# Number of data points in this cluster: 4
#
# Cluster 93:
# Indices of data points: [947, 1610, 3035]
# Number of data points in this cluster: 3
#
# Cluster 80:
# Indices of data points: [963, 1762, 1778, 2986]
# Number of data points in this cluster: 4
#
# Cluster 357:
# Indices of data points: [965, 1421, 1458, 1896]
# Number of data points in this cluster: 4
#
# Cluster 382:
# Indices of data points: [967, 1346, 2079, 2435]
# Number of data points in this cluster: 4
#
# Cluster 452:
# Indices of data points: [973, 1650, 1812, 2347, 2358, 2432, 2466, 2578, 2740, 2884]
# Number of data points in this cluster: 10
#
# Cluster 3:
# Indices of data points: [976, 1169, 1288, 1391, 1789, 1940, 2223, 2284]
# Number of data points in this cluster: 8
#
# Cluster 427:
# Indices of data points: [977, 2910]
# Number of data points in this cluster: 2
#
# Cluster 313:
# Indices of data points: [978, 1437]
# Number of data points in this cluster: 2
#
# Cluster 350:
# Indices of data points: [979, 1317, 1418]
# Number of data points in this cluster: 3
#
# Cluster 66:
# Indices of data points: [986, 1476, 1954]
# Number of data points in this cluster: 3
#
# Cluster 455:
# Indices of data points: [987, 1480, 2183, 2819]
# Number of data points in this cluster: 4
#
# Cluster 179:
# Indices of data points: [989, 1427]
# Number of data points in this cluster: 2
#
# Cluster 458:
# Indices of data points: [993, 1477]
# Number of data points in this cluster: 2
#
# Cluster 333:
# Indices of data points: [998, 1632, 1820, 2110]
# Number of data points in this cluster: 4
#
# Cluster 239:
# Indices of data points: [1007, 2164]
# Number of data points in this cluster: 2
#
# Cluster 259:
# Indices of data points: [1030, 1406]
# Number of data points in this cluster: 2
#
# Cluster 234:
# Indices of data points: [1034, 1516, 1877]
# Number of data points in this cluster: 3
#
# Cluster 33:
# Indices of data points: [1040, 1783, 2229]
# Number of data points in this cluster: 3
#
# Cluster 277:
# Indices of data points: [1043, 1607, 1939, 1958, 2208]
# Number of data points in this cluster: 5
#
# Cluster 329:
# Indices of data points: [1053, 1075, 1144, 1173, 1226, 1425, 1862, 2054, 2072, 2309, 2996]
# Number of data points in this cluster: 11
#
# Cluster 316:
# Indices of data points: [1064, 1398, 1496, 2399, 2410, 2622, 2655, 3054]
# Number of data points in this cluster: 8
#
# Cluster 442:
# Indices of data points: [1087, 2007, 2058, 2447, 2508, 2838]
# Number of data points in this cluster: 6
#
# Cluster 388:
# Indices of data points: [1089, 1792, 1859, 2257, 2574]
# Number of data points in this cluster: 5
#
# Cluster 229:
# Indices of data points: [1107, 1207, 1264, 2405, 2525, 2546, 2600, 2709]
# Number of data points in this cluster: 8
#
# Cluster 320:
# Indices of data points: [1141, 1228, 1319, 1547, 1608, 1656, 2512, 2998]
# Number of data points in this cluster: 8
#
# Cluster 151:
# Indices of data points: [1167, 1611, 2890]
# Number of data points in this cluster: 3
#
# Cluster 160:
# Indices of data points: [1175, 1305, 1384, 1956, 2261, 2823]
# Number of data points in this cluster: 6
#
# Cluster 454:
# Indices of data points: [1176, 1212, 2877, 2878, 2886]
# Number of data points in this cluster: 5
#
# Cluster 175:
# Indices of data points: [1185, 1805, 2305]
# Number of data points in this cluster: 3
#
# Cluster 5:
# Indices of data points: [1190, 1223, 1428, 1432, 1494, 1545, 1581, 1686, 1708, 1739, 1787, 1949, 2924]
# Number of data points in this cluster: 13
#
# Cluster 439:
# Indices of data points: [1210]
# Number of data points in this cluster: 1
#
# Cluster 294:
# Indices of data points: [1220, 1578, 2128]
# Number of data points in this cluster: 3
#
# Cluster 281:
# Indices of data points: [1222, 1396, 1465, 2409, 2450, 2524, 2673, 2691]
# Number of data points in this cluster: 8
#
# Cluster 232:
# Indices of data points: [1246, 1645, 1707, 2760, 2981]
# Number of data points in this cluster: 5
#
# Cluster 365:
# Indices of data points: [1252, 1390, 2184, 2331, 2393, 2636, 2865, 3029]
# Number of data points in this cluster: 8
#
# Cluster 45:
# Indices of data points: [1276, 2354, 2417, 2635, 2644, 2681]
# Number of data points in this cluster: 6
#
# Cluster 176:
# Indices of data points: [1332, 1350, 1616]
# Number of data points in this cluster: 3
#
# Cluster 0:
# Indices of data points: [1344, 1404, 1499, 2277, 2887]
# Number of data points in this cluster: 5
#
# Cluster 24:
# Indices of data points: [1349, 1997, 2153]
# Number of data points in this cluster: 3
#
# Cluster 338:
# Indices of data points: [1351, 1721, 1889, 2652, 3058]
# Number of data points in this cluster: 5
#
# Cluster 443:
# Indices of data points: [1352]
# Number of data points in this cluster: 1
#
# Cluster 214:
# Indices of data points: [1361, 1385, 1486, 1576]
# Number of data points in this cluster: 4
#
# Cluster 321:
# Indices of data points: [1363, 1798, 2059, 2259, 2617, 2948]
# Number of data points in this cluster: 6
#
# Cluster 327:
# Indices of data points: [1364, 1436, 3008]
# Number of data points in this cluster: 3
#
# Cluster 258:
# Indices of data points: [1365, 1929, 2030, 2172]
# Number of data points in this cluster: 4
#
# Cluster 266:
# Indices of data points: [1367, 1528, 2925]
# Number of data points in this cluster: 3
#
# Cluster 16:
# Indices of data points: [1377, 1595, 2294]
# Number of data points in this cluster: 3
#
# Cluster 206:
# Indices of data points: [1388, 2036]
# Number of data points in this cluster: 2
#
# Cluster 378:
# Indices of data points: [1394, 1410, 1764, 2966]
# Number of data points in this cluster: 4
#
# Cluster 448:
# Indices of data points: [1400]
# Number of data points in this cluster: 1
#
# Cluster 344:
# Indices of data points: [1408]
# Number of data points in this cluster: 1
#
# Cluster 108:
# Indices of data points: [1409, 1527, 1543, 1653, 1665, 1729, 2276, 2805]
# Number of data points in this cluster: 8
#
# Cluster 53:
# Indices of data points: [1422, 1525, 2031, 2759]
# Number of data points in this cluster: 4
#
# Cluster 392:
# Indices of data points: [1449, 1661, 1766, 2280, 2282, 2607]
# Number of data points in this cluster: 6
#
# Cluster 90:
# Indices of data points: [1452, 1609, 2419]
# Number of data points in this cluster: 3
#
# Cluster 389:
# Indices of data points: [1507]
# Number of data points in this cluster: 1
#
# Cluster 193:
# Indices of data points: [1519, 2630]
# Number of data points in this cluster: 2
#
# Cluster 273:
# Indices of data points: [1522]
# Number of data points in this cluster: 1
#
# Cluster 171:
# Indices of data points: [1566, 2915]
# Number of data points in this cluster: 2
#
# Cluster 300:
# Indices of data points: [1567, 2168, 3050]
# Number of data points in this cluster: 3
#
# Cluster 419:
# Indices of data points: [1593, 2293, 3015]
# Number of data points in this cluster: 3
#
# Cluster 395:
# Indices of data points: [1594, 1771]
# Number of data points in this cluster: 2
#
# Cluster 103:
# Indices of data points: [1598, 1720, 1863, 2123, 2454]
# Number of data points in this cluster: 5
#
# Cluster 216:
# Indices of data points: [1603, 1663, 1974, 2092, 2165, 2729]
# Number of data points in this cluster: 6
#
# Cluster 225:
# Indices of data points: [1617, 2197, 2987]
# Number of data points in this cluster: 3
#
# Cluster 341:
# Indices of data points: [1639, 1657, 2098, 2222]
# Number of data points in this cluster: 4
#
# Cluster 330:
# Indices of data points: [1646, 2514]
# Number of data points in this cluster: 2
#
# Cluster 153:
# Indices of data points: [1660, 2080, 2227, 2758]
# Number of data points in this cluster: 4
#
# Cluster 404:
# Indices of data points: [1670, 1988]
# Number of data points in this cluster: 2
#
# Cluster 159:
# Indices of data points: [1699, 2044, 2984]
# Number of data points in this cluster: 3
#
# Cluster 403:
# Indices of data points: [1705, 2963]
# Number of data points in this cluster: 2
#
# Cluster 451:
# Indices of data points: [1723, 1955, 2278]
# Number of data points in this cluster: 3
#
# Cluster 139:
# Indices of data points: [1728, 2297]
# Number of data points in this cluster: 2
#
# Cluster 244:
# Indices of data points: [1734, 1832]
# Number of data points in this cluster: 2
#
# Cluster 393:
# Indices of data points: [1773]
# Number of data points in this cluster: 1
#
# Cluster 138:
# Indices of data points: [1776, 2136, 2597, 2883]
# Number of data points in this cluster: 4
#
# Cluster 398:
# Indices of data points: [1796, 1833]
# Number of data points in this cluster: 2
#
# Cluster 418:
# Indices of data points: [1822]
# Number of data points in this cluster: 1
#
# Cluster 154:
# Indices of data points: [1856, 2922]
# Number of data points in this cluster: 2
#
# Cluster 433:
# Indices of data points: [1860]
# Number of data points in this cluster: 1
#
# Cluster 297:
# Indices of data points: [1926, 2243, 2850]
# Number of data points in this cluster: 3
#
# Cluster 1:
# Indices of data points: [1946, 1963]
# Number of data points in this cluster: 2
#
# Cluster 376:
# Indices of data points: [1972, 2160]
# Number of data points in this cluster: 2
#
# Cluster 363:
# Indices of data points: [2132, 2977]
# Number of data points in this cluster: 2
#
# Cluster 390:
# Indices of data points: [2137]
# Number of data points in this cluster: 1
#
# Cluster 354:
# Indices of data points: [2150]
# Number of data points in this cluster: 1
#
# Cluster 400:
# Indices of data points: [2154, 3048]
# Number of data points in this cluster: 2
#
# Cluster 190:
# Indices of data points: [2244, 2270]
# Number of data points in this cluster: 2
#
# Cluster 64:
# Indices of data points: [2253, 2943]
# Number of data points in this cluster: 2
#
# Cluster 285:
# Indices of data points: [2255, 2737]
# Number of data points in this cluster: 2
#
# Cluster 174:
# Indices of data points: [2618, 2933]
# Number of data points in this cluster: 2
#
# Cluster 353:
# Indices of data points: [2725]
# Number of data points in this cluster: 1
#
# Cluster 457:
# Indices of data points: [2730]
# Number of data points in this cluster: 1
#
# Cluster 291:
# Indices of data points: [2764]
# Number of data points in this cluster: 1
#
# Cluster 459:
# Indices of data points: [2841]
# Number of data points in this cluster: 1
#
# Cluster 387:
# Indices of data points: [2978]
# Number of data points in this cluster: 1
#
# Cluster 407:
# Indices of data points: [2980]
# Number of data points in this cluster: 1
#
# Cluster 288:
# Indices of data points: [2989]
# Number of data points in this cluster: 1
#
# Cluster 424:
# Indices of data points: [3049]
# Number of data points in this cluster: 1

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Step 1: Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBp\features_last_lstm.npy")

# Step 2: (Optional) Preprocess the data if needed
# For example, you might want to scale the features to ensure the clustering works well
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 3: Perform Agglomerative Clustering
# You can specify the number of clusters or other hyperparameters here
n_clusters = 460  # Example, set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model to the feature matrix
clustering_labels = clustering.fit_predict(features_scaled)

# Step 4: (Optional) Visualize the results if the features are 2D (or use dimensionality reduction)
if features_scaled.shape[1] == 2:  # If your features are 2D, you can visualize them
    plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=clustering_labels, cmap='viridis')
    plt.title("Agglomerative Clustering Results")
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# If you have higher-dimensional features, consider using PCA to reduce to 2D for visualization
# For example:
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# features_2d = pca.fit_transform(features_scaled)
# plt.scatter(features_2d[:, 0], features_2d[:, 1], c=clustering_labels, cmap='viridis')
# plt.show()

# Step 5: View the labels assigned to each data point
print("Cluster Labels:", clustering_labels)
# Out:
# Cluster Labels: [131 101 275 ... 122  62 290]

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBp\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters = 460  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Function to get the keyframe index (centroid-based approach)
def get_keyframe_for_cluster(cluster_indices):
    # Extract the features for the current cluster
    cluster_features = features_scaled[cluster_indices]
    
    # Compute the centroid of the cluster (mean of the features)
    centroid = np.mean(cluster_features, axis=0)
    
    # Calculate the distance from each point to the centroid
    distances = cdist([centroid], cluster_features)
    
    # Get the index of the point closest to the centroid
    keyframe_index = cluster_indices[np.argmin(distances)]
    return keyframe_index

# Generate and display the sequence of keyframe indices for each cluster
keyframe_sequence = []

for cluster_label, indices in cluster_dict.items():
    keyframe_index = get_keyframe_for_cluster(indices)
    keyframe_sequence.append((cluster_label, keyframe_index))

# Print the sequence of keyframes in the desired format
for cluster_label, keyframe_index in keyframe_sequence:
    print(f"Cluster {cluster_label}: Keyframe index: {keyframe_index}")
# Out:
# Cluster 131: Keyframe index: 1747
# Cluster 101: Keyframe index: 183
# Cluster 275: Keyframe index: 2
# Cluster 348: Keyframe index: 84
# Cluster 283: Keyframe index: 4
# Cluster 69: Keyframe index: 884
# Cluster 57: Keyframe index: 2186
# Cluster 124: Keyframe index: 239
# Cluster 135: Keyframe index: 128
# Cluster 150: Keyframe index: 498
# Cluster 136: Keyframe index: 2810
# Cluster 89: Keyframe index: 11
# Cluster 140: Keyframe index: 537
# Cluster 435: Keyframe index: 177
# Cluster 280: Keyframe index: 15
# Cluster 105: Keyframe index: 16
# Cluster 71: Keyframe index: 2453
# Cluster 4: Keyframe index: 1440
# Cluster 126: Keyframe index: 799
# Cluster 165: Keyframe index: 20
# Cluster 237: Keyframe index: 474
# Cluster 119: Keyframe index: 895
# Cluster 215: Keyframe index: 2322
# Cluster 230: Keyframe index: 470
# Cluster 121: Keyframe index: 621
# Cluster 207: Keyframe index: 26
# Cluster 23: Keyframe index: 1918
# Cluster 192: Keyframe index: 28
# Cluster 408: Keyframe index: 30
# Cluster 209: Keyframe index: 932
# Cluster 147: Keyframe index: 2505
# Cluster 242: Keyframe index: 411
# Cluster 15: Keyframe index: 424
# Cluster 385: Keyframe index: 2605
# Cluster 99: Keyframe index: 38
# Cluster 62: Keyframe index: 632
# Cluster 364: Keyframe index: 901
# Cluster 373: Keyframe index: 41
# Cluster 200: Keyframe index: 805
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist
from scipy.io import savemat  # Import savemat to save in .mat format
import pandas as pd  # Import pandas for CSV file export

# Load the LSTM features from the .npy file
lstm_features = np.load(r"C:\SumMe\Augmentation\AugBp\features_last_lstm.npy")

# Flatten LSTM features for clustering (if necessary)
n_samples = lstm_features.shape[0]  # Define the number of samples
n_clusters = 460  # Set the number of clusters
lstm_features_flattened = lstm_features.reshape(n_samples, -1)

# Standardizing the data before clustering
scaler = StandardScaler()
lstm_features_scaled = scaler.fit_transform(lstm_features_flattened)

# Apply Agglomerative Clustering with 'ward' linkage (no need to specify affinity)
agg_clustering = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
labels = agg_clustering.fit_predict(lstm_features_scaled)

# Group data points by cluster
clustered_data = {}

for idx, label in enumerate(labels):
    if label not in clustered_data:
        clustered_data[label] = []
    clustered_data[label].append(idx)

# Find keyframe for each cluster
keyframes = {}

for cluster_id, indices in clustered_data.items():
    # Get the feature vectors for the data points in this cluster
    cluster_features = lstm_features_scaled[indices]
    
    # Compute the centroid of the cluster (average of all feature vectors in the cluster)
    centroid = np.mean(cluster_features, axis=0)
    
    # Compute the Euclidean distance from each data point to the centroid
    distances = cdist(cluster_features, [centroid], metric='euclidean')
    
    # Find the index of the closest data point (keyframe)
    keyframe_idx = indices[np.argmin(distances)]
    
    # Store the keyframe index for the cluster
    keyframes[cluster_id] = keyframe_idx

# Create a binary matrix of shape (n_samples, n_clusters)
keyframe_matrix = np.zeros((n_samples, n_clusters), dtype=int)

# Mark the keyframes (set the corresponding index to 1)
for cluster_id, keyframe_idx in keyframes.items():
    keyframe_matrix[keyframe_idx, cluster_id] = 1

# Save the keyframe binary matrix as a .mat file
keyframe_data = {'keyframe_matrix': keyframe_matrix}  # Create a dictionary to save in .mat format
savemat(r'C:\SumMe\Augmentation\AugBp\features_last_lstm1.mat', keyframe_data)

# Print confirmation for .mat file
print(f"Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.mat")
print(f"Dimensions of the keyframe binary matrix: {keyframe_matrix.shape}")

# Save the keyframe binary matrix as a .csv file
keyframe_matrix_df = pd.DataFrame(keyframe_matrix)  # Convert matrix to DataFrame
keyframe_matrix_df.to_csv(r'C:\SumMe\Augmentation\AugBp\features_last_lstm1.csv', index=False)

# Print confirmation for .csv file
print(f"Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.csv")

# Print the sequence of keyframe indices in order of cluster numbers (Cluster 0, Cluster 1, ..., Cluster n)
print("\nKeyframe indices for each cluster:")
for cluster_id in range(n_clusters):
    if cluster_id in keyframes:
        print(f"Cluster {cluster_id}: Keyframe Index {keyframes[cluster_id]}")
# Cluster 404: Keyframe Index 1988
# Cluster 405: Keyframe Index 389
# Cluster 406: Keyframe Index 888
# Cluster 407: Keyframe Index 2980
# Cluster 408: Keyframe Index 30
# Cluster 409: Keyframe Index 551
# Cluster 410: Keyframe Index 1535
# Cluster 411: Keyframe Index 555
# Cluster 412: Keyframe Index 915
# Cluster 413: Keyframe Index 2408
# Cluster 414: Keyframe Index 383
# Cluster 415: Keyframe Index 753
# Cluster 416: Keyframe Index 48
# Cluster 417: Keyframe Index 894
# Cluster 418: Keyframe Index 1822
# Cluster 419: Keyframe Index 3015
# Cluster 420: Keyframe Index 919
# Cluster 421: Keyframe Index 1751
# Cluster 422: Keyframe Index 504
# Cluster 423: Keyframe Index 566
# Cluster 424: Keyframe Index 3049
# Cluster 425: Keyframe Index 1247
# Cluster 426: Keyframe Index 427
# Cluster 427: Keyframe Index 977
# Cluster 428: Keyframe Index 546
# Cluster 429: Keyframe Index 663
# Cluster 430: Keyframe Index 2364
# Cluster 431: Keyframe Index 298
# Cluster 432: Keyframe Index 724
# Cluster 433: Keyframe Index 1860
# Cluster 434: Keyframe Index 2726
# Cluster 435: Keyframe Index 177
# Cluster 436: Keyframe Index 935
# Cluster 437: Keyframe Index 296
# Cluster 438: Keyframe Index 1869
# Cluster 439: Keyframe Index 1210
# Cluster 440: Keyframe Index 1763
# Cluster 441: Keyframe Index 1277
# Cluster 442: Keyframe Index 2007
# Cluster 443: Keyframe Index 1352
# Cluster 444: Keyframe Index 1910
# Cluster 445: Keyframe Index 295
# Cluster 446: Keyframe Index 2217
# Cluster 447: Keyframe Index 1077
# Cluster 448: Keyframe Index 1400
# Cluster 449: Keyframe Index 1255
# Cluster 450: Keyframe Index 2659
# Cluster 451: Keyframe Index 1955
# Cluster 452: Keyframe Index 2578
# Cluster 453: Keyframe Index 1004
# Cluster 454: Keyframe Index 2877
# Cluster 455: Keyframe Index 987
# Cluster 456: Keyframe Index 1704
# Cluster 457: Keyframe Index 2730
# Cluster 458: Keyframe Index 1477
# Cluster 459: Keyframe Index 2841

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import scipy.io

# Step 1: Load the annotator labels from the .mat file
annotator_path = r"C:\SumMe\GT\Bike Polo.mat" # Path to the .mat file
mat_data = scipy.io.loadmat(annotator_path)

# Check the keys in the .mat file
print("Keys in the .mat file:", mat_data.keys())


user_scores = mat_data['user_score']  
print(f"Shape of user_score: {user_scores.shape}")

# Step 2: Load our model's predictions from the .csv file
our_path = r"C:\SumMe\Augmentation\AugBp\features_last_lstm1.csv" # Path to the CSV file
u1 = pd.read_csv(our_path, header=None).values.flatten()  # Our model's predictions (binary array)


print(f"Shape of model's predictions (u1): {u1.shape}")

# Ensure that the length of u1 matches the number of rows in user_scores
if u1.shape[0] != user_scores.shape[0]:
    print(f"Warning: Mismatched lengths. Adjusting the data...")
    u1 = u1[:user_scores.shape[0]]  # Truncate u1 to match the number of rows in user_scores

# Step 3: Ensure both u1 and user_scores are binary (logical values, 0 or 1)
u1 = u1.astype(bool)

# Step 4: Compute the F1-Score for each of the 15 datasets (columns in user_scores)
f1_scores = []  # List to store F1 scores for each dataset

for i in range(user_scores.shape[1]):  # Loop through the 15 columns
    u2 = user_scores[:, i]  # Extract the i-th column (ground truth labels for the i-th dataset)
    
    # Ensure u2 is a boolean array
    u2 = u2.astype(bool)
    
    # Step 5: Compute the confusion matrix
    cm = confusion_matrix(u2, u1)
    
    # Extract the confusion matrix components
    tn, fp, fn, tp = cm.ravel()  # Unpack the confusion matrix
    
    # Debugging step: Print confusion matrix for the 4th column
    if i == 3:  # Checking the 4th column
        print(f"Confusion Matrix for user_score column {i+1} (4th column):")
        print(f"TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")
    
    # Check for zero denominators and calculate Precision, Recall, and F1-Score safely
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    
    # F1 Score is calculated if both precision and recall are non-zero, otherwise it's 0 or nan
    if precision + recall > 0:
        fscore = 2 * (precision * recall) / (precision + recall)
    else:
        fscore = 0.0  # F1 score is 0 if either precision or recall is zero
    
    f1_scores.append(fscore)  # Append F1 score for this dataset
    
    # Print the F1 Score for this dataset
    print(f"\nF1-Score for user_score column {i+1}: {fscore:.4f}")

# Step 6: Output all the F1 scores for the 15 datasets
print("\nAll F1 Scores:")
for i, score in enumerate(f1_scores, 1):
    print(f"F1 Score for user_score column {i}: {score:.4f}")
# Out:
# Keys in the .mat file: dict_keys(['__header__', '__version__', '__globals__', 'all_userIDs', 'segments', 'nFrames', 'video_duration', 'FPS', 'gt_score', 'user_score'])
# Shape of user_score: (3064, 15)
# Shape of model's predictions (u1): (1409900,)
# Warning: Mismatched lengths. Adjusting the data...
#
# F1-Score for user_score column 1: 0.0000
#
# F1-Score for user_score column 2: 0.0023
#
# F1-Score for user_score column 3: 0.0000
# Confusion Matrix for user_score column 4 (4th column):
# TN: 2304, FP: 303, FN: 299, TP: 158
#
# F1-Score for user_score column 4: 0.3442
#
# F1-Score for user_score column 5: 0.0095
#
# F1-Score for user_score column 6: 0.0022
#
# F1-Score for user_score column 7: 0.2047
#
# F1-Score for user_score column 8: 0.0029
#
# F1-Score for user_score column 9: 0.0022
#
# F1-Score for user_score column 10: 0.1283
#
# F1-Score for user_score column 11: 0.1527
#
# F1-Score for user_score column 12: 0.1686
#
# F1-Score for user_score column 13: 0.0000
#
# F1-Score for user_score column 14: 0.0023
#
# F1-Score for user_score column 15: 0.1799
#
# All F1 Scores:
# F1 Score for user_score column 1: 0.0000
# F1 Score for user_score column 2: 0.0023
# F1 Score for user_score column 3: 0.0000
# F1 Score for user_score column 4: 0.3442
# F1 Score for user_score column 5: 0.0095
# F1 Score for user_score column 6: 0.0022
# F1 Score for user_score column 7: 0.2047
# F1 Score for user_score column 8: 0.0029
# F1 Score for user_score column 9: 0.0022
# F1 Score for user_score column 10: 0.1283
# F1 Score for user_score column 11: 0.1527
# F1 Score for user_score column 12: 0.1686
# F1 Score for user_score column 13: 0.0000
# F1 Score for user_score column 14: 0.0023
# F1 Score for user_score column 15: 0.1799
