# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Step 1: Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBus\features_last_lstm.npy")

# Step 2: (Optional) Preprocess the data if needed
# For example, you might want to scale the features to ensure the clustering works well
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 3: Perform Agglomerative Clustering
# You can specify the number of clusters or other hyperparameters here
n_clusters = 770  # Example, set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model to the feature matrix
clustering_labels = clustering.fit_predict(features_scaled)

# Step 4: (Optional) Visualize the results if the features are 2D (or use dimensionality reduction)
if features_scaled.shape[1] == 2:  # If your features are 2D, you can visualize them
    plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=clustering_labels, cmap='viridis')
    plt.title("Agglomerative Clustering Results")
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# If you have higher-dimensional features, consider using PCA to reduce to 2D for visualization
# For example:
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# features_2d = pca.fit_transform(features_scaled)
# plt.scatter(features_2d[:, 0], features_2d[:, 1], c=clustering_labels, cmap='viridis')
# plt.show()

# Step 5: View the labels assigned to each data point
print("Cluster Labels:", clustering_labels)
# Out:
# Cluster Labels: [ 11 227 299 ... 686 332  40]

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBus\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters =770  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Display the clusters in the desired format
for cluster_label, indices in cluster_dict.items():
    print(f"Cluster {cluster_label}:")
    print(f"Indices of data points: {indices}")
    print(f"Number of data points in this cluster: {len(indices)}\n")
# Out:
# Cluster 11:
# Indices of data points: [0, 137, 1191, 1221, 1560, 1629, 2191, 2386, 3083, 3180, 3353, 3359, 3478, 3592, 4849, 4904]
# Number of data points in this cluster: 16
#
# Cluster 227:
# Indices of data points: [1, 246, 409, 1118, 2668, 3010, 3092, 3166, 3491, 3793, 3979, 4121, 4533, 5011, 5109]
# Number of data points in this cluster: 15
#
# Cluster 299:
# Indices of data points: [2, 49, 134, 240, 759, 1155, 1487, 1621, 1632, 2002, 3027, 3367, 3519, 4010, 4050, 4094, 4900]
# Number of data points in this cluster: 17
#
# Cluster 650:
# Indices of data points: [3, 487, 803, 935, 1426, 1435, 1586, 1988, 3432, 3750, 4287, 4718, 5079, 5122]
# Number of data points in this cluster: 14
#
# Cluster 226:
# Indices of data points: [4, 1074, 1228, 1380, 1890, 2103, 2972, 3254, 4000, 4224, 5068]
# Number of data points in this cluster: 11
#
# Cluster 479:
# Indices of data points: [5, 358, 1410, 1475, 2115, 2731, 3961, 4745, 4923]
# Number of data points in this cluster: 9
#
# Cluster 466:
# Indices of data points: [6, 1521, 2492, 2768, 4943]
# Number of data points in this cluster: 5
#
# Cluster 24:
# Indices of data points: [7, 55, 811, 822, 1665, 3085, 3360, 3531, 3821, 4019, 4612, 4736]
# Number of data points in this cluster: 12
#
# Cluster 635:
# Indices of data points: [8, 1189, 3480, 3944, 4242, 4814, 4905]
# Number of data points in this cluster: 7
#
# Cluster 753:
# Indices of data points: [9, 1474, 1564, 1772, 2058]
# Number of data points in this cluster: 5
#
# Cluster 534:
# Indices of data points: [10, 1100, 1266, 1345, 3690]
# Number of data points in this cluster: 5
#
# Cluster 404:
# Indices of data points: [11, 313, 764, 1227, 1504, 2780, 4158]
# Number of data points in this cluster: 7
#
# Cluster 651:
# Indices of data points: [12, 649, 1737, 3357, 3426, 3548, 3916, 4367, 4728, 4765]
# Number of data points in this cluster: 10
#
# Cluster 32:
# Indices of data points: [13, 1133, 1210, 1561, 1998, 2545, 2547, 2702, 3031, 3054, 3541, 3786, 4097, 4144, 4174]
# Number of data points in this cluster: 15
#
# Cluster 87:
# Indices of data points: [14, 102, 189, 639, 2218, 2455, 2843, 2868, 3366, 4267, 4695, 4882, 4891]
# Number of data points in this cluster: 13
#
# Cluster 572:
# Indices of data points: [15, 1138, 2443, 2475, 2519, 3509, 3631]
# Number of data points in this cluster: 7
#
# Cluster 752:
# Indices of data points: [16]
# Number of data points in this cluster: 1
#
# Cluster 614:
# Indices of data points: [17, 486, 1563, 2185, 4703, 4769, 4980]
# Number of data points in this cluster: 7
#
# Cluster 14:
# Indices of data points: [18, 83, 740, 1001, 1388, 2053, 2915, 3694, 3871, 4243, 4562, 4731, 4767]
# Number of data points in this cluster: 13
#
# Cluster 80:
# Indices of data points: [19, 723, 742, 1664, 3667, 3670, 4231, 4505]
# Number of data points in this cluster: 8
#
# Cluster 190:
# Indices of data points: [20, 3237, 3255, 3348, 4257, 4363]
# Number of data points in this cluster: 6
#
# Cluster 128:
# Indices of data points: [21, 106, 806, 1225, 1269, 1429, 1825, 2844, 2936, 3062, 4347, 4895]
# Number of data points in this cluster: 12
#
# Cluster 369:
# Indices of data points: [22, 1500, 1553, 1674, 3248, 3558, 4651, 4908]
# Number of data points in this cluster: 8
#
# Cluster 673:
# Indices of data points: [23, 309, 2407, 4330]
# Number of data points in this cluster: 4
#
# Cluster 679:
# Indices of data points: [24, 253, 448, 683, 924, 1011, 1989, 2068, 2521, 4290, 4727]
# Number of data points in this cluster: 11
#
# Cluster 304:
# Indices of data points: [25, 354, 611, 693, 905, 919, 1377, 1577, 1928, 2368, 3172, 4331, 5110, 5114]
# Number of data points in this cluster: 14
#
# Cluster 57:
# Indices of data points: [26, 350, 514, 627, 812, 1897, 1987, 2673, 2976, 3033, 3043, 4095, 4419, 4988]
# Number of data points in this cluster: 14
#
# Cluster 758:
# Indices of data points: [27, 131, 800, 1507, 1590, 2288, 2808, 2831, 3543, 4682, 4936]
# Number of data points in this cluster: 11
#
# Cluster 662:
# Indices of data points: [28, 372, 418, 1575, 1874, 1957, 3013, 4894, 4977]
# Number of data points in this cluster: 9
#
# Cluster 750:
# Indices of data points: [29, 837, 2634, 3234, 4800]
# Number of data points in this cluster: 5
#
# Cluster 33:
# Indices of data points: [30, 233, 239, 362, 866, 1789, 1879, 1896, 2039, 2501, 3485, 4137, 4806, 4911]
# Number of data points in this cluster: 14
#
# Cluster 459:
# Indices of data points: [31, 1308, 2469]
# Number of data points in this cluster: 3
#
# Cluster 493:
# Indices of data points: [32, 907, 2513, 2739, 2918]
# Number of data points in this cluster: 5
#
# Cluster 89:
# Indices of data points: [33, 987, 1961, 2149, 3538]
# Number of data points in this cluster: 5
#
# Cluster 457:
# Indices of data points: [34, 288, 1235, 2226]
# Number of data points in this cluster: 4
#
# Cluster 53:
# Indices of data points: [35, 1391, 1483, 2691, 3057, 4056]
# Number of data points in this cluster: 6
#
# Cluster 529:
# Indices of data points: [36, 1534, 2877, 3266, 3797]
# Number of data points in this cluster: 5
#
# Cluster 0:
# Indices of data points: [37, 167, 184, 405, 997, 1022, 1175, 1214, 1441, 1477, 2060, 2646, 2846, 2953, 3930, 4271, 4332, 4910]
# Number of data points in this cluster: 18
#
# Cluster 62:
# Indices of data points: [38, 1713, 2362, 2962, 3111, 3452]
# Number of data points in this cluster: 6
#
# Cluster 525:
# Indices of data points: [39, 700, 839, 2328, 2985, 3318, 4749, 4968]
# Number of data points in this cluster: 8
#
# Cluster 397:
# Indices of data points: [40, 307, 798, 950, 2128, 2584, 3194, 5026, 5045, 5060]
# Number of data points in this cluster: 10
#
# Cluster 250:
# Indices of data points: [41, 2400, 2839, 3623, 4167, 4215, 4280, 4715, 4789, 4865, 5063]
# Number of data points in this cluster: 11
#
# Cluster 658:
# Indices of data points: [42, 1148, 1196, 2137, 2361, 2857, 3628, 3692, 4670, 5017]
# Number of data points in this cluster: 10
#
# Cluster 487:
# Indices of data points: [43, 334, 357, 402, 894, 1974, 2073, 2237, 2664, 3386, 3790, 3825, 3957, 4376]
# Number of data points in this cluster: 14
#
# Cluster 177:
# Indices of data points: [44, 100, 112, 412, 429, 1707, 2094, 2675, 2864, 3262, 4469, 4629, 5023]
# Number of data points in this cluster: 13
#
# Cluster 532:
# Indices of data points: [45, 2422, 2779, 3050, 3712, 3794]
# Number of data points in this cluster: 6
#
# Cluster 337:
# Indices of data points: [46, 378, 1965, 2372, 2567, 3329, 4326]
# Number of data points in this cluster: 7
#
# Cluster 355:
# Indices of data points: [47, 624, 669, 704, 1053, 1488, 2347, 2606, 2913, 2939, 3076, 3207, 3381, 4543, 4940]
# Number of data points in this cluster: 15
#
# Cluster 74:
# Indices of data points: [48, 96, 408, 503, 795, 1828, 1864, 1904, 2441, 3764, 4565, 4643]
# Number of data points in this cluster: 12
#
# Cluster 523:
# Indices of data points: [50, 665, 695, 1083, 1968, 2294, 2607, 4627, 4838, 4976, 5099, 5106]
# Number of data points in this cluster: 12
#
# Cluster 562:
# Indices of data points: [51, 73, 2370, 4644]
# Number of data points in this cluster: 4
#
# Cluster 68:
# Indices of data points: [52, 75, 258, 590, 1351, 1525, 1745, 2076, 4192, 4219, 4472, 4937]
# Number of data points in this cluster: 12
#
# Cluster 48:
# Indices of data points: [53, 1078, 1915, 2265, 2463, 3099, 3617, 4078, 4283]
# Number of data points in this cluster: 9
#
# Cluster 291:
# Indices of data points: [54, 672, 966, 2121, 3514, 3768, 4313, 4607, 4848]
# Number of data points in this cluster: 9
#
# Cluster 654:
# Indices of data points: [56, 1239, 2064, 2281, 3288, 4624]
# Number of data points in this cluster: 6
#
# Cluster 285:
# Indices of data points: [57, 1599, 1859, 2159, 3123, 3782, 3803, 4003, 5009]
# Number of data points in this cluster: 9
#
# Cluster 85:
# Indices of data points: [58, 1335, 2239, 3272, 3516, 4389, 4441]
# Number of data points in this cluster: 7
#
# Cluster 160:
# Indices of data points: [59, 1900, 2091, 2448, 3569, 3854, 4364, 4637, 4698, 4709, 4933, 4949]
# Number of data points in this cluster: 12
#
# Cluster 2:
# Indices of data points: [60, 256, 361, 543, 675, 1593, 1696, 2162, 2429, 2884, 2897, 3438, 3741, 4657, 4927, 5061]
# Number of data points in this cluster: 16
#
# Cluster 721:
# Indices of data points: [61, 135, 1548, 1812, 2929, 3208, 4516, 4859, 5095]
# Number of data points in this cluster: 9
#
# Cluster 400:
# Indices of data points: [62, 119, 922, 1167, 1288, 1946, 2635, 3064, 3594, 4557, 4610]
# Number of data points in this cluster: 11
#
# Cluster 98:
# Indices of data points: [63, 507, 1921, 2476, 3059, 4169, 4541]
# Number of data points in this cluster: 7
#
# Cluster 140:
# Indices of data points: [64, 234, 1476, 1838, 1877, 1926, 2551, 2778, 2815, 3055, 3395, 3818, 4026, 4521]
# Number of data points in this cluster: 14
#
# Cluster 37:
# Indices of data points: [65, 1467, 1506, 1636, 1766, 2167, 2655, 2907]
# Number of data points in this cluster: 8
#
# Cluster 410:
# Indices of data points: [66, 190, 299, 1150, 1469, 1596, 1865, 2009, 2040, 3490, 3563, 3565, 3876]
# Number of data points in this cluster: 13
#
# Cluster 103:
# Indices of data points: [67, 87, 236, 676, 1654, 1837, 1858, 2176, 3953, 4201, 4529, 4816, 4946, 4948]
# Number of data points in this cluster: 14
#
# Cluster 284:
# Indices of data points: [68, 1048, 2062, 2127, 3595, 4213, 4251, 5075]
# Number of data points in this cluster: 8
#
# Cluster 681:
# Indices of data points: [69, 1337, 1727, 2041, 2300, 2670, 4872]
# Number of data points in this cluster: 7
#
# Cluster 6:
# Indices of data points: [70, 91, 168, 327, 1258, 2014, 2169, 2193, 3167, 3709, 3788, 3981, 4191, 4604]
# Number of data points in this cluster: 14
#
# Cluster 99:
# Indices of data points: [71, 158, 422, 823, 1567, 1682, 2485, 3029, 3184, 3515, 5077]
# Number of data points in this cluster: 11
#
# Cluster 630:
# Indices of data points: [72, 705, 4126]
# Number of data points in this cluster: 3
#
# Cluster 743:
# Indices of data points: [74, 1716, 1935, 2189, 4947]
# Number of data points in this cluster: 5
#
# Cluster 114:
# Indices of data points: [76, 269, 596, 1110, 1455, 1752, 2390, 2494, 2575, 2732, 3430, 3442, 3461, 3927, 3987, 4590, 4794, 4922, 5094]
# Number of data points in this cluster: 19
#
# Cluster 709:
# Indices of data points: [77, 473, 4394]
# Number of data points in this cluster: 3
#
# Cluster 547:
# Indices of data points: [78, 81, 138, 875, 925, 1208, 1309, 1400, 2943, 3396, 3533]
# Number of data points in this cluster: 11
#
# Cluster 403:
# Indices of data points: [79, 403, 1771, 2048, 2410, 3844, 3989, 4185, 4426, 4591, 4929]
# Number of data points in this cluster: 11
#
# Cluster 205:
# Indices of data points: [80, 2063, 2414, 2875, 3674]
# Number of data points in this cluster: 5
#
# Cluster 283:
# Indices of data points: [82, 238, 1443, 2577, 4014, 4665, 4939, 5034]
# Number of data points in this cluster: 8
#
# Cluster 593:
# Indices of data points: [84, 452, 1099, 2194, 2210, 4060, 4163]
# Number of data points in this cluster: 7
#
# Cluster 189:
# Indices of data points: [85, 330, 400, 882, 1449, 1582, 1872, 3753, 3827]
# Number of data points in this cluster: 9
#
# Cluster 431:
# Indices of data points: [86, 888, 2827, 2837, 3899, 4199, 4826]
# Number of data points in this cluster: 7
#
# Cluster 476:
# Indices of data points: [88, 532, 2145, 2543, 3488, 3762, 4147]
# Number of data points in this cluster: 7
#
# Cluster 401:
# Indices of data points: [89, 129, 2110, 2256, 3192, 3468, 4085, 4159, 4593, 4669]
# Number of data points in this cluster: 10
#
# Cluster 175:
# Indices of data points: [90, 368, 489, 1780, 3726, 3995, 4054]
# Number of data points in this cluster: 7
#
# Cluster 622:
# Indices of data points: [92, 778, 886, 2358]
# Number of data points in this cluster: 4
#
# Cluster 574:
# Indices of data points: [93, 410, 505, 698, 1361, 1754, 2004, 2679, 3469, 3947, 4266, 4523, 4784, 4991]
# Number of data points in this cluster: 14
#
# Cluster 113:
# Indices of data points: [94, 124, 502, 1024, 1920, 2993, 3417, 3784, 4839, 5015]
# Number of data points in this cluster: 10
#
# Cluster 157:
# Indices of data points: [95, 480, 1007, 1383, 1409, 1458, 2049, 2071, 3000, 3557, 3958]
# Number of data points in this cluster: 11
#
# Cluster 422:
# Indices of data points: [97, 286, 325, 648, 677, 861, 1043, 1152, 1385, 1523, 1641, 1796, 2158, 2510, 2701, 3074, 3915, 4110, 4699, 4971]
# Number of data points in this cluster: 20
#
# Cluster 288:
# Indices of data points: [98, 602, 967]
# Number of data points in this cluster: 3
#
# Cluster 600:
# Indices of data points: [99, 1518, 1741, 2587, 2785, 2796, 4843, 5089]
# Number of data points in this cluster: 8
#
# Cluster 271:
# Indices of data points: [101, 1711, 1817, 1868, 2954, 3566, 3882, 3903, 3964, 4503, 4975, 5097]
# Number of data points in this cluster: 12
#
# Cluster 228:
# Indices of data points: [103, 428, 516, 1206, 1268, 1371, 1566, 2373, 3537, 3838, 4256, 4309, 4633, 4958]
# Number of data points in this cluster: 14
#
# Cluster 83:
# Indices of data points: [104, 319, 832, 841, 1122, 1403, 2010, 2296, 2726, 2904, 3117, 3489, 3774, 4809, 4987, 5100]
# Number of data points in this cluster: 16
#
# Cluster 648:
# Indices of data points: [105, 720, 1168, 1491, 1688, 3398, 3439, 3615, 3801]
# Number of data points in this cluster: 9
#
# Cluster 341:
# Indices of data points: [107, 276, 929, 1298, 1831, 2810, 3412]
# Number of data points in this cluster: 7
#
# Cluster 71:
# Indices of data points: [108, 209, 289, 382, 419, 815, 852, 941, 1591, 1808, 2160, 2478, 2520, 2829, 3084, 4913, 5042]
# Number of data points in this cluster: 17
#
# Cluster 81:
# Indices of data points: [109, 164, 406, 501, 550, 1040, 2247, 3920, 4125]
# Number of data points in this cluster: 9
#
# Cluster 693:
# Indices of data points: [110, 2612, 3409, 3730, 3994]
# Number of data points in this cluster: 5
#
# Cluster 670:
# Indices of data points: [111, 320, 2395, 4443]
# Number of data points in this cluster: 4
#
# Cluster 554:
# Indices of data points: [113, 2106, 2170, 3118, 3691, 4272]
# Number of data points in this cluster: 6
#
# Cluster 452:
# Indices of data points: [114, 141, 4128]
# Number of data points in this cluster: 3
#
# Cluster 26:
# Indices of data points: [115, 290, 960, 2099, 2122, 2859, 3662, 3991, 4182]
# Number of data points in this cluster: 9
#
# Cluster 51:
# Indices of data points: [116, 347, 392, 536, 817, 903, 3901, 4012, 4292, 4494, 5117]
# Number of data points in this cluster: 11
#
# Cluster 584:
# Indices of data points: [117, 395, 871, 872, 1522, 2818, 3069, 3324, 3950, 4218]
# Number of data points in this cluster: 10
#
# Cluster 324:
# Indices of data points: [118, 1517, 3725, 4553]
# Number of data points in this cluster: 4
#
# Cluster 194:
# Indices of data points: [120, 499, 2682, 4301, 4458, 4959]
# Number of data points in this cluster: 6
#
# Cluster 334:
# Indices of data points: [121, 369, 1583, 2479, 2694, 2952, 4005, 4877, 5020]
# Number of data points in this cluster: 9
#
# Cluster 515:
# Indices of data points: [122, 593, 936, 1287, 1291, 1562, 4756, 4791, 4879]
# Number of data points in this cluster: 9
#
# Cluster 588:
# Indices of data points: [123, 1787, 2464, 3918]
# Number of data points in this cluster: 4
#
# Cluster 430:
# Indices of data points: [125, 562, 783, 3009, 3287, 4296, 4329, 4532, 4739, 4986]
# Number of data points in this cluster: 10
#
# Cluster 527:
# Indices of data points: [126, 143, 667, 1776, 2401, 2495, 2605, 2931, 4966, 5067]
# Number of data points in this cluster: 10
#
# Cluster 162:
# Indices of data points: [127, 181, 208, 348, 863, 887, 1919, 2047, 2311, 2706, 2980, 2987, 3187, 3800, 3925, 4098, 4833, 4853, 4856]
# Number of data points in this cluster: 19
#
# Cluster 472:
# Indices of data points: [128, 2216, 2991, 3955]
# Number of data points in this cluster: 4
#
# Cluster 256:
# Indices of data points: [130, 163, 169, 819, 2625, 2888, 3037, 4712, 4840, 5078, 5087, 5123]
# Number of data points in this cluster: 12
#
# Cluster 137:
# Indices of data points: [132, 1912, 2045, 2107, 2166, 3539, 3865, 4497, 4901]
# Number of data points in this cluster: 9
#
# Cluster 172:
# Indices of data points: [133, 310, 926, 1038, 1423, 3787, 3896, 4018, 4655, 4711, 4716]
# Number of data points in this cluster: 11
#
# Cluster 209:
# Indices of data points: [136, 188, 893, 1951, 2056, 2923, 3295, 3703, 3848, 4760, 4778, 4818, 4825, 5112]
# Number of data points in this cluster: 14
#
# Cluster 435:
# Indices of data points: [139, 1498, 1550, 2413, 2909]
# Number of data points in this cluster: 5
#
# Cluster 710:
# Indices of data points: [140, 154, 477, 563, 1319, 1628, 1811, 1958]
# Number of data points in this cluster: 8
#
# Cluster 125:
# Indices of data points: [142, 182, 853, 889, 1390, 2120, 2314, 3522, 3603, 3998, 4033, 4924]
# Number of data points in this cluster: 12
#
# Cluster 29:
# Indices of data points: [144, 688, 2317, 2338, 2512, 2616, 3139]
# Number of data points in this cluster: 7
#
# Cluster 480:
# Indices of data points: [145, 557, 774, 1311, 1876, 3912]
# Number of data points in this cluster: 6
#
# Cluster 107:
# Indices of data points: [146, 580, 694, 844, 927, 1331, 1933, 2588, 2644, 2662, 2887, 4365, 4717, 4735, 4858, 4997]
# Number of data points in this cluster: 16
#
# Cluster 499:
# Indices of data points: [147, 324, 2135, 2474, 3534, 4143, 4153]
# Number of data points in this cluster: 7
#
# Cluster 282:
# Indices of data points: [148, 769, 851, 2032, 2271, 3004, 3153, 3493, 4187, 4433]
# Number of data points in this cluster: 10
#
# Cluster 470:
# Indices of data points: [149, 2105, 2975, 3868, 3969, 4179, 4255]
# Number of data points in this cluster: 7
#
# Cluster 1:
# Indices of data points: [150, 1067, 1357, 2967, 4291, 4659, 4876]
# Number of data points in this cluster: 7
#
# Cluster 546:
# Indices of data points: [151, 344, 453, 1190, 2359, 3428, 4377, 4754, 4886]
# Number of data points in this cluster: 9
#
# Cluster 199:
# Indices of data points: [152, 548, 1584, 2695, 3812, 4236, 4605, 4662, 4663, 4681, 4827, 4961, 5076, 5113]
# Number of data points in this cluster: 14
#
# Cluster 694:
# Indices of data points: [153, 2117, 2767, 3728, 3837, 4792, 4938, 5056]
# Number of data points in this cluster: 8
#
# Cluster 754:
# Indices of data points: [155, 983, 1980, 2082]
# Number of data points in this cluster: 4
#
# Cluster 191:
# Indices of data points: [156, 200, 337, 559, 804, 1255, 2364, 2614, 2950, 3012, 3437]
# Number of data points in this cluster: 11
#
# Cluster 661:
# Indices of data points: [157, 176, 1098, 1515, 2165, 2934]
# Number of data points in this cluster: 6
#
# Cluster 691:
# Indices of data points: [159, 1639, 1735, 3505, 4286]
# Number of data points in this cluster: 5
#
# Cluster 153:
# Indices of data points: [160, 1264, 1396, 1462, 1622, 2054, 3265, 3500, 3771, 3993, 4087, 4819, 4836, 4889]
# Number of data points in this cluster: 14
#
# Cluster 56:
# Indices of data points: [161, 218, 775, 830, 1025, 1339, 1959, 2204, 2533, 2630, 3400, 3611, 3739, 3881, 3933, 4183]
# Number of data points in this cluster: 16
#
# Cluster 79:
# Indices of data points: [162, 232, 271, 434, 668, 1359, 1738, 2075, 2297, 2791, 2969, 3079, 3147, 3275, 3455, 3699, 3758, 4359, 4558]
# Number of data points in this cluster: 19
#
# Cluster 95:
# Indices of data points: [165, 1035, 1595, 1942, 3042, 4189, 4621, 4685, 4831]
# Number of data points in this cluster: 9
#
# Cluster 136:
# Indices of data points: [166, 1180, 1439, 2013, 2043, 2665, 2681, 2968, 4528, 5038]
# Number of data points in this cluster: 10
#
# Cluster 413:
# Indices of data points: [170, 1516, 1565, 2377, 2406, 2503, 4967, 5070, 5119]
# Number of data points in this cluster: 9
#
# Cluster 677:
# Indices of data points: [171, 384, 1453, 1827, 2111, 4641]
# Number of data points in this cluster: 6
#
# Cluster 241:
# Indices of data points: [172, 939, 1045, 1482, 2180, 3474, 3763, 3805, 4442]
# Number of data points in this cluster: 9
#
# Cluster 605:
# Indices of data points: [173, 834, 4863]
# Number of data points in this cluster: 3
#
# Cluster 274:
# Indices of data points: [174, 1160, 3293, 3640, 4237]
# Number of data points in this cluster: 5
#
# Cluster 539:
# Indices of data points: [175, 1087, 1607, 2327, 2516, 3559, 3698, 3888, 4141, 4298, 4852, 5082]
# Number of data points in this cluster: 12
#
# Cluster 640:
# Indices of data points: [177, 231, 743, 1089, 1637, 2854, 2965, 5024]
# Number of data points in this cluster: 8
#
# Cluster 559:
# Indices of data points: [178, 527, 2022, 3190, 3551]
# Number of data points in this cluster: 5
#
# Cluster 122:
# Indices of data points: [179, 187, 425, 586, 953, 1114, 1347, 1432, 1532, 3441]
# Number of data points in this cluster: 10
#
# Cluster 202:
# Indices of data points: [180, 686, 2707, 3216, 3249, 3276, 4211, 4372, 5037]
# Number of data points in this cluster: 9
#
# Cluster 105:
# Indices of data points: [183, 443, 510, 625, 2225, 2621, 3028, 3322, 3472, 4278, 4572]
# Number of data points in this cluster: 11
#
# Cluster 751:
# Indices of data points: [185, 318, 504, 1447, 2243, 2374, 3026, 3221, 3278, 4034, 5044]
# Number of data points in this cluster: 11
#
# Cluster 660:
# Indices of data points: [186, 485, 518, 603, 3299, 3575, 4361]
# Number of data points in this cluster: 7
#
# Cluster 533:
# Indices of data points: [191, 241, 387, 1246, 2304, 3931, 4496, 4606, 4645]
# Number of data points in this cluster: 9
#
# Cluster 566:
# Indices of data points: [192, 544, 932, 1059, 2034, 2234, 3729]
# Number of data points in this cluster: 7
#
# Cluster 598:
# Indices of data points: [193, 591, 2801, 3091, 3134]
# Number of data points in this cluster: 5
#
# Cluster 592:
# Indices of data points: [194, 2035]
# Number of data points in this cluster: 2
#
# Cluster 300:
# Indices of data points: [195, 728, 2493, 2556, 3024, 3860]
# Number of data points in this cluster: 6
#
# Cluster 49:
# Indices of data points: [196, 224, 2042, 2352, 2631, 2901, 3494, 3893, 4039, 4597, 4726, 4994, 5053]
# Number of data points in this cluster: 13
#
# Cluster 273:
# Indices of data points: [197, 446, 579, 1342, 1434, 1802, 3196, 3867, 4677, 4956, 5091]
# Number of data points in this cluster: 11
#
# Cluster 72:
# Indices of data points: [198, 1066, 1202, 1655, 2650, 2894, 4575]
# Number of data points in this cluster: 7
#
# Cluster 289:
# Indices of data points: [199, 1944, 1996, 3457, 3600, 4172, 4957]
# Number of data points in this cluster: 7
#
# Cluster 504:
# Indices of data points: [201, 280, 1334, 2065, 3003, 4527, 4830, 4869]
# Number of data points in this cluster: 8
#
# Cluster 134:
# Indices of data points: [202, 617, 808, 913, 1438, 2747, 3427, 3622, 4013, 4084, 4887]
# Number of data points in this cluster: 11
#
# Cluster 609:
# Indices of data points: [203, 1489, 1574, 2133, 3051, 3582, 4048]
# Number of data points in this cluster: 7
#
# Cluster 380:
# Indices of data points: [204, 855, 1270, 1814, 2219, 2803, 3206, 3218, 3270, 3415]
# Number of data points in this cluster: 10
#
# Cluster 185:
# Indices of data points: [205, 214, 449, 2005, 3608, 4388, 4934]
# Number of data points in this cluster: 7
#
# Cluster 363:
# Indices of data points: [206, 681, 2771, 3975, 4238]
# Number of data points in this cluster: 5
#
# Cluster 699:
# Indices of data points: [207, 2903, 3654, 4490]
# Number of data points in this cluster: 4
#
# Cluster 90:
# Indices of data points: [210, 1050, 2114, 2781, 4264, 4422, 5008]
# Number of data points in this cluster: 7
#
# Cluster 317:
# Indices of data points: [211, 390, 1041, 1708, 4679, 4790, 4970]
# Number of data points in this cluster: 7
#
# Cluster 586:
# Indices of data points: [212, 1154, 1405, 4090, 4700, 4866]
# Number of data points in this cluster: 6
#
# Cluster 281:
# Indices of data points: [213, 312, 396, 612, 796, 1173, 1541, 2108, 2710, 2765, 4068, 4803]
# Number of data points in this cluster: 12
#
# Cluster 150:
# Indices of data points: [215, 228, 315, 1354, 1914, 1986, 2333, 2576, 2838, 3487, 4733, 4771, 4808, 4906]
# Number of data points in this cluster: 14
#
# Cluster 313:
# Indices of data points: [216, 431, 1093, 1329, 1994, 3228, 3454, 4061, 4109]
# Number of data points in this cluster: 9
#
# Cluster 399:
# Indices of data points: [217, 1016, 1253, 1370, 1373, 1725, 2436, 3596, 3609, 4409]
# Number of data points in this cluster: 10
#
# Cluster 601:
# Indices of data points: [219, 465, 2206, 4107]
# Number of data points in this cluster: 4
#
# Cluster 545:
# Indices of data points: [220, 1382, 1683, 1970, 3447, 3748, 4253, 4890]
# Number of data points in this cluster: 8
#
# Cluster 144:
# Indices of data points: [221, 417, 642, 1387, 1452, 1610, 2692, 2744, 2852, 2958, 4424]
# Number of data points in this cluster: 11
#
# Cluster 414:
# Indices of data points: [222, 656, 1350, 1461, 1945, 2323, 3173, 4706, 4730]
# Number of data points in this cluster: 9
#
# Cluster 167:
# Indices of data points: [223, 416, 582, 788, 2079, 2508, 4030, 4495, 4867]
# Number of data points in this cluster: 9
#
# Cluster 117:
# Indices of data points: [225, 651, 792, 916, 1295, 1620, 1666, 2550, 2705, 3641, 4678, 4759, 5014, 5022, 5071]
# Number of data points in this cluster: 15
#
# Cluster 746:
# Indices of data points: [226, 691, 1418, 1442, 3344, 4732]
# Number of data points in this cluster: 6
#
# Cluster 565:
# Indices of data points: [227, 574, 2229, 3247, 3358, 3371, 3959]
# Number of data points in this cluster: 7
#
# Cluster 727:
# Indices of data points: [229, 1243, 2488, 3245, 3291, 4965]
# Number of data points in this cluster: 6
#
# Cluster 218:
# Indices of data points: [230, 430, 750, 785, 1554, 1571, 1813, 2298, 2589, 3052, 4761, 4782]
# Number of data points in this cluster: 12
#
# Cluster 360:
# Indices of data points: [235, 341, 420, 495, 781, 973, 1109, 1256, 2671, 3721, 3946, 4101]
# Number of data points in this cluster: 12
#
# Cluster 292:
# Indices of data points: [237, 1589, 1934, 2435, 3680, 4059]
# Number of data points in this cluster: 6
#
# Cluster 161:
# Indices of data points: [242, 867, 1161, 1512, 1908, 1969, 2822, 2911, 3008, 4168, 4692]
# Number of data points in this cluster: 11
#
# Cluster 522:
# Indices of data points: [243, 427, 885, 1137, 2154, 2786, 2872, 3306, 4928, 5032]
# Number of data points in this cluster: 10
#
# Cluster 763:
# Indices of data points: [244, 821, 3032, 3133, 3388, 4387, 4952, 4964]
# Number of data points in this cluster: 8
#
# Cluster 59:
# Indices of data points: [245, 770, 784, 1194, 1417, 1643, 1748, 1775, 1788, 2848, 4016, 4713, 4828, 4995, 5012]
# Number of data points in this cluster: 15
#
# Cluster 734:
# Indices of data points: [247, 827, 1153, 1676, 4216, 4963, 5003]
# Number of data points in this cluster: 7
#
# Cluster 675:
# Indices of data points: [248, 279, 707, 4133]
# Number of data points in this cluster: 4
#
# Cluster 45:
# Indices of data points: [249, 1326, 1736, 2066, 2486, 3463, 3850, 4104, 4177, 4194]
# Number of data points in this cluster: 10
#
# Cluster 474:
# Indices of data points: [250, 732, 2074, 2433, 2893, 3150, 3186, 3414, 3527, 4154]
# Number of data points in this cluster: 10
#
# Cluster 374:
# Indices of data points: [251, 1004, 1421, 1492, 1800, 2538, 2892, 3298, 3736, 4704]
# Number of data points in this cluster: 10
#
# Cluster 216:
# Indices of data points: [252, 560, 1104, 1151, 1834, 2531, 2660, 2754, 3759, 4658, 4763, 5083]
# Number of data points in this cluster: 12
#
# Cluster 36:
# Indices of data points: [254, 1127, 1263, 1280, 2144, 3086, 3181]
# Number of data points in this cluster: 7
#
# Cluster 502:
# Indices of data points: [255, 1128, 1555, 1721, 2663, 3618]
# Number of data points in this cluster: 6
#
# Cluster 230:
# Indices of data points: [257, 718, 816, 1171, 1254, 1473, 2392, 2618]
# Number of data points in this cluster: 8
#
# Cluster 388:
# Indices of data points: [259, 650, 738, 2491, 4022]
# Number of data points in this cluster: 5
#
# Cluster 481:
# Indices of data points: [260, 261, 1218, 1963, 2224, 3080, 3917]
# Number of data points in this cluster: 7
#
# Cluster 101:
# Indices of data points: [262, 613, 653, 1634, 1889, 2072, 3301, 4619, 4820, 4841, 5006, 5055, 5066]
# Number of data points in this cluster: 13
#
# Cluster 211:
# Indices of data points: [263, 1088, 1261, 1323, 1389, 1463, 1627, 2089, 2142, 2236, 2458, 2935, 3189, 3550, 3587, 4570]
# Number of data points in this cluster: 16
#
# Cluster 393:
# Indices of data points: [264, 284, 295, 869, 2275, 2276, 2925, 3279, 3482, 3682, 3814, 4697]
# Number of data points in this cluster: 12
#
# Cluster 385:
# Indices of data points: [265, 1499, 1531, 1927]
# Number of data points in this cluster: 4
#
# Cluster 697:
# Indices of data points: [266, 755, 1120, 1760, 3470, 4546]
# Number of data points in this cluster: 6
#
# Cluster 232:
# Indices of data points: [267, 714, 1252, 1281, 1379, 2214, 4285]
# Number of data points in this cluster: 7
#
# Cluster 615:
# Indices of data points: [268, 595, 635, 801, 923, 1012, 1678, 3416]
# Number of data points in this cluster: 8
#
# Cluster 293:
# Indices of data points: [270, 697, 949, 1006, 1197, 1328, 1375, 2481, 3471, 3810, 4356, 4857]
# Number of data points in this cluster: 12
#
# Cluster 131:
# Indices of data points: [272, 1422, 1663, 1978, 2131, 2157, 2184, 2879, 3094, 3159, 3171, 3941]
# Number of data points in this cluster: 12
#
# Cluster 305:
# Indices of data points: [273, 305, 338, 355, 1046, 2290, 3572, 3576, 3666, 3779, 4044]
# Number of data points in this cluster: 11
#
# Cluster 623:
# Indices of data points: [274]
# Number of data points in this cluster: 1
#
# Cluster 432:
# Indices of data points: [275, 2899, 3320]
# Number of data points in this cluster: 3
#
# Cluster 507:
# Indices of data points: [277, 655, 2203, 2447, 3506, 4350]
# Number of data points in this cluster: 6
#
# Cluster 286:
# Indices of data points: [278, 1673, 2982, 3018, 4053]
# Number of data points in this cluster: 5
#
# Cluster 310:
# Indices of data points: [281, 969, 1971, 2255, 3914, 3977, 4489, 4845]
# Number of data points in this cluster: 8
#
# Cluster 259:
# Indices of data points: [282, 328, 1322, 1756, 2626]
# Number of data points in this cluster: 5
#
# Cluster 206:
# Indices of data points: [283, 1614, 2320, 2574, 3115, 4009, 4080]
# Number of data points in this cluster: 7
#
# Cluster 18:
# Indices of data points: [285, 1731, 2242, 2580, 4023, 4186, 4453]
# Number of data points in this cluster: 7
#
# Cluster 665:
# Indices of data points: [287, 993, 2197, 2652]
# Number of data points in this cluster: 4
#
# Cluster 597:
# Indices of data points: [291, 1962, 2324, 2546, 2855, 3124, 3826, 4632, 4960, 5062]
# Number of data points in this cluster: 10
#
# Cluster 108:
# Indices of data points: [292, 294, 4293, 4454]
# Number of data points in this cluster: 4
#
# Cluster 43:
# Indices of data points: [293, 373, 398, 432, 567, 637, 898, 1293, 1320, 1923, 2254, 2920, 3303, 3702]
# Number of data points in this cluster: 14
#
# Cluster 251:
# Indices of data points: [296, 1372, 1759, 4412, 4478, 4587]
# Number of data points in this cluster: 6
#
# Cluster 356:
# Indices of data points: [297, 2278, 2339, 2856]
# Number of data points in this cluster: 4
#
# Cluster 336:
# Indices of data points: [298, 521, 539, 1289, 1840, 2403, 3785, 4223, 4824, 5010]
# Number of data points in this cluster: 10
#
# Cluster 224:
# Indices of data points: [300, 492, 622, 876, 1481, 2207, 3875, 4870]
# Number of data points in this cluster: 8
#
# Cluster 761:
# Indices of data points: [301, 1833, 2092, 2922, 3997, 4581, 4625, 4780]
# Number of data points in this cluster: 8
#
# Cluster 19:
# Indices of data points: [302, 456, 597, 696, 918, 1051, 1159, 1638, 2283, 2712, 2862, 4580, 4628]
# Number of data points in this cluster: 13
#
# Cluster 454:
# Indices of data points: [303, 787, 1538, 1724, 2130, 2921, 3840, 3924, 4647, 5030]
# Number of data points in this cluster: 10
#
# Cluster 133:
# Indices of data points: [304, 375, 1009, 1419, 3492, 3620, 4129]
# Number of data points in this cluster: 7
#
# Cluster 212:
# Indices of data points: [306, 454, 519, 2615, 4105, 4205, 4484, 4822, 4873, 4990, 5064]
# Number of data points in this cluster: 11
#
# Cluster 664:
# Indices of data points: [308, 763, 1169, 3945, 4797, 4953, 5033]
# Number of data points in this cluster: 7
#
# Cluster 69:
# Indices of data points: [311, 1215, 1415, 2356, 4047, 4138]
# Number of data points in this cluster: 6
#
# Cluster 688:
# Indices of data points: [314, 1556, 2141, 3824, 3952, 4984, 5059]
# Number of data points in this cluster: 7
#
# Cluster 391:
# Indices of data points: [316, 386, 645, 751, 1570, 1953, 2649, 3495, 3791, 4915, 4974]
# Number of data points in this cluster: 11
#
# Cluster 40:
# Indices of data points: [317, 547, 609, 951, 1032, 1302, 3070, 3835, 4444, 4944, 5002, 5130]
# Number of data points in this cluster: 12
#
# Cluster 556:
# Indices of data points: [321, 421, 1082, 1749, 2017, 2044, 3988, 4480, 4750]
# Number of data points in this cluster: 9
#
# Cluster 10:
# Indices of data points: [322, 1071, 1349, 2188, 2293, 2592, 2598, 2764, 2777, 3217, 4720]
# Number of data points in this cluster: 11
#
# Cluster 15:
# Indices of data points: [323, 760, 1539, 3523, 4344, 4993]
# Number of data points in this cluster: 6
#
# Cluster 276:
# Indices of data points: [326, 450, 2211, 3100, 3571, 3581, 5007]
# Number of data points in this cluster: 7
#
# Cluster 395:
# Indices of data points: [329, 525, 2259, 2313, 3309, 3708, 4162]
# Number of data points in this cluster: 7
#
# Cluster 7:
# Indices of data points: [331, 360, 523, 604, 618, 659, 870, 2343, 3154, 3889, 3984, 4757]
# Number of data points in this cluster: 12
#
# Cluster 12:
# Indices of data points: [332, 1283, 1425, 1609, 1612, 2015, 2490, 4982]
# Number of data points in this cluster: 8
#
# Cluster 210:
# Indices of data points: [333, 976, 2088, 3310, 3630, 4537, 4650]
# Number of data points in this cluster: 7
#
# Cluster 501:
# Indices of data points: [335, 1332, 1459, 2992, 3090, 3373, 4502]
# Number of data points in this cluster: 7
#
# Cluster 225:
# Indices of data points: [336, 500, 553, 658, 840, 1026, 2021, 2677, 4106, 4926]
# Number of data points in this cluster: 10
#
# Cluster 368:
# Indices of data points: [339, 1427, 1633, 1847, 1888, 2867, 3555, 3869, 4366, 4874, 4893]
# Number of data points in this cluster: 11
#
# Cluster 471:
# Indices of data points: [340, 345, 1097, 1251, 2036, 2790, 2983, 4279, 4322, 4683]
# Number of data points in this cluster: 10
#
# Cluster 645:
# Indices of data points: [342, 998, 1411, 1993, 1997, 3232, 3443, 3530, 3683, 5027]
# Number of data points in this cluster: 10
#
# Cluster 364:
# Indices of data points: [343, 607, 2394, 3573, 3795, 3942, 4115, 4300]
# Number of data points in this cluster: 8
#
# Cluster 52:
# Indices of data points: [346, 529, 943, 995, 1448, 2235, 3096]
# Number of data points in this cluster: 7
#
# Cluster 50:
# Indices of data points: [349, 1183, 1199, 1484, 1581, 1792, 1809, 3191, 4588, 5013]
# Number of data points in this cluster: 10
#
# Cluster 541:
# Indices of data points: [351, 367, 716, 2629, 3963, 4492]
# Number of data points in this cluster: 6
#
# Cluster 242:
# Indices of data points: [352, 1299, 2714, 3039, 4783]
# Number of data points in this cluster: 5
#
# Cluster 168:
# Indices of data points: [353, 985, 986, 2756, 3263, 5039]
# Number of data points in this cluster: 6
#
# Cluster 756:
# Indices of data points: [356, 1454, 2033, 3205, 4108, 4648]
# Number of data points in this cluster: 6
#
# Cluster 4:
# Indices of data points: [359, 370, 379, 415, 589, 670, 1835, 1893, 2081, 2445, 3093, 3807, 4127, 4178, 4589, 4775, 4875, 4921, 5000]
# Number of data points in this cluster: 19
#
# Cluster 64:
# Indices of data points: [363, 2153, 3235, 3282, 3619, 4834, 4998]
# Number of data points in this cluster: 7
#
# Cluster 8:
# Indices of data points: [364, 702, 901, 1142, 1158, 1317, 1470, 2380, 2654, 2816, 3068, 3536, 3601, 4601, 4902]
# Number of data points in this cluster: 15
#
# Cluster 441:
# Indices of data points: [365, 1743, 2869, 3497]
# Number of data points in this cluster: 4
#
# Cluster 646:
# Indices of data points: [366, 411, 1052, 1436, 3935, 4978]
# Number of data points in this cluster: 6
#
# Cluster 86:
# Indices of data points: [371, 1236, 1242, 2642, 2916, 3011, 3911]
# Number of data points in this cluster: 7
#
# Cluster 644:
# Indices of data points: [374, 3223, 3851]
# Number of data points in this cluster: 3
#
# Cluster 65:
# Indices of data points: [376, 463, 1472, 2566, 2648, 2890, 3707, 4228, 4259, 4568, 5021]
# Number of data points in this cluster: 11
#
# Cluster 344:
# Indices of data points: [377, 1223, 1398, 1677, 1804, 2908, 3001, 4563, 4805]
# Number of data points in this cluster: 9
#
# Cluster 155:
# Indices of data points: [380, 1626, 1937, 2245, 2579, 4585]
# Number of data points in this cluster: 6
#
# Cluster 343:
# Indices of data points: [381, 805, 2198, 3385, 4567, 4676]
# Number of data points in this cluster: 6
#
# Cluster 573:
# Indices of data points: [383, 873, 1015, 1479, 3215, 4318]
# Number of data points in this cluster: 6
#
# Cluster 261:
# Indices of data points: [385, 388, 687, 1611, 2917, 3326, 3695, 5116]
# Number of data points in this cluster: 8
#
# Cluster 578:
# Indices of data points: [389, 1195, 3949, 4020, 4832]
# Number of data points in this cluster: 5
#
# Cluster 116:
# Indices of data points: [391, 678, 2101, 2143, 2205, 2480, 2830, 3376]
# Number of data points in this cluster: 8
#
# Cluster 272:
# Indices of data points: [393, 782, 794, 1445, 2238, 3243, 3382, 3521, 3922, 4996]
# Number of data points in this cluster: 10
#
# Cluster 39:
# Indices of data points: [394, 864, 957, 2684, 3465, 4461, 4544]
# Number of data points in this cluster: 7
#
# Cluster 735:
# Indices of data points: [397, 476, 615, 1200, 2070, 3005, 3928]
# Number of data points in this cluster: 7
#
# Cluster 132:
# Indices of data points: [399, 713, 1292, 1430, 2366, 2946, 3098, 3418, 3545, 4401]
# Number of data points in this cluster: 10
#
# Cluster 124:
# Indices of data points: [401, 1112, 4540, 4573]
# Number of data points in this cluster: 4
#
# Cluster 666:
# Indices of data points: [404, 1231, 3983, 4173]
# Number of data points in this cluster: 4
#
# Cluster 383:
# Indices of data points: [407, 522, 1123, 1836, 3152, 4217, 4274, 4538, 5019]
# Number of data points in this cluster: 9
#
# Cluster 659:
# Indices of data points: [413, 3873, 4592, 4630, 4742, 5103]
# Number of data points in this cluster: 6
#
# Cluster 320:
# Indices of data points: [414, 455, 654, 710, 831, 1125, 1176, 2363, 2498, 3333, 3535, 3934, 4599, 5096]
# Number of data points in this cluster: 14
#
# Cluster 38:
# Indices of data points: [423, 981, 4036, 4380, 4854]
# Number of data points in this cluster: 5
#
# Cluster 365:
# Indices of data points: [424, 956, 1130, 1444, 2353]
# Number of data points in this cluster: 5
#
# Cluster 260:
# Indices of data points: [426, 1778, 2342, 4436, 5001]
# Number of data points in this cluster: 5
#
# Cluster 126:
# Indices of data points: [433, 679, 899, 1854, 2774, 3097, 4245, 4455, 4463, 4504, 4914]
# Number of data points in this cluster: 11
#
# Cluster 748:
# Indices of data points: [435, 3106, 3140, 4064]
# Number of data points in this cluster: 4
#
# Cluster 220:
# Indices of data points: [436, 709, 828, 1019, 2012, 2900, 2932, 3399, 3580, 4622, 4807, 4909, 5048]
# Number of data points in this cluster: 13
#
# Cluster 510:
# Indices of data points: [437]
# Number of data points in this cluster: 1
#
# Cluster 611:
# Indices of data points: [438, 1117, 1602, 1779, 2540, 3948, 4429, 4552]
# Number of data points in this cluster: 8
#
# Cluster 346:
# Indices of data points: [439, 1028, 1049, 1315, 1699, 2132, 2383, 3183, 3369, 3560, 4275, 4416, 5057]
# Number of data points in this cluster: 13
#
# Cluster 201:
# Indices of data points: [440, 594, 1147, 1866, 2321, 2417, 3044, 3747]
# Number of data points in this cluster: 8
#
# Cluster 348:
# Indices of data points: [441, 662, 1823, 2253, 3613, 4410]
# Number of data points in this cluster: 6
#
# Cluster 641:
# Indices of data points: [442, 3204, 3798, 3879, 4001]
# Number of data points in this cluster: 5
#
# Cluster 149:
# Indices of data points: [444, 737, 2104]
# Number of data points in this cluster: 3
#
# Cluster 60:
# Indices of data points: [445, 767, 836, 860, 1909, 1954, 2337, 2805, 3466, 4017, 4198, 4212, 4823, 5036]
# Number of data points in this cluster: 14
#
# Cluster 402:
# Indices of data points: [447, 884, 978, 1044, 4930]
# Number of data points in this cluster: 5
#
# Cluster 768:
# Indices of data points: [451, 1513, 2573, 4385, 4470]
# Number of data points in this cluster: 5
#
# Cluster 708:
# Indices of data points: [457, 533, 3327, 3568]
# Number of data points in this cluster: 4
#
# Cluster 213:
# Indices of data points: [458, 657, 1058, 1580, 1983, 3030, 3659, 3884, 3960, 4636, 5081, 5084]
# Number of data points in this cluster: 12
#
# Cluster 696:
# Indices of data points: [459, 490, 1013, 2215, 3526, 3846, 4932]
# Number of data points in this cluster: 7
#
# Cluster 186:
# Indices of data points: [460, 542, 3067, 3284]
# Number of data points in this cluster: 4
#
# Cluster 442:
# Indices of data points: [461, 2711, 3304, 3632, 4055, 4384]
# Number of data points in this cluster: 6
#
# Cluster 181:
# Indices of data points: [462, 1072, 3307]
# Number of data points in this cluster: 3
#
# Cluster 438:
# Indices of data points: [464, 2624, 2858, 3113, 4070]
# Number of data points in this cluster: 5
#
# Cluster 255:
# Indices of data points: [466, 481, 938, 1630, 3202, 3503, 3769, 3777, 4032, 4466, 4595, 5107]
# Number of data points in this cluster: 12
#
# Cluster 215:
# Indices of data points: [467, 895, 1241, 1362, 1493, 1557, 2096, 2582, 2639, 3816, 4297]
# Number of data points in this cluster: 11
#
# Cluster 558:
# Indices of data points: [468, 703, 1121, 1220, 1260, 1282, 1301, 2404, 3130]
# Number of data points in this cluster: 9
#
# Cluster 154:
# Indices of data points: [469, 1177, 1230, 2177, 2286, 2415, 3621, 4207, 5043]
# Number of data points in this cluster: 9
#
# Cluster 530:
# Indices of data points: [470, 2031, 2735]
# Number of data points in this cluster: 3
#
# Cluster 749:
# Indices of data points: [471, 4069, 4473, 4519, 4550]
# Number of data points in this cluster: 5
#
# Cluster 429:
# Indices of data points: [472, 545, 1027, 1853, 2360, 2775]
# Number of data points in this cluster: 6
#
# Cluster 446:
# Indices of data points: [474, 1505, 1659, 1826, 3162, 3679, 4161, 4229]
# Number of data points in this cluster: 8
#
# Cluster 411:
# Indices of data points: [475, 583, 1631, 1873, 2542, 2951, 3296, 3996, 4579, 4617, 5092]
# Number of data points in this cluster: 11
#
# Cluster 308:
# Indices of data points: [478, 1219, 2310, 2659, 4149]
# Number of data points in this cluster: 5
#
# Cluster 277:
# Indices of data points: [479, 1818, 4415]
# Number of data points in this cluster: 3
#
# Cluster 248:
# Indices of data points: [482, 1213, 1406, 3337, 4666, 4693]
# Number of data points in this cluster: 6
#
# Cluster 28:
# Indices of data points: [483, 771, 904, 1984, 2319]
# Number of data points in this cluster: 5
#
# Cluster 408:
# Indices of data points: [484, 1679, 2452, 2608, 2686, 3475, 4390, 4702]
# Number of data points in this cluster: 8
#
# Cluster 390:
# Indices of data points: [488, 3453, 4067, 4418]
# Number of data points in this cluster: 4
#
# Cluster 625:
# Indices of data points: [491, 2947, 3710, 4058, 4785, 4812, 4842]
# Number of data points in this cluster: 7
#
# Cluster 415:
# Indices of data points: [493, 4123, 4299, 4450]
# Number of data points in this cluster: 4
#
# Cluster 519:
# Indices of data points: [494, 1929, 2269, 2881, 3397, 3649]
# Number of data points in this cluster: 6
#
# Cluster 178:
# Indices of data points: [496, 1939, 2116, 2151, 2221, 2994, 3075, 3160, 3177, 4694, 4942]
# Number of data points in this cluster: 11
#
# Cluster 764:
# Indices of data points: [497, 2643, 3332, 4114, 4671, 4770]
# Number of data points in this cluster: 6
#
# Cluster 421:
# Indices of data points: [498, 626, 900, 1671, 2723, 3321, 3992, 4583, 4725, 4777, 4861]
# Number of data points in this cluster: 11
#
# Cluster 690:
# Indices of data points: [506, 4476]
# Number of data points in this cluster: 2
#
# Cluster 319:
# Indices of data points: [508, 1511, 3665, 3744, 3765, 4507]
# Number of data points in this cluster: 6
#
# Cluster 78:
# Indices of data points: [509, 955, 1973, 2365, 2595, 2878, 3273, 4096, 4307]
# Number of data points in this cluster: 9
#
# Cluster 91:
# Indices of data points: [511, 2910, 2996, 3227, 3855, 3943]
# Number of data points in this cluster: 6
#
# Cluster 524:
# Indices of data points: [512, 2248, 2571, 3897, 4941, 4962, 5018]
# Number of data points in this cluster: 7
#
# Cluster 416:
# Indices of data points: [513, 2730, 3423, 4037]
# Number of data points in this cluster: 4
#
# Cluster 311:
# Indices of data points: [515, 2140, 4327]
# Number of data points in this cluster: 3
#
# Cluster 70:
# Indices of data points: [517, 2506, 2623, 4446]
# Number of data points in this cluster: 4
#
# Cluster 361:
# Indices of data points: [520, 1549, 2227, 4181, 5049, 5104, 5121]
# Number of data points in this cluster: 7
#
# Cluster 620:
# Indices of data points: [524, 1005, 4155]
# Number of data points in this cluster: 3
#
# Cluster 370:
# Indices of data points: [526, 972, 2201, 3110, 4089]
# Number of data points in this cluster: 5
#
# Cluster 187:
# Indices of data points: [528, 717, 2393, 3435, 4057]
# Number of data points in this cluster: 5
#
# Cluster 376:
# Indices of data points: [530, 1424, 1846, 3220, 3323, 3819, 3836, 4555, 4892]
# Number of data points in this cluster: 9
#
# Cluster 433:
# Indices of data points: [531, 908, 1353, 2745, 3445, 4028, 4393]
# Number of data points in this cluster: 7
#
# Cluster 146:
# Indices of data points: [534, 2277, 2279, 3629]
# Number of data points in this cluster: 4
#
# Cluster 100:
# Indices of data points: [535, 1600, 1717, 2348, 3102, 3929, 4156, 4241, 4439]
# Number of data points in this cluster: 9
#
# Cluster 482:
# Indices of data points: [537, 708, 2006, 3127, 3211, 3802, 4738, 4779]
# Number of data points in this cluster: 8
#
# Cluster 713:
# Indices of data points: [538, 2563, 3389, 3633, 4166, 4531, 4972]
# Number of data points in this cluster: 7
#
# Cluster 495:
# Indices of data points: [540, 2696, 3314, 4748]
# Number of data points in this cluster: 4
#
# Cluster 505:
# Indices of data points: [541, 2098, 2647, 2988]
# Number of data points in this cluster: 4
#
# Cluster 111:
# Indices of data points: [546, 1279, 1466, 1478, 3313, 4620]
# Number of data points in this cluster: 6
#
# Cluster 192:
# Indices of data points: [549, 636, 701, 1055, 1839, 2683, 5093]
# Number of data points in this cluster: 7
#
# Cluster 246:
# Indices of data points: [551, 850, 2442, 2499, 2703, 3908, 4501]
# Number of data points in this cluster: 7
#
# Cluster 66:
# Indices of data points: [552, 619, 1062, 1170, 1657, 2720, 2757, 3887, 5025, 5069]
# Number of data points in this cluster: 10
#
# Cluster 703:
# Indices of data points: [554, 2332, 4027, 4043, 4653, 4918]
# Number of data points in this cluster: 6
#
# Cluster 458:
# Indices of data points: [555, 1204, 2820, 2880, 3561, 4462]
# Number of data points in this cluster: 6
#
# Cluster 762:
# Indices of data points: [556, 891]
# Number of data points in this cluster: 2
#
# Cluster 269:
# Indices of data points: [558, 1094, 1528, 1686, 1732, 2685]
# Number of data points in this cluster: 6
#
# Cluster 706:
# Indices of data points: [561, 1529, 1617, 2742]
# Number of data points in this cluster: 4
#
# Cluster 263:
# Indices of data points: [564, 684, 857, 1020, 1257, 3017, 3297, 3986, 4566, 5051]
# Number of data points in this cluster: 10
#
# Cluster 548:
# Indices of data points: [565, 2866, 3886, 5120]
# Number of data points in this cluster: 4
#
# Cluster 738:
# Indices of data points: [566, 2784]
# Number of data points in this cluster: 2
#
# Cluster 118:
# Indices of data points: [568, 1136, 1381, 1603, 1720, 2653, 2955, 3394, 3658, 3831, 4325, 4762]
# Number of data points in this cluster: 12
#
# Cluster 182:
# Indices of data points: [569, 977, 2305, 2525, 2995, 4040, 4352, 4397, 4500, 5085]
# Number of data points in this cluster: 10
#
# Cluster 196:
# Indices of data points: [570, 598, 842, 914, 1070, 1294]
# Number of data points in this cluster: 6
#
# Cluster 731:
# Indices of data points: [571, 692, 1367, 1615, 1948, 2522, 3856, 4260]
# Number of data points in this cluster: 8
#
# Cluster 382:
# Indices of data points: [572, 663, 826, 1585, 1604, 1605, 2544, 2798, 2865, 3164, 3267, 3372, 4254, 4303, 4881]
# Number of data points in this cluster: 15
#
# Cluster 104:
# Indices of data points: [573, 1132, 1594, 1941, 2018, 2026, 2564, 3727, 4467]
# Number of data points in this cluster: 9
#
# Cluster 498:
# Indices of data points: [575, 982, 2389, 3909]
# Number of data points in this cluster: 4
#
# Cluster 221:
# Indices of data points: [576, 833, 1105, 1925, 2974, 4099, 4258, 4554, 4654]
# Number of data points in this cluster: 9
#
# Cluster 67:
# Indices of data points: [577, 1000, 1186, 1198, 2252, 2270, 2727, 3378, 3967]
# Number of data points in this cluster: 9
#
# Cluster 119:
# Indices of data points: [578, 640, 772, 865, 1135, 1238, 2272, 2736, 2949, 3564, 4092]
# Number of data points in this cluster: 11
#
# Cluster 46:
# Indices of data points: [581, 614, 917, 2183, 2593, 3783, 4002, 4520]
# Number of data points in this cluster: 8
#
# Cluster 757:
# Indices of data points: [584, 2181, 2709, 3149]
# Number of data points in this cluster: 4
#
# Cluster 686:
# Indices of data points: [585, 1307, 1755, 3464, 3843, 3847, 3892, 4374, 5128]
# Number of data points in this cluster: 9
#
# Cluster 127:
# Indices of data points: [587, 727, 734, 1325, 1880, 2178, 2408, 2657, 5040]
# Number of data points in this cluster: 9
#
# Cluster 514:
# Indices of data points: [588, 2119, 2578, 3063, 4559]
# Number of data points in this cluster: 5
#
# Cluster 492:
# Indices of data points: [592, 1163, 1718, 2794, 4270]
# Number of data points in this cluster: 5
#
# Cluster 174:
# Indices of data points: [599, 1036, 1943, 2572, 3343, 4746]
# Number of data points in this cluster: 6
#
# Cluster 439:
# Indices of data points: [600, 643, 2155, 2213, 2600]
# ...
# Number of data points in this cluster: 13
#
# Cluster 737:
# Indices of data points: [1495, 1815, 2487, 3567, 3574]
# Number of data points in this cluster: 5
#
# Cluster 325:
# Indices of data points: [1514, 1747, 1795, 1938, 3684]
# Number of data points in this cluster: 5
#
# Cluster 607:
# Indices of data points: [1520, 2437, 3689, 4535]
# Number of data points in this cluster: 4
#
# Cluster 575:
# Indices of data points: [1536, 1569, 1645, 1733, 2454, 2941, 2959, 3481]
# Number of data points in this cluster: 8
#
# Cluster 270:
# Indices of data points: [1537, 1862, 1869, 2173, 2299, 2322, 3436]
# Number of data points in this cluster: 7
#
# Cluster 668:
# Indices of data points: [1543, 2966, 4768]
# Number of data points in this cluster: 3
#
# Cluster 550:
# Indices of data points: [1544, 2080, 2112, 2752, 2758]
# Number of data points in this cluster: 5
#
# Cluster 506:
# Indices of data points: [1559, 2482, 3799, 4405, 4594]
# Number of data points in this cluster: 5
#
# Cluster 637:
# Indices of data points: [1572, 3280]
# Number of data points in this cluster: 2
#
# Cluster 621:
# Indices of data points: [1597, 2740, 4317, 4660]
# Number of data points in this cluster: 4
#
# Cluster 449:
# Indices of data points: [1598, 1932, 2192, 4574]
# Number of data points in this cluster: 4
#
# Cluster 21:
# Indices of data points: [1601, 2978, 3429, 3645]
# Number of data points in this cluster: 4
#
# Cluster 353:
# Indices of data points: [1606, 2011, 2146, 3046, 3408]
# Number of data points in this cluster: 5
#
# Cluster 627:
# Indices of data points: [1608, 1807, 1881, 2527, 3733]
# Number of data points in this cluster: 5
#
# Cluster 747:
# Indices of data points: [1616, 2483, 3155, 3225]
# Number of data points in this cluster: 4
#
# Cluster 298:
# Indices of data points: [1644, 1703, 2282, 3088, 3146, 3214, 4041]
# Number of data points in this cluster: 7
#
# Cluster 266:
# Indices of data points: [1647, 1913, 2523, 3459, 4214, 4314]
# Number of data points in this cluster: 6
#
# Cluster 497:
# Indices of data points: [1649, 2517, 4112, 4724]
# Number of data points in this cluster: 4
#
# Cluster 568:
# Indices of data points: [1656, 1734, 3706, 3789, 4116, 4603, 4737, 5127]
# Number of data points in this cluster: 8
#
# Cluster 464:
# Indices of data points: [1662, 2267, 2367, 3138]
# Number of data points in this cluster: 4
#
# Cluster 594:
# Indices of data points: [1667, 1917, 3529, 3717]
# Number of data points in this cluster: 4
#
# Cluster 252:
# Indices of data points: [1669, 2532, 2833, 4249, 5090]
# Number of data points in this cluster: 5
#
# Cluster 357:
# Indices of data points: [1681, 2749, 2970, 3073, 3300, 4430]
# Number of data points in this cluster: 6
#
# Cluster 425:
# Indices of data points: [1692, 2280, 3056, 4432]
# Number of data points in this cluster: 4
#
# Cluster 583:
# Indices of data points: [1695, 1930]
# Number of data points in this cluster: 2
#
# Cluster 44:
# Indices of data points: [1700, 1981, 3375, 3598, 3735, 4487]
# Number of data points in this cluster: 6
#
# Cluster 595:
# Indices of data points: [1702, 2418, 3014]
# Number of data points in this cluster: 3
#
# Cluster 279:
# Indices of data points: [1710, 2292, 3356, 4206, 4652]
# Number of data points in this cluster: 5
#
# Cluster 560:
# Indices of data points: [1730, 2200, 2622, 2835, 3135]
# Number of data points in this cluster: 5
#
# Cluster 740:
# Indices of data points: [1739, 1842]
# Number of data points in this cluster: 2
#
# Cluster 508:
# Indices of data points: [1750, 1793, 1922, 2438]
# Number of data points in this cluster: 4
#
# Cluster 316:
# Indices of data points: [1753, 3590, 3808]
# Number of data points in this cluster: 3
#
# Cluster 115:
# Indices of data points: [1757, 2434, 3772, 4281, 4811]
# Number of data points in this cluster: 5
#
# Cluster 561:
# Indices of data points: [1768, 2223, 3034]
# Number of data points in this cluster: 3
#
# Cluster 587:
# Indices of data points: [1769, 3678, 4077, 4578]
# Number of data points in this cluster: 4
#
# Cluster 769:
# Indices of data points: [1773, 2030, 2344, 2428]
# Number of data points in this cluster: 4
#
# Cluster 120:
# Indices of data points: [1774, 1863]
# Number of data points in this cluster: 2
#
# Cluster 240:
# Indices of data points: [1782, 3755, 4517]
# Number of data points in this cluster: 3
#
# Cluster 500:
# Indices of data points: [1783, 1857, 2721, 2942, 3305, 3458, 3910]
# Number of data points in this cluster: 7
#
# Cluster 405:
# Indices of data points: [1786, 3161, 3905, 4240]
# Number of data points in this cluster: 4
#
# Cluster 396:
# Indices of data points: [1801, 1855, 4148, 4392]
# Number of data points in this cluster: 4
#
# Cluster 278:
# Indices of data points: [1803, 2231, 2811, 4165]
# Number of data points in this cluster: 4
#
# Cluster 571:
# Indices of data points: [1806, 1887, 3511, 3832, 3891, 4029]
# Number of data points in this cluster: 6
#
# Cluster 448:
# Indices of data points: [1843, 3724, 3737]
# Number of data points in this cluster: 3
#
# Cluster 121:
# Indices of data points: [1848, 3434, 3460, 3605, 3681, 3906]
# Number of data points in this cluster: 6
#
# Cluster 576:
# Indices of data points: [1851, 2003, 4200]
# Number of data points in this cluster: 3
#
# Cluster 347:
# Indices of data points: [1852, 2038, 3648, 3767, 4042]
# Number of data points in this cluster: 5
#
# Cluster 30:
# Indices of data points: [1883, 2019, 3583, 3585, 3813, 4118, 4170, 4642]
# Number of data points in this cluster: 8
#
# Cluster 453:
# Indices of data points: [1885, 1952, 2450, 2597, 3122, 3281, 3499, 4864, 5065]
# Number of data points in this cluster: 9
#
# Cluster 253:
# Indices of data points: [1886, 3195, 3292]
# Number of data points in this cluster: 3
#
# Cluster 290:
# Indices of data points: [1892, 2468, 4751]
# Number of data points in this cluster: 3
#
# Cluster 173:
# Indices of data points: [1894, 1982, 2971, 4035, 4413]
# Number of data points in this cluster: 5
#
# Cluster 302:
# Indices of data points: [1895, 2250, 2303, 2689]
# Number of data points in this cluster: 4
#
# Cluster 567:
# Indices of data points: [1950, 2724, 3637]
# Number of data points in this cluster: 3
#
# Cluster 417:
# Indices of data points: [1975, 3331, 3817, 4483]
# Number of data points in this cluster: 4
#
# Cluster 656:
# Indices of data points: [1976, 3661, 3951, 4616]
# Number of data points in this cluster: 4
#
# Cluster 692:
# Indices of data points: [1985, 3965, 4348]
# Number of data points in this cluster: 3
#
# Cluster 555:
# Indices of data points: [1995, 3693, 3842]
# Number of data points in this cluster: 3
#
# Cluster 406:
# Indices of data points: [1999, 2759, 3639, 4052]
# Number of data points in this cluster: 4
#
# Cluster 643:
# Indices of data points: [2001, 2355, 3849, 4474]
# Number of data points in this cluster: 4
#
# Cluster 687:
# Indices of data points: [2007, 2083]
# Number of data points in this cluster: 2
#
# Cluster 585:
# Indices of data points: [2023, 3175, 3338, 4506]
# Number of data points in this cluster: 4
#
# Cluster 579:
# Indices of data points: [2027, 2944]
# Number of data points in this cluster: 2
#
# Cluster 531:
# Indices of data points: [2037, 3351, 4247]
# Number of data points in this cluster: 3
#
# Cluster 739:
# Indices of data points: [2051, 4477, 4985]
# Number of data points in this cluster: 3
#
# Cluster 193:
# Indices of data points: [2055, 2113, 2518, 3673]
# Number of data points in this cluster: 4
#
# Cluster 180:
# Indices of data points: [2090, 3145, 4421, 4465]
# Number of data points in this cluster: 4
#
# Cluster 349:
# Indices of data points: [2109, 2148, 2351, 2496, 2680, 3756, 3841, 3923, 4707]
# Number of data points in this cluster: 9
#
# Cluster 352:
# Indices of data points: [2129, 2261, 2515, 3433]
# Number of data points in this cluster: 4
#
# Cluster 222:
# Indices of data points: [2134, 3450]
# Number of data points in this cluster: 2
#
# Cluster 512:
# Indices of data points: [2172, 2583, 3626, 4171]
# Number of data points in this cluster: 4
#
# Cluster 715:
# Indices of data points: [2175, 2562, 4004, 4031]
# Number of data points in this cluster: 4
#
# Cluster 148:
# Indices of data points: [2179, 2651, 2812, 3021, 3022, 3700, 4320]
# Number of data points in this cluster: 7
#
# Cluster 138:
# Indices of data points: [2208, 4046, 4202, 4395, 4534, 4584, 4989]
# Number of data points in this cluster: 7
#
# Cluster 733:
# Indices of data points: [2228, 2738, 3653]
# Number of data points in this cluster: 3
#
# Cluster 142:
# Indices of data points: [2301, 4475, 4586, 5028]
# Number of data points in this cluster: 4
#
# Cluster 130:
# Indices of data points: [2302, 3444, 4196]
# Number of data points in this cluster: 3
#
# Cluster 338:
# Indices of data points: [2306, 4438]
# Number of data points in this cluster: 2
#
# Cluster 372:
# Indices of data points: [2309, 2569, 3723, 4324]
# Number of data points in this cluster: 4
#
# Cluster 407:
# Indices of data points: [2312, 2398, 2828, 3345, 4345]
# Number of data points in this cluster: 5
#
# Cluster 569:
# Indices of data points: [2316, 4448]
# Number of data points in this cluster: 2
#
# Cluster 636:
# Indices of data points: [2326, 3120, 3319]
# Number of data points in this cluster: 3
#
# Cluster 165:
# Indices of data points: [2330, 2640, 2817, 3364]
# Number of data points in this cluster: 4
#
# Cluster 420:
# Indices of data points: [2331, 4407]
# Number of data points in this cluster: 2
#
# Cluster 314:
# Indices of data points: [2334, 3829, 4403]
# Number of data points in this cluster: 3
#
# Cluster 419:
# Indices of data points: [2335, 2704, 4197, 4428, 4522]
# Number of data points in this cluster: 5
#
# Cluster 469:
# Indices of data points: [2350, 4468]
# Number of data points in this cluster: 2
#
# Cluster 488:
# Indices of data points: [2378, 4151]
# Number of data points in this cluster: 2
#
# Cluster 309:
# Indices of data points: [2391, 2989, 3312]
# Number of data points in this cluster: 3
#
# Cluster 655:
# Indices of data points: [2409]
# Number of data points in this cluster: 1
#
# Cluster 718:
# Indices of data points: [2416]
# Number of data points in this cluster: 1
#
# Cluster 170:
# Indices of data points: [2419, 2802, 3143, 3209, 3431, 3828]
# Number of data points in this cluster: 6
#
# Cluster 373:
# Indices of data points: [2424, 3354, 3484, 4596]
# Number of data points in this cluster: 4
#
# Cluster 249:
# Indices of data points: [2425, 2444, 2809, 2847, 4006]
# Number of data points in this cluster: 5
#
# Cluster 490:
# Indices of data points: [2431, 4071]
# Number of data points in this cluster: 2
#
# Cluster 591:
# Indices of data points: [2453, 2860]
# Number of data points in this cluster: 2
#
# Cluster 468:
# Indices of data points: [2467]
# Number of data points in this cluster: 1
#
# Cluster 544:
# Indices of data points: [2500, 3383, 4335]
# Number of data points in this cluster: 3
#
# Cluster 323:
# Indices of data points: [2502, 2514, 3253, 4284]
# Number of data points in this cluster: 4
#
# Cluster 604:
# Indices of data points: [2504, 2819, 3006, 3101]
# Number of data points in this cluster: 4
#
# Cluster 723:
# Indices of data points: [2509, 3508]
# Number of data points in this cluster: 2
#
# Cluster 496:
# Indices of data points: [2524, 4015, 4079]
# Number of data points in this cluster: 3
#
# Cluster 536:
# Indices of data points: [2529]
# Number of data points in this cluster: 1
#
# Cluster 649:
# Indices of data points: [2530]
# Number of data points in this cluster: 1
#
# Cluster 450:
# Indices of data points: [2541, 4119, 4369]
# Number of data points in this cluster: 3
#
# Cluster 535:
# Indices of data points: [2555, 2986, 3330, 3625, 3627]
# Number of data points in this cluster: 5
#
# Cluster 695:
# Indices of data points: [2558]
# Number of data points in this cluster: 1
#
# Cluster 387:
# Indices of data points: [2585, 4130, 4916]
# Number of data points in this cluster: 3
#
# Cluster 151:
# Indices of data points: [2594, 4024, 5052]
# Number of data points in this cluster: 3
#
# Cluster 171:
# Indices of data points: [2601, 2641, 2741, 3019, 3158, 3231, 3990, 4362]
# Number of data points in this cluster: 8
#
# Cluster 485:
# Indices of data points: [2602, 3252, 3365, 4386, 4437]
# Number of data points in this cluster: 5
#
# Cluster 76:
# Indices of data points: [2604, 2797, 3040, 3257, 4381, 4518, 4888]
# Number of data points in this cluster: 7
#
# Cluster 511:
# Indices of data points: [2611, 3962, 4379]
# Number of data points in this cluster: 3
#
# Cluster 312:
# Indices of data points: [2627, 3570]
# Number of data points in this cluster: 2
#
# Cluster 331:
# Indices of data points: [2633, 3129, 3547]
# Number of data points in this cluster: 3
#
# Cluster 494:
# Indices of data points: [2700, 2725, 2750, 4456, 4457]
# Number of data points in this cluster: 5
#
# Cluster 526:
# Indices of data points: [2737, 3880]
# Number of data points in this cluster: 2
#
# Cluster 440:
# Indices of data points: [2770, 2851, 3391, 4460, 4776]
# Number of data points in this cluster: 5
#
# Cluster 672:
# Indices of data points: [2773, 3182, 3185]
# Number of data points in this cluster: 3
#
# Cluster 716:
# Indices of data points: [2795, 3045, 3650, 3806, 4336]
# Number of data points in this cluster: 5
#
# Cluster 77:
# Indices of data points: [2832, 3244, 3317, 4250, 4844]
# Number of data points in this cluster: 5
#
# Cluster 321:
# Indices of data points: [2842, 3125]
# Number of data points in this cluster: 2
#
# Cluster 712:
# Indices of data points: [2853, 2898, 4383]
# Number of data points in this cluster: 3
#
# Cluster 766:
# Indices of data points: [2874, 3058, 3379, 4135, 4246]
# Number of data points in this cluster: 5
#
# Cluster 509:
# Indices of data points: [2882, 4204]
# Number of data points in this cluster: 2
#
# Cluster 297:
# Indices of data points: [2895, 2977, 4536]
# Number of data points in this cluster: 3
#
# Cluster 744:
# Indices of data points: [3047]
# Number of data points in this cluster: 1
#
# Cluster 366:
# Indices of data points: [3065, 3486, 4306]
# Number of data points in this cluster: 3
#
# Cluster 521:
# Indices of data points: [3078, 3219, 4227]
# Number of data points in this cluster: 3
#
# Cluster 581:
# Indices of data points: [3142, 3264]
# Number of data points in this cluster: 2
#
# Cluster 145:
# Indices of data points: [3203, 3804]
# Number of data points in this cluster: 2
#
# Cluster 156:
# Indices of data points: [3212, 3542, 3589, 3606, 4638, 4708]
# Number of data points in this cluster: 6
#
# Cluster 671:
# Indices of data points: [3226]
# Number of data points in this cluster: 1
#
# Cluster 389:
# Indices of data points: [3230]
# Number of data points in this cluster: 1
#
# Cluster 296:
# Indices of data points: [3290, 3446, 3502, 3823, 3980]
# Number of data points in this cluster: 5
#
# Cluster 767:
# Indices of data points: [3316]
# Number of data points in this cluster: 1
#
# Cluster 462:
# Indices of data points: [3325, 3410]
# Number of data points in this cluster: 2
#
# Cluster 663:
# Indices of data points: [3350]
# Number of data points in this cluster: 1
#
# Cluster 725:
# Indices of data points: [3390, 5125]
# Number of data points in this cluster: 2
#
# Cluster 207:
# Indices of data points: [3392, 4551, 5105]
# Number of data points in this cluster: 3
#
# Cluster 669:
# Indices of data points: [3405]
# Number of data points in this cluster: 1
#
# Cluster 262:
# Indices of data points: [3440, 5035]
# Number of data points in this cluster: 2
#
# Cluster 294:
# Indices of data points: [3462, 3657, 4188]
# Number of data points in this cluster: 3
#
# Cluster 619:
# Indices of data points: [3584, 3597]
# Number of data points in this cluster: 2
#
# Cluster 303:
# Indices of data points: [3607, 3738, 4086]
# Number of data points in this cluster: 3
#
# Cluster 428:
# Indices of data points: [3646]
# Number of data points in this cluster: 1
#
# Cluster 628:
# Indices of data points: [3647, 3716, 4399]
# Number of data points in this cluster: 3
#
# Cluster 717:
# Indices of data points: [3663, 4082]
# Number of data points in this cluster: 2
#
# Cluster 602:
# Indices of data points: [3770, 3862, 4209, 4931]
# Number of data points in this cluster: 4
#
# Cluster 538:
# Indices of data points: [3926, 4375, 4510, 4631, 4661]
# Number of data points in this cluster: 5
#
# Cluster 667:
# Indices of data points: [4146, 4373, 4614, 4787]
# Number of data points in this cluster: 4
#
# Cluster 418:
# Indices of data points: [4282, 4896]
# Number of data points in this cluster: 2
#
# Cluster 726:
# Indices of data points: [4295, 4556]
# Number of data points in this cluster: 2
#
# Cluster 596:
# Indices of data points: [4349, 4434]
# Number of data points in this cluster: 2
#
# Cluster 698:
# Indices of data points: [4400]
# Number of data points in this cluster: 1
#
# Cluster 333:
# Indices of data points: [4425, 4486]
# Number of data points in this cluster: 2

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Step 1: Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBus\features_last_lstm.npy")

# Step 2: (Optional) Preprocess the data if needed
# For example, you might want to scale the features to ensure the clustering works well
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 3: Perform Agglomerative Clustering
# You can specify the number of clusters or other hyperparameters here
n_clusters = 770  # Example, set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model to the feature matrix
clustering_labels = clustering.fit_predict(features_scaled)

# Step 4: (Optional) Visualize the results if the features are 2D (or use dimensionality reduction)
if features_scaled.shape[1] == 2:  # If your features are 2D, you can visualize them
    plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=clustering_labels, cmap='viridis')
    plt.title("Agglomerative Clustering Results")
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# If you have higher-dimensional features, consider using PCA to reduce to 2D for visualization
# For example:
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# features_2d = pca.fit_transform(features_scaled)
# plt.scatter(features_2d[:, 0], features_2d[:, 1], c=clustering_labels, cmap='viridis')
# plt.show()

# Step 5: View the labels assigned to each data point
print("Cluster Labels:", clustering_labels)
# Out:
# Cluster Labels: [ 11 227 299 ... 686 332  40]

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBus\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters =770  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Display the clusters in the desired format
for cluster_label, indices in cluster_dict.items():
    print(f"Cluster {cluster_label}:")
    print(f"Indices of data points: {indices}")
    print(f"Number of data points in this cluster: {len(indices)}\n")
# Out:
# Cluster 11:
# Indices of data points: [0, 137, 1191, 1221, 1560, 1629, 2191, 2386, 3083, 3180, 3353, 3359, 3478, 3592, 4849, 4904]
# Number of data points in this cluster: 16
#
# Cluster 227:
# Indices of data points: [1, 246, 409, 1118, 2668, 3010, 3092, 3166, 3491, 3793, 3979, 4121, 4533, 5011, 5109]
# Number of data points in this cluster: 15
#
# Cluster 299:
# Indices of data points: [2, 49, 134, 240, 759, 1155, 1487, 1621, 1632, 2002, 3027, 3367, 3519, 4010, 4050, 4094, 4900]
# Number of data points in this cluster: 17
#
# Cluster 650:
# Indices of data points: [3, 487, 803, 935, 1426, 1435, 1586, 1988, 3432, 3750, 4287, 4718, 5079, 5122]
# Number of data points in this cluster: 14
#
# Cluster 226:
# Indices of data points: [4, 1074, 1228, 1380, 1890, 2103, 2972, 3254, 4000, 4224, 5068]
# Number of data points in this cluster: 11
#
# Cluster 479:
# Indices of data points: [5, 358, 1410, 1475, 2115, 2731, 3961, 4745, 4923]
# Number of data points in this cluster: 9
#
# Cluster 466:
# Indices of data points: [6, 1521, 2492, 2768, 4943]
# Number of data points in this cluster: 5
#
# Cluster 24:
# Indices of data points: [7, 55, 811, 822, 1665, 3085, 3360, 3531, 3821, 4019, 4612, 4736]
# Number of data points in this cluster: 12
#
# Cluster 635:
# Indices of data points: [8, 1189, 3480, 3944, 4242, 4814, 4905]
# Number of data points in this cluster: 7
#
# Cluster 753:
# Indices of data points: [9, 1474, 1564, 1772, 2058]
# Number of data points in this cluster: 5
#
# Cluster 534:
# Indices of data points: [10, 1100, 1266, 1345, 3690]
# Number of data points in this cluster: 5
#
# Cluster 404:
# Indices of data points: [11, 313, 764, 1227, 1504, 2780, 4158]
# Number of data points in this cluster: 7
#
# Cluster 651:
# Indices of data points: [12, 649, 1737, 3357, 3426, 3548, 3916, 4367, 4728, 4765]
# Number of data points in this cluster: 10
#
# Cluster 32:
# Indices of data points: [13, 1133, 1210, 1561, 1998, 2545, 2547, 2702, 3031, 3054, 3541, 3786, 4097, 4144, 4174]
# Number of data points in this cluster: 15
#
# Cluster 87:
# Indices of data points: [14, 102, 189, 639, 2218, 2455, 2843, 2868, 3366, 4267, 4695, 4882, 4891]
# Number of data points in this cluster: 13
#
# Cluster 572:
# Indices of data points: [15, 1138, 2443, 2475, 2519, 3509, 3631]
# Number of data points in this cluster: 7
#
# Cluster 752:
# Indices of data points: [16]
# Number of data points in this cluster: 1
#
# Cluster 614:
# Indices of data points: [17, 486, 1563, 2185, 4703, 4769, 4980]
# Number of data points in this cluster: 7
#
# Cluster 14:
# Indices of data points: [18, 83, 740, 1001, 1388, 2053, 2915, 3694, 3871, 4243, 4562, 4731, 4767]
# Number of data points in this cluster: 13
#
# Cluster 80:
# Indices of data points: [19, 723, 742, 1664, 3667, 3670, 4231, 4505]
# Number of data points in this cluster: 8
#
# Cluster 190:
# Indices of data points: [20, 3237, 3255, 3348, 4257, 4363]
# Number of data points in this cluster: 6
#
# Cluster 128:
# Indices of data points: [21, 106, 806, 1225, 1269, 1429, 1825, 2844, 2936, 3062, 4347, 4895]
# Number of data points in this cluster: 12
#
# Cluster 369:
# Indices of data points: [22, 1500, 1553, 1674, 3248, 3558, 4651, 4908]
# Number of data points in this cluster: 8
#
# Cluster 673:
# Indices of data points: [23, 309, 2407, 4330]
# Number of data points in this cluster: 4
#
# Cluster 679:
# Indices of data points: [24, 253, 448, 683, 924, 1011, 1989, 2068, 2521, 4290, 4727]
# Number of data points in this cluster: 11
#
# Cluster 304:
# Indices of data points: [25, 354, 611, 693, 905, 919, 1377, 1577, 1928, 2368, 3172, 4331, 5110, 5114]
# Number of data points in this cluster: 14
#
# Cluster 57:
# Indices of data points: [26, 350, 514, 627, 812, 1897, 1987, 2673, 2976, 3033, 3043, 4095, 4419, 4988]
# Number of data points in this cluster: 14
#
# Cluster 758:
# Indices of data points: [27, 131, 800, 1507, 1590, 2288, 2808, 2831, 3543, 4682, 4936]
# Number of data points in this cluster: 11
#
# Cluster 662:
# Indices of data points: [28, 372, 418, 1575, 1874, 1957, 3013, 4894, 4977]
# Number of data points in this cluster: 9
#
# Cluster 750:
# Indices of data points: [29, 837, 2634, 3234, 4800]
# Number of data points in this cluster: 5
#
# Cluster 33:
# Indices of data points: [30, 233, 239, 362, 866, 1789, 1879, 1896, 2039, 2501, 3485, 4137, 4806, 4911]
# Number of data points in this cluster: 14
#
# Cluster 459:
# Indices of data points: [31, 1308, 2469]
# Number of data points in this cluster: 3
#
# Cluster 493:
# Indices of data points: [32, 907, 2513, 2739, 2918]
# Number of data points in this cluster: 5
#
# Cluster 89:
# Indices of data points: [33, 987, 1961, 2149, 3538]
# Number of data points in this cluster: 5
#
# Cluster 457:
# Indices of data points: [34, 288, 1235, 2226]
# Number of data points in this cluster: 4
#
# Cluster 53:
# Indices of data points: [35, 1391, 1483, 2691, 3057, 4056]
# Number of data points in this cluster: 6
#
# Cluster 529:
# Indices of data points: [36, 1534, 2877, 3266, 3797]
# Number of data points in this cluster: 5
#
# Cluster 0:
# Indices of data points: [37, 167, 184, 405, 997, 1022, 1175, 1214, 1441, 1477, 2060, 2646, 2846, 2953, 3930, 4271, 4332, 4910]
# Number of data points in this cluster: 18
#
# Cluster 62:
# Indices of data points: [38, 1713, 2362, 2962, 3111, 3452]
# Number of data points in this cluster: 6
#
# Cluster 525:
# Indices of data points: [39, 700, 839, 2328, 2985, 3318, 4749, 4968]
# Number of data points in this cluster: 8
#
# Cluster 397:
# Indices of data points: [40, 307, 798, 950, 2128, 2584, 3194, 5026, 5045, 5060]
# Number of data points in this cluster: 10
#
# Cluster 250:
# Indices of data points: [41, 2400, 2839, 3623, 4167, 4215, 4280, 4715, 4789, 4865, 5063]
# Number of data points in this cluster: 11
#
# Cluster 658:
# Indices of data points: [42, 1148, 1196, 2137, 2361, 2857, 3628, 3692, 4670, 5017]
# Number of data points in this cluster: 10
#
# Cluster 487:
# Indices of data points: [43, 334, 357, 402, 894, 1974, 2073, 2237, 2664, 3386, 3790, 3825, 3957, 4376]
# Number of data points in this cluster: 14
#
# Cluster 177:
# Indices of data points: [44, 100, 112, 412, 429, 1707, 2094, 2675, 2864, 3262, 4469, 4629, 5023]
# Number of data points in this cluster: 13
#
# Cluster 532:
# Indices of data points: [45, 2422, 2779, 3050, 3712, 3794]
# Number of data points in this cluster: 6
#
# Cluster 337:
# Indices of data points: [46, 378, 1965, 2372, 2567, 3329, 4326]
# Number of data points in this cluster: 7
#
# Cluster 355:
# Indices of data points: [47, 624, 669, 704, 1053, 1488, 2347, 2606, 2913, 2939, 3076, 3207, 3381, 4543, 4940]
# Number of data points in this cluster: 15
#
# Cluster 74:
# Indices of data points: [48, 96, 408, 503, 795, 1828, 1864, 1904, 2441, 3764, 4565, 4643]
# Number of data points in this cluster: 12
#
# Cluster 523:
# Indices of data points: [50, 665, 695, 1083, 1968, 2294, 2607, 4627, 4838, 4976, 5099, 5106]
# Number of data points in this cluster: 12
#
# Cluster 562:
# Indices of data points: [51, 73, 2370, 4644]
# Number of data points in this cluster: 4
#
# Cluster 68:
# Indices of data points: [52, 75, 258, 590, 1351, 1525, 1745, 2076, 4192, 4219, 4472, 4937]
# Number of data points in this cluster: 12
#
# Cluster 48:
# Indices of data points: [53, 1078, 1915, 2265, 2463, 3099, 3617, 4078, 4283]
# Number of data points in this cluster: 9
#
# Cluster 291:
# Indices of data points: [54, 672, 966, 2121, 3514, 3768, 4313, 4607, 4848]
# Number of data points in this cluster: 9
#
# Cluster 654:
# Indices of data points: [56, 1239, 2064, 2281, 3288, 4624]
# Number of data points in this cluster: 6
#
# Cluster 285:
# Indices of data points: [57, 1599, 1859, 2159, 3123, 3782, 3803, 4003, 5009]
# Number of data points in this cluster: 9
#
# Cluster 85:
# Indices of data points: [58, 1335, 2239, 3272, 3516, 4389, 4441]
# Number of data points in this cluster: 7
#
# Cluster 160:
# Indices of data points: [59, 1900, 2091, 2448, 3569, 3854, 4364, 4637, 4698, 4709, 4933, 4949]
# Number of data points in this cluster: 12
#
# Cluster 2:
# Indices of data points: [60, 256, 361, 543, 675, 1593, 1696, 2162, 2429, 2884, 2897, 3438, 3741, 4657, 4927, 5061]
# Number of data points in this cluster: 16
#
# Cluster 721:
# Indices of data points: [61, 135, 1548, 1812, 2929, 3208, 4516, 4859, 5095]
# Number of data points in this cluster: 9
#
# Cluster 400:
# Indices of data points: [62, 119, 922, 1167, 1288, 1946, 2635, 3064, 3594, 4557, 4610]
# Number of data points in this cluster: 11
#
# Cluster 98:
# Indices of data points: [63, 507, 1921, 2476, 3059, 4169, 4541]
# Number of data points in this cluster: 7
#
# Cluster 140:
# Indices of data points: [64, 234, 1476, 1838, 1877, 1926, 2551, 2778, 2815, 3055, 3395, 3818, 4026, 4521]
# Number of data points in this cluster: 14
#
# Cluster 37:
# Indices of data points: [65, 1467, 1506, 1636, 1766, 2167, 2655, 2907]
# Number of data points in this cluster: 8
#
# Cluster 410:
# Indices of data points: [66, 190, 299, 1150, 1469, 1596, 1865, 2009, 2040, 3490, 3563, 3565, 3876]
# Number of data points in this cluster: 13
#
# Cluster 103:
# Indices of data points: [67, 87, 236, 676, 1654, 1837, 1858, 2176, 3953, 4201, 4529, 4816, 4946, 4948]
# Number of data points in this cluster: 14
#
# Cluster 284:
# Indices of data points: [68, 1048, 2062, 2127, 3595, 4213, 4251, 5075]
# Number of data points in this cluster: 8
#
# Cluster 681:
# Indices of data points: [69, 1337, 1727, 2041, 2300, 2670, 4872]
# Number of data points in this cluster: 7
#
# Cluster 6:
# Indices of data points: [70, 91, 168, 327, 1258, 2014, 2169, 2193, 3167, 3709, 3788, 3981, 4191, 4604]
# Number of data points in this cluster: 14
#
# Cluster 99:
# Indices of data points: [71, 158, 422, 823, 1567, 1682, 2485, 3029, 3184, 3515, 5077]
# Number of data points in this cluster: 11
#
# Cluster 630:
# Indices of data points: [72, 705, 4126]
# Number of data points in this cluster: 3
#
# Cluster 743:
# Indices of data points: [74, 1716, 1935, 2189, 4947]
# Number of data points in this cluster: 5
#
# Cluster 114:
# Indices of data points: [76, 269, 596, 1110, 1455, 1752, 2390, 2494, 2575, 2732, 3430, 3442, 3461, 3927, 3987, 4590, 4794, 4922, 5094]
# Number of data points in this cluster: 19
#
# Cluster 709:
# Indices of data points: [77, 473, 4394]
# Number of data points in this cluster: 3
#
# Cluster 547:
# Indices of data points: [78, 81, 138, 875, 925, 1208, 1309, 1400, 2943, 3396, 3533]
# Number of data points in this cluster: 11
#
# Cluster 403:
# Indices of data points: [79, 403, 1771, 2048, 2410, 3844, 3989, 4185, 4426, 4591, 4929]
# Number of data points in this cluster: 11
#
# Cluster 205:
# Indices of data points: [80, 2063, 2414, 2875, 3674]
# Number of data points in this cluster: 5
#
# Cluster 283:
# Indices of data points: [82, 238, 1443, 2577, 4014, 4665, 4939, 5034]
# Number of data points in this cluster: 8
#
# Cluster 593:
# Indices of data points: [84, 452, 1099, 2194, 2210, 4060, 4163]
# Number of data points in this cluster: 7
#
# Cluster 189:
# Indices of data points: [85, 330, 400, 882, 1449, 1582, 1872, 3753, 3827]
# Number of data points in this cluster: 9
#
# Cluster 431:
# Indices of data points: [86, 888, 2827, 2837, 3899, 4199, 4826]
# Number of data points in this cluster: 7
#
# Cluster 476:
# Indices of data points: [88, 532, 2145, 2543, 3488, 3762, 4147]
# Number of data points in this cluster: 7
#
# Cluster 401:
# Indices of data points: [89, 129, 2110, 2256, 3192, 3468, 4085, 4159, 4593, 4669]
# Number of data points in this cluster: 10
#
# Cluster 175:
# Indices of data points: [90, 368, 489, 1780, 3726, 3995, 4054]
# Number of data points in this cluster: 7
#
# Cluster 622:
# Indices of data points: [92, 778, 886, 2358]
# Number of data points in this cluster: 4
#
# Cluster 574:
# Indices of data points: [93, 410, 505, 698, 1361, 1754, 2004, 2679, 3469, 3947, 4266, 4523, 4784, 4991]
# Number of data points in this cluster: 14
#
# Cluster 113:
# Indices of data points: [94, 124, 502, 1024, 1920, 2993, 3417, 3784, 4839, 5015]
# Number of data points in this cluster: 10
#
# Cluster 157:
# Indices of data points: [95, 480, 1007, 1383, 1409, 1458, 2049, 2071, 3000, 3557, 3958]
# Number of data points in this cluster: 11
#
# Cluster 422:
# Indices of data points: [97, 286, 325, 648, 677, 861, 1043, 1152, 1385, 1523, 1641, 1796, 2158, 2510, 2701, 3074, 3915, 4110, 4699, 4971]
# Number of data points in this cluster: 20
#
# Cluster 288:
# Indices of data points: [98, 602, 967]
# Number of data points in this cluster: 3
#
# Cluster 600:
# Indices of data points: [99, 1518, 1741, 2587, 2785, 2796, 4843, 5089]
# Number of data points in this cluster: 8
#
# Cluster 271:
# Indices of data points: [101, 1711, 1817, 1868, 2954, 3566, 3882, 3903, 3964, 4503, 4975, 5097]
# Number of data points in this cluster: 12
#
# Cluster 228:
# Indices of data points: [103, 428, 516, 1206, 1268, 1371, 1566, 2373, 3537, 3838, 4256, 4309, 4633, 4958]
# Number of data points in this cluster: 14
#
# Cluster 83:
# Indices of data points: [104, 319, 832, 841, 1122, 1403, 2010, 2296, 2726, 2904, 3117, 3489, 3774, 4809, 4987, 5100]
# Number of data points in this cluster: 16
#
# Cluster 648:
# Indices of data points: [105, 720, 1168, 1491, 1688, 3398, 3439, 3615, 3801]
# Number of data points in this cluster: 9
#
# Cluster 341:
# Indices of data points: [107, 276, 929, 1298, 1831, 2810, 3412]
# Number of data points in this cluster: 7
#
# Cluster 71:
# Indices of data points: [108, 209, 289, 382, 419, 815, 852, 941, 1591, 1808, 2160, 2478, 2520, 2829, 3084, 4913, 5042]
# Number of data points in this cluster: 17
#
# Cluster 81:
# Indices of data points: [109, 164, 406, 501, 550, 1040, 2247, 3920, 4125]
# Number of data points in this cluster: 9
#
# Cluster 693:
# Indices of data points: [110, 2612, 3409, 3730, 3994]
# Number of data points in this cluster: 5
#
# Cluster 670:
# Indices of data points: [111, 320, 2395, 4443]
# Number of data points in this cluster: 4
#
# Cluster 554:
# Indices of data points: [113, 2106, 2170, 3118, 3691, 4272]
# Number of data points in this cluster: 6
#
# Cluster 452:
# Indices of data points: [114, 141, 4128]
# Number of data points in this cluster: 3
#
# Cluster 26:
# Indices of data points: [115, 290, 960, 2099, 2122, 2859, 3662, 3991, 4182]
# Number of data points in this cluster: 9
#
# Cluster 51:
# Indices of data points: [116, 347, 392, 536, 817, 903, 3901, 4012, 4292, 4494, 5117]
# Number of data points in this cluster: 11
#
# Cluster 584:
# Indices of data points: [117, 395, 871, 872, 1522, 2818, 3069, 3324, 3950, 4218]
# Number of data points in this cluster: 10
#
# Cluster 324:
# Indices of data points: [118, 1517, 3725, 4553]
# Number of data points in this cluster: 4
#
# Cluster 194:
# Indices of data points: [120, 499, 2682, 4301, 4458, 4959]
# Number of data points in this cluster: 6
#
# Cluster 334:
# Indices of data points: [121, 369, 1583, 2479, 2694, 2952, 4005, 4877, 5020]
# Number of data points in this cluster: 9
#
# Cluster 515:
# Indices of data points: [122, 593, 936, 1287, 1291, 1562, 4756, 4791, 4879]
# Number of data points in this cluster: 9
#
# Cluster 588:
# Indices of data points: [123, 1787, 2464, 3918]
# Number of data points in this cluster: 4
#
# Cluster 430:
# Indices of data points: [125, 562, 783, 3009, 3287, 4296, 4329, 4532, 4739, 4986]
# Number of data points in this cluster: 10
#
# Cluster 527:
# Indices of data points: [126, 143, 667, 1776, 2401, 2495, 2605, 2931, 4966, 5067]
# Number of data points in this cluster: 10
#
# Cluster 162:
# Indices of data points: [127, 181, 208, 348, 863, 887, 1919, 2047, 2311, 2706, 2980, 2987, 3187, 3800, 3925, 4098, 4833, 4853, 4856]
# Number of data points in this cluster: 19
#
# Cluster 472:
# Indices of data points: [128, 2216, 2991, 3955]
# Number of data points in this cluster: 4
#
# Cluster 256:
# Indices of data points: [130, 163, 169, 819, 2625, 2888, 3037, 4712, 4840, 5078, 5087, 5123]
# Number of data points in this cluster: 12
#
# Cluster 137:
# Indices of data points: [132, 1912, 2045, 2107, 2166, 3539, 3865, 4497, 4901]
# Number of data points in this cluster: 9
#
# Cluster 172:
# Indices of data points: [133, 310, 926, 1038, 1423, 3787, 3896, 4018, 4655, 4711, 4716]
# Number of data points in this cluster: 11
#
# Cluster 209:
# Indices of data points: [136, 188, 893, 1951, 2056, 2923, 3295, 3703, 3848, 4760, 4778, 4818, 4825, 5112]
# Number of data points in this cluster: 14
#
# Cluster 435:
# Indices of data points: [139, 1498, 1550, 2413, 2909]
# Number of data points in this cluster: 5
#
# Cluster 710:
# Indices of data points: [140, 154, 477, 563, 1319, 1628, 1811, 1958]
# Number of data points in this cluster: 8
#
# Cluster 125:
# Indices of data points: [142, 182, 853, 889, 1390, 2120, 2314, 3522, 3603, 3998, 4033, 4924]
# Number of data points in this cluster: 12
#
# Cluster 29:
# Indices of data points: [144, 688, 2317, 2338, 2512, 2616, 3139]
# Number of data points in this cluster: 7
#
# Cluster 480:
# Indices of data points: [145, 557, 774, 1311, 1876, 3912]
# Number of data points in this cluster: 6
#
# Cluster 107:
# Indices of data points: [146, 580, 694, 844, 927, 1331, 1933, 2588, 2644, 2662, 2887, 4365, 4717, 4735, 4858, 4997]
# Number of data points in this cluster: 16
#
# Cluster 499:
# Indices of data points: [147, 324, 2135, 2474, 3534, 4143, 4153]
# Number of data points in this cluster: 7
#
# Cluster 282:
# Indices of data points: [148, 769, 851, 2032, 2271, 3004, 3153, 3493, 4187, 4433]
# Number of data points in this cluster: 10
#
# Cluster 470:
# Indices of data points: [149, 2105, 2975, 3868, 3969, 4179, 4255]
# Number of data points in this cluster: 7
#
# Cluster 1:
# Indices of data points: [150, 1067, 1357, 2967, 4291, 4659, 4876]
# Number of data points in this cluster: 7
#
# Cluster 546:
# Indices of data points: [151, 344, 453, 1190, 2359, 3428, 4377, 4754, 4886]
# Number of data points in this cluster: 9
#
# Cluster 199:
# Indices of data points: [152, 548, 1584, 2695, 3812, 4236, 4605, 4662, 4663, 4681, 4827, 4961, 5076, 5113]
# Number of data points in this cluster: 14
#
# Cluster 694:
# Indices of data points: [153, 2117, 2767, 3728, 3837, 4792, 4938, 5056]
# Number of data points in this cluster: 8
#
# Cluster 754:
# Indices of data points: [155, 983, 1980, 2082]
# Number of data points in this cluster: 4
#
# Cluster 191:
# Indices of data points: [156, 200, 337, 559, 804, 1255, 2364, 2614, 2950, 3012, 3437]
# Number of data points in this cluster: 11
#
# Cluster 661:
# Indices of data points: [157, 176, 1098, 1515, 2165, 2934]
# Number of data points in this cluster: 6
#
# Cluster 691:
# Indices of data points: [159, 1639, 1735, 3505, 4286]
# Number of data points in this cluster: 5
#
# Cluster 153:
# Indices of data points: [160, 1264, 1396, 1462, 1622, 2054, 3265, 3500, 3771, 3993, 4087, 4819, 4836, 4889]
# Number of data points in this cluster: 14
#
# Cluster 56:
# Indices of data points: [161, 218, 775, 830, 1025, 1339, 1959, 2204, 2533, 2630, 3400, 3611, 3739, 3881, 3933, 4183]
# Number of data points in this cluster: 16
#
# Cluster 79:
# Indices of data points: [162, 232, 271, 434, 668, 1359, 1738, 2075, 2297, 2791, 2969, 3079, 3147, 3275, 3455, 3699, 3758, 4359, 4558]
# Number of data points in this cluster: 19
#
# Cluster 95:
# Indices of data points: [165, 1035, 1595, 1942, 3042, 4189, 4621, 4685, 4831]
# Number of data points in this cluster: 9
#
# Cluster 136:
# Indices of data points: [166, 1180, 1439, 2013, 2043, 2665, 2681, 2968, 4528, 5038]
# Number of data points in this cluster: 10
#
# Cluster 413:
# Indices of data points: [170, 1516, 1565, 2377, 2406, 2503, 4967, 5070, 5119]
# Number of data points in this cluster: 9
#
# Cluster 677:
# Indices of data points: [171, 384, 1453, 1827, 2111, 4641]
# Number of data points in this cluster: 6
#
# Cluster 241:
# Indices of data points: [172, 939, 1045, 1482, 2180, 3474, 3763, 3805, 4442]
# Number of data points in this cluster: 9
#
# Cluster 605:
# Indices of data points: [173, 834, 4863]
# Number of data points in this cluster: 3
#
# Cluster 274:
# Indices of data points: [174, 1160, 3293, 3640, 4237]
# Number of data points in this cluster: 5
#
# Cluster 539:
# Indices of data points: [175, 1087, 1607, 2327, 2516, 3559, 3698, 3888, 4141, 4298, 4852, 5082]
# Number of data points in this cluster: 12
#
# Cluster 640:
# Indices of data points: [177, 231, 743, 1089, 1637, 2854, 2965, 5024]
# Number of data points in this cluster: 8
#
# Cluster 559:
# Indices of data points: [178, 527, 2022, 3190, 3551]
# Number of data points in this cluster: 5
#
# Cluster 122:
# Indices of data points: [179, 187, 425, 586, 953, 1114, 1347, 1432, 1532, 3441]
# Number of data points in this cluster: 10
#
# Cluster 202:
# Indices of data points: [180, 686, 2707, 3216, 3249, 3276, 4211, 4372, 5037]
# Number of data points in this cluster: 9
#
# Cluster 105:
# Indices of data points: [183, 443, 510, 625, 2225, 2621, 3028, 3322, 3472, 4278, 4572]
# Number of data points in this cluster: 11
#
# Cluster 751:
# Indices of data points: [185, 318, 504, 1447, 2243, 2374, 3026, 3221, 3278, 4034, 5044]
# Number of data points in this cluster: 11
#
# Cluster 660:
# Indices of data points: [186, 485, 518, 603, 3299, 3575, 4361]
# Number of data points in this cluster: 7
#
# Cluster 533:
# Indices of data points: [191, 241, 387, 1246, 2304, 3931, 4496, 4606, 4645]
# Number of data points in this cluster: 9
#
# Cluster 566:
# Indices of data points: [192, 544, 932, 1059, 2034, 2234, 3729]
# Number of data points in this cluster: 7
#
# Cluster 598:
# Indices of data points: [193, 591, 2801, 3091, 3134]
# Number of data points in this cluster: 5
#
# Cluster 592:
# Indices of data points: [194, 2035]
# Number of data points in this cluster: 2
#
# Cluster 300:
# Indices of data points: [195, 728, 2493, 2556, 3024, 3860]
# Number of data points in this cluster: 6
#
# Cluster 49:
# Indices of data points: [196, 224, 2042, 2352, 2631, 2901, 3494, 3893, 4039, 4597, 4726, 4994, 5053]
# Number of data points in this cluster: 13
#
# Cluster 273:
# Indices of data points: [197, 446, 579, 1342, 1434, 1802, 3196, 3867, 4677, 4956, 5091]
# Number of data points in this cluster: 11
#
# Cluster 72:
# Indices of data points: [198, 1066, 1202, 1655, 2650, 2894, 4575]
# Number of data points in this cluster: 7
#
# Cluster 289:
# Indices of data points: [199, 1944, 1996, 3457, 3600, 4172, 4957]
# Number of data points in this cluster: 7
#
# Cluster 504:
# Indices of data points: [201, 280, 1334, 2065, 3003, 4527, 4830, 4869]
# Number of data points in this cluster: 8
#
# Cluster 134:
# Indices of data points: [202, 617, 808, 913, 1438, 2747, 3427, 3622, 4013, 4084, 4887]
# Number of data points in this cluster: 11
#
# Cluster 609:
# Indices of data points: [203, 1489, 1574, 2133, 3051, 3582, 4048]
# Number of data points in this cluster: 7
#
# Cluster 380:
# Indices of data points: [204, 855, 1270, 1814, 2219, 2803, 3206, 3218, 3270, 3415]
# Number of data points in this cluster: 10
#
# Cluster 185:
# Indices of data points: [205, 214, 449, 2005, 3608, 4388, 4934]
# Number of data points in this cluster: 7
#
# Cluster 363:
# Indices of data points: [206, 681, 2771, 3975, 4238]
# Number of data points in this cluster: 5
#
# Cluster 699:
# Indices of data points: [207, 2903, 3654, 4490]
# Number of data points in this cluster: 4
#
# Cluster 90:
# Indices of data points: [210, 1050, 2114, 2781, 4264, 4422, 5008]
# Number of data points in this cluster: 7
#
# Cluster 317:
# Indices of data points: [211, 390, 1041, 1708, 4679, 4790, 4970]
# Number of data points in this cluster: 7
#
# Cluster 586:
# Indices of data points: [212, 1154, 1405, 4090, 4700, 4866]
# Number of data points in this cluster: 6
#
# Cluster 281:
# Indices of data points: [213, 312, 396, 612, 796, 1173, 1541, 2108, 2710, 2765, 4068, 4803]
# Number of data points in this cluster: 12
#
# Cluster 150:
# Indices of data points: [215, 228, 315, 1354, 1914, 1986, 2333, 2576, 2838, 3487, 4733, 4771, 4808, 4906]
# Number of data points in this cluster: 14
#
# Cluster 313:
# Indices of data points: [216, 431, 1093, 1329, 1994, 3228, 3454, 4061, 4109]
# Number of data points in this cluster: 9
#
# Cluster 399:
# Indices of data points: [217, 1016, 1253, 1370, 1373, 1725, 2436, 3596, 3609, 4409]
# Number of data points in this cluster: 10
#
# Cluster 601:
# Indices of data points: [219, 465, 2206, 4107]
# Number of data points in this cluster: 4
#
# Cluster 545:
# Indices of data points: [220, 1382, 1683, 1970, 3447, 3748, 4253, 4890]
# Number of data points in this cluster: 8
#
# Cluster 144:
# Indices of data points: [221, 417, 642, 1387, 1452, 1610, 2692, 2744, 2852, 2958, 4424]
# Number of data points in this cluster: 11
#
# Cluster 414:
# Indices of data points: [222, 656, 1350, 1461, 1945, 2323, 3173, 4706, 4730]
# Number of data points in this cluster: 9
#
# Cluster 167:
# Indices of data points: [223, 416, 582, 788, 2079, 2508, 4030, 4495, 4867]
# Number of data points in this cluster: 9
#
# Cluster 117:
# Indices of data points: [225, 651, 792, 916, 1295, 1620, 1666, 2550, 2705, 3641, 4678, 4759, 5014, 5022, 5071]
# Number of data points in this cluster: 15
#
# Cluster 746:
# Indices of data points: [226, 691, 1418, 1442, 3344, 4732]
# Number of data points in this cluster: 6
#
# Cluster 565:
# Indices of data points: [227, 574, 2229, 3247, 3358, 3371, 3959]
# Number of data points in this cluster: 7
#
# Cluster 727:
# Indices of data points: [229, 1243, 2488, 3245, 3291, 4965]
# Number of data points in this cluster: 6
#
# Cluster 218:
# Indices of data points: [230, 430, 750, 785, 1554, 1571, 1813, 2298, 2589, 3052, 4761, 4782]
# Number of data points in this cluster: 12
#
# Cluster 360:
# Indices of data points: [235, 341, 420, 495, 781, 973, 1109, 1256, 2671, 3721, 3946, 4101]
# Number of data points in this cluster: 12
#
# Cluster 292:
# Indices of data points: [237, 1589, 1934, 2435, 3680, 4059]
# Number of data points in this cluster: 6
#
# Cluster 161:
# Indices of data points: [242, 867, 1161, 1512, 1908, 1969, 2822, 2911, 3008, 4168, 4692]
# Number of data points in this cluster: 11
#
# Cluster 522:
# Indices of data points: [243, 427, 885, 1137, 2154, 2786, 2872, 3306, 4928, 5032]
# Number of data points in this cluster: 10
#
# Cluster 763:
# Indices of data points: [244, 821, 3032, 3133, 3388, 4387, 4952, 4964]
# Number of data points in this cluster: 8
#
# Cluster 59:
# Indices of data points: [245, 770, 784, 1194, 1417, 1643, 1748, 1775, 1788, 2848, 4016, 4713, 4828, 4995, 5012]
# Number of data points in this cluster: 15
#
# Cluster 734:
# Indices of data points: [247, 827, 1153, 1676, 4216, 4963, 5003]
# Number of data points in this cluster: 7
#
# Cluster 675:
# Indices of data points: [248, 279, 707, 4133]
# Number of data points in this cluster: 4
#
# Cluster 45:
# Indices of data points: [249, 1326, 1736, 2066, 2486, 3463, 3850, 4104, 4177, 4194]
# Number of data points in this cluster: 10
#
# Cluster 474:
# Indices of data points: [250, 732, 2074, 2433, 2893, 3150, 3186, 3414, 3527, 4154]
# Number of data points in this cluster: 10
#
# Cluster 374:
# Indices of data points: [251, 1004, 1421, 1492, 1800, 2538, 2892, 3298, 3736, 4704]
# Number of data points in this cluster: 10
#
# Cluster 216:
# Indices of data points: [252, 560, 1104, 1151, 1834, 2531, 2660, 2754, 3759, 4658, 4763, 5083]
# Number of data points in this cluster: 12
#
# Cluster 36:
# Indices of data points: [254, 1127, 1263, 1280, 2144, 3086, 3181]
# Number of data points in this cluster: 7
#
# Cluster 502:
# Indices of data points: [255, 1128, 1555, 1721, 2663, 3618]
# Number of data points in this cluster: 6
#
# Cluster 230:
# Indices of data points: [257, 718, 816, 1171, 1254, 1473, 2392, 2618]
# Number of data points in this cluster: 8
#
# Cluster 388:
# Indices of data points: [259, 650, 738, 2491, 4022]
# Number of data points in this cluster: 5
#
# Cluster 481:
# Indices of data points: [260, 261, 1218, 1963, 2224, 3080, 3917]
# Number of data points in this cluster: 7
#
# Cluster 101:
# Indices of data points: [262, 613, 653, 1634, 1889, 2072, 3301, 4619, 4820, 4841, 5006, 5055, 5066]
# Number of data points in this cluster: 13
#
# Cluster 211:
# Indices of data points: [263, 1088, 1261, 1323, 1389, 1463, 1627, 2089, 2142, 2236, 2458, 2935, 3189, 3550, 3587, 4570]
# Number of data points in this cluster: 16
#
# Cluster 393:
# Indices of data points: [264, 284, 295, 869, 2275, 2276, 2925, 3279, 3482, 3682, 3814, 4697]
# Number of data points in this cluster: 12
#
# Cluster 385:
# Indices of data points: [265, 1499, 1531, 1927]
# Number of data points in this cluster: 4
#
# Cluster 697:
# Indices of data points: [266, 755, 1120, 1760, 3470, 4546]
# Number of data points in this cluster: 6
#
# Cluster 232:
# Indices of data points: [267, 714, 1252, 1281, 1379, 2214, 4285]
# Number of data points in this cluster: 7
#
# Cluster 615:
# Indices of data points: [268, 595, 635, 801, 923, 1012, 1678, 3416]
# Number of data points in this cluster: 8
#
# Cluster 293:
# Indices of data points: [270, 697, 949, 1006, 1197, 1328, 1375, 2481, 3471, 3810, 4356, 4857]
# Number of data points in this cluster: 12
#
# Cluster 131:
# Indices of data points: [272, 1422, 1663, 1978, 2131, 2157, 2184, 2879, 3094, 3159, 3171, 3941]
# Number of data points in this cluster: 12
#
# Cluster 305:
# Indices of data points: [273, 305, 338, 355, 1046, 2290, 3572, 3576, 3666, 3779, 4044]
# Number of data points in this cluster: 11
#
# Cluster 623:
# Indices of data points: [274]
# Number of data points in this cluster: 1
#
# Cluster 432:
# Indices of data points: [275, 2899, 3320]
# Number of data points in this cluster: 3
#
# Cluster 507:
# Indices of data points: [277, 655, 2203, 2447, 3506, 4350]
# Number of data points in this cluster: 6
#
# Cluster 286:
# Indices of data points: [278, 1673, 2982, 3018, 4053]
# Number of data points in this cluster: 5
#
# Cluster 310:
# Indices of data points: [281, 969, 1971, 2255, 3914, 3977, 4489, 4845]
# Number of data points in this cluster: 8
#
# Cluster 259:
# Indices of data points: [282, 328, 1322, 1756, 2626]
# Number of data points in this cluster: 5
#
# Cluster 206:
# Indices of data points: [283, 1614, 2320, 2574, 3115, 4009, 4080]
# Number of data points in this cluster: 7
#
# Cluster 18:
# Indices of data points: [285, 1731, 2242, 2580, 4023, 4186, 4453]
# Number of data points in this cluster: 7
#
# Cluster 665:
# Indices of data points: [287, 993, 2197, 2652]
# Number of data points in this cluster: 4
#
# Cluster 597:
# Indices of data points: [291, 1962, 2324, 2546, 2855, 3124, 3826, 4632, 4960, 5062]
# Number of data points in this cluster: 10
#
# Cluster 108:
# Indices of data points: [292, 294, 4293, 4454]
# Number of data points in this cluster: 4
#
# Cluster 43:
# Indices of data points: [293, 373, 398, 432, 567, 637, 898, 1293, 1320, 1923, 2254, 2920, 3303, 3702]
# Number of data points in this cluster: 14
#
# Cluster 251:
# Indices of data points: [296, 1372, 1759, 4412, 4478, 4587]
# Number of data points in this cluster: 6
#
# Cluster 356:
# Indices of data points: [297, 2278, 2339, 2856]
# Number of data points in this cluster: 4
#
# Cluster 336:
# Indices of data points: [298, 521, 539, 1289, 1840, 2403, 3785, 4223, 4824, 5010]
# Number of data points in this cluster: 10
#
# Cluster 224:
# Indices of data points: [300, 492, 622, 876, 1481, 2207, 3875, 4870]
# Number of data points in this cluster: 8
#
# Cluster 761:
# Indices of data points: [301, 1833, 2092, 2922, 3997, 4581, 4625, 4780]
# Number of data points in this cluster: 8
#
# Cluster 19:
# Indices of data points: [302, 456, 597, 696, 918, 1051, 1159, 1638, 2283, 2712, 2862, 4580, 4628]
# Number of data points in this cluster: 13
#
# Cluster 454:
# Indices of data points: [303, 787, 1538, 1724, 2130, 2921, 3840, 3924, 4647, 5030]
# Number of data points in this cluster: 10
#
# Cluster 133:
# Indices of data points: [304, 375, 1009, 1419, 3492, 3620, 4129]
# Number of data points in this cluster: 7
#
# Cluster 212:
# Indices of data points: [306, 454, 519, 2615, 4105, 4205, 4484, 4822, 4873, 4990, 5064]
# Number of data points in this cluster: 11
#
# Cluster 664:
# Indices of data points: [308, 763, 1169, 3945, 4797, 4953, 5033]
# Number of data points in this cluster: 7
#
# Cluster 69:
# Indices of data points: [311, 1215, 1415, 2356, 4047, 4138]
# Number of data points in this cluster: 6
#
# Cluster 688:
# Indices of data points: [314, 1556, 2141, 3824, 3952, 4984, 5059]
# Number of data points in this cluster: 7
#
# Cluster 391:
# Indices of data points: [316, 386, 645, 751, 1570, 1953, 2649, 3495, 3791, 4915, 4974]
# Number of data points in this cluster: 11
#
# Cluster 40:
# Indices of data points: [317, 547, 609, 951, 1032, 1302, 3070, 3835, 4444, 4944, 5002, 5130]
# Number of data points in this cluster: 12
#
# Cluster 556:
# Indices of data points: [321, 421, 1082, 1749, 2017, 2044, 3988, 4480, 4750]
# Number of data points in this cluster: 9
#
# Cluster 10:
# Indices of data points: [322, 1071, 1349, 2188, 2293, 2592, 2598, 2764, 2777, 3217, 4720]
# Number of data points in this cluster: 11
#
# Cluster 15:
# Indices of data points: [323, 760, 1539, 3523, 4344, 4993]
# Number of data points in this cluster: 6
#
# Cluster 276:
# Indices of data points: [326, 450, 2211, 3100, 3571, 3581, 5007]
# Number of data points in this cluster: 7
#
# Cluster 395:
# Indices of data points: [329, 525, 2259, 2313, 3309, 3708, 4162]
# Number of data points in this cluster: 7
#
# Cluster 7:
# Indices of data points: [331, 360, 523, 604, 618, 659, 870, 2343, 3154, 3889, 3984, 4757]
# Number of data points in this cluster: 12
#
# Cluster 12:
# Indices of data points: [332, 1283, 1425, 1609, 1612, 2015, 2490, 4982]
# Number of data points in this cluster: 8
#
# Cluster 210:
# Indices of data points: [333, 976, 2088, 3310, 3630, 4537, 4650]
# Number of data points in this cluster: 7
#
# Cluster 501:
# Indices of data points: [335, 1332, 1459, 2992, 3090, 3373, 4502]
# Number of data points in this cluster: 7
#
# Cluster 225:
# Indices of data points: [336, 500, 553, 658, 840, 1026, 2021, 2677, 4106, 4926]
# Number of data points in this cluster: 10
#
# Cluster 368:
# Indices of data points: [339, 1427, 1633, 1847, 1888, 2867, 3555, 3869, 4366, 4874, 4893]
# Number of data points in this cluster: 11
#
# Cluster 471:
# Indices of data points: [340, 345, 1097, 1251, 2036, 2790, 2983, 4279, 4322, 4683]
# Number of data points in this cluster: 10
#
# Cluster 645:
# Indices of data points: [342, 998, 1411, 1993, 1997, 3232, 3443, 3530, 3683, 5027]
# Number of data points in this cluster: 10
#
# Cluster 364:
# Indices of data points: [343, 607, 2394, 3573, 3795, 3942, 4115, 4300]
# Number of data points in this cluster: 8
#
# Cluster 52:
# Indices of data points: [346, 529, 943, 995, 1448, 2235, 3096]
# Number of data points in this cluster: 7
#
# Cluster 50:
# Indices of data points: [349, 1183, 1199, 1484, 1581, 1792, 1809, 3191, 4588, 5013]
# Number of data points in this cluster: 10
#
# Cluster 541:
# Indices of data points: [351, 367, 716, 2629, 3963, 4492]
# Number of data points in this cluster: 6
#
# Cluster 242:
# Indices of data points: [352, 1299, 2714, 3039, 4783]
# Number of data points in this cluster: 5
#
# Cluster 168:
# Indices of data points: [353, 985, 986, 2756, 3263, 5039]
# Number of data points in this cluster: 6
#
# Cluster 756:
# Indices of data points: [356, 1454, 2033, 3205, 4108, 4648]
# Number of data points in this cluster: 6
#
# Cluster 4:
# Indices of data points: [359, 370, 379, 415, 589, 670, 1835, 1893, 2081, 2445, 3093, 3807, 4127, 4178, 4589, 4775, 4875, 4921, 5000]
# Number of data points in this cluster: 19
#
# Cluster 64:
# Indices of data points: [363, 2153, 3235, 3282, 3619, 4834, 4998]
# Number of data points in this cluster: 7
#
# Cluster 8:
# Indices of data points: [364, 702, 901, 1142, 1158, 1317, 1470, 2380, 2654, 2816, 3068, 3536, 3601, 4601, 4902]
# Number of data points in this cluster: 15
#
# Cluster 441:
# Indices of data points: [365, 1743, 2869, 3497]
# Number of data points in this cluster: 4
#
# Cluster 646:
# Indices of data points: [366, 411, 1052, 1436, 3935, 4978]
# Number of data points in this cluster: 6
#
# Cluster 86:
# Indices of data points: [371, 1236, 1242, 2642, 2916, 3011, 3911]
# Number of data points in this cluster: 7
#
# Cluster 644:
# Indices of data points: [374, 3223, 3851]
# Number of data points in this cluster: 3
#
# Cluster 65:
# Indices of data points: [376, 463, 1472, 2566, 2648, 2890, 3707, 4228, 4259, 4568, 5021]
# Number of data points in this cluster: 11
#
# Cluster 344:
# Indices of data points: [377, 1223, 1398, 1677, 1804, 2908, 3001, 4563, 4805]
# Number of data points in this cluster: 9
#
# Cluster 155:
# Indices of data points: [380, 1626, 1937, 2245, 2579, 4585]
# Number of data points in this cluster: 6
#
# Cluster 343:
# Indices of data points: [381, 805, 2198, 3385, 4567, 4676]
# Number of data points in this cluster: 6
#
# Cluster 573:
# Indices of data points: [383, 873, 1015, 1479, 3215, 4318]
# Number of data points in this cluster: 6
#
# Cluster 261:
# Indices of data points: [385, 388, 687, 1611, 2917, 3326, 3695, 5116]
# Number of data points in this cluster: 8
#
# Cluster 578:
# Indices of data points: [389, 1195, 3949, 4020, 4832]
# Number of data points in this cluster: 5
#
# Cluster 116:
# Indices of data points: [391, 678, 2101, 2143, 2205, 2480, 2830, 3376]
# Number of data points in this cluster: 8
#
# Cluster 272:
# Indices of data points: [393, 782, 794, 1445, 2238, 3243, 3382, 3521, 3922, 4996]
# Number of data points in this cluster: 10
#
# Cluster 39:
# Indices of data points: [394, 864, 957, 2684, 3465, 4461, 4544]
# Number of data points in this cluster: 7
#
# Cluster 735:
# Indices of data points: [397, 476, 615, 1200, 2070, 3005, 3928]
# Number of data points in this cluster: 7
#
# Cluster 132:
# Indices of data points: [399, 713, 1292, 1430, 2366, 2946, 3098, 3418, 3545, 4401]
# Number of data points in this cluster: 10
#
# Cluster 124:
# Indices of data points: [401, 1112, 4540, 4573]
# Number of data points in this cluster: 4
#
# Cluster 666:
# Indices of data points: [404, 1231, 3983, 4173]
# Number of data points in this cluster: 4
#
# Cluster 383:
# Indices of data points: [407, 522, 1123, 1836, 3152, 4217, 4274, 4538, 5019]
# Number of data points in this cluster: 9
#
# Cluster 659:
# Indices of data points: [413, 3873, 4592, 4630, 4742, 5103]
# Number of data points in this cluster: 6
#
# Cluster 320:
# Indices of data points: [414, 455, 654, 710, 831, 1125, 1176, 2363, 2498, 3333, 3535, 3934, 4599, 5096]
# Number of data points in this cluster: 14
#
# Cluster 38:
# Indices of data points: [423, 981, 4036, 4380, 4854]
# Number of data points in this cluster: 5
#
# Cluster 365:
# Indices of data points: [424, 956, 1130, 1444, 2353]
# Number of data points in this cluster: 5
#
# Cluster 260:
# Indices of data points: [426, 1778, 2342, 4436, 5001]
# Number of data points in this cluster: 5
#
# Cluster 126:
# Indices of data points: [433, 679, 899, 1854, 2774, 3097, 4245, 4455, 4463, 4504, 4914]
# Number of data points in this cluster: 11
#
# Cluster 748:
# Indices of data points: [435, 3106, 3140, 4064]
# Number of data points in this cluster: 4
#
# Cluster 220:
# Indices of data points: [436, 709, 828, 1019, 2012, 2900, 2932, 3399, 3580, 4622, 4807, 4909, 5048]
# Number of data points in this cluster: 13
#
# Cluster 510:
# Indices of data points: [437]
# Number of data points in this cluster: 1
#
# Cluster 611:
# Indices of data points: [438, 1117, 1602, 1779, 2540, 3948, 4429, 4552]
# Number of data points in this cluster: 8
#
# Cluster 346:
# Indices of data points: [439, 1028, 1049, 1315, 1699, 2132, 2383, 3183, 3369, 3560, 4275, 4416, 5057]
# Number of data points in this cluster: 13
#
# Cluster 201:
# Indices of data points: [440, 594, 1147, 1866, 2321, 2417, 3044, 3747]
# Number of data points in this cluster: 8
#
# Cluster 348:
# Indices of data points: [441, 662, 1823, 2253, 3613, 4410]
# Number of data points in this cluster: 6
#
# Cluster 641:
# Indices of data points: [442, 3204, 3798, 3879, 4001]
# Number of data points in this cluster: 5
#
# Cluster 149:
# Indices of data points: [444, 737, 2104]
# Number of data points in this cluster: 3
#
# Cluster 60:
# Indices of data points: [445, 767, 836, 860, 1909, 1954, 2337, 2805, 3466, 4017, 4198, 4212, 4823, 5036]
# Number of data points in this cluster: 14
#
# Cluster 402:
# Indices of data points: [447, 884, 978, 1044, 4930]
# Number of data points in this cluster: 5
#
# Cluster 768:
# Indices of data points: [451, 1513, 2573, 4385, 4470]
# Number of data points in this cluster: 5
#
# Cluster 708:
# Indices of data points: [457, 533, 3327, 3568]
# Number of data points in this cluster: 4
#
# Cluster 213:
# Indices of data points: [458, 657, 1058, 1580, 1983, 3030, 3659, 3884, 3960, 4636, 5081, 5084]
# Number of data points in this cluster: 12
#
# Cluster 696:
# Indices of data points: [459, 490, 1013, 2215, 3526, 3846, 4932]
# Number of data points in this cluster: 7
#
# Cluster 186:
# Indices of data points: [460, 542, 3067, 3284]
# Number of data points in this cluster: 4
#
# Cluster 442:
# Indices of data points: [461, 2711, 3304, 3632, 4055, 4384]
# Number of data points in this cluster: 6
#
# Cluster 181:
# Indices of data points: [462, 1072, 3307]
# Number of data points in this cluster: 3
#
# Cluster 438:
# Indices of data points: [464, 2624, 2858, 3113, 4070]
# Number of data points in this cluster: 5
#
# Cluster 255:
# Indices of data points: [466, 481, 938, 1630, 3202, 3503, 3769, 3777, 4032, 4466, 4595, 5107]
# Number of data points in this cluster: 12
#
# Cluster 215:
# Indices of data points: [467, 895, 1241, 1362, 1493, 1557, 2096, 2582, 2639, 3816, 4297]
# Number of data points in this cluster: 11
#
# Cluster 558:
# Indices of data points: [468, 703, 1121, 1220, 1260, 1282, 1301, 2404, 3130]
# Number of data points in this cluster: 9
#
# Cluster 154:
# Indices of data points: [469, 1177, 1230, 2177, 2286, 2415, 3621, 4207, 5043]
# Number of data points in this cluster: 9
#
# Cluster 530:
# Indices of data points: [470, 2031, 2735]
# Number of data points in this cluster: 3
#
# Cluster 749:
# Indices of data points: [471, 4069, 4473, 4519, 4550]
# Number of data points in this cluster: 5
#
# Cluster 429:
# Indices of data points: [472, 545, 1027, 1853, 2360, 2775]
# Number of data points in this cluster: 6
#
# Cluster 446:
# Indices of data points: [474, 1505, 1659, 1826, 3162, 3679, 4161, 4229]
# Number of data points in this cluster: 8
#
# Cluster 411:
# Indices of data points: [475, 583, 1631, 1873, 2542, 2951, 3296, 3996, 4579, 4617, 5092]
# Number of data points in this cluster: 11
#
# Cluster 308:
# Indices of data points: [478, 1219, 2310, 2659, 4149]
# Number of data points in this cluster: 5
#
# Cluster 277:
# Indices of data points: [479, 1818, 4415]
# Number of data points in this cluster: 3
#
# Cluster 248:
# Indices of data points: [482, 1213, 1406, 3337, 4666, 4693]
# Number of data points in this cluster: 6
#
# Cluster 28:
# Indices of data points: [483, 771, 904, 1984, 2319]
# Number of data points in this cluster: 5
#
# Cluster 408:
# Indices of data points: [484, 1679, 2452, 2608, 2686, 3475, 4390, 4702]
# Number of data points in this cluster: 8
#
# Cluster 390:
# Indices of data points: [488, 3453, 4067, 4418]
# Number of data points in this cluster: 4
#
# Cluster 625:
# Indices of data points: [491, 2947, 3710, 4058, 4785, 4812, 4842]
# Number of data points in this cluster: 7
#
# Cluster 415:
# Indices of data points: [493, 4123, 4299, 4450]
# Number of data points in this cluster: 4
#
# Cluster 519:
# Indices of data points: [494, 1929, 2269, 2881, 3397, 3649]
# Number of data points in this cluster: 6
#
# Cluster 178:
# Indices of data points: [496, 1939, 2116, 2151, 2221, 2994, 3075, 3160, 3177, 4694, 4942]
# Number of data points in this cluster: 11
#
# Cluster 764:
# Indices of data points: [497, 2643, 3332, 4114, 4671, 4770]
# Number of data points in this cluster: 6
#
# Cluster 421:
# Indices of data points: [498, 626, 900, 1671, 2723, 3321, 3992, 4583, 4725, 4777, 4861]
# Number of data points in this cluster: 11
#
# Cluster 690:
# Indices of data points: [506, 4476]
# Number of data points in this cluster: 2
#
# Cluster 319:
# Indices of data points: [508, 1511, 3665, 3744, 3765, 4507]
# Number of data points in this cluster: 6
#
# Cluster 78:
# Indices of data points: [509, 955, 1973, 2365, 2595, 2878, 3273, 4096, 4307]
# Number of data points in this cluster: 9
#
# Cluster 91:
# Indices of data points: [511, 2910, 2996, 3227, 3855, 3943]
# Number of data points in this cluster: 6
#
# Cluster 524:
# Indices of data points: [512, 2248, 2571, 3897, 4941, 4962, 5018]
# Number of data points in this cluster: 7
#
# Cluster 416:
# Indices of data points: [513, 2730, 3423, 4037]
# Number of data points in this cluster: 4
#
# Cluster 311:
# Indices of data points: [515, 2140, 4327]
# Number of data points in this cluster: 3
#
# Cluster 70:
# Indices of data points: [517, 2506, 2623, 4446]
# Number of data points in this cluster: 4
#
# Cluster 361:
# Indices of data points: [520, 1549, 2227, 4181, 5049, 5104, 5121]
# Number of data points in this cluster: 7
#
# Cluster 620:
# Indices of data points: [524, 1005, 4155]
# Number of data points in this cluster: 3
#
# Cluster 370:
# Indices of data points: [526, 972, 2201, 3110, 4089]
# Number of data points in this cluster: 5
#
# Cluster 187:
# Indices of data points: [528, 717, 2393, 3435, 4057]
# Number of data points in this cluster: 5
#
# Cluster 376:
# Indices of data points: [530, 1424, 1846, 3220, 3323, 3819, 3836, 4555, 4892]
# Number of data points in this cluster: 9
#
# Cluster 433:
# Indices of data points: [531, 908, 1353, 2745, 3445, 4028, 4393]
# Number of data points in this cluster: 7
#
# Cluster 146:
# Indices of data points: [534, 2277, 2279, 3629]
# Number of data points in this cluster: 4
#
# Cluster 100:
# Indices of data points: [535, 1600, 1717, 2348, 3102, 3929, 4156, 4241, 4439]
# Number of data points in this cluster: 9
#
# Cluster 482:
# Indices of data points: [537, 708, 2006, 3127, 3211, 3802, 4738, 4779]
# Number of data points in this cluster: 8
#
# Cluster 713:
# Indices of data points: [538, 2563, 3389, 3633, 4166, 4531, 4972]
# Number of data points in this cluster: 7
#
# Cluster 495:
# Indices of data points: [540, 2696, 3314, 4748]
# Number of data points in this cluster: 4
#
# Cluster 505:
# Indices of data points: [541, 2098, 2647, 2988]
# Number of data points in this cluster: 4
#
# Cluster 111:
# Indices of data points: [546, 1279, 1466, 1478, 3313, 4620]
# Number of data points in this cluster: 6
#
# Cluster 192:
# Indices of data points: [549, 636, 701, 1055, 1839, 2683, 5093]
# Number of data points in this cluster: 7
#
# Cluster 246:
# Indices of data points: [551, 850, 2442, 2499, 2703, 3908, 4501]
# Number of data points in this cluster: 7
#
# Cluster 66:
# Indices of data points: [552, 619, 1062, 1170, 1657, 2720, 2757, 3887, 5025, 5069]
# Number of data points in this cluster: 10
#
# Cluster 703:
# Indices of data points: [554, 2332, 4027, 4043, 4653, 4918]
# Number of data points in this cluster: 6
#
# Cluster 458:
# Indices of data points: [555, 1204, 2820, 2880, 3561, 4462]
# Number of data points in this cluster: 6
#
# Cluster 762:
# Indices of data points: [556, 891]
# Number of data points in this cluster: 2
#
# Cluster 269:
# Indices of data points: [558, 1094, 1528, 1686, 1732, 2685]
# Number of data points in this cluster: 6
#
# Cluster 706:
# Indices of data points: [561, 1529, 1617, 2742]
# Number of data points in this cluster: 4
#
# Cluster 263:
# Indices of data points: [564, 684, 857, 1020, 1257, 3017, 3297, 3986, 4566, 5051]
# Number of data points in this cluster: 10
#
# Cluster 548:
# Indices of data points: [565, 2866, 3886, 5120]
# Number of data points in this cluster: 4
#
# Cluster 738:
# Indices of data points: [566, 2784]
# Number of data points in this cluster: 2
#
# Cluster 118:
# Indices of data points: [568, 1136, 1381, 1603, 1720, 2653, 2955, 3394, 3658, 3831, 4325, 4762]
# Number of data points in this cluster: 12
#
# Cluster 182:
# Indices of data points: [569, 977, 2305, 2525, 2995, 4040, 4352, 4397, 4500, 5085]
# Number of data points in this cluster: 10
#
# Cluster 196:
# Indices of data points: [570, 598, 842, 914, 1070, 1294]
# Number of data points in this cluster: 6
#
# Cluster 731:
# Indices of data points: [571, 692, 1367, 1615, 1948, 2522, 3856, 4260]
# Number of data points in this cluster: 8
#
# Cluster 382:
# Indices of data points: [572, 663, 826, 1585, 1604, 1605, 2544, 2798, 2865, 3164, 3267, 3372, 4254, 4303, 4881]
# Number of data points in this cluster: 15
#
# Cluster 104:
# Indices of data points: [573, 1132, 1594, 1941, 2018, 2026, 2564, 3727, 4467]
# Number of data points in this cluster: 9
#
# Cluster 498:
# Indices of data points: [575, 982, 2389, 3909]
# Number of data points in this cluster: 4
#
# Cluster 221:
# Indices of data points: [576, 833, 1105, 1925, 2974, 4099, 4258, 4554, 4654]
# Number of data points in this cluster: 9
#
# Cluster 67:
# Indices of data points: [577, 1000, 1186, 1198, 2252, 2270, 2727, 3378, 3967]
# Number of data points in this cluster: 9
#
# Cluster 119:
# Indices of data points: [578, 640, 772, 865, 1135, 1238, 2272, 2736, 2949, 3564, 4092]
# Number of data points in this cluster: 11
#
# Cluster 46:
# Indices of data points: [581, 614, 917, 2183, 2593, 3783, 4002, 4520]
# Number of data points in this cluster: 8
#
# Cluster 757:
# Indices of data points: [584, 2181, 2709, 3149]
# Number of data points in this cluster: 4
#
# Cluster 686:
# Indices of data points: [585, 1307, 1755, 3464, 3843, 3847, 3892, 4374, 5128]
# Number of data points in this cluster: 9
#
# Cluster 127:
# Indices of data points: [587, 727, 734, 1325, 1880, 2178, 2408, 2657, 5040]
# Number of data points in this cluster: 9
#
# Cluster 514:
# Indices of data points: [588, 2119, 2578, 3063, 4559]
# Number of data points in this cluster: 5
#
# Cluster 492:
# Indices of data points: [592, 1163, 1718, 2794, 4270]
# Number of data points in this cluster: 5
#
# Cluster 174:
# Indices of data points: [599, 1036, 1943, 2572, 3343, 4746]
# Number of data points in this cluster: 6
#
# Cluster 439:
# Indices of data points: [600, 643, 2155, 2213, 2600]
# ...
# Number of data points in this cluster: 13
#
# Cluster 737:
# Indices of data points: [1495, 1815, 2487, 3567, 3574]
# Number of data points in this cluster: 5
#
# Cluster 325:
# Indices of data points: [1514, 1747, 1795, 1938, 3684]
# Number of data points in this cluster: 5
#
# Cluster 607:
# Indices of data points: [1520, 2437, 3689, 4535]
# Number of data points in this cluster: 4
#
# Cluster 575:
# Indices of data points: [1536, 1569, 1645, 1733, 2454, 2941, 2959, 3481]
# Number of data points in this cluster: 8
#
# Cluster 270:
# Indices of data points: [1537, 1862, 1869, 2173, 2299, 2322, 3436]
# Number of data points in this cluster: 7
#
# Cluster 668:
# Indices of data points: [1543, 2966, 4768]
# Number of data points in this cluster: 3
#
# Cluster 550:
# Indices of data points: [1544, 2080, 2112, 2752, 2758]
# Number of data points in this cluster: 5
#
# Cluster 506:
# Indices of data points: [1559, 2482, 3799, 4405, 4594]
# Number of data points in this cluster: 5
#
# Cluster 637:
# Indices of data points: [1572, 3280]
# Number of data points in this cluster: 2
#
# Cluster 621:
# Indices of data points: [1597, 2740, 4317, 4660]
# Number of data points in this cluster: 4
#
# Cluster 449:
# Indices of data points: [1598, 1932, 2192, 4574]
# Number of data points in this cluster: 4
#
# Cluster 21:
# Indices of data points: [1601, 2978, 3429, 3645]
# Number of data points in this cluster: 4
#
# Cluster 353:
# Indices of data points: [1606, 2011, 2146, 3046, 3408]
# Number of data points in this cluster: 5
#
# Cluster 627:
# Indices of data points: [1608, 1807, 1881, 2527, 3733]
# Number of data points in this cluster: 5
#
# Cluster 747:
# Indices of data points: [1616, 2483, 3155, 3225]
# Number of data points in this cluster: 4
#
# Cluster 298:
# Indices of data points: [1644, 1703, 2282, 3088, 3146, 3214, 4041]
# Number of data points in this cluster: 7
#
# Cluster 266:
# Indices of data points: [1647, 1913, 2523, 3459, 4214, 4314]
# Number of data points in this cluster: 6
#
# Cluster 497:
# Indices of data points: [1649, 2517, 4112, 4724]
# Number of data points in this cluster: 4
#
# Cluster 568:
# Indices of data points: [1656, 1734, 3706, 3789, 4116, 4603, 4737, 5127]
# Number of data points in this cluster: 8
#
# Cluster 464:
# Indices of data points: [1662, 2267, 2367, 3138]
# Number of data points in this cluster: 4
#
# Cluster 594:
# Indices of data points: [1667, 1917, 3529, 3717]
# Number of data points in this cluster: 4
#
# Cluster 252:
# Indices of data points: [1669, 2532, 2833, 4249, 5090]
# Number of data points in this cluster: 5
#
# Cluster 357:
# Indices of data points: [1681, 2749, 2970, 3073, 3300, 4430]
# Number of data points in this cluster: 6
#
# Cluster 425:
# Indices of data points: [1692, 2280, 3056, 4432]
# Number of data points in this cluster: 4
#
# Cluster 583:
# Indices of data points: [1695, 1930]
# Number of data points in this cluster: 2
#
# Cluster 44:
# Indices of data points: [1700, 1981, 3375, 3598, 3735, 4487]
# Number of data points in this cluster: 6
#
# Cluster 595:
# Indices of data points: [1702, 2418, 3014]
# Number of data points in this cluster: 3
#
# Cluster 279:
# Indices of data points: [1710, 2292, 3356, 4206, 4652]
# Number of data points in this cluster: 5
#
# Cluster 560:
# Indices of data points: [1730, 2200, 2622, 2835, 3135]
# Number of data points in this cluster: 5
#
# Cluster 740:
# Indices of data points: [1739, 1842]
# Number of data points in this cluster: 2
#
# Cluster 508:
# Indices of data points: [1750, 1793, 1922, 2438]
# Number of data points in this cluster: 4
#
# Cluster 316:
# Indices of data points: [1753, 3590, 3808]
# Number of data points in this cluster: 3
#
# Cluster 115:
# Indices of data points: [1757, 2434, 3772, 4281, 4811]
# Number of data points in this cluster: 5
#
# Cluster 561:
# Indices of data points: [1768, 2223, 3034]
# Number of data points in this cluster: 3
#
# Cluster 587:
# Indices of data points: [1769, 3678, 4077, 4578]
# Number of data points in this cluster: 4
#
# Cluster 769:
# Indices of data points: [1773, 2030, 2344, 2428]
# Number of data points in this cluster: 4
#
# Cluster 120:
# Indices of data points: [1774, 1863]
# Number of data points in this cluster: 2
#
# Cluster 240:
# Indices of data points: [1782, 3755, 4517]
# Number of data points in this cluster: 3
#
# Cluster 500:
# Indices of data points: [1783, 1857, 2721, 2942, 3305, 3458, 3910]
# Number of data points in this cluster: 7
#
# Cluster 405:
# Indices of data points: [1786, 3161, 3905, 4240]
# Number of data points in this cluster: 4
#
# Cluster 396:
# Indices of data points: [1801, 1855, 4148, 4392]
# Number of data points in this cluster: 4
#
# Cluster 278:
# Indices of data points: [1803, 2231, 2811, 4165]
# Number of data points in this cluster: 4
#
# Cluster 571:
# Indices of data points: [1806, 1887, 3511, 3832, 3891, 4029]
# Number of data points in this cluster: 6
#
# Cluster 448:
# Indices of data points: [1843, 3724, 3737]
# Number of data points in this cluster: 3
#
# Cluster 121:
# Indices of data points: [1848, 3434, 3460, 3605, 3681, 3906]
# Number of data points in this cluster: 6
#
# Cluster 576:
# Indices of data points: [1851, 2003, 4200]
# Number of data points in this cluster: 3
#
# Cluster 347:
# Indices of data points: [1852, 2038, 3648, 3767, 4042]
# Number of data points in this cluster: 5
#
# Cluster 30:
# Indices of data points: [1883, 2019, 3583, 3585, 3813, 4118, 4170, 4642]
# Number of data points in this cluster: 8
#
# Cluster 453:
# Indices of data points: [1885, 1952, 2450, 2597, 3122, 3281, 3499, 4864, 5065]
# Number of data points in this cluster: 9
#
# Cluster 253:
# Indices of data points: [1886, 3195, 3292]
# Number of data points in this cluster: 3
#
# Cluster 290:
# Indices of data points: [1892, 2468, 4751]
# Number of data points in this cluster: 3
#
# Cluster 173:
# Indices of data points: [1894, 1982, 2971, 4035, 4413]
# Number of data points in this cluster: 5
#
# Cluster 302:
# Indices of data points: [1895, 2250, 2303, 2689]
# Number of data points in this cluster: 4
#
# Cluster 567:
# Indices of data points: [1950, 2724, 3637]
# Number of data points in this cluster: 3
#
# Cluster 417:
# Indices of data points: [1975, 3331, 3817, 4483]
# Number of data points in this cluster: 4
#
# Cluster 656:
# Indices of data points: [1976, 3661, 3951, 4616]
# Number of data points in this cluster: 4
#
# Cluster 692:
# Indices of data points: [1985, 3965, 4348]
# Number of data points in this cluster: 3
#
# Cluster 555:
# Indices of data points: [1995, 3693, 3842]
# Number of data points in this cluster: 3
#
# Cluster 406:
# Indices of data points: [1999, 2759, 3639, 4052]
# Number of data points in this cluster: 4
#
# Cluster 643:
# Indices of data points: [2001, 2355, 3849, 4474]
# Number of data points in this cluster: 4
#
# Cluster 687:
# Indices of data points: [2007, 2083]
# Number of data points in this cluster: 2
#
# Cluster 585:
# Indices of data points: [2023, 3175, 3338, 4506]
# Number of data points in this cluster: 4
#
# Cluster 579:
# Indices of data points: [2027, 2944]
# Number of data points in this cluster: 2
#
# Cluster 531:
# Indices of data points: [2037, 3351, 4247]
# Number of data points in this cluster: 3
#
# Cluster 739:
# Indices of data points: [2051, 4477, 4985]
# Number of data points in this cluster: 3
#
# Cluster 193:
# Indices of data points: [2055, 2113, 2518, 3673]
# Number of data points in this cluster: 4
#
# Cluster 180:
# Indices of data points: [2090, 3145, 4421, 4465]
# Number of data points in this cluster: 4
#
# Cluster 349:
# Indices of data points: [2109, 2148, 2351, 2496, 2680, 3756, 3841, 3923, 4707]
# Number of data points in this cluster: 9
#
# Cluster 352:
# Indices of data points: [2129, 2261, 2515, 3433]
# Number of data points in this cluster: 4
#
# Cluster 222:
# Indices of data points: [2134, 3450]
# Number of data points in this cluster: 2
#
# Cluster 512:
# Indices of data points: [2172, 2583, 3626, 4171]
# Number of data points in this cluster: 4
#
# Cluster 715:
# Indices of data points: [2175, 2562, 4004, 4031]
# Number of data points in this cluster: 4
#
# Cluster 148:
# Indices of data points: [2179, 2651, 2812, 3021, 3022, 3700, 4320]
# Number of data points in this cluster: 7
#
# Cluster 138:
# Indices of data points: [2208, 4046, 4202, 4395, 4534, 4584, 4989]
# Number of data points in this cluster: 7
#
# Cluster 733:
# Indices of data points: [2228, 2738, 3653]
# Number of data points in this cluster: 3
#
# Cluster 142:
# Indices of data points: [2301, 4475, 4586, 5028]
# Number of data points in this cluster: 4
#
# Cluster 130:
# Indices of data points: [2302, 3444, 4196]
# Number of data points in this cluster: 3
#
# Cluster 338:
# Indices of data points: [2306, 4438]
# Number of data points in this cluster: 2
#
# Cluster 372:
# Indices of data points: [2309, 2569, 3723, 4324]
# Number of data points in this cluster: 4
#
# Cluster 407:
# Indices of data points: [2312, 2398, 2828, 3345, 4345]
# Number of data points in this cluster: 5
#
# Cluster 569:
# Indices of data points: [2316, 4448]
# Number of data points in this cluster: 2
#
# Cluster 636:
# Indices of data points: [2326, 3120, 3319]
# Number of data points in this cluster: 3
#
# Cluster 165:
# Indices of data points: [2330, 2640, 2817, 3364]
# Number of data points in this cluster: 4
#
# Cluster 420:
# Indices of data points: [2331, 4407]
# Number of data points in this cluster: 2
#
# Cluster 314:
# Indices of data points: [2334, 3829, 4403]
# Number of data points in this cluster: 3
#
# Cluster 419:
# Indices of data points: [2335, 2704, 4197, 4428, 4522]
# Number of data points in this cluster: 5
#
# Cluster 469:
# Indices of data points: [2350, 4468]
# Number of data points in this cluster: 2
#
# Cluster 488:
# Indices of data points: [2378, 4151]
# Number of data points in this cluster: 2
#
# Cluster 309:
# Indices of data points: [2391, 2989, 3312]
# Number of data points in this cluster: 3
#
# Cluster 655:
# Indices of data points: [2409]
# Number of data points in this cluster: 1
#
# Cluster 718:
# Indices of data points: [2416]
# Number of data points in this cluster: 1
#
# Cluster 170:
# Indices of data points: [2419, 2802, 3143, 3209, 3431, 3828]
# Number of data points in this cluster: 6
#
# Cluster 373:
# Indices of data points: [2424, 3354, 3484, 4596]
# Number of data points in this cluster: 4
#
# Cluster 249:
# Indices of data points: [2425, 2444, 2809, 2847, 4006]
# Number of data points in this cluster: 5
#
# Cluster 490:
# Indices of data points: [2431, 4071]
# Number of data points in this cluster: 2
#
# Cluster 591:
# Indices of data points: [2453, 2860]
# Number of data points in this cluster: 2
#
# Cluster 468:
# Indices of data points: [2467]
# Number of data points in this cluster: 1
#
# Cluster 544:
# Indices of data points: [2500, 3383, 4335]
# Number of data points in this cluster: 3
#
# Cluster 323:
# Indices of data points: [2502, 2514, 3253, 4284]
# Number of data points in this cluster: 4
#
# Cluster 604:
# Indices of data points: [2504, 2819, 3006, 3101]
# Number of data points in this cluster: 4
#
# Cluster 723:
# Indices of data points: [2509, 3508]
# Number of data points in this cluster: 2
#
# Cluster 496:
# Indices of data points: [2524, 4015, 4079]
# Number of data points in this cluster: 3
#
# Cluster 536:
# Indices of data points: [2529]
# Number of data points in this cluster: 1
#
# Cluster 649:
# Indices of data points: [2530]
# Number of data points in this cluster: 1
#
# Cluster 450:
# Indices of data points: [2541, 4119, 4369]
# Number of data points in this cluster: 3
#
# Cluster 535:
# Indices of data points: [2555, 2986, 3330, 3625, 3627]
# Number of data points in this cluster: 5
#
# Cluster 695:
# Indices of data points: [2558]
# Number of data points in this cluster: 1
#
# Cluster 387:
# Indices of data points: [2585, 4130, 4916]
# Number of data points in this cluster: 3
#
# Cluster 151:
# Indices of data points: [2594, 4024, 5052]
# Number of data points in this cluster: 3
#
# Cluster 171:
# Indices of data points: [2601, 2641, 2741, 3019, 3158, 3231, 3990, 4362]
# Number of data points in this cluster: 8
#
# Cluster 485:
# Indices of data points: [2602, 3252, 3365, 4386, 4437]
# Number of data points in this cluster: 5
#
# Cluster 76:
# Indices of data points: [2604, 2797, 3040, 3257, 4381, 4518, 4888]
# Number of data points in this cluster: 7
#
# Cluster 511:
# Indices of data points: [2611, 3962, 4379]
# Number of data points in this cluster: 3
#
# Cluster 312:
# Indices of data points: [2627, 3570]
# Number of data points in this cluster: 2
#
# Cluster 331:
# Indices of data points: [2633, 3129, 3547]
# Number of data points in this cluster: 3
#
# Cluster 494:
# Indices of data points: [2700, 2725, 2750, 4456, 4457]
# Number of data points in this cluster: 5
#
# Cluster 526:
# Indices of data points: [2737, 3880]
# Number of data points in this cluster: 2
#
# Cluster 440:
# Indices of data points: [2770, 2851, 3391, 4460, 4776]
# Number of data points in this cluster: 5
#
# Cluster 672:
# Indices of data points: [2773, 3182, 3185]
# Number of data points in this cluster: 3
#
# Cluster 716:
# Indices of data points: [2795, 3045, 3650, 3806, 4336]
# Number of data points in this cluster: 5
#
# Cluster 77:
# Indices of data points: [2832, 3244, 3317, 4250, 4844]
# Number of data points in this cluster: 5
#
# Cluster 321:
# Indices of data points: [2842, 3125]
# Number of data points in this cluster: 2
#
# Cluster 712:
# Indices of data points: [2853, 2898, 4383]
# Number of data points in this cluster: 3
#
# Cluster 766:
# Indices of data points: [2874, 3058, 3379, 4135, 4246]
# Number of data points in this cluster: 5
#
# Cluster 509:
# Indices of data points: [2882, 4204]
# Number of data points in this cluster: 2
#
# Cluster 297:
# Indices of data points: [2895, 2977, 4536]
# Number of data points in this cluster: 3
#
# Cluster 744:
# Indices of data points: [3047]
# Number of data points in this cluster: 1
#
# Cluster 366:
# Indices of data points: [3065, 3486, 4306]
# Number of data points in this cluster: 3
#
# Cluster 521:
# Indices of data points: [3078, 3219, 4227]
# Number of data points in this cluster: 3
#
# Cluster 581:
# Indices of data points: [3142, 3264]
# Number of data points in this cluster: 2
#
# Cluster 145:
# Indices of data points: [3203, 3804]
# Number of data points in this cluster: 2
#
# Cluster 156:
# Indices of data points: [3212, 3542, 3589, 3606, 4638, 4708]
# Number of data points in this cluster: 6
#
# Cluster 671:
# Indices of data points: [3226]
# Number of data points in this cluster: 1
#
# Cluster 389:
# Indices of data points: [3230]
# Number of data points in this cluster: 1
#
# Cluster 296:
# Indices of data points: [3290, 3446, 3502, 3823, 3980]
# Number of data points in this cluster: 5
#
# Cluster 767:
# Indices of data points: [3316]
# Number of data points in this cluster: 1
#
# Cluster 462:
# Indices of data points: [3325, 3410]
# Number of data points in this cluster: 2
#
# Cluster 663:
# Indices of data points: [3350]
# Number of data points in this cluster: 1
#
# Cluster 725:
# Indices of data points: [3390, 5125]
# Number of data points in this cluster: 2
#
# Cluster 207:
# Indices of data points: [3392, 4551, 5105]
# Number of data points in this cluster: 3
#
# Cluster 669:
# Indices of data points: [3405]
# Number of data points in this cluster: 1
#
# Cluster 262:
# Indices of data points: [3440, 5035]
# Number of data points in this cluster: 2
#
# Cluster 294:
# Indices of data points: [3462, 3657, 4188]
# Number of data points in this cluster: 3
#
# Cluster 619:
# Indices of data points: [3584, 3597]
# Number of data points in this cluster: 2
#
# Cluster 303:
# Indices of data points: [3607, 3738, 4086]
# Number of data points in this cluster: 3
#
# Cluster 428:
# Indices of data points: [3646]
# Number of data points in this cluster: 1
#
# Cluster 628:
# Indices of data points: [3647, 3716, 4399]
# Number of data points in this cluster: 3
#
# Cluster 717:
# Indices of data points: [3663, 4082]
# Number of data points in this cluster: 2
#
# Cluster 602:
# Indices of data points: [3770, 3862, 4209, 4931]
# Number of data points in this cluster: 4
#
# Cluster 538:
# Indices of data points: [3926, 4375, 4510, 4631, 4661]
# Number of data points in this cluster: 5
#
# Cluster 667:
# Indices of data points: [4146, 4373, 4614, 4787]
# Number of data points in this cluster: 4
#
# Cluster 418:
# Indices of data points: [4282, 4896]
# Number of data points in this cluster: 2
#
# Cluster 726:
# Indices of data points: [4295, 4556]
# Number of data points in this cluster: 2
#
# Cluster 596:
# Indices of data points: [4349, 4434]
# Number of data points in this cluster: 2
#
# Cluster 698:
# Indices of data points: [4400]
# Number of data points in this cluster: 1
#
# Cluster 333:
# Indices of data points: [4425, 4486]
# Number of data points in this cluster: 2

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\AugBus\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters = 770  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Function to get the keyframe index (centroid-based approach)
def get_keyframe_for_cluster(cluster_indices):
    # Extract the features for the current cluster
    cluster_features = features_scaled[cluster_indices]
    
    # Compute the centroid of the cluster (mean of the features)
    centroid = np.mean(cluster_features, axis=0)
    
    # Calculate the distance from each point to the centroid
    distances = cdist([centroid], cluster_features)
    
    # Get the index of the point closest to the centroid
    keyframe_index = cluster_indices[np.argmin(distances)]
    return keyframe_index

# Generate and display the sequence of keyframe indices for each cluster
keyframe_sequence = []

for cluster_label, indices in cluster_dict.items():
    keyframe_index = get_keyframe_for_cluster(indices)
    keyframe_sequence.append((cluster_label, keyframe_index))

# Print the sequence of keyframes in the desired format
for cluster_label, keyframe_index in keyframe_sequence:
    print(f"Cluster {cluster_label}: Keyframe index: {keyframe_index}")
# Out:
# Cluster 11: Keyframe index: 3359
# Cluster 227: Keyframe index: 1118
# Cluster 299: Keyframe index: 1487
# Cluster 650: Keyframe index: 4718
# Cluster 226: Keyframe index: 5068
# Cluster 479: Keyframe index: 5
# Cluster 156: Keyframe index: 4638
# Cluster 671: Keyframe index: 3226
# Cluster 389: Keyframe index: 3230
# Cluster 296: Keyframe index: 3446
# Cluster 767: Keyframe index: 3316
# Cluster 462: Keyframe index: 3325
# Cluster 663: Keyframe index: 3350
# Cluster 725: Keyframe index: 5125
# Cluster 207: Keyframe index: 3392
# Cluster 669: Keyframe index: 3405
# Cluster 262: Keyframe index: 3440
# Cluster 294: Keyframe index: 3657
# Cluster 619: Keyframe index: 3597
# Cluster 303: Keyframe index: 3607
# Cluster 428: Keyframe index: 3646
# Cluster 628: Keyframe index: 3716
# Cluster 717: Keyframe index: 4082
# Cluster 602: Keyframe index: 4209
# Cluster 538: Keyframe index: 4661
# Cluster 667: Keyframe index: 4614
# Cluster 418: Keyframe index: 4896
# Cluster 726: Keyframe index: 4556
# Cluster 596: Keyframe index: 4349
# Cluster 698: Keyframe index: 4400
# Cluster 333: Keyframe index: 4486

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist
from scipy.io import savemat  # Import savemat to save in .mat format
import pandas as pd  # Import pandas for CSV file export

# Load the LSTM features from the .npy file
lstm_features = np.load(r"C:\SumMe\Augmentation\AugBus\features_last_lstm.npy")

# Flatten LSTM features for clustering (if necessary)
n_samples = lstm_features.shape[0]  # Define the number of samples
n_clusters = 770  # Set the number of clusters
lstm_features_flattened = lstm_features.reshape(n_samples, -1)

# Standardizing the data before clustering
scaler = StandardScaler()
lstm_features_scaled = scaler.fit_transform(lstm_features_flattened)

# Apply Agglomerative Clustering with 'ward' linkage (no need to specify affinity)
agg_clustering = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
labels = agg_clustering.fit_predict(lstm_features_scaled)

# Group data points by cluster
clustered_data = {}

for idx, label in enumerate(labels):
    if label not in clustered_data:
        clustered_data[label] = []
    clustered_data[label].append(idx)

# Find keyframe for each cluster
keyframes = {}

for cluster_id, indices in clustered_data.items():
    # Get the feature vectors for the data points in this cluster
    cluster_features = lstm_features_scaled[indices]
    
    # Compute the centroid of the cluster (average of all feature vectors in the cluster)
    centroid = np.mean(cluster_features, axis=0)
    
    # Compute the Euclidean distance from each data point to the centroid
    distances = cdist(cluster_features, [centroid], metric='euclidean')
    
    # Find the index of the closest data point (keyframe)
    keyframe_idx = indices[np.argmin(distances)]
    
    # Store the keyframe index for the cluster
    keyframes[cluster_id] = keyframe_idx

# Create a binary matrix of shape (n_samples, n_clusters)
keyframe_matrix = np.zeros((n_samples, n_clusters), dtype=int)

# Mark the keyframes (set the corresponding index to 1)
for cluster_id, keyframe_idx in keyframes.items():
    keyframe_matrix[keyframe_idx, cluster_id] = 1

# Save the keyframe binary matrix as a .mat file
keyframe_data = {'keyframe_matrix': keyframe_matrix}  # Create a dictionary to save in .mat format
savemat(r'C:\SumMe\Augmentation\AugBus\features_last_lstm1.mat', keyframe_data)

# Print confirmation for .mat file
print(f"Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.mat")
print(f"Dimensions of the keyframe binary matrix: {keyframe_matrix.shape}")

# Save the keyframe binary matrix as a .csv file
keyframe_matrix_df = pd.DataFrame(keyframe_matrix)  # Convert matrix to DataFrame
keyframe_matrix_df.to_csv(r'C:\SumMe\Augmentation\AugBus\features_last_lstm1.csv', index=False)

# Print confirmation for .csv file
print(f"Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.csv")

# Print the sequence of keyframe indices in order of cluster numbers (Cluster 0, Cluster 1, ..., Cluster n)
print("\nKeyframe indices for each cluster:")
for cluster_id in range(n_clusters):
    if cluster_id in keyframes:
        print(f"Cluster {cluster_id}: Keyframe Index {keyframes[cluster_id]}")
    else:
        print(f"Cluster {cluster_id}: No keyframe found")
# Out:
# Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.mat
# Dimensions of the keyframe binary matrix: (5131, 770)
# Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.csv
#
# Keyframe indices for each cluster:
# Cluster 0: Keyframe Index 2846
# Cluster 1: Keyframe Index 2967
# Cluster 2: Keyframe Index 3438
# Cluster 3: Keyframe Index 807
# Cluster 4: Keyframe Index 4875
# Cluster 5: Keyframe Index 2814
# Cluster 6: Keyframe Index 70
# Cluster 7: Keyframe Index 3154
# Cluster 8: Keyframe Index 2380
# Cluster 9: Keyframe Index 1956
# Cluster 10: Keyframe Index 2764
# Cluster 11: Keyframe Index 3359
# Cluster 12: Keyframe Index 1283
# Cluster 13: Keyframe Index 1642
# Cluster 14: Keyframe Index 4767
# Cluster 15: Keyframe Index 1539
# Cluster 16: Keyframe Index 1882
# Cluster 17: Keyframe Index 1374
# Cluster 18: Keyframe Index 4023
# Cluster 19: Keyframe Index 696
# Cluster 20: Keyframe Index 3131
# Cluster 21: Keyframe Index 2978
# Cluster 22: Keyframe Index 2186
# Cluster 23: Keyframe Index 1284
# Cluster 24: Keyframe Index 7
# Cluster 25: Keyframe Index 2097
# Cluster 26: Keyframe Index 2859
# Cluster 27: Keyframe Index 2690
# Cluster 28: Keyframe Index 771
# Cluster 29: Keyframe Index 3139
# Cluster 30: Keyframe Index 3813
# Cluster 31: Keyframe Index 2209
# Cluster 32: Keyframe Index 1561
# Cluster 33: Keyframe Index 2039
# Cluster 34: Keyframe Index 1002
# Cluster 35: Keyframe Index 2938
# Cluster 36: Keyframe Index 1263
# Cluster 37: Keyframe Index 1766
# Cluster 38: Keyframe Index 423
# Cluster 39: Keyframe Index 864
# Cluster 40: Keyframe Index 4944
# Cluster 41: Keyframe Index 3334
# Cluster 42: Keyframe Index 3578
# Cluster 43: Keyframe Index 398
# Cluster 44: Keyframe Index 3735
# Cluster 45: Keyframe Index 3463
# Cluster 46: Keyframe Index 4520
# Cluster 47: Keyframe Index 2220
# Cluster 48: Keyframe Index 3099
# Cluster 49: Keyframe Index 4039
# Cluster 50: Keyframe Index 1484
# Cluster 51: Keyframe Index 3901
# Cluster 52: Keyframe Index 2235
# Cluster 53: Keyframe Index 35
# Cluster 54: Keyframe Index 2440
# Cluster 55: Keyframe Index 1237
# Cluster 56: Keyframe Index 3933
# Cluster 715: Keyframe Index 2562
# Cluster 716: Keyframe Index 3650
# Cluster 717: Keyframe Index 4082
# Cluster 718: Keyframe Index 2416
# Cluster 719: Keyframe Index 2456
# Cluster 720: Keyframe Index 1086
# Cluster 721: Keyframe Index 5095
# Cluster 722: Keyframe Index 2139
# Cluster 723: Keyframe Index 3508
# Cluster 724: Keyframe Index 980
# Cluster 725: Keyframe Index 5125
# Cluster 726: Keyframe Index 4556
# Cluster 727: Keyframe Index 1243
# Cluster 728: Keyframe Index 3775
# Cluster 729: Keyframe Index 4435
# Cluster 730: Keyframe Index 3456
# Cluster 731: Keyframe Index 1948
# Cluster 732: Keyframe Index 3852
# Cluster 733: Keyframe Index 2228
# Cluster 734: Keyframe Index 1153
# Cluster 735: Keyframe Index 615
# Cluster 736: Keyframe Index 2087
# Cluster 737: Keyframe Index 2487
# Cluster 738: Keyframe Index 2784
# Cluster 739: Keyframe Index 4477
# Cluster 740: Keyframe Index 1739
# Cluster 741: Keyframe Index 1327
# Cluster 742: Keyframe Index 3972
# Cluster 743: Keyframe Index 74
# Cluster 744: Keyframe Index 3047
# Cluster 745: Keyframe Index 1108
# Cluster 746: Keyframe Index 3344
# Cluster 747: Keyframe Index 1616
# Cluster 748: Keyframe Index 435
# Cluster 749: Keyframe Index 4473
# Cluster 750: Keyframe Index 837
# Cluster 751: Keyframe Index 3026
# Cluster 752: Keyframe Index 16
# Cluster 753: Keyframe Index 9
# Cluster 754: Keyframe Index 2082
# Cluster 755: Keyframe Index 799
# Cluster 756: Keyframe Index 1454
# Cluster 757: Keyframe Index 2181
# Cluster 758: Keyframe Index 4936
# Cluster 759: Keyframe Index 1465
# Cluster 760: Keyframe Index 2964
# Cluster 761: Keyframe Index 2092
# Cluster 762: Keyframe Index 556
# Cluster 763: Keyframe Index 3032
# Cluster 764: Keyframe Index 4671
# Cluster 765: Keyframe Index 902
# Cluster 766: Keyframe Index 4246
# Cluster 767: Keyframe Index 3316
# Cluster 768: Keyframe Index 4385
# Cluster 769: Keyframe Index 2428

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import scipy.io

# Step 1: Load the annotator labels from the .mat file
annotator_path = r"C:\SumMe\GT\Bus_in_Rock_Tunnel.mat" # Path to the .mat file
mat_data = scipy.io.loadmat(annotator_path)

# Check the keys in the .mat file
print("Keys in the .mat file:", mat_data.keys())


user_scores = mat_data['user_score']  
print(f"Shape of user_score: {user_scores.shape}")

# Step 2: Load our model's predictions from the .csv file
our_path = r"C:\SumMe\Augmentation\AugBus\features_last_lstm1.csv" # Path to the CSV file
u1 = pd.read_csv(our_path, header=None).values.flatten()  # Our model's predictions (binary array)


print(f"Shape of model's predictions (u1): {u1.shape}")

# Ensure that the length of u1 matches the number of rows in user_scores
if u1.shape[0] != user_scores.shape[0]:
    print(f"Warning: Mismatched lengths. Adjusting the data...")
    u1 = u1[:user_scores.shape[0]]  # Truncate u1 to match the number of rows in user_scores

# Step 3: Ensure both u1 and user_scores are binary (logical values, 0 or 1)
u1 = u1.astype(bool)

# Step 4: Compute the F1-Score for each of the 15 datasets (columns in user_scores)
f1_scores = []  # List to store F1 scores for each dataset

for i in range(user_scores.shape[1]):  # Loop through the 15 columns
    u2 = user_scores[:, i]  # Extract the i-th column (ground truth labels for the i-th dataset)
    
    # Ensure u2 is a boolean array
    u2 = u2.astype(bool)
    
    # Step 5: Compute the confusion matrix
    cm = confusion_matrix(u2, u1)
    
    # Extract the confusion matrix components
    tn, fp, fn, tp = cm.ravel()  # Unpack the confusion matrix
    
    # Debugging step: Print confusion matrix for the 4th column
    if i == 3:  # Checking the 4th column
        print(f"Confusion Matrix for user_score column {i+1} (4th column):")
        print(f"TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")
    
    # Check for zero denominators and calculate Precision, Recall, and F1-Score safely
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    
    # F1 Score is calculated if both precision and recall are non-zero, otherwise it's 0 or nan
    if precision + recall > 0:
        fscore = 2 * (precision * recall) / (precision + recall)
    else:
        fscore = 0.0  # F1 score is 0 if either precision or recall is zero
    
    f1_scores.append(fscore)  # Append F1 score for this dataset
    
    # Print the F1 Score for this dataset
    print(f"\nF1-Score for user_score column {i+1}: {fscore:.4f}")

# Step 6: Output all the F1 scores for the 15 datasets
print("\nAll F1 Scores:")
for i, score in enumerate(f1_scores, 1):
    print(f"F1 Score for user_score column {i}: {score:.4f}")
# Out:
# Keys in the .mat file: dict_keys(['__header__', '__version__', '__globals__', 'all_userIDs', 'segments', 'nFrames', 'video_duration', 'FPS', 'gt_score', 'user_score'])
# Shape of user_score: (5131, 15)
# Shape of model's predictions (u1): (3951640,)
# Warning: Mismatched lengths. Adjusting the data...
#
# F1-Score for user_score column 1: 0.0000
#
# F1-Score for user_score column 2: 0.0000
#
# F1-Score for user_score column 3: 0.0724
# Confusion Matrix for user_score column 4 (4th column):
# TN: 3607, FP: 770, FN: 754, TP: 0
#
# F1-Score for user_score column 4: 0.0000
#
# F1-Score for user_score column 5: 0.1242
#
# F1-Score for user_score column 6: 0.0000
#
# F1-Score for user_score column 7: 0.1043
#
# F1-Score for user_score column 8: 0.0000
#
# F1-Score for user_score column 9: 0.0000
#
# F1-Score for user_score column 10: 0.0117
#
# F1-Score for user_score column 11: 0.0000
#
# F1-Score for user_score column 12: 0.0000
#
# F1-Score for user_score column 13: 0.0000
#
# F1-Score for user_score column 14: 0.1272
#
# F1-Score for user_score column 15: 0.0000
#
# All F1 Scores:
# F1 Score for user_score column 1: 0.0000
# F1 Score for user_score column 2: 0.0000
# F1 Score for user_score column 3: 0.0724
# F1 Score for user_score column 4: 0.0000
# F1 Score for user_score column 5: 0.1242
# F1 Score for user_score column 6: 0.0000
# F1 Score for user_score column 7: 0.1043
# F1 Score for user_score column 8: 0.0000
# F1 Score for user_score column 9: 0.0000
# F1 Score for user_score column 10: 0.0117
# F1 Score for user_score column 11: 0.0000
# F1 Score for user_score column 12: 0.0000
# F1 Score for user_score column 13: 0.0000
# F1 Score for user_score column 14: 0.1272
# F1 Score for user_score column 15: 0.0000
