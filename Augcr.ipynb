# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os

# %%
import cv2 
import os

# %%
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def dataset_train_processing():
    # Hardcode dataset path
    data_path =r'C:\SumMe\Frame\Car rail crossing'
    augmented_data_path = r'C:\SumMe\Augmentation\Augcr\Aug'
    
    # Create the directory for augmented data if it doesn't exist
    if not os.path.exists(augmented_data_path):
        os.makedirs(augmented_data_path)
    
    # Process dataset
    file_names = os.listdir(data_path)
    
    # Set a datagenerator for augmentation
    train_datagen = ImageDataGenerator(rotation_range=15,
                                       shear_range=0.1,
                                       zoom_range=0.2,
                                       horizontal_flip=True,
                                       width_shift_range=0.1,
                                       height_shift_range=0.1)
    
    # Create batches of data for augmentation
    for file_name in file_names:
        image_path = os.path.join(data_path, file_name)
        img = plt.imread(image_path)
        img = img.reshape((1,) + img.shape)  # Reshape to add batch dimension
        
        # Flow the image through the generator and save augmented images
        i = 0
        for batch in train_datagen.flow(img, 
                                        batch_size=1,
                                        save_to_dir=augmented_data_path,
                                        save_prefix=f'aug_{os.path.splitext(file_name)[0]}',
                                        save_format='jpeg'):
            i += 1
            if i >= 1:  # Save 2 augmented versions of each image
                break
    
    # Sample visualization of augmented images (optional)
    example_gen = train_datagen.flow_from_directory(data_path,
                                                    target_size=(224, 224),
                                                    batch_size=1,
                                                    class_mode=None,
                                                    save_to_dir=augmented_data_path,
                                                    save_prefix='aug_example',
                                                    save_format='jpg')
    
    plt.figure(figsize=(12, 12))
    for i in range(0, 15):
        plt.subplot(5, 3, i + 1)
        for X in example_gen:
            image = X[0]
            plt.imshow(image)
            break
    plt.tight_layout()
    plt.show()

# Usage
dataset_train_processing()
# Out:
# Found 0 images belonging to 0 classes.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 58
#      55     plt.show()
#      57 # Usage
# ---> 58 dataset_train_processing()
#
# Cell In[5], line 51, in dataset_train_processing()
#      49 plt.subplot(5, 3, i + 1)
#      50 for X in example_gen:
# ---> 51     image = X[0]
#      52     plt.imshow(image)
#      53     break
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np
import os

# Load the InceptionV3 model
net = InceptionV3(include_top=True, weights='imagenet')
net.summary()

# Load images from directory using ImageDataGenerator
image_directory = r'C:\SumMe\Augmentation\Augcr'
input_size = net.input_shape[1:3]  # Get the input size (height, width)

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# Create a data generator for the images
augimds = datagen.flow_from_directory(image_directory,
                                      target_size=input_size,
                                      batch_size=32,  # Adjust the batch size if needed
                                      class_mode=None,
                                      shuffle=False) 

# Create a model that outputs the activations from the specified layer
layer_name = 'predictions'  # Example layer name in InceptionV3 (change as needed)
intermediate_layer_model = tf.keras.Model(inputs=net.input,
                                          outputs=net.get_layer(layer_name).output)

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Reshape the features to ensure they are in 'rows' format (2D)
features_train = features_train.reshape(features_train.shape[0], -1)
np.save(os.path.join(image_directory, 'inceptionv3_features_train.npy'), features_train)

print(f"Features shape: {features_train.shape}")

# Print some sample features
print("Sample features (first 5 rows):")
print(features_train[:5])
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_59[0][0]']
# ...
#  conv2d_77 (Conv2D)             (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 8, 8, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,851,784
# Trainable params: 23,817,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# Found 5075 images belonging to 1 classes.
# 159/159 [==============================] - 719s 4s/step
# Features shape: (5075, 1000)
# Sample features (first 5 rows):
# [[2.1453672e-05 3.4899913e-05 2.5161353e-05 ... 1.5615786e-05
#   3.3358596e-05 5.6121451e-05]
#  [7.0300548e-06 1.2199911e-05 1.7378756e-05 ... 1.0794843e-05
#   3.3983924e-05 1.0714534e-05]
#  [2.2121920e-05 7.4179050e-05 9.0655281e-05 ... 2.7656621e-05
#   2.6221309e-04 7.4222851e-05]
#  [7.9839818e-05 1.2267419e-04 1.0992245e-04 ... 1.7775080e-04
#   3.0785750e-04 8.3160892e-05]
#  [3.2648848e-05 3.8609374e-05 4.4895038e-05 ... 1.8831015e-05
#   2.4910155e-04 2.6798312e-05]]

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import os


# Load the ResNet50 model
net = ResNet50(include_top=True, weights='imagenet')
net.summary()

# Load images from directory using ImageDataGenerator
image_directory = r'C:\SumMe\Augmentation\Augcr'
input_size = net.input_shape[1:3]  # Get the input size (height, width)

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# Create a data generator for the images
augimds = datagen.flow_from_directory(image_directory,
                                      target_size=input_size,
                                      batch_size=32,  # Adjust the batch size if needed
                                      class_mode=None,
                                      shuffle=False) 

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Create a model that outputs the activations from the specified layer
layer_name = 'predictions'  # Example layer name in ResNet50
intermediate_layer_model = tf.keras.Model(inputs=net.input,
                                          outputs=net.get_layer(layer_name).output)

# Generate activations
features_train = intermediate_layer_model.predict(augimds)
# Reshape the features to ensure they are in 'rows' format (2D)
features_train = features_train.reshape(features_train.shape[0], -1)
np.save(os.path.join(image_directory, 'resnet50_features_train.npy'), features_train)


print(f"Features shape: {features_train.shape}")

# Print some sample features
print("Sample features (first 5 rows):")
print(features_train[:5])
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Found 5075 images belonging to 1 classes.
# 159/159 [==============================] - 442s 3s/step
# 159/159 [==============================] - 1262s 8s/step
# Features shape: (5075, 1000)
# Sample features (first 5 rows):
# [[2.2658041e-07 3.1640269e-07 1.0179759e-05 ... 1.7976619e-08
#   2.2266379e-07 4.3145408e-07]
#  [2.1812534e-06 4.8280422e-06 5.3343178e-06 ... 1.6050018e-07
#   3.8909266e-06 6.2920735e-06]
#  [2.3014788e-06 3.1351123e-05 4.1511430e-05 ... 2.3621436e-07
#   1.1132521e-05 4.8035952e-05]
#  [1.3838034e-07 1.7358283e-06 2.5176889e-06 ... 7.0225859e-08
#   8.5001011e-06 2.0356818e-05]
#  [1.3547240e-06 1.3390144e-05 5.6655281e-06 ... 2.4045502e-07
#   2.1330134e-05 5.5543973e-05]]

# %%
import numpy as np
import os

# Define the directory where your features are saved
image_directory = r'C:\SumMe\Augmentation\Augcr'

# Load the features from the saved .npy files
features_resnet = np.load(os.path.join(image_directory, 'resnet50_features_train.npy'))
features_inceptionv3 = np.load(os.path.join(image_directory, 'inceptionv3_features_train.npy'))

# Ensure both feature arrays have the same number of samples
assert features_resnet.shape[0] == features_inceptionv3.shape[0], "Number of samples must be the same in both feature arrays."

# Concatenate the features along the feature dimension (axis=1)
features_combined = np.concatenate((features_resnet, features_inceptionv3), axis=1)

# Save the combined features to a new .npy file
np.save(os.path.join(image_directory, 'combined_features_train.npy'), features_combined)

print(f"Combined features shape: {features_combined.shape}")

# Print some sample combined features
print("Sample combined features (first 5 rows):")
print(features_combined[:5])
# Out:
# Combined features shape: (5075, 2000)
# Sample combined features (first 5 rows):
# [[2.2658041e-07 3.1640269e-07 1.0179759e-05 ... 1.5615786e-05
#   3.3358596e-05 5.6121451e-05]
#  [2.1812534e-06 4.8280422e-06 5.3343178e-06 ... 1.0794843e-05
#   3.3983924e-05 1.0714534e-05]
#  [2.3014788e-06 3.1351123e-05 4.1511430e-05 ... 2.7656621e-05
#   2.6221309e-04 7.4222851e-05]
#  [1.3838034e-07 1.7358283e-06 2.5176889e-06 ... 1.7775080e-04
#   3.0785750e-04 8.3160892e-05]
#  [1.3547240e-06 1.3390144e-05 5.6655281e-06 ... 1.8831015e-05
#   2.4910155e-04 2.6798312e-05]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input

# Define the directory where your features are saved
image_directory = r'C:\SumMe\Augmentation\Augcr'

# Load the features from the saved .npy files
features_combined = np.load(os.path.join(image_directory, 'combined_features_train.npy'))

# Define the number of timesteps (sequence length) and features
timesteps = 1  # Assuming each sample is treated as a sequence of length 1 for this example
input_dim = features_combined.shape[1]  # Should be 2000

# Prepare data for LSTM
# For this example, we'll use the features directly as sequences of length 1
X = features_combined
y = np.random.randint(0, 100, size=(features_combined.shape[0],))  # Example target variable, replace with your actual labels

# Reshape input to be [samples, timesteps, features]
X = X.reshape((X.shape[0], timesteps, input_dim))

# Define the LSTM model
inputs = Input(shape=(timesteps, input_dim))

# Add LSTM layers
x = LSTM(64, return_sequences=True)(inputs)
x = Dropout(0.5)(x)

x = LSTM(128, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(256, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(256, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(128, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(64, return_sequences=True)(x)
x = Dropout(0.5)(x)

x = LSTM(32)(x)
x = Dropout(0.5)(x)

# Add a Dense layer for output
outputs = Dense(100, activation='softmax')(x)  # Adjust the number of units based on your specific task

# Create the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
# For this example, we use dummy targets. Replace y with your actual labels.
model.fit(X, y, epochs=20, batch_size=32, validation_split=0.2)

# Extract features from the last LSTM layer
feature_extractor = Model(inputs=model.input, outputs=model.layers[-3].output)  # Layer before the final Dense layer

# Obtain features from the last LSTM layer
features_last_lstm = feature_extractor.predict(X)

# Save the extracted features
np.save(os.path.join(image_directory, 'features_last_lstm.npy'), features_last_lstm)

# Print the feature shape
print(f"Shape of features extracted from the last LSTM layer: {features_last_lstm.shape}")

# Print some sample features
print("Sample features from the last LSTM layer (first 5 samples):")
print(features_last_lstm[:5])
# Out:
# Epoch 1/20
# 127/127 [==============================] - 60s 147ms/step - loss: 4.6051 - accuracy: 0.0108 - val_loss: 4.6054 - val_accuracy: 0.0099
# Epoch 2/20
# 127/127 [==============================] - 9s 73ms/step - loss: 4.6033 - accuracy: 0.0135 - val_loss: 4.6057 - val_accuracy: 0.0099
# Epoch 3/20
# 127/127 [==============================] - 9s 73ms/step - loss: 4.6015 - accuracy: 0.0131 - val_loss: 4.6071 - val_accuracy: 0.0099
# Epoch 4/20
# 127/127 [==============================] - 9s 72ms/step - loss: 4.5987 - accuracy: 0.0123 - val_loss: 4.6111 - val_accuracy: 0.0099
# Epoch 5/20
# 127/127 [==============================] - 9s 71ms/step - loss: 4.5987 - accuracy: 0.0135 - val_loss: 4.6101 - val_accuracy: 0.0099
# Epoch 6/20
# 127/127 [==============================] - 9s 73ms/step - loss: 4.5977 - accuracy: 0.0140 - val_loss: 4.6118 - val_accuracy: 0.0099
# Epoch 7/20
# 127/127 [==============================] - 9s 74ms/step - loss: 4.5945 - accuracy: 0.0121 - val_loss: 4.6154 - val_accuracy: 0.0099
# Epoch 8/20
# 127/127 [==============================] - 9s 74ms/step - loss: 4.5928 - accuracy: 0.0118 - val_loss: 4.6142 - val_accuracy: 0.0099
#   -1.25946447e-01 -8.80326033e-02 -1.52152687e-01  8.17434266e-02
#    2.03407202e-02  7.49817863e-02 -7.61308149e-02  1.01997808e-01
#    1.61456347e-01 -6.64275885e-02  5.98757081e-02 -1.18710048e-01
#    9.00142128e-04 -5.35150059e-02  1.03325851e-01  3.80574577e-02]
#  [-1.50153309e-03 -2.07068329e-03  1.43478038e-02 -2.13986281e-02
#   -6.78766053e-03  2.27302257e-02  1.03524495e-02 -3.30741778e-02
#   -8.07674043e-03  8.24275333e-03 -6.40482688e-03  3.13503481e-03
#    1.94533560e-02 -1.39355415e-03  6.42229058e-03 -1.19178544e-03
#   -7.95715395e-03 -5.00660855e-03 -1.48428511e-02  2.67736167e-02
#   -6.94462052e-03 -3.65771353e-02 -1.79968588e-02  1.24477223e-02
#    7.50697963e-03 -1.96000998e-04 -1.62996782e-03  1.73597094e-02
#    1.55037967e-02  1.66783668e-02  2.45189555e-02 -6.08503073e-03]
#  [ 4.64938618e-02 -5.27721867e-02  5.53522594e-02 -6.83719590e-02
#   -3.27401571e-02 -5.07409405e-03  2.84538325e-03  2.92332601e-02
#    8.41062963e-02 -4.58854735e-02  1.49637805e-02  3.87443304e-02
#    8.18357021e-02  4.16446030e-02 -2.09180433e-02 -1.30698849e-02
#   -1.08348742e-01 -6.83926791e-02 -1.04632206e-01  6.41505569e-02
#    1.61337070e-02  5.08719906e-02 -6.50700256e-02  8.97884667e-02
#    1.06823638e-01 -4.96605970e-02  4.77142185e-02 -8.33945423e-02
#    5.73961297e-03 -3.50374132e-02  8.39200169e-02  2.92422846e-02]
#  [ 2.23569684e-02 -2.49830522e-02  3.57640013e-02 -4.46161367e-02
#   -1.68964639e-02  8.61732941e-03  9.40737128e-03 -4.57868166e-03
#    3.67092602e-02 -1.84491724e-02 -4.42743803e-05  2.02363823e-02
#    4.95092943e-02  2.13411413e-02 -5.34852268e-03 -5.34651009e-03
#   -5.82719892e-02 -3.20358351e-02 -4.61574458e-02  4.04580683e-02
#    4.19016089e-03  2.45868624e-03 -4.05959524e-02  5.27250767e-02
#    4.16201875e-02 -2.15592999e-02  2.07933225e-02 -2.45882235e-02
#    1.14002964e-02 -5.09356847e-03  4.95360531e-02  9.74573102e-03]]

# %%
import numpy as np
from sklearn.cluster import KMeans

# Load data (assuming the data is saved in a numpy array .npy file)
# Replace the path with the actual location of your data file
F = np.load(r"C:\SumMe\Augmentation\Augcr\features_last_lstm.npy")  # Adjust this path if necessary

# Set parameters
N = 761
np.random.seed(2)  # Setting the random seed for reproducibility

# Perform k-means clustering
kmeans = KMeans(n_clusters=N, init='k-means++', random_state=2)
kmeans.fit(F)

# Get cluster assignments (C_IDX) and cluster centroids (CC)
C_IDX = kmeans.labels_
CC = kmeans.cluster_centers_

# Initialize list to store indices of data points in each cluster
C = {i: np.where(C_IDX == i)[0] for i in range(N)}

# C now contains the indices of data points in each cluster

# %%
# Print the actual data points in the first cluster (cluster 0)
cluster_0_data_points = F[C[0], :]
print(cluster_0_data_points)
# Out:
#    0.10419059  0.03838842]
#  [ 0.05686045 -0.06643813  0.06211631 -0.0775226  -0.04456481 -0.00886166
#   -0.00674896  0.04875756  0.10185114 -0.05589659  0.03021626  0.04664483
#    0.09693444  0.04637552 -0.02982401 -0.02003265 -0.12646078 -0.08879069
#   -0.15446065  0.08257509  0.02044877  0.07589372 -0.07651902  0.10235148
#    0.16411823 -0.06715883  0.06026607 -0.12020752  0.0006232  -0.05433401
#    0.10408878  0.03834562]
#  [ 0.05684749 -0.06642133  0.06210907 -0.07751113 -0.04454508 -0.00885895
#   -0.00673052  0.04872602  0.1018329  -0.05588491  0.03018853  0.0466351
#    0.09691621  0.04637355 -0.02981039 -0.02001922 -0.12644161 -0.08876173
#   -0.1543712   0.08254106  0.02044613  0.07585784 -0.0765031   0.10233775
#    0.16401502 -0.06713085  0.06025196 -0.12015069  0.00063205 -0.0543026
#    0.10405894  0.03833577]]

# %%
# Print all the indices and their corresponding cluster values
for cluster_idx in range(N):
    print(f"Cluster {cluster_idx}:")
    print("Indices of data points:", C[cluster_idx])
    print("Number of data points in this cluster:", len(C[cluster_idx]))
    print()
# Out:
# Cluster 0:
# Indices of data points: [  83 1025 1892 2161 2169 2212 2448 2641 4215]
# Number of data points in this cluster: 9
#
# Cluster 1:
# Indices of data points: [ 219 1691 1772 2669 2856 2883]
# Number of data points in this cluster: 6
#
# Cluster 2:
# Indices of data points: [ 732 1608 1829 2178 2757 3132]
# Number of data points in this cluster: 6
#
# Cluster 3:
# Indices of data points: [3141 3857 4075]
# Number of data points in this cluster: 3
#
# Cluster 4:
# Indices of data points: [ 714  882 1047 1444 1733 1845 2032 2416 3249 3460 3621 3664 4021 4178]
# Number of data points in this cluster: 14
#
# Cluster 5:
# Indices of data points: [1393 2327 2792 4697]
# Number of data points in this cluster: 4
#
# Cluster 6:
# Indices of data points: [2564 2828 3130 4090 4723]
# Number of data points in this cluster: 5
#
# Cluster 7:
# Indices of data points: [  57  185 1085 2089 2576 3052 3426 4297 4782]
# Number of data points in this cluster: 9
#
# Cluster 8:
# Indices of data points: [  68  310  358  674  938 1123 1228 1602 1721 3846 4231 4579 5039]
# Number of data points in this cluster: 13
#
# Cluster 9:
# Indices of data points: [1817]
# Number of data points in this cluster: 1
#
# Cluster 10:
# Indices of data points: [ 131 2827 4205 5062]
# Number of data points in this cluster: 4
#
# Cluster 11:
# Indices of data points: [2359 2834 4074 4219]
# Number of data points in this cluster: 4
#
# Cluster 12:
# Indices of data points: [3152 3879]
# Number of data points in this cluster: 2
#
# Cluster 13:
# Indices of data points: [ 750  830 1062 1187 1286 1351 1649 2570 3336 3447 3514 3562 3575 3899
#  4132 4388 4563 4728 4982 5038]
# Number of data points in this cluster: 20
#
# Cluster 14:
# Indices of data points: [1816 2475 2522 4480 4568]
# Number of data points in this cluster: 5
#
# Cluster 15:
# Indices of data points: [1448 1527 2583 2889 2907 3015]
# Number of data points in this cluster: 6
#
# Cluster 16:
# Indices of data points: [ 765 1112 3401 3801 4621]
# Number of data points in this cluster: 5
#
# Cluster 17:
# Indices of data points: [ 441 1115 1894 2346 2374 2965]
# Number of data points in this cluster: 6
#
# Cluster 18:
# Indices of data points: [ 180 1366 2274 2280 3747 4194 4947]
# Number of data points in this cluster: 7
#
# Cluster 19:
# Indices of data points: [ 536 3425 3756 4184]
# Number of data points in this cluster: 4
#
# Cluster 20:
# Indices of data points: [2302 3301 4441 4787]
# Number of data points in this cluster: 4
#
# Cluster 21:
# Indices of data points: [1328 2552 3198 3985 4598]
# Number of data points in this cluster: 5
#
# Cluster 22:
# Indices of data points: [ 329  345  596 1270 2051 2450 3121 4403 4525 4629]
# Number of data points in this cluster: 10
#
# Cluster 23:
# Indices of data points: [  30   65  261  642  700 1566 1900 2646 2697 2835 3144 3326 3775 3806
#  4268 4508 4687 5068]
# Number of data points in this cluster: 18
#
# Cluster 24:
# Indices of data points: [  59  234  546  837  963 1665 2028 2255 2449 2451 2660 3542 3710 3938]
# Number of data points in this cluster: 14
#
# Cluster 25:
# Indices of data points: [ 926 2228 4633]
# Number of data points in this cluster: 3
#
# Cluster 26:
# Indices of data points: [1758 2365 2379 3627]
# Number of data points in this cluster: 4
#
# Cluster 27:
# Indices of data points: [1715 2398 2900 3133 3706 4366]
# Number of data points in this cluster: 6
#
# Cluster 28:
# Indices of data points: [4100]
# Number of data points in this cluster: 1
#
# Cluster 29:
# Indices of data points: [ 588  670  784 1133 1275 1876 2285 2875 3053 4417 4459 4954 4975]
# Number of data points in this cluster: 13
#
# Cluster 30:
# Indices of data points: [ 197  238  845 1272 1370 2086 2124 2195 2558 2711 2713 2767 3717 4282]
# Number of data points in this cluster: 14
#
# Cluster 31:
# Indices of data points: [2091 3701 3953 4970 4978]
# Number of data points in this cluster: 5
#
# Cluster 32:
# Indices of data points: [1205 1439 1478 1506 1824 2528 2725 2866 3783 4779]
# Number of data points in this cluster: 10
#
# Cluster 33:
# Indices of data points: [ 302 2322 5016]
# Number of data points in this cluster: 3
#
# Cluster 34:
# Indices of data points: [1839 1939 2323 3479 3684 4792 4967]
# Number of data points in this cluster: 7
#
# Cluster 35:
# Indices of data points: [1619 1825 3331]
# Number of data points in this cluster: 3
#
# Cluster 36:
# Indices of data points: [ 747 1653 1734 3413]
# Number of data points in this cluster: 4
#
# Cluster 37:
# Indices of data points: [ 619 1795 1808 2119 3883]
# Number of data points in this cluster: 5
#
# Cluster 38:
# Indices of data points: [ 600  887 1163 4689 4806]
# Number of data points in this cluster: 5
#
# Cluster 39:
# Indices of data points: [ 590 1830 1998 2772]
# Number of data points in this cluster: 4
#
# Cluster 40:
# Indices of data points: [ 902 1842 4188 4195 4932]
# Number of data points in this cluster: 5
#
# Cluster 41:
# Indices of data points: [ 160 1467 4131]
# Number of data points in this cluster: 3
#
# Cluster 42:
# Indices of data points: [ 501 2291 4277 4710 5070]
# Number of data points in this cluster: 5
#
# Cluster 43:
# Indices of data points: [ 164 1778 2335]
# Number of data points in this cluster: 3
#
# Cluster 44:
# Indices of data points: [ 366  568 1570 1614 1722 1755 1791 2024 3590 4285 4347 4352 4769 4881]
# Number of data points in this cluster: 14
#
# Cluster 45:
# Indices of data points: [ 618  738  808 4010 4692]
# Number of data points in this cluster: 5
#
# Cluster 46:
# Indices of data points: [ 731 1499 3677 3916 4442]
# Number of data points in this cluster: 5
#
# Cluster 47:
# Indices of data points: [  61  400  828  941 1149 1236 1282 2107 2510 3553 3931 4182 4245 4501
#  4626 4750]
# Number of data points in this cluster: 16
#
# Cluster 48:
# Indices of data points: [1775 3230 3850 4085 4258]
# Number of data points in this cluster: 5
#
# Cluster 49:
# Indices of data points: [ 149  755  811 1258 1666 2146 2180 2424 2491 2985 3011 3051 3190 3256
#  4478]
# Number of data points in this cluster: 15
#
# Cluster 50:
# Indices of data points: [  89 2117 3734]
# Number of data points in this cluster: 3
#
# Cluster 51:
# Indices of data points: [1815 2585 4394]
# Number of data points in this cluster: 3
#
# Cluster 52:
# Indices of data points: [1137 1792 2996 4046 4603 5048]
# Number of data points in this cluster: 6
#
# Cluster 53:
# Indices of data points: [1150 1386 1400 1674 1918 2058 2483 2513 2559 2632 2928 3044 3180]
# Number of data points in this cluster: 13
#
# Cluster 54:
# Indices of data points: [ 446  475  537  629  920 1989 2457 2678 2783 2815 3111 3242 4619 4752]
# Number of data points in this cluster: 14
#
# Cluster 55:
# Indices of data points: [2219 3788 3905 4854]
# Number of data points in this cluster: 4
#
# Cluster 56:
# Indices of data points: [ 661 1714 1731 1942 4361]
# Number of data points in this cluster: 5
#
# Cluster 57:
# Indices of data points: [  48  876 1136 1260 1477 1926 4062 4173 4910]
# Number of data points in this cluster: 9
#
# Cluster 58:
# Indices of data points: [ 655 1325 1738 2030 2695 2932 4087 4308 4835]
# Number of data points in this cluster: 9
#
# Cluster 59:
# Indices of data points: [ 362 2314 4316 4370]
# Number of data points in this cluster: 4
#
# Cluster 60:
# Indices of data points: [ 879 1561 2334 2839 4776 5043]
# Number of data points in this cluster: 6
#
# Cluster 61:
# Indices of data points: [ 455  549  675 1261 1931 2013 2242 2496 2648 3154 3981 4014 4663 4976]
# Number of data points in this cluster: 14
#
# Cluster 62:
# Indices of data points: [1481 2019 3314 3988 4369]
# Number of data points in this cluster: 5
#
# Cluster 63:
# Indices of data points: [ 771 1107 1178 1983 3955]
# Number of data points in this cluster: 5
#
# Cluster 64:
# Indices of data points: [3612 4341 4931]
# Number of data points in this cluster: 3
#
# Cluster 65:
# Indices of data points: [4110 4200 4724]
# Number of data points in this cluster: 3
#
# Cluster 66:
# Indices of data points: [1533 3873 4089]
# Number of data points in this cluster: 3
#
# Cluster 67:
# Indices of data points: [2478 2910 3563]
# Number of data points in this cluster: 3
#
# Cluster 68:
# Indices of data points: [1642 4648]
# Number of data points in this cluster: 2
#
# Cluster 69:
# Indices of data points: [1521 2187 4024]
# Number of data points in this cluster: 3
#
# Cluster 70:
# Indices of data points: [  80  367  514  703  781 1070 1290 1312 1473 2154 2595 2852 2938 3224
#  3765 3804 4342 4485 4915]
# Number of data points in this cluster: 19
#
# Cluster 71:
# Indices of data points: [ 666 1623 1841 1910 2049]
# Number of data points in this cluster: 5
#
# Cluster 72:
# Indices of data points: [1503 1719 3505 3864 3870 4192 4199]
# Number of data points in this cluster: 7
#
# Cluster 73:
# Indices of data points: [2596 3541 3593]
# Number of data points in this cluster: 3
#
# Cluster 74:
# Indices of data points: [1801 2533 3499]
# Number of data points in this cluster: 3
#
# Cluster 75:
# Indices of data points: [3057 3816 4098]
# Number of data points in this cluster: 3
#
# Cluster 76:
# Indices of data points: [ 305  927 1531 1585 1745 4128 4395 4396 4489]
# Number of data points in this cluster: 9
#
# Cluster 77:
# Indices of data points: [ 691  930 4445]
# Number of data points in this cluster: 3
#
# Cluster 78:
# Indices of data points: [ 312  350  531 1427 1575]
# Number of data points in this cluster: 5
#
# Cluster 79:
# Indices of data points: [ 166  181  347  850  946  954 1177 1898 2364 2407 2630 2936 2943 3422
#  3743 4606 4735 4747 4764]
# Number of data points in this cluster: 19
#
# Cluster 80:
# Indices of data points: [ 172  435  683  720 1655 2742 2786 3226 3378 3432 4148 4819 4831]
# Number of data points in this cluster: 13
#
# Cluster 81:
# Indices of data points: [1519 1565 3370 3409 4026 4367]
# Number of data points in this cluster: 6
#
# Cluster 82:
# Indices of data points: [ 279  450  598  960 1175 2160 2809 2898 3560 4558]
# Number of data points in this cluster: 10
#
# Cluster 83:
# Indices of data points: [ 403  544  853 1237 2081 2143 3753 3912 4224 4304 4601 4994]
# Number of data points in this cluster: 12
#
# Cluster 84:
# Indices of data points: [ 258 2376 4980]
# Number of data points in this cluster: 3
#
# Cluster 85:
# Indices of data points: [  79  257 1630 1767 4125 4537]
# Number of data points in this cluster: 6
#
# Cluster 86:
# Indices of data points: [ 545  663 1453 1919 2136 3375 3382 3592 4127]
# Number of data points in this cluster: 9
#
# Cluster 87:
# Indices of data points: [  96  222  287  678 1032 2428 2465 2627 2686 3166 3332 3551 3581 3714
#  4151 4283 4339 4534 4600]
# Number of data points in this cluster: 19
#
# Cluster 88:
# Indices of data points: [  91  522 1887 2672 3114 3623 3844 4610 4668 4714 4765 4795]
# Number of data points in this cluster: 12
#
# Cluster 89:
# Indices of data points: [1840 1872 3258 3694 4333 4518 4861]
# Number of data points in this cluster: 7
#
# Cluster 90:
# Indices of data points: [2367 2517 2520 4817]
# Number of data points in this cluster: 4
#
# Cluster 91:
# Indices of data points: [ 190  378 1069 1257 2130 2311 2543 2566 2574 2902 3041 3245 4140]
# Number of data points in this cluster: 13
#
# Cluster 92:
# Indices of data points: [ 298 1730 3469]
# Number of data points in this cluster: 3
#
# Cluster 93:
# Indices of data points: [ 999 1372 4778]
# Number of data points in this cluster: 3
#
# Cluster 94:
# Indices of data points: [ 250  409  880 1229 1410 1530 2182 2375 2732 3235 3697 4338 4387 4476
#  4913 5051]
# Number of data points in this cluster: 16
#
# Cluster 95:
# Indices of data points: [ 606 1040 1542 2468 3131 3473 3887 4754 4768]
# Number of data points in this cluster: 9
#
# Cluster 96:
# Indices of data points: [1414 1701 1916]
# Number of data points in this cluster: 3
#
# Cluster 97:
# Indices of data points: [1476 1603 1992 2970 3454 3763 4516]
# Number of data points in this cluster: 7
#
# Cluster 98:
# Indices of data points: [  21  215 1482 2139 4270 5034]
# Number of data points in this cluster: 6
#
# Cluster 99:
# Indices of data points: [ 129  231  597  630 1252 1626 1945 1987 2002 2101 2157 2189 2194 2263
#  2599 3484 3515 4306 4550]
# Number of data points in this cluster: 19
#
# Cluster 100:
# Indices of data points: [1441 1725 2842 3012 3579]
# Number of data points in this cluster: 5
#
# Cluster 101:
# Indices of data points: [1446 1818 2362 3462 4079]
# Number of data points in this cluster: 5
#
# Cluster 102:
# Indices of data points: [ 547 1118 1155 1238 1262 1958 2333 2472 2608 2631 2653 3264 4313 4814]
# Number of data points in this cluster: 14
#
# Cluster 103:
# Indices of data points: [2458]
# Number of data points in this cluster: 1
#
# Cluster 104:
# Indices of data points: [  39  217  356 1382 3962]
# Number of data points in this cluster: 5
#
# Cluster 105:
# Indices of data points: [ 357 1556 2541]
# Number of data points in this cluster: 3
#
# Cluster 106:
# Indices of data points: [  42 3390 4981]
# Number of data points in this cluster: 3
#
# Cluster 107:
# Indices of data points: [  15  284 1592 3296]
# Number of data points in this cluster: 4
#
# Cluster 108:
# Indices of data points: [2736 3059]
# Number of data points in this cluster: 2
#
# Cluster 109:
# Indices of data points: [   0   14   31  551  735 1091 1668 1974 2133 2317 2722 3126 4266 4693]
# Number of data points in this cluster: 14
#
# Cluster 110:
# Indices of data points: [ 820 2679 3100 3260 4452]
# Number of data points in this cluster: 5
#
# Cluster 111:
# Indices of data points: [ 593 1426 2072 2532 3911]
# Number of data points in this cluster: 5
#
# Cluster 112:
# Indices of data points: [ 156  641 1250 1422 1707 2265 2635 3065 3238 3959 4168 4557 4803]
# Number of data points in this cluster: 13
#
# Cluster 113:
# Indices of data points: [5044]
# Number of data points in this cluster: 1
#
# Cluster 114:
# Indices of data points: [ 807 1160 1740 1743 1973 2111 3860 3946 4808]
# Number of data points in this cluster: 9
#
# Cluster 115:
# Indices of data points: [ 919 3719 3894 3954 4522 4887]
# Number of data points in this cluster: 6
#
# Cluster 116:
# Indices of data points: [1875 2325 2358 2801]
# Number of data points in this cluster: 4
#
# Cluster 117:
# Indices of data points: [ 244 1879 2760 3492 3937 4453 4811]
# Number of data points in this cluster: 7
#
# Cluster 118:
# Indices of data points: [ 605 1568 2292 2390 2720 2798 3056 3155 3644 3835 4517 4746]
# Number of data points in this cluster: 12
#
# Cluster 119:
# Indices of data points: [ 339  725 2042 2952 3429 3611 4739]
# Number of data points in this cluster: 7
#
# Cluster 120:
# Indices of data points: [ 759  866  976 1079 1688 2041 2504 2600 3016 3070 3738 4201 4917]
# Number of data points in this cluster: 13
#
# Cluster 121:
# Indices of data points: [ 760 1637 2244 3013 3700 3829 4007]
# Number of data points in this cluster: 7
#
# Cluster 122:
# Indices of data points: [1009 1093 1579 2554 3085 3195 3547 3614 4042 4076]
# Number of data points in this cluster: 10
#
# Cluster 123:
# Indices of data points: [ 186  275  369  585  677 1117 1358 2142 2213 2420 2593 2680 3023 3392
#  4265 4672]
# Number of data points in this cluster: 16
#
# Cluster 124:
# Indices of data points: [2186 3572 3939 4653]
# Number of data points in this cluster: 4
#
# Cluster 125:
# Indices of data points: [1991 2762 3389]
# Number of data points in this cluster: 3
#
# Cluster 126:
# Indices of data points: [ 479 1874 3104 3270 4512]
# Number of data points in this cluster: 5
#
# Cluster 127:
# Indices of data points: [2217 3836]
# Number of data points in this cluster: 2
#
# Cluster 128:
# Indices of data points: [2087 3119 4038]
# Number of data points in this cluster: 3
#
# Cluster 129:
# Indices of data points: [ 608  696 1018 1071 1662 2125 2400 2438 2544 2665 2731 3022 3072 3463
#  3766 3984 4470 4548]
# Number of data points in this cluster: 18
#
# Cluster 130:
# Indices of data points: [ 326  824 2095 2534 2886 3501 3558 3913 4677]
# Number of data points in this cluster: 9
#
# Cluster 131:
# Indices of data points: [1090 1096 2832 3037 4294]
# Number of data points in this cluster: 5
#
# Cluster 132:
# Indices of data points: [2777 4158 4691]
# Number of data points in this cluster: 3
#
# Cluster 133:
# Indices of data points: [2481 3604 3721]
# Number of data points in this cluster: 3
#
# Cluster 134:
# Indices of data points: [1496 1508 2579 4069 4989]
# Number of data points in this cluster: 5
#
# Cluster 135:
# Indices of data points: [ 532  644 1739 2998]
# Number of data points in this cluster: 4
#
# Cluster 136:
# Indices of data points: [ 162  170  396 1536 1629 1885 2371 2531 2820 4271 4761 4916 4956]
# Number of data points in this cluster: 13
#
# Cluster 137:
# Indices of data points: [1724 2614 4753]
# Number of data points in this cluster: 3
#
# Cluster 138:
# Indices of data points: [ 792 1673 1981 3371 3656 4123]
# Number of data points in this cluster: 6
#
# Cluster 139:
# Indices of data points: [ 154 2068 2807 3884 4496]
# Number of data points in this cluster: 5
#
# Cluster 140:
# Indices of data points: [1550 1762 4146 4360 4762]
# Number of data points in this cluster: 5
#
# Cluster 141:
# Indices of data points: [ 247 2350 2969]
# Number of data points in this cluster: 3
#
# Cluster 142:
# Indices of data points: [1726 2673 4143]
# Number of data points in this cluster: 3
#
# Cluster 143:
# Indices of data points: [   5   38  121  313  322  562  617  653  753  988 1315 1397 2201 2404
#  2822 3039 3184 3204 3344 4295 4379 4713 4790 5067]
# Number of data points in this cluster: 24
#
# Cluster 144:
# Indices of data points: [ 106 1033 1387 2210 2644 2662 2884 3424 3769 4204 4618]
# Number of data points in this cluster: 11
#
# Cluster 145:
# Indices of data points: [1771 1851 2968 5024]
# Number of data points in this cluster: 4
#
# Cluster 146:
# Indices of data points: [ 101  404  684  886 1545 2519 2865 3635 4771 5045]
# Number of data points in this cluster: 10
#
# Cluster 147:
# Indices of data points: [ 355  713 1853 2174 2703 3343 4147 4936 5064]
# Number of data points in this cluster: 9
#
# Cluster 148:
# Indices of data points: [1539 1562]
# Number of data points in this cluster: 2
#
# Cluster 149:
# Indices of data points: [  72  205  268  860  964 1078 1124 1287 1326 1464 1490 2460 3399]
# Number of data points in this cluster: 13
#
# Cluster 150:
# Indices of data points: [ 285  303  386  467 1050 2485 2800 3586 3620 3631 3777 3817 4755 4846
#  4986 5047]
# Number of data points in this cluster: 16
#
# Cluster 151:
# Indices of data points: [ 654 1515 1870 4027]
# Number of data points in this cluster: 4
#
# Cluster 152:
# Indices of data points: [2315 3600 3815 3823]
# Number of data points in this cluster: 4
#
# Cluster 153:
# Indices of data points: [ 940 1376 1526 1978 2298 2781 3005 3129 3210 3524]
# Number of data points in this cluster: 10
#
# Cluster 154:
# Indices of data points: [ 158  293  453 1265 1483 1882 1902 2414 2634 3188 4176]
# Number of data points in this cluster: 11
#
# Cluster 155:
# Indices of data points: [4375]
# Number of data points in this cluster: 1
#
# Cluster 156:
# Indices of data points: [4551 4575]
# Number of data points in this cluster: 2
#
# Cluster 157:
# Indices of data points: [1560 3165 3539 3772]
# Number of data points in this cluster: 4
#
# Cluster 158:
# Indices of data points: [ 167  251 2109 2239 2433 3936 4336 4460 4924]
# Number of data points in this cluster: 9
#
# Cluster 159:
# Indices of data points: [  95  405  709  742 1017 1020 1030 1144 1197 1997 2185 3038 3417 3508
#  3534 3646 4798]
# Number of data points in this cluster: 17
#
# Cluster 160:
# Indices of data points: [ 734 1420 1807 2329]
# Number of data points in this cluster: 4
#
# Cluster 161:
# Indices of data points: [ 440  474 1056 3702 4005 4211]
# Number of data points in this cluster: 6
#
# Cluster 162:
# Indices of data points: [ 114 1495 2885 3851]
# Number of data points in this cluster: 4
#
# Cluster 163:
# Indices of data points: [ 580 2303]
# Number of data points in this cluster: 2
#
# Cluster 164:
# Indices of data points: [ 399  436 1006 1323 1820 4122 4263 4743]
# Number of data points in this cluster: 8
#
# Cluster 165:
# Indices of data points: [3049 3930 3948]
# Number of data points in this cluster: 3
#
# Cluster 166:
# Indices of data points: [1785 3328 3711 4040 4137]
# Number of data points in this cluster: 5
#
# Cluster 167:
# Indices of data points: [ 752 1028 1457 1692 3087]
# Number of data points in this cluster: 5
#
# Cluster 168:
# Indices of data points: [ 176  269  433  971 1647 2249 2935 3048 3229 4564 4686 4788]
# Number of data points in this cluster: 12
#
# Cluster 169:
# Indices of data points: [1925 3145 4077]
# Number of data points in this cluster: 3
#
# Cluster 170:
# Indices of data points: [1671 2874 4701]
# Number of data points in this cluster: 3
#
# Cluster 171:
# Indices of data points: [2872 3810 4141]
# Number of data points in this cluster: 3
#
# Cluster 172:
# Indices of data points: [  63  113  490 1274 1324 1413 1583 1723 1886 2373 2505 2937 2973 3329
#  3530 3538 3872 4509 4879 5022]
# Number of data points in this cluster: 20
#
# Cluster 173:
# Indices of data points: [ 565 2229 3570 4670]
# Number of data points in this cluster: 4
#
# Cluster 174:
# Indices of data points: [2719 4012 4780]
# Number of data points in this cluster: 3
#
# Cluster 175:
# Indices of data points: [  13  774 1749 1977 2126 3809]
# Number of data points in this cluster: 6
#
# Cluster 176:
# Indices of data points: [ 682 1082 2471 3980]
# Number of data points in this cluster: 4
#
# Cluster 177:
# Indices of data points: [2571 3149 4153 4278]
# Number of data points in this cluster: 4
#
# Cluster 178:
# Indices of data points: [2394 3918]
# Number of data points in this cluster: 2
#
# Cluster 179:
# Indices of data points: [ 480  839  932 1463 4145 4327 5014]
# Number of data points in this cluster: 7
#
# Cluster 180:
# Indices of data points: [ 138  203  477  581 1074 2426 2462 2947 3209 3228 3728 4220 4472 4909
#  4914 4985]
# Number of data points in this cluster: 16
#
# Cluster 181:
# Indices of data points: [2277 2843 3359 3360 3791 3902]
# Number of data points in this cluster: 6
#
# Cluster 182:
# Indices of data points: [ 281  408  471  898  997 1240 1278 1644 1650 1658 2084 2123 3019 3584
#  3755 3842 3886 4495 4584 4749]
# Number of data points in this cluster: 20
#
# Cluster 183:
# Indices of data points: [ 569 3347 4136]
# Number of data points in this cluster: 3
#
# Cluster 184:
# Indices of data points: [3292 3540]
# Number of data points in this cluster: 2
#
# Cluster 185:
# Indices of data points: [ 504  841  929 1087 1248 1675 1979 2128 2553 2780 2925 2981 3965 4237
#  4419 4466 4631 4928]
# Number of data points in this cluster: 18
#
# Cluster 186:
# Indices of data points: [1832 2967 3386 3601]
# Number of data points in this cluster: 4
#
# Cluster 187:
# Indices of data points: [2308 2964 3705 4111]
# Number of data points in this cluster: 4
#
# Cluster 188:
# Indices of data points: [ 844 3453 3482 4457]
# Number of data points in this cluster: 4
#
# Cluster 189:
# Indices of data points: [  75  461 2986 3435 3699 3757 3781 4455 4494 4506]
# Number of data points in this cluster: 10
#
# Cluster 190:
# Indices of data points: [ 296  961 1327 3439 3548 4725]
# Number of data points in this cluster: 6
#
# Cluster 191:
# Indices of data points: [1471 1783 3727 3867 3991 4019 4034 4436]
# Number of data points in this cluster: 8
#
# Cluster 192:
# Indices of data points: [ 776 1790 2911 3866]
# Number of data points in this cluster: 4
#
# Cluster 193:
# Indices of data points: [1596 2366 2961 3146 4057 5009]
# Number of data points in this cluster: 6
#
# Cluster 194:
# Indices of data points: [ 626 1103 1331 2636 3471]
# Number of data points in this cluster: 5
#
# Cluster 195:
# Indices of data points: [1172 2484 4425]
# Number of data points in this cluster: 3
#
# Cluster 196:
# Indices of data points: [ 564  688 1005 2332 2717 4912]
# Number of data points in this cluster: 6
#
# Cluster 197:
# Indices of data points: [  85  148 1268 2881 3489 3869 4157]
# Number of data points in this cluster: 7
#
# Cluster 198:
# Indices of data points: [1618 3568 3774 3979 4519 4777 4868 4899]
# Number of data points in this cluster: 8
#
# Cluster 199:
# Indices of data points: [ 639  679  806  890 1518 2488 2561 3194 3315 4033]
# Number of data points in this cluster: 10
#
# Cluster 200:
# Indices of data points: [3847 4022]
# Number of data points in this cluster: 2
#
# Cluster 201:
# Indices of data points: [1452 1472 1803 3122 4487 4828]
# Number of data points in this cluster: 6
#
# Cluster 202:
# Indices of data points: [1643 3410 4680]
# Number of data points in this cluster: 3
#
# Cluster 203:
# Indices of data points: [1470 2912 3140 4055 4105 4344]
# Number of data points in this cluster: 6
#
# Cluster 204:
# Indices of data points: [2342 2904 2913 4003 4356]
# Number of data points in this cluster: 5
#
# Cluster 205:
# Indices of data points: [ 119  265  331  464  836 1002 1060 1435 1513 2605 2787 3069 3177 4152
#  4565]
# Number of data points in this cluster: 15
#
# Cluster 206:
# Indices of data points: [2840 3025 3478 3693 3740 3853]
# Number of data points in this cluster: 6
#
# Cluster 207:
# Indices of data points: [  52  958 1003 1207 3692 4264 4583 4628]
# Number of data points in this cluster: 8
#
# Cluster 208:
# Indices of data points: [ 604 1084 2573 3313 4397 4726]
# Number of data points in this cluster: 6
#
# Cluster 209:
# Indices of data points: [1670 2959 3120 4044 4179 4206]
# Number of data points in this cluster: 6
#
# Cluster 210:
# Indices of data points: [ 309 2223 2692 3640]
# Number of data points in this cluster: 4
#
# Cluster 211:
# Indices of data points: [   3  266  624  751 1098 1151 1208 1943 2978 3073 3197 3236 3885 4477
#  4593 4766 4838 5032]
# Number of data points in this cluster: 18
#
# Cluster 212:
# Indices of data points: [ 739 1484 2854 4949]
# Number of data points in this cluster: 4
#
# Cluster 213:
# Indices of data points: [2540 2897 3137]
# Number of data points in this cluster: 3
#
# Cluster 214:
# Indices of data points: [  67  470 1680 1934 2714 2779 3102]
# Number of data points in this cluster: 7
#
# Cluster 215:
# Indices of data points: [ 627 2137 3252]
# Number of data points in this cluster: 3
#
# Cluster 216:
# Indices of data points: [1383 2386 4794]
# Number of data points in this cluster: 3
#
# Cluster 217:
# Indices of data points: [ 123  311  595  979 1067 1210 1897 1971 3181]
# Number of data points in this cluster: 9
#
# Cluster 218:
# Indices of data points: [ 193  327 1336 2044 2082 2500 3722 4172]
# Number of data points in this cluster: 8
#
# Cluster 219:
# Indices of data points: [ 237 1612 1921 2225 2845 2857 3418 4004 4232]
# Number of data points in this cluster: 9
#
# Cluster 220:
# Indices of data points: [2097 2691 2831 3654 4218]
# Number of data points in this cluster: 5
#
# Cluster 221:
# Indices of data points: [  34  667 1024 1311 1337 3474 4590]
# Number of data points in this cluster: 7
#
# Cluster 222:
# Indices of data points: [ 277 4118 4150 4256]
# Number of data points in this cluster: 4
#
# Cluster 223:
# Indices of data points: [ 391  392  447  510  520  571 1066 1493 1578 2080 2556 3182 3283 3441
#  3522 3865 4637]
# Number of data points in this cluster: 17
#
# Cluster 224:
# Indices of data points: [  41  660  843  931 1000 1171 1996 2010 2156 2380 2727 2778 3171 3350
#  3395 4431 4552]
# Number of data points in this cluster: 17
#
# Cluster 225:
# Indices of data points: [1849 2056 2368 3116 3891]
# Number of data points in this cluster: 5
#
# Cluster 226:
# Indices of data points: [1509 3438 3876 4385 4406]
# Number of data points in this cluster: 5
#
# Cluster 227:
# Indices of data points: [  64  664 1234 1826 1828 4413]
# Number of data points in this cluster: 6
#
# Cluster 228:
# Indices of data points: [2047 4362]
# Number of data points in this cluster: 2
#
# Cluster 229:
# Indices of data points: [2266 3266 3383 3875]
# Number of data points in this cluster: 4
#
# Cluster 230:
# Indices of data points: [ 221 2175 4363]
# Number of data points in this cluster: 3
#
# Cluster 231:
# Indices of data points: [ 146  566 2929 3205 3388 3813]
# Number of data points in this cluster: 6
#
# Cluster 232:
# Indices of data points: [2001 2537 3099 3232]
# Number of data points in this cluster: 4
#
# Cluster 233:
# Indices of data points: [  50  319  442  955 1267 1320 1920 2214 2226 2256 2261 4617 4650 4660
#  4801 5006]
# Number of data points in this cluster: 16
#
# Cluster 234:
# Indices of data points: [1233 1962 3345]
# Number of data points in this cluster: 3
#
# Cluster 235:
# Indices of data points: [2241 2637 4250 4303 4893]
# Number of data points in this cluster: 5
#
# Cluster 236:
# Indices of data points: [2893 3273 4275]
# Number of data points in this cluster: 3
#
# Cluster 237:
# Indices of data points: [ 448 1092 1097 4767]
# Number of data points in this cluster: 4
#
# Cluster 238:
# Indices of data points: [ 718 1253 2430 4229 4521]
# Number of data points in this cluster: 5
#
# Cluster 239:
# Indices of data points: [2283 4966 5000]
# Number of data points in this cluster: 3
#
# Cluster 240:
# Indices of data points: [1139 1809 3495 5025]
# Number of data points in this cluster: 4
#
# Cluster 241:
# Indices of data points: [  66  151  444  953  956 1004 2547 2668 3452 3843 4241 4435 4888]
# Number of data points in this cluster: 13
#
# Cluster 242:
# Indices of data points: [ 262 2860 2951 3565 3726 3773 4727]
# Number of data points in this cluster: 7
#
# Cluster 243:
# Indices of data points: [2349 3742 4365 4544]
# Number of data points in this cluster: 4
#
# Cluster 244:
# Indices of data points: [ 218  256  398  482  969 1713 2661 2753 2765 3599]
# Number of data points in this cluster: 10
#
# Cluster 245:
# Indices of data points: [ 317  332  334  340 2440 2498 2629 2716]
# Number of data points in this cluster: 8
#
# Cluster 246:
# Indices of data points: [1246 1855 3637 3649 4081 4732]
# Number of data points in this cluster: 6
#
# Cluster 247:
# Indices of data points: [ 812 2378 3108 3123 3970 4386 4793]
# Number of data points in this cluster: 7
#
# Cluster 248:
# Indices of data points: [2326]
# Number of data points in this cluster: 1
#
# Cluster 249:
# Indices of data points: [  70  318  526  681  791 1102 1182 1245 1293 1302 1348 1532 1551 1966
#  2412 2567 2948 3421 3537 3919 4374 4705]
# Number of data points in this cluster: 22
#
# Cluster 250:
# Indices of data points: [ 921 1863 3545 4560]
# Number of data points in this cluster: 4
#
# Cluster 251:
# Indices of data points: [1819 2602 3652 4312]
# Number of data points in this cluster: 4
#
# Cluster 252:
# Indices of data points: [1806 2901 3318 3373 3396 3826 4070]
# Number of data points in this cluster: 7
#
# Cluster 253:
# Indices of data points: [ 524  535 1036 1214 1754 2473 2619 3377 3442 4581]
# Number of data points in this cluster: 10
#
# Cluster 254:
# Indices of data points: [1988 3032]
# Number of data points in this cluster: 2
#
# Cluster 255:
# Indices of data points: [ 135 3880 4030 4235]
# Number of data points in this cluster: 4
#
# Cluster 256:
# Indices of data points: [ 112  125  503  762  772 1007 1281 1993 2100 2482 2652 2743 3076 3494
#  4207 4400 4688 4896]
# Number of data points in this cluster: 18
#
# Cluster 257:
# Indices of data points: [ 991 2065 3733]
# Number of data points in this cluster: 3
#
# Cluster 258:
# Indices of data points: [ 239 1857 3361 4340]
# Number of data points in this cluster: 4
#
# Cluster 259:
# Indices of data points: [ 199 1221 3861 4414 4461]
# Number of data points in this cluster: 5
#
# Cluster 260:
# Indices of data points: [  16  224  383 1727 1982 2170 3046 3093 4649 5026 5058]
# Number of data points in this cluster: 11
#
# Cluster 261:
# Indices of data points: [1956 2118 2384 2971]
# Number of data points in this cluster: 4
#
# Cluster 262:
# Indices of data points: [ 333 1748 2022 3745 3761 4279]
# Number of data points in this cluster: 6
#
# Cluster 263:
# Indices of data points: [1605 1893 4060]
# Number of data points in this cluster: 3
#
# Cluster 264:
# Indices of data points: [ 621  711 2064 3480 4407]
# Number of data points in this cluster: 5
#
# Cluster 265:
# Indices of data points: [3325 3951]
# Number of data points in this cluster: 2
#
# Cluster 266:
# Indices of data points: [3971 4031 4183]
# Number of data points in this cluster: 3
#
# Cluster 267:
# Indices of data points: [4073 4448 4526]
# Number of data points in this cluster: 3
#
# Cluster 268:
# Indices of data points: [ 109  984 1191 2202 2604 2706 3010 3828]
# Number of data points in this cluster: 8
#
# Cluster 269:
# Indices of data points: [2045 2063 2270]
# Number of data points in this cluster: 3
#
# Cluster 270:
# Indices of data points: [   2  210  498  594  948 1212 1408 1559 3561 4498 4945]
# Number of data points in this cluster: 11
#
# Cluster 271:
# Indices of data points: [ 957 1035 1230 1615 1937 2796 3186 3444 3531 3998 4134]
# Number of data points in this cluster: 11
#
# Cluster 272:
# Indices of data points: [1355 1777 1844 2873 3578 5019 5027]
# Number of data points in this cluster: 7
#
# Cluster 273:
# Indices of data points: [1014 3997 4539 5031]
# Number of data points in this cluster: 4
#
# Cluster 274:
# Indices of data points: [  25  556  877 2425 2821 3513]
# Number of data points in this cluster: 6
#
# Cluster 275:
# Indices of data points: [  44 2492 2578 2999 3054 3067 3407 3669 3921 3942 4129 4154 4332 4605]
# Number of data points in this cluster: 14
#
# Cluster 276:
# Indices of data points: [1627 1814 3630 3642 3794]
# Number of data points in this cluster: 5
#
# Cluster 277:
# Indices of data points: [ 286  343  376  387  756 1572 1865 2043 2110 2222 2397 2919 3349 3450
#  3567 3785 4679]
# Number of data points in this cluster: 17
#
# Cluster 278:
# Indices of data points: [3681]
# Number of data points in this cluster: 1
#
# Cluster 279:
# Indices of data points: [ 147  497  651 1514 1710 1744 1904 2603 2694 2829 3933 3945 4382 4503]
# Number of data points in this cluster: 14
#
# Cluster 280:
# Indices of data points: [3641 3731 3859]
# Number of data points in this cluster: 3
#
# Cluster 281:
# Indices of data points: [1398 2021 2254 2979 3566 3695 4101]
# Number of data points in this cluster: 7
#
# Cluster 282:
# Indices of data points: [ 829 3992 4684 4963]
# Number of data points in this cluster: 4
#
# Cluster 283:
# Indices of data points: [1076 1659 2993 4068]
# Number of data points in this cluster: 4
#
# Cluster 284:
# Indices of data points: [ 364  658 2039 2096 2667 3124]
# Number of data points in this cluster: 6
#
# Cluster 285:
# Indices of data points: [4467]
# Number of data points in this cluster: 1
#
# Cluster 286:
# Indices of data points: [ 351  512  575  810 1001 1200 1202 1761 3004 3376 3411 3650 3800 4324
#  4464]
# Number of data points in this cluster: 15
#
# Cluster 287:
# Indices of data points: [ 374  870  980 1436 1461 2009 2319 2377 2594 2616 2647 3416 3517 3629
#  4816]
# Number of data points in this cluster: 15
#
# Cluster 288:
# Indices of data points: [1999 2004 3708 4097 4380]
# Number of data points in this cluster: 5
#
# Cluster 289:
# Indices of data points: [1479 3147 4458]
# Number of data points in this cluster: 3
#
# Cluster 290:
# Indices of data points: [ 144  288 2337 2882 3618]
# Number of data points in this cluster: 5
#
# Cluster 291:
# Indices of data points: [ 487  511  796 1113 2518 2621 2876 4249 4286 4424 4449]
# Number of data points in this cluster: 11
#
# Cluster 292:
# Indices of data points: [1054 1838 3348 4023 4941]
# Number of data points in this cluster: 5
#
# Cluster 293:
# Indices of data points: [ 457  491  601  638 1125 1307 1852 2179 2205 3498 3512 3587 4189 4547]
# Number of data points in this cluster: 14
#
# Cluster 294:
# Indices of data points: [  33  130  715 1768 2318 2344 2696 3795 4254 4323 4402 4666 4805]
# Number of data points in this cluster: 13
#
# Cluster 295:
# Indices of data points: [ 100  208 2062 2221 2247 3174 3408 3412 3707 3960 4337 4535 4576 4741
#  4821]
# Number of data points in this cluster: 15
#
# Cluster 296:
# Indices of data points: [1667 2723 3715]
# Number of data points in this cluster: 3
#
# Cluster 297:
# Indices of data points: [ 124 2304 4064 4233 4473]
# Number of data points in this cluster: 5
#
# Cluster 298:
# Indices of data points: [ 478 2896 3789 5020 5028]
# Number of data points in this cluster: 5
#
# Cluster 299:
# Indices of data points: [ 415 1833 3294 3519 4155 4736 4797]
# Number of data points in this cluster: 7
#
# Cluster 300:
# Indices of data points: [ 108  743 1729]
# Number of data points in this cluster: 3
#
# Cluster 301:
# Indices of data points: [ 264  449  513 1301 2162 2264 2340 3024 3058 4839]
# Number of data points in this cluster: 10
#
# Cluster 302:
# Indices of data points: [ 695 3060 3237 3351 4612]
# Number of data points in this cluster: 5
#
# Cluster 303:
# Indices of data points: [ 799 3957 4002]
# Number of data points in this cluster: 3
#
# Cluster 304:
# Indices of data points: [ 171 1333 1480 2331 3365 4115 4763]
# Number of data points in this cluster: 7
#
# Cluster 305:
# Indices of data points: [  94  107  368 1141 1185 1316 1332 1371 2193 2231 2494 2709 2776 2934
#  2950 3106 3167 3346 3443 3550 3665 3825 4161 4678 5036]
# Number of data points in this cluster: 25
#
# Cluster 306:
# Indices of data points: [ 554 1342 2351 2976 3827 3896]
# Number of data points in this cluster: 6
#
# Cluster 307:
# Indices of data points: [1451 4006 4438 4620]
# Number of data points in this cluster: 4
#
# Cluster 308:
# Indices of data points: [2361 3779 3989]
# Number of data points in this cluster: 3
#
# Cluster 309:
# Indices of data points: [1860 2506 3476 3557]
# Number of data points in this cluster: 4
#
# Cluster 310:
# Indices of data points: [ 187  616 1021 1548 2288 2372 4704]
# Number of data points in this cluster: 7
#
# Cluster 311:
# Indices of data points: [ 864 2550 3571 3596]
# Number of data points in this cluster: 4
#
# Cluster 312:
# Indices of data points: [1516 3220 3403 3502 3521 4198 4437 4987]
# Number of data points in this cluster: 8
#
# Cluster 313:
# Indices of data points: [ 291  394  787 1189 1416 2048 2059 2268 2613 2638 3034 3089 4907]
# Number of data points in this cluster: 13
#
# Cluster 314:
# Indices of data points: [ 489  861 1369 2977 3506 3606 3890 4849 5046]
# Number of data points in this cluster: 9
#
# Cluster 315:
# Indices of data points: [3608 4350 4641]
# Number of data points in this cluster: 3
#
# Cluster 316:
# Indices of data points: [ 142 2415 2769 4017]
# Number of data points in this cluster: 4
#
# Cluster 317:
# Indices of data points: [2794 3112 4346]
# Number of data points in this cluster: 3
#
# Cluster 318:
# Indices of data points: [  93  143  933 1507 2497 2795 3680 4119 4504 4591 4812]
# Number of data points in this cluster: 11
#
# Cluster 319:
# Indices of data points: [1949 3497 3901]
# Number of data points in this cluster: 3
#
# Cluster 320:
# Indices of data points: [ 365  473  500  764  973 1038 1314 1418 2921 3223 3342 3786 3917 3975
#  4208 4632 4690]
# Number of data points in this cluster: 17
#
# Cluster 321:
# Indices of data points: [ 111  527 1417 1425 1624 1708 2129 2859 4404 4751 4774 5055]
# Number of data points in this cluster: 12
#
# Cluster 322:
# Indices of data points: [ 736 1763 2495 4991]
# Number of data points in this cluster: 4
#
# Cluster 323:
# Indices of data points: [1686 1804 3709 4992]
# Number of data points in this cluster: 4
#
# Cluster 324:
# Indices of data points: [ 412 1625 3529 3818]
# Number of data points in this cluster: 4
#
# Cluster 325:
# Indices of data points: [ 212 1169 1903 4083]
# Number of data points in this cluster: 4
#
# Cluster 326:
# Indices of data points: [  97  338  884 1138 1632 2090 2114 2132 2459 2645 2712 3668]
# Number of data points in this cluster: 12
#
# Cluster 327:
# Indices of data points: [ 463  509 1106 1407 2245 3268 3404 3543 3638 3812 4545 4742]
# Number of data points in this cluster: 12
#
# Cluster 328:
# Indices of data points: [1784 2453 2721 4063 4139 4166 4373]
# Number of data points in this cluster: 7
#
# Cluster 329:
# Indices of data points: [  29  492  740  942 1948 2321 3595 3639 3830 4785]
# Number of data points in this cluster: 10
#
# Cluster 330:
# Indices of data points: [  81 1147 1702 2034 2085 2677 3415 3574 4121 4376 4409 4596 4859 5003
#  5005]
# Number of data points in this cluster: 15
#
# Cluster 331:
# Indices of data points: [  58  169  353  370  560  859  914 1180 1442 2499 3040 3169 3183 3208
#  3247 4230 4343 4643 4654 4815 4929 4988]
# Number of data points in this cluster: 22
#
# Cluster 332:
# Indices of data points: [ 995 1432 2588 4832]
# Number of data points in this cluster: 4
#
# Cluster 333:
# Indices of data points: [ 647  846  915 1544 2040 2250 2991 3622 3751 3972 4572]
# Number of data points in this cluster: 11
#
# Cluster 334:
# Indices of data points: [ 191  602  786 1008 1130 1162 1192 1399 1944 1959 2395 2454 2823 2922
#  3084 3185 4135 4515 4845 4918]
# Number of data points in this cluster: 20
#
# Cluster 335:
# Indices of data points: [1156 2330 3219 3295 3300 3464]
# Number of data points in this cluster: 6
#
# Cluster 336:
# Indices of data points: [1522 2750 2816 4059]
# Number of data points in this cluster: 4
#
# Cluster 337:
# Indices of data points: [  55  389 1455 1906 2383 3029 3533 3643 3647 4604 4836 4857 4873]
# Number of data points in this cluster: 13
#
# Cluster 338:
# Indices of data points: [1638 1793 1847 2735 4615]
# Number of data points in this cluster: 5
#
# Cluster 339:
# Indices of data points: [ 665 1015 2150 3564 3582]
# Number of data points in this cluster: 5
#
# Cluster 340:
# Indices of data points: [1209 1474 2279 2341 2664 3172 3193 3202 3241 3352 3871 3974 4065 4269
#  4276 4863]
# Number of data points in this cluster: 16
#
# Cluster 341:
# Indices of data points: [ 540  907 1388 1597 3776 4225]
# Number of data points in this cluster: 6
#
# Cluster 342:
# Indices of data points: [ 456  767 1835 2418 2429 3552 4492 4807]
# Number of data points in this cluster: 8
#
# Cluster 343:
# Indices of data points: [ 805  998 3021 3090 3490 3958]
# Number of data points in this cluster: 6
#
# Cluster 344:
# Indices of data points: [ 140  589  668  801  863 1296 1321 2200 3248 3549 4307 4616]
# Number of data points in this cluster: 12
#
# Cluster 345:
# Indices of data points: [2316 3780 3839]
# Number of data points in this cluster: 3
#
# Cluster 346:
# Indices of data points: [1555 2260 5017]
# Number of data points in this cluster: 3
#
# Cluster 347:
# Indices of data points: [1689 3585 3882 3893]
# Number of data points in this cluster: 4
#
# Cluster 348:
# Indices of data points: [1764 4433]
# Number of data points in this cluster: 2
#
# Cluster 349:
# Indices of data points: [  18  865 1022 1161 1535 1880 1994 2181 2586 2869 3064 3265 3455 4291
#  4853]
# Number of data points in this cluster: 15
#
# Cluster 350:
# Indices of data points: [2192 2572 2833 4261 4423 4825]
# Number of data points in this cluster: 6
#
# Cluster 351:
# Indices of data points: [ 118  316  407  508  517 1126 1357 1392 2684 2755 2785 4644 4651 4865
#  4876 4920 4957]
# Number of data points in this cluster: 17
#
# Cluster 352:
# Indices of data points: [ 276  466 1891 1935 1936 2282]
# Number of data points in this cluster: 6
#
# Cluster 353:
# Indices of data points: [1553 2300 2324 3803 3973 4072 4246]
# Number of data points in this cluster: 7
#
# Cluster 354:
# Indices of data points: [1048 1075 1717 3437 4221 4372]
# Number of data points in this cluster: 6
#
# Cluster 355:
# Indices of data points: [2166 2405 2474 2988 3784 4348]
# Number of data points in this cluster: 6
#
# Cluster 356:
# Indices of data points: [   6  153  201 1922 3026 4330]
# Number of data points in this cluster: 6
#
# Cluster 357:
# Indices of data points: [ 872  952 1466 1537 3978]
# Number of data points in this cluster: 5
#
# Cluster 358:
# Indices of data points: [ 196 2982 3143]
# Number of data points in this cluster: 3
#
# Cluster 359:
# Indices of data points: [ 157  970 1802 1932 2053 2957 3062 4345]
# Number of data points in this cluster: 8
#
# Cluster 360:
# Indices of data points: [ 418 1295 3081 4358]
# Number of data points in this cluster: 4
#
# Cluster 361:
# Indices of data points: [1800 1836 3239]
# Number of data points in this cluster: 3
#
# Cluster 362:
# Indices of data points: [1500 2515 2849 3672 4384]
# Number of data points in this cluster: 5
#
# Cluster 363:
# Indices of data points: [ 424  680  707  893  936 1099 1304 1345 1593 1599 2083 2168 2516 2651
#  2658 3105 3987 5008]
# Number of data points in this cluster: 18
#
# Cluster 364:
# Indices of data points: [ 889 1528 3759 3764]
# Number of data points in this cluster: 4
#
# Cluster 365:
# Indices of data points: [1664 2864 3609 4104]
# Number of data points in this cluster: 4
#
# Cluster 366:
# Indices of data points: [ 225  314  476  922 1291 1610 2011 2173 2257 2443 2690 2797 4300 4720]
# Number of data points in this cluster: 14
#
# Cluster 367:
# Indices of data points: [1142 1170 1179 1873 3456 3895 4117 4217]
# Number of data points in this cluster: 8
#
# Cluster 368:
# Indices of data points: [1460 2476 2837 3150 4048]
# Number of data points in this cluster: 5
#
# Cluster 369:
# Indices of data points: [ 183  851  978 1263 1285 1901 2102 2176 2204 2276 2493 2715 2726 2867
#  3263 3910 4020 4138 4302 4667]
# Number of data points in this cluster: 20
#
# Cluster 370:
# Indices of data points: [2272 4164]
# Number of data points in this cluster: 2
#
# Cluster 371:
# Indices of data points: [ 175 1821 2456 4566 4952]
# Number of data points in this cluster: 5
#
# Cluster 372:
# Indices of data points: [ 591 1104 1204 1211 1587 1823 2106 2974 3148 3536 4540]
# Number of data points in this cluster: 11
#
# Cluster 373:
# Indices of data points: [ 586 2234]
# Number of data points in this cluster: 2
#
# Cluster 374:
# Indices of data points: [2666 3854 4051]
# Number of data points in this cluster: 3
#
# Cluster 375:
# Indices of data points: [ 737 3475 3900]
# Number of data points in this cluster: 3
#
# Cluster 376:
# Indices of data points: [  43  423  869 1223 1864 2895 4737]
# Number of data points in this cluster: 7
#
# Cluster 377:
# Indices of data points: [ 950 1134 2320]
# Number of data points in this cluster: 3
#
# Cluster 378:
# Indices of data points: [ 429 1501 1661 1780 2568 2749 2945 3330 3651 4602]
# Number of data points in this cluster: 10
#
# Cluster 379:
# Indices of data points: [ 230  254  821 1195 1288 1622 2382 2419 2486 3160 3163 3457 4197]
# Number of data points in this cluster: 13
#
# Cluster 380:
# Indices of data points: [ 373  451 3950]
# Number of data points in this cluster: 3
#
# Cluster 381:
# Indices of data points: [ 122  488 1805 4895 4972]
# Number of data points in this cluster: 5
#
# Cluster 382:
# Indices of data points: [1985 2023 4796]
# Number of data points in this cluster: 3
#
# Cluster 383:
# Indices of data points: [ 204  410  452 1946 2054]
# Number of data points in this cluster: 5
#
# Cluster 384:
# Indices of data points: [2530 2830 3290]
# Number of data points in this cluster: 3
#
# Cluster 385:
# Indices of data points: [1488 3840 4165 4186 4428]
# Number of data points in this cluster: 5
#
# Cluster 386:
# Indices of data points: [ 428  632 1051]
# Number of data points in this cluster: 3
#
# Cluster 387:
# Indices of data points: [3334 3771 4349]
# Number of data points in this cluster: 3
#
# Cluster 388:
# Indices of data points: [ 159  283  726 2527 3924 5021]
# Number of data points in this cluster: 6
#
# Cluster 389:
# Indices of data points: [2307 3316 3367 3398 3696 3768 4091 4318 4505 4511]
# Number of data points in this cluster: 10
#
# Cluster 390:
# Indices of data points: [1606 1732 2070 2535]
# Number of data points in this cluster: 4
#
# Cluster 391:
# Indices of data points: [ 260 1505 2328 2734]
# Number of data points in this cluster: 4
#
# Cluster 392:
# Indices of data points: [ 297  460 1206 4440 4770]
# Number of data points in this cluster: 5
#
# Cluster 393:
# Indices of data points: [ 719 2878 3063]
# Number of data points in this cluster: 3
#
# Cluster 394:
# Indices of data points: [ 523 1198 1584 1679 3605 4209 5015]
# Number of data points in this cluster: 7
#
# Cluster 395:
# Indices of data points: [ 184  301  803  923 1094 1929 1940 2163 2262 2439 2464 2549 2784 3952
#  4474]
# Number of data points in this cluster: 15
#
# Cluster 396:
# Indices of data points: [1698 2751 3397 3787 4092]
# Number of data points in this cluster: 5
#
# Cluster 397:
# Indices of data points: [ 236 1434 3007 3598]
# Number of data points in this cluster: 4
#
# Cluster 398:
# Indices of data points: [   9 2269 2402 2447 3380 3516 3556 3685 4032 4149 4553 4696 4721 4922
#  5057]
# Number of data points in this cluster: 15
#
# Cluster 399:
# Indices of data points: [ 754  905  913 2014 2396 3748 4240 4443]
# Number of data points in this cluster: 8
#
# Cluster 400:
# Indices of data points: [1699 2879]
# Number of data points in this cluster: 2
#
# Cluster 401:
# Indices of data points: [ 206  354 1041 1329 1540 1552 1611 2071 2369 3103 3164 3366 3500 4109
#  4408 4592 4810 5052]
# Number of data points in this cluster: 18
#
# Cluster 402:
# Indices of data points: [1848 4222 4656 5012]
# Number of data points in this cluster: 4
#
# Cluster 403:
# Indices of data points: [3678 4071 4510]
# Number of data points in this cluster: 3
#
# Cluster 404:
# Indices of data points: [ 875  917 1277 1616 1759 3080 3308 3509 4334 4699 4842]
# Number of data points in this cluster: 11
#
# Cluster 405:
# Indices of data points: [4786 4968]
# Number of data points in this cluster: 2
#
# Cluster 406:
# Indices of data points: [ 308  493  552  572  990 1266 1462 1799 1960 1963 2077 2489 2615 2628
#  3778 3926 4292 4359 4848]
# Number of data points in this cluster: 19
#
# Cluster 407:
# Indices of data points: [2923]
# Number of data points in this cluster: 1
#
# Cluster 408:
# Indices of data points: [ 103  662  895 4310 4533 4561 4996]
# Number of data points in this cluster: 7
#
# Cluster 409:
# Indices of data points: [1635 2073]
# Number of data points in this cluster: 2
#
# Cluster 410:
# Indices of data points: [ 253  371  555  559  705 1406 1941 2436 2654 2924 3793 3888 4418 4541]
# Number of data points in this cluster: 14
#
# Cluster 411:
# Indices of data points: [ 255 1705 2819 2975 3282]
# Number of data points in this cluster: 5
#
# Cluster 412:
# Indices of data points: [ 697  728 1027 1512 2855 3293 4357]
# ...
#  2278 2487 2514 3097 3222]
# Number of data points in this cluster: 19
#
# Cluster 617:
# Indices of data points: [ 320 2336 3496 4378 4451]
# Number of data points in this cluster: 5
#
# Cluster 618:
# Indices of data points: [ 422  757  825 2233 2687 3319 3634 4758 4875]
# Number of data points in this cluster: 9
#
# Cluster 619:
# Indices of data points: [1523 2306 3078]
# Number of data points in this cluster: 3
#
# Cluster 620:
# Indices of data points: [2151]
# Number of data points in this cluster: 1
#
# Cluster 621:
# Indices of data points: [ 542  657  712  827 2076 2825 3156 3525 4587 4820 5040]
# Number of data points in this cluster: 11
#
# Cluster 622:
# Indices of data points: [ 214 1222 2017 2524]
# Number of data points in this cluster: 4
#
# Cluster 623:
# Indices of data points: [1656 2738 2858 3394 4351]
# Number of data points in this cluster: 5
#
# Cluster 624:
# Indices of data points: [ 615 1121 2763 3724]
# Number of data points in this cluster: 4
#
# Cluster 625:
# Indices of data points: [1773 2562 3136]
# Number of data points in this cluster: 3
#
# Cluster 626:
# Indices of data points: [3704 4450 4471]
# Number of data points in this cluster: 3
#
# Cluster 627:
# Indices of data points: [ 818 1907 3246 3673]
# Number of data points in this cluster: 4
#
# Cluster 628:
# Indices of data points: [2088 2297 2511]
# Number of data points in this cluster: 3
#
# Cluster 629:
# Indices of data points: [2812 2848 3583 3703]
# Number of data points in this cluster: 4
#
# Cluster 630:
# Indices of data points: [  36 2363 3986]
# Number of data points in this cluster: 3
#
# Cluster 631:
# Indices of data points: [ 136  280  419  852  883  985 1756 3257 3493 3736 3819 4529 4608 4661]
# Number of data points in this cluster: 14
#
# Cluster 632:
# Indices of data points: [ 116 1601 1700 3299 4214]
# Number of data points in this cluster: 5
#
# Cluster 633:
# Indices of data points: [1447 1475 1965 2773 3597]
# Number of data points in this cluster: 5
#
# Cluster 634:
# Indices of data points: [ 252  706  891 1011 1055 1244 1264 1741 2098 2477 2626 2909 2933 4124
#  4934 5002]
# Number of data points in this cluster: 16
#
# Cluster 635:
# Indices of data points: [  46  420 1487 3279 4695]
# Number of data points in this cluster: 5
#
# Cluster 636:
# Indices of data points: [1782 2293]
# Number of data points in this cluster: 2
#
# Cluster 637:
# Indices of data points: [ 173  388  421  831  834  910  924 1520 2220 2238 2442 3808 4133 4328
#  4331 4589 4999]
# Number of data points in this cluster: 17
#
# Cluster 638:
# Indices of data points: [ 413  561  741  901  975 1158 1235 1335 1429 1837 2092 2246 2693 2761
#  3170 3688 4144 4163 4170 4187 4681 4818 4969]
# Number of data points in this cluster: 23
#
# Cluster 639:
# Indices of data points: [2140 3278 3832 4052 4427 4665]
# Number of data points in this cluster: 6
#
# Cluster 640:
# Indices of data points: [ 360 2038 2122 2251]
# Number of data points in this cluster: 4
#
# Cluster 641:
# Indices of data points: [2851 4570]
# Number of data points in this cluster: 2
#
# Cluster 642:
# Indices of data points: [  73 1712 2523 4368 4507 4711 4833]
# Number of data points in this cluster: 7
#
# Cluster 643:
# Indices of data points: [ 300  363 4126]
# Number of data points in this cluster: 3
#
# Cluster 644:
# Indices of data points: [  92  773  981 1276 1684 2710 2850 2942 3852 4251 4645 4856]
# Number of data points in this cluster: 12
#
# Cluster 645:
# Indices of data points: [ 242 2057 2164 2452 2908 3225 4272]
# Number of data points in this cluster: 7
#
# Cluster 646:
# Indices of data points: [3406]
# Number of data points in this cluster: 1
#
# Cluster 647:
# Indices of data points: [3491 3848]
# Number of data points in this cluster: 2
#
# Cluster 648:
# Indices of data points: [ 168  381  469  499  693  903 1682 1752 2610 2745 3035 3068 3157 3280
#  3288 3683 3720 4309 4694 4885]
# Number of data points in this cluster: 20
#
# Cluster 649:
# Indices of data points: [ 189 1361 1645 1776 2431 2888 2891]
# Number of data points in this cluster: 7
#
# Cluster 650:
# Indices of data points: [ 161  881 1080 2789 4718]
# Number of data points in this cluster: 5
#
# Cluster 651:
# Indices of data points: [ 248  263  379 1148 1241 1895 1908 2007 2105 2290 3091 3277 3449 4580]
# Number of data points in this cluster: 14
#
# Cluster 652:
# Indices of data points: [1590 2804 2931]
# Number of data points in this cluster: 3
#
# Cluster 653:
# Indices of data points: [ 459 3066 3353 4067 4114 4622 4826]
# Number of data points in this cluster: 7
#
# Cluster 654:
# Indices of data points: [  54  797 1105 1203 1308 1554 2479 3071 3083]
# Number of data points in this cluster: 9
#
# Cluster 655:
# Indices of data points: [ 777 1574 2657]
# Number of data points in this cluster: 3
#
# Cluster 656:
# Indices of data points: [ 733  874  959 1242 1690 2512 4759 4903 4943]
# Number of data points in this cluster: 9
#
# Cluster 657:
# Indices of data points: [2305 3485 4016]
# Number of data points in this cluster: 3
#
# Cluster 658:
# Indices of data points: [1856 1859 3379 4234]
# Number of data points in this cluster: 4
#
# Cluster 659:
# Indices of data points: [  26  179 1338 1546]
# Number of data points in this cluster: 4
#
# Cluster 660:
# Indices of data points: [  45  335  425  656 1019 2172 3109 4571 4962]
# Number of data points in this cluster: 9
#
# Cluster 661:
# Indices of data points: [1114 2688 3135]
# Number of data points in this cluster: 3
#
# Cluster 662:
# Indices of data points: [ 336 1181 1271 1298 1402 1757 2191 2480 2987 3337 4213 4636]
# Number of data points in this cluster: 12
#
# Cluster 663:
# Indices of data points: [3741]
# Number of data points in this cluster: 1
#
# Cluster 664:
# Indices of data points: [ 780  867  989 1888 2206 4497]
# Number of data points in this cluster: 6
#
# Cluster 665:
# Indices of data points: [1654 3790 4531 4908]
# Number of data points in this cluster: 4
#
# Cluster 666:
# Indices of data points: [ 516  541  788  897  986 3698 4559]
# Number of data points in this cluster: 7
#
# Cluster 667:
# Indices of data points: [  49  174  427 2747 2940 3127 4683 4946]
# Number of data points in this cluster: 8
#
# Cluster 668:
# Indices of data points: [  35  472  613  894 1889 2196 2944 2949 3423 3451 3739 4675 4944]
# Number of data points in this cluster: 13
#
# Cluster 669:
# Indices of data points: [1747 3368]
# Number of data points in this cluster: 2
#
# Cluster 670:
# Indices of data points: [3306 3713]
# Number of data points in this cluster: 2
#
# Cluster 671:
# Indices of data points: [ 202  465  947 3481 4894]
# Number of data points in this cluster: 5
#
# Cluster 672:
# Indices of data points: [  90  104  528  842 1186 1390 3018 3254 3436 3762 4990]
# Number of data points in this cluster: 11
#
# Cluster 673:
# Indices of data points: [ 397 2144 2699 3837 4554 4950]
# Number of data points in this cluster: 6
#
# Cluster 674:
# Indices of data points: [1108 1421 2649]
# Number of data points in this cluster: 3
#
# Cluster 675:
# Indices of data points: [ 139 1881 2580 3431 3834 4543 4802]
# Number of data points in this cluster: 7
#
# Cluster 676:
# Indices of data points: [1588 4594]
# Number of data points in this cluster: 2
#
# Cluster 677:
# Indices of data points: [ 538 1576 2841 3305 4877 5018]
# Number of data points in this cluster: 6
#
# Cluster 678:
# Indices of data points: [ 227  395  582 1468 1557 1646 2887 3203 3648 4984]
# Number of data points in this cluster: 10
#
# Cluster 679:
# Indices of data points: [1681 1706 3797]
# Number of data points in this cluster: 3
#
# Cluster 680:
# Indices of data points: [2705 2861]
# Number of data points in this cluster: 2
#
# Cluster 681:
# Indices of data points: [ 793 4043 4288 4493 4847]
# Number of data points in this cluster: 5
#
# Cluster 682:
# Indices of data points: [3526 3625 4784]
# Number of data points in this cluster: 3
#
# Cluster 683:
# Indices of data points: [ 270  609 1339 1933 2392 4586]
# Number of data points in this cluster: 6
#
# Cluster 684:
# Indices of data points: [2075 3317 3868]
# Number of data points in this cluster: 3
#
# Cluster 685:
# Indices of data points: [ 857  977 3176 3477 3770 3856 3908 4108]
# Number of data points in this cluster: 8
#
# Cluster 686:
# Indices of data points: [ 637  871 1669]
# Number of data points in this cluster: 3
#
# Cluster 687:
# Indices of data points: [   8  155  633 1633 2121 2347 2607 4673 4789 5073]
# Number of data points in this cluster: 10
#
# Cluster 688:
# Indices of data points: [1395 1415 1586 4248]
# Number of data points in this cluster: 4
#
# Cluster 689:
# Indices of data points: [ 494  912 1736 2006 2470 4813]
# Number of data points in this cluster: 6
#
# Cluster 690:
# Indices of data points: [1120 2355 3271 3577 3660 3687 4897]
# Number of data points in this cluster: 7
#
# Cluster 691:
# Indices of data points: [ 539  640  819 1013 1980 2437 3212 3792]
# Number of data points in this cluster: 8
#
# Cluster 692:
# Indices of data points: [1469 3675]
# Number of data points in this cluster: 2
#
# Cluster 693:
# Indices of data points: [2810 4434]
# Number of data points in this cluster: 2
#
# Cluster 694:
# Indices of data points: [2050 3723 4191]
# Number of data points in this cluster: 3
#
# Cluster 695:
# Indices of data points: [ 817 2177 4274]
# Number of data points in this cluster: 3
#
# Cluster 696:
# Indices of data points: [1492 2966 3400 3402 3483 4935]
# Number of data points in this cluster: 6
#
# Cluster 697:
# Indices of data points: [1628 2918 3922]
# Number of data points in this cluster: 3
#
# Cluster 698:
# Indices of data points: [ 292  328 2295]
# Number of data points in this cluster: 3
#
# Cluster 699:
# Indices of data points: [2230 2824 3107]
# Number of data points in this cluster: 3
#
# Cluster 700:
# Indices of data points: [  71   77  659  943 1029 1135 1391 1683 2211 3033 3095 3189 4799]
# Number of data points in this cluster: 13
#
# Cluster 701:
# Indices of data points: [ 966 1095 1770 4456]
# Number of data points in this cluster: 4
#
# Cluster 702:
# Indices of data points: [ 685  862  878 1046 2682 4317 4514 4542 4804]
# Number of data points in this cluster: 9
#
# Cluster 703:
# Indices of data points: [ 141  163  315  445  972 1164 1600 2103 2575 2670 3754 4614]
# Number of data points in this cluster: 12
#
# Cluster 704:
# Indices of data points: [1613 2555 2701]
# Number of data points in this cluster: 3
#
# Cluster 705:
# Indices of data points: [  24  868 1423 1924 2529 2814 3929 4647]
# Number of data points in this cluster: 8
#
# Cluster 706:
# Indices of data points: [1259 1459 1595 4757]
# Number of data points in this cluster: 4
#
# Cluster 707:
# Indices of data points: [ 766  906 2565 2612 2700 2836 3244 3744 4175 4843 4919 5059]
# Number of data points in this cluster: 12
#
# Cluster 708:
# Indices of data points: [ 127 1037 1254 1854 2199 2656 2862 4255 4574 4700 4925 4973 5069]
# Number of data points in this cluster: 13
#
# Cluster 709:
# Indices of data points: [2545 2589 3655 4588]
# Number of data points in this cluster: 4
#
# Cluster 710:
# Indices of data points: [2766 3355 3903 4398]
# Number of data points in this cluster: 4
#
# Cluster 711:
# Indices of data points: [ 937 2310 2675 3082 3845 4948 4971]
# Number of data points in this cluster: 7
#
# Cluster 712:
# Indices of data points: [3362 3385 4050]
# Number of data points in this cluster: 3
#
# Cluster 713:
# Indices of data points: [1454 1529 2434 2748 4011]
# Number of data points in this cluster: 5
#
# Cluster 714:
# Indices of data points: [1786 2563]
# Number of data points in this cluster: 2
#
# Cluster 715:
# Indices of data points: [4439]
# Number of data points in this cluster: 1
#
# Cluster 716:
# Indices of data points: [1127 1166 1310 1433 1746 1976 4527 4546 4890]
# Number of data points in this cluster: 9
#
# Cluster 717:
# Indices of data points: [  12 1073 1862]
# Number of data points in this cluster: 3
#
# Cluster 718:
# Indices of data points: [ 587 2236 2490 4569]
# Number of data points in this cluster: 4
#
# Cluster 719:
# Indices of data points: [ 974 1950 1984 2754 4927]
# Number of data points in this cluster: 5
#
# Cluster 720:
# Indices of data points: [ 249  505  802 1363 1788 2526 2606 2955 3227 3729 4481 4733 4874]
# Number of data points in this cluster: 13
#
# Cluster 721:
# Indices of data points: [  23 4422]
# Number of data points in this cluster: 2
#
# Cluster 722:
# Indices of data points: [1954 4719]
# Number of data points in this cluster: 2
#
# Cluster 723:
# Indices of data points: [2209 4039 4685]
# Number of data points in this cluster: 3
#
# Cluster 724:
# Indices of data points: [ 563 3303 4106]
# Number of data points in this cluster: 3
#
# Cluster 725:
# Indices of data points: [1485 1970 4377 4513 4627]
# Number of data points in this cluster: 5
#
# Cluster 726:
# Indices of data points: [  84  967 1072 1497 2271 2633 3821 4015 4411]
# Number of data points in this cluster: 9
#
# Cluster 727:
# Indices of data points: [1728 1737 1779 3253]
# Number of data points in this cluster: 4
#
# Cluster 728:
# Indices of data points: [3472 3503 3923]
# Number of data points in this cluster: 3
#
# Cluster 729:
# Indices of data points: [ 226 1930 4273]
# Number of data points in this cluster: 3
#
# Cluster 730:
# Indices of data points: [1796 3000 3670 3994 4112]
# Number of data points in this cluster: 5
#
# Cluster 731:
# Indices of data points: [ 599  798 1377 1914 3031 3077 3251 3944 4169 4523]
# Number of data points in this cluster: 10
#
# Cluster 732:
# Indices of data points: [1589 2817 3662 4880]
# Number of data points in this cluster: 4
#
# Cluster 733:
# Indices of data points: [ 579 1617 2033 3221 3297]
# Number of data points in this cluster: 5
#
# Cluster 734:
# Indices of data points: [ 628  746 1313 1394 2758 3518 3528]
# Number of data points in this cluster: 7
#
# Cluster 735:
# Indices of data points: [4855 5013]
# Number of data points in this cluster: 2
#
# Cluster 736:
# Indices of data points: [ 583  813 1154 1405 2343 2408 2916 4412 4902]
# Number of data points in this cluster: 9
#
# Cluster 737:
# Indices of data points: [2237 3626 4923]
# Number of data points in this cluster: 3
#
# Cluster 738:
# Indices of data points: [2805 4634 4738]
# Number of data points in this cluster: 3
#
# Cluster 739:
# Indices of data points: [2112 2145 4500 4638]
# Number of data points in this cluster: 4
#
# Cluster 740:
# Indices of data points: [1196 1915 3269]
# Number of data points in this cluster: 3
#
# Cluster 741:
# Indices of data points: [ 372 1430 5041]
# Number of data points in this cluster: 3
#
# Cluster 742:
# Indices of data points: [2391 2989 3659]
# Number of data points in this cluster: 3
#
# Cluster 743:
# Indices of data points: [1456 2906 3307 3752]
# Number of data points in this cluster: 4
#
# Cluster 744:
# Indices of data points: [ 232 2617 2659 3030 3138 3320 3920 4177 4707 4841 4884]
# Number of data points in this cluster: 11
#
# Cluster 745:
# Indices of data points: [  56 1379 1711 1890 2036 2198 2445 2584 4415 4549 4578 4892 5072]
# Number of data points in this cluster: 13
#
# Cluster 746:
# Indices of data points: [1781 2903 4299]
# Number of data points in this cluster: 3
#
# Cluster 747:
# Indices of data points: [ 573 2643 3274 3855]
# Number of data points in this cluster: 4
#
# Cluster 748:
# Indices of data points: [  47   88 1858 2411 2689 3215 3833 4392 4702 4827 4864]
# Number of data points in this cluster: 11
#
# Cluster 749:
# Indices of data points: [ 612 3594 4160 4482]
# Number of data points in this cluster: 4
#
# Cluster 750:
# Indices of data points: [4463 4998]
# Number of data points in this cluster: 2
#
# Cluster 751:
# Indices of data points: [2035 2104]
# Number of data points in this cluster: 2
#
# Cluster 752:
# Indices of data points: [1016 1385 3162 4181 4364]
# Number of data points in this cluster: 5
#
# Cluster 753:
# Indices of data points: [ 359 1299 1718 3006 3624 4577 4911]
# Number of data points in this cluster: 7
#
# Cluster 754:
# Indices of data points: [1194]
# Number of data points in this cluster: 1
#
# Cluster 755:
# Indices of data points: [  32  294  325  650  892  983 2171 3128 3187 3217 4421 5054]
# Number of data points in this cluster: 12
#
# Cluster 756:
# Indices of data points: [  76  847 1044 1380 1765 3028 3179 3915 3943 4657 4703]
# Number of data points in this cluster: 11
#
# Cluster 757:
# Indices of data points: [ 229  652 1061 1157 1165 2926 3086 3286 3357 4216 4227 4671]
# Number of data points in this cluster: 12
#
# Cluster 758:
# Indices of data points: [2980 3968]
# Number of data points in this cluster: 2
#
# Cluster 759:
# Indices of data points: [1869 4446]
# Number of data points in this cluster: 2
#
# Cluster 760:
# Indices of data points: [1621 2037 2770 4066]
# Number of data points in this cluster: 4

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# Load data (assuming the data is saved in a numpy array .npy file)
try:
    F = np.load(r"C:\SumMe\Augmentation\Augcr\features_last_lstm.npy")  # Adjust this path if necessary
except FileNotFoundError:
    print("Error: The specified file was not found.")
    exit(1)

# Set parameters
N = 761  # Number of clusters
num_samples = F.shape[0]  # Number of data points (950)
np.random.seed(2)  # Setting the random seed for reproducibility

# Perform k-means clustering
kmeans = KMeans(n_clusters=N, init='k-means++', random_state=2)
kmeans.fit(F)

# Get cluster assignments (C_IDX) and cluster centroids (CC)
C_IDX = kmeans.labels_
CC = kmeans.cluster_centers_

# Initialize binary matrix (950 x 143) with zeros
keyframe_matrix = np.zeros((num_samples, N), dtype=int)

# Loop through each cluster and find the closest data point to the centroid
for cluster_idx in range(N):
    # Get the indices of the data points in the current cluster
    cluster_indices = np.where(C_IDX == cluster_idx)[0]
    
    # Skip empty clusters (if any)
    if len(cluster_indices) == 0:
        print(f"Cluster {cluster_idx} is empty, skipping.")
        continue
    
    # Get the feature vectors for the data points in this cluster
    cluster_features = F[cluster_indices, :]
    
    # Get the centroid of this cluster
    centroid = CC[cluster_idx]
    
    # Compute the Euclidean distance between each point in the cluster and the centroid
    distances = cdist(cluster_features, centroid.reshape(1, -1), metric='euclidean')
    
    # Get the index of the closest data point to the centroid
    closest_point_idx = cluster_indices[np.argmin(distances)]
    
    # Set the corresponding entry in the binary matrix to 1 (keyframe)
    keyframe_matrix[closest_point_idx, cluster_idx] = 1

    # Optionally, print the keyframe index for each cluster
    print(f"Cluster {cluster_idx}: Keyframe index: {closest_point_idx}")
# keyframe_matrix is now a 950 x 143 binary matrix
# You can use it for further analysis or saving to a file
# Out:
# Cluster 0: Keyframe index: 2212
# Cluster 1: Keyframe index: 219
# Cluster 2: Keyframe index: 3132
# Cluster 3: Keyframe index: 4075
# Cluster 4: Keyframe index: 3664
# Cluster 5: Keyframe index: 2792
# Cluster 6: Keyframe index: 2564
# Cluster 7: Keyframe index: 3052
# Cluster 8: Keyframe index: 1602
# Cluster 9: Keyframe index: 1817
# Cluster 10: Keyframe index: 131
# Cluster 11: Keyframe index: 2834
# Cluster 12: Keyframe index: 3879
# Cluster 13: Keyframe index: 750
# Cluster 14: Keyframe index: 1816
# Cluster 15: Keyframe index: 1448
# Cluster 16: Keyframe index: 3401
# Cluster 17: Keyframe index: 2965
# Cluster 18: Keyframe index: 3747
# Cluster 19: Keyframe index: 536
# Cluster 20: Keyframe index: 2302
# Cluster 21: Keyframe index: 3198
# Cluster 22: Keyframe index: 345
# Cluster 23: Keyframe index: 642
# Cluster 24: Keyframe index: 2451
# Cluster 25: Keyframe index: 926
# Cluster 26: Keyframe index: 2365
# Cluster 27: Keyframe index: 1715
# Cluster 28: Keyframe index: 4100
# Cluster 29: Keyframe index: 1133
# Cluster 30: Keyframe index: 2086
# Cluster 31: Keyframe index: 3953
# Cluster 32: Keyframe index: 3783
# Cluster 33: Keyframe index: 302
# Cluster 34: Keyframe index: 1839
# Cluster 35: Keyframe index: 1825
# Cluster 36: Keyframe index: 3413
# Cluster 37: Keyframe index: 1808
# Cluster 38: Keyframe index: 887
# Cluster 39: Keyframe index: 2772
# Cluster 40: Keyframe index: 4188
# Cluster 41: Keyframe index: 160
# Cluster 42: Keyframe index: 501
# Cluster 43: Keyframe index: 164
# Cluster 44: Keyframe index: 4769
# Cluster 45: Keyframe index: 4692
# Cluster 46: Keyframe index: 3916
# Cluster 47: Keyframe index: 1149
# Cluster 48: Keyframe index: 4085
# Cluster 699: Keyframe index: 3107
# Cluster 700: Keyframe index: 71
# Cluster 701: Keyframe index: 966
# Cluster 702: Keyframe index: 4804
# Cluster 703: Keyframe index: 141
# Cluster 704: Keyframe index: 2701
# Cluster 705: Keyframe index: 2529
# Cluster 706: Keyframe index: 4757
# Cluster 707: Keyframe index: 906
# Cluster 708: Keyframe index: 1854
# Cluster 709: Keyframe index: 2545
# Cluster 710: Keyframe index: 4398
# Cluster 711: Keyframe index: 2310
# Cluster 712: Keyframe index: 4050
# Cluster 713: Keyframe index: 1529
# Cluster 714: Keyframe index: 1786
# Cluster 715: Keyframe index: 4439
# Cluster 716: Keyframe index: 1310
# Cluster 717: Keyframe index: 12
# Cluster 718: Keyframe index: 587
# Cluster 719: Keyframe index: 4927
# Cluster 720: Keyframe index: 4481
# Cluster 721: Keyframe index: 4422
# Cluster 722: Keyframe index: 1954
# Cluster 723: Keyframe index: 2209
# Cluster 724: Keyframe index: 563
# Cluster 725: Keyframe index: 1970
# Cluster 726: Keyframe index: 4015
# Cluster 727: Keyframe index: 1728
# Cluster 728: Keyframe index: 3923
# Cluster 729: Keyframe index: 1930
# Cluster 730: Keyframe index: 1796
# Cluster 731: Keyframe index: 3251
# Cluster 732: Keyframe index: 3662
# Cluster 733: Keyframe index: 3297
# Cluster 734: Keyframe index: 3518
# Cluster 735: Keyframe index: 4855
# Cluster 736: Keyframe index: 813
# Cluster 737: Keyframe index: 2237
# Cluster 738: Keyframe index: 4738
# Cluster 739: Keyframe index: 4500
# Cluster 740: Keyframe index: 3269
# Cluster 741: Keyframe index: 1430
# Cluster 742: Keyframe index: 3659
# Cluster 743: Keyframe index: 2906
# Cluster 744: Keyframe index: 3920
# Cluster 745: Keyframe index: 2198
# Cluster 746: Keyframe index: 1781
# Cluster 747: Keyframe index: 2643
# Cluster 748: Keyframe index: 1858
# Cluster 749: Keyframe index: 612
# Cluster 750: Keyframe index: 4463
# Cluster 751: Keyframe index: 2035
# Cluster 752: Keyframe index: 4181
# Cluster 753: Keyframe index: 359
# Cluster 754: Keyframe index: 1194
# Cluster 755: Keyframe index: 3187
# Cluster 756: Keyframe index: 3943
# Cluster 757: Keyframe index: 2926
# Cluster 758: Keyframe index: 2980
# Cluster 759: Keyframe index: 4446
# Cluster 760: Keyframe index: 4066

# %%
# Save the keyframe binary matrix
np.save(r'C:\SumMe\Augmentation\Augcr\keyframe', keyframe_matrix)

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from scipy.io import savemat

# Load data (assuming the data is saved in a numpy array .npy file)
try:
    F = np.load(r"C:\SumMe\Augmentation\Augcr\features_last_lstm.npy")  # Adjust this path if necessary
except FileNotFoundError:
    print("Error: The specified file was not found.")
    exit(1)

# Check shape of input data
print("Shape of input data F:", F.shape)

# Set parameters
N = 761  # Number of clusters
num_samples = F.shape[0]  # Number of data points (should be 950)
np.random.seed(2)  # Setting the random seed for reproducibility

# Perform k-means clustering
kmeans = KMeans(n_clusters=N, init='k-means++', n_init=50, random_state=2)
kmeans.fit(F)

# Get cluster assignments (C_IDX) and cluster centroids (CC)
C_IDX = kmeans.labels_
CC = kmeans.cluster_centers_

# Check cluster assignments
unique, counts = np.unique(C_IDX, return_counts=True)
cluster_sizes = dict(zip(unique, counts))
print("Cluster sizes:", cluster_sizes)

# Initialize binary matrix (950 x 143) with zeros
keyframe_matrix = np.zeros((num_samples, N), dtype=int)

# Loop through each cluster and find the closest data point to the centroid
for cluster_idx in range(N):
    # Get the indices of the data points in the current cluster
    cluster_indices = np.where(C_IDX == cluster_idx)[0]
    
    # Skip empty clusters (if any)
    if len(cluster_indices) == 0:
        print(f"Warning: Cluster {cluster_idx} is empty, skipping.")
        continue
    
    # Get the feature vectors for the data points in this cluster
    cluster_features = F[cluster_indices, :]
    
    # Get the centroid of this cluster
    centroid = CC[cluster_idx]
    
    # Compute the Euclidean distance between each point in the cluster and the centroid
    distances = cdist(cluster_features, centroid.reshape(1, -1), metric='euclidean')
    
    # Get the index of the closest data point to the centroid
    closest_point_idx = cluster_indices[np.argmin(distances)]
    
    # Set the corresponding entry in the binary matrix to 1 (keyframe)
    keyframe_matrix[closest_point_idx, cluster_idx] = 1

# Check the shape of the keyframe matrix
print("Shape of keyframe matrix:", keyframe_matrix.shape)

# Save the matrix as a .mat file
savemat(r'C:\SumMe\Augmentation\Augcr\keyframe_matrix.mat', {'keyframe_matrix': keyframe_matrix})
# Out:
# Shape of input data F: (5075, 32)
# Cluster sizes: {0: 5, 1: 21, 2: 4, 3: 9, 4: 5, 5: 11, 6: 4, 7: 13, 8: 4, 9: 2, 10: 19, 11: 7, 12: 12, 13: 12, 14: 3, 15: 3, 16: 5, 17: 4, 18: 11, 19: 2, 20: 15, 21: 8, 22: 6, 23: 5, 24: 10, 25: 3, 26: 3, 27: 7, 28: 9, 29: 20, 30: 5, 31: 8, 32: 7, 33: 4, 34: 12, 35: 17, 36: 5, 37: 5, 38: 4, 39: 7, 40: 17, 41: 7, 42: 3, 43: 9, 44: 2, 45: 11, 46: 4, 47: 4, 48: 2, 49: 4, 50: 6, 51: 15, 52: 11, 53: 4, 54: 7, 55: 7, 56: 8, 57: 7, 58: 4, 59: 11, 60: 4, 61: 4, 62: 9, 63: 10, 64: 5, 65: 20, 66: 4, 67: 4, 68: 3, 69: 4, 70: 16, 71: 4, 72: 5, 73: 2, 74: 8, 75: 7, 76: 14, 77: 5, 78: 8, 79: 12, 80: 9, 81: 4, 82: 4, 83: 3, 84: 5, 85: 4, 86: 2, 87: 5, 88: 9, 89: 9, 90: 8, 91: 4, 92: 17, 93: 18, 94: 14, 95: 11, 96: 2, 97: 7, 98: 6, 99: 5, 100: 8, 101: 6, 102: 5, 103: 13, 104: 2, 105: 2, 106: 5, 107: 3, 108: 4, 109: 4, 110: 8, 111: 4, 112: 6, 113: 19, 114: 4, 115: 4, 116: 7, 117: 4, 118: 6, 119: 3, 120: 15, 121: 7, 122: 3, 123: 11, 124: 13, 125: 12, 126: 4, 127: 2, 128: 4
, 384: 1, 385: 13, 386: 2, 387: 11, 388: 6, 389: 15, 390: 18, 391: 12, 392: 5, 393: 3, 394: 6, 395: 2, 396: 5, 397: 1, 398: 13, 399: 8, 400: 17, 401: 7, 402: 3, 403: 6, 404: 7, 405: 16, 406: 4, 407: 10, 408: 3, 409: 6, 410: 5, 411: 3, 412: 2, 413: 7, 414: 7, 415: 11, 416: 7, 417: 2, 418: 10, 419: 14, 420: 4, 421: 4, 422: 6, 423: 7, 424: 4, 425: 1, 426: 4, 427: 2, 428: 3, 429: 5, 430: 3, 431: 4, 432: 5, 433: 14, 434: 18, 435: 3, 436: 9, 437: 3, 438: 5, 439: 4, 440: 3, 441: 5, 442: 5, 443: 4, 444: 10, 445: 9, 446: 3, 447: 2, 448: 17, 449: 6, 450: 2, 451: 4, 452: 5, 453: 6, 454: 9, 455: 3, 456: 15, 457: 4, 458: 19, 459: 4, 460: 2, 461: 6, 462: 2, 463: 12, 464: 12, 465: 4, 466: 3, 467: 12, 468: 6, 469: 5, 470: 9, 471: 6, 472: 22, 473: 2, 474: 8, 475: 6, 476: 14, 477: 4, 478: 10, 479: 4, 480: 16, 481: 3, 482: 6, 483: 3, 484: 7, 485: 5, 486: 3, 487: 5, 488: 6, 489: 16, 490: 8, 491: 17, 492: 5, 493: 2, 494: 3, 495: 3, 496: 1 ...
# Shape of keyframe matrix: (5075, 761)

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Step 1: Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augcr\features_last_lstm.npy")

# Step 2: (Optional) Preprocess the data if needed
# For example, you might want to scale the features to ensure the clustering works well
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 3: Perform Agglomerative Clustering
# You can specify the number of clusters or other hyperparameters here
n_clusters = 761  # Example, set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model to the feature matrix
clustering_labels = clustering.fit_predict(features_scaled)

# Step 4: (Optional) Visualize the results if the features are 2D (or use dimensionality reduction)
if features_scaled.shape[1] == 2:  # If your features are 2D, you can visualize them
    plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=clustering_labels, cmap='viridis')
    plt.title("Agglomerative Clustering Results")
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# If you have higher-dimensional features, consider using PCA to reduce to 2D for visualization
# For example:
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# features_2d = pca.fit_transform(features_scaled)
# plt.scatter(features_2d[:, 0], features_2d[:, 1], c=clustering_labels, cmap='viridis')
# plt.show()

# Step 5: View the labels assigned to each data point
print("Cluster Labels:", clustering_labels)
# Out:
# Cluster Labels: [408 128 374 ... 741  97 385]

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augcr\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters =761  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Display the clusters in the desired format
for cluster_label, indices in cluster_dict.items():
    print(f"Cluster {cluster_label}:")
    print(f"Indices of data points: {indices}")
    print(f"Number of data points in this cluster: {len(indices)}\n")
# Out:
# Cluster 408:
# Indices of data points: [0, 14, 31, 551, 735, 1091, 1668, 1974, 2133, 2317, 2722, 3126, 4266, 4693]
# Number of data points in this cluster: 14
#
# Cluster 128:
# Indices of data points: [1, 533, 1036, 1214, 1273, 1591, 2167, 3377, 4530, 4581, 4611, 5010]
# Number of data points in this cluster: 12
#
# Cluster 374:
# Indices of data points: [2, 210, 498, 594, 948, 1212, 1408, 1559, 3561, 4498, 4945]
# Number of data points in this cluster: 11
#
# Cluster 207:
# Indices of data points: [3, 266, 1151, 1208, 1943, 2978, 3073, 3197, 3236, 3885, 4477, 4593, 4766, 4838, 5032]
# Number of data points in this cluster: 15
#
# Cluster 159:
# Indices of data points: [4, 550, 724, 858, 937, 1428, 2310, 2675, 3082, 3845, 4948, 4971, 5065]
# Number of data points in this cluster: 13
#
# Cluster 318:
# Indices of data points: [5, 38, 121, 562, 617, 988, 1315, 2201, 3204, 4790]
# Number of data points in this cluster: 10
#
# Cluster 375:
# Indices of data points: [6, 153, 201, 1114, 1922, 2688, 3026, 3135, 4330]
# Number of data points in this cluster: 9
#
# Cluster 493:
# Indices of data points: [7, 1350, 1834, 3909]
# Number of data points in this cluster: 4
#
# Cluster 97:
# Indices of data points: [8, 155, 633, 1633, 2121, 2347, 2607, 4673, 4789, 5073]
# Number of data points in this cluster: 10
#
# Cluster 173:
# Indices of data points: [9, 2269, 2402, 2447, 3380, 3516, 3556, 3685, 4032, 4149, 4553, 4696, 4721, 4922, 5057]
# Number of data points in this cluster: 15
#
# Cluster 78:
# Indices of data points: [10, 274, 491, 704, 1125, 1218, 2029, 2078, 2149, 2179, 2205, 3101, 3498, 3587, 4212, 4236, 4426]
# Number of data points in this cluster: 17
#
# Cluster 430:
# Indices of data points: [11, 506, 1850, 2683, 4210]
# Number of data points in this cluster: 5
#
# Cluster 129:
# Indices of data points: [12, 536, 1073, 1862, 3425, 3756, 4184]
# Number of data points in this cluster: 7
#
# Cluster 316:
# Indices of data points: [13, 774, 1749, 1977, 2126, 3809]
# Number of data points in this cluster: 6
#
# Cluster 721:
# Indices of data points: [15, 284, 1592, 3296]
# Number of data points in this cluster: 4
#
# Cluster 328:
# Indices of data points: [16, 224, 383, 1982, 2170, 2922, 3046, 3093, 4649, 5026, 5058]
# Number of data points in this cluster: 11
#
# Cluster 674:
# Indices of data points: [17, 815, 2581, 2941, 3338, 4389]
# Number of data points in this cluster: 6
#
# Cluster 322:
# Indices of data points: [18, 450, 960, 3455]
# Number of data points in this cluster: 4
#
# Cluster 336:
# Indices of data points: [19, 575, 1202, 1227, 3376, 4926]
# Number of data points in this cluster: 6
#
# Cluster 556:
# Indices of data points: [20, 1955, 3142, 3820, 4262]
# Number of data points in this cluster: 5
#
# Cluster 609:
# Indices of data points: [21, 1482, 2139, 4270]
# Number of data points in this cluster: 4
#
# Cluster 40:
# Indices of data points: [22, 900, 1120, 1696, 2355, 3271, 3660, 3687, 4103, 4354, 4897]
# Number of data points in this cluster: 11
#
# Cluster 683:
# Indices of data points: [23, 4422]
# Number of data points in this cluster: 2
#
# Cluster 212:
# Indices of data points: [24, 868, 1050, 1423, 1924, 2529, 2814, 3929, 4647, 5047]
# Number of data points in this cluster: 10
#
# Cluster 576:
# Indices of data points: [25, 556, 877, 2425, 2821, 3513]
# Number of data points in this cluster: 6
#
# Cluster 544:
# Indices of data points: [26, 179, 569, 1338, 1546]
# Number of data points in this cluster: 5
#
# Cluster 546:
# Indices of data points: [27, 534, 804, 977, 1751, 4965]
# Number of data points in this cluster: 6
#
# Cluster 19:
# Indices of data points: [28, 592, 694, 847, 909, 1044, 1086, 1380, 1765, 3028, 3943, 4582, 4657, 4703]
# Number of data points in this cluster: 14
#
# Cluster 506:
# Indices of data points: [29, 492, 740, 942, 1561, 1948, 2321, 3595, 3639, 3830, 4785]
# Number of data points in this cluster: 11
#
# Cluster 508:
# Indices of data points: [30, 642, 700, 1900, 2646, 2697, 2835, 3326, 4268, 4508, 5068]
# Number of data points in this cluster: 11
#
# Cluster 3:
# Indices of data points: [32, 294, 325, 983, 1238, 1262, 2472, 2631, 3128, 3187, 3217, 4313, 4421, 4814, 5054]
# Number of data points in this cluster: 15
#
# Cluster 68:
# Indices of data points: [33, 130, 715, 1768, 2318, 2344, 2696, 3795, 4254, 4323, 4402, 4666, 4805]
# Number of data points in this cluster: 13
#
# Cluster 271:
# Indices of data points: [34, 667, 1024, 1129, 1311, 1337, 3474, 4590]
# Number of data points in this cluster: 8
#
# Cluster 533:
# Indices of data points: [35, 472, 613, 894, 2196, 2949, 3423, 3451, 3739, 4675, 4944]
# Number of data points in this cluster: 11
#
# Cluster 605:
# Indices of data points: [36, 2363, 3986]
# Number of data points in this cluster: 3
#
# Cluster 392:
# Indices of data points: [37, 344, 945, 2015, 3020, 3446, 3554, 3602, 3679, 4190, 4223]
# Number of data points in this cluster: 11
#
# Cluster 527:
# Indices of data points: [39, 217, 356, 1382, 3962]
# Number of data points in this cluster: 5
#
# Cluster 214:
# Indices of data points: [40, 207, 346, 1279, 1381, 2061, 2546, 2704, 3168, 3231, 4061]
# Number of data points in this cluster: 11
#
# Cluster 55:
# Indices of data points: [41, 660, 843, 1000, 1171, 1996, 2010, 2156, 2380, 2778, 3171, 3350]
# Number of data points in this cluster: 12
#
# Cluster 43:
# Indices of data points: [42, 966, 1068, 1095, 1770, 3390, 4260, 4456, 4981]
# Number of data points in this cluster: 9
#
# Cluster 86:
# Indices of data points: [43, 423, 869, 1223, 1864, 2346, 2895, 4737]
# Number of data points in this cluster: 8
#
# Cluster 206:
# Indices of data points: [44, 2492, 2578, 2999, 3054, 3067, 3407, 3669, 3921, 3942, 4129, 4154, 4332, 4605]
# Number of data points in this cluster: 14
#
# Cluster 365:
# Indices of data points: [45, 335, 425, 656, 1019, 2172, 3109, 4962]
# Number of data points in this cluster: 8
#
# Cluster 637:
# Indices of data points: [46, 3279, 4695]
# Number of data points in this cluster: 3
#
# Cluster 289:
# Indices of data points: [47, 88, 1858, 2411, 2689, 3215, 3833, 4702, 4864]
# Number of data points in this cluster: 9
#
# Cluster 482:
# Indices of data points: [48, 876, 1136, 1260, 1477, 1926, 4062, 4173, 4910]
# Number of data points in this cluster: 9
#
# Cluster 310:
# Indices of data points: [49, 60, 174, 427, 2406, 2435, 2747, 2940, 3127, 4683, 4946]
# Number of data points in this cluster: 11
#
# Cluster 103:
# Indices of data points: [50, 235, 763, 1320, 1920, 2226, 4429, 4617, 4801]
# Number of data points in this cluster: 9
#
# Cluster 167:
# Indices of data points: [51, 263, 377, 625, 904, 1283, 1676, 1760, 1895, 2503, 3234, 3449, 4259, 4901]
# Number of data points in this cluster: 14
#
# Cluster 91:
# Indices of data points: [52, 669, 968, 1039, 1353, 1861, 3191, 3311, 3692, 4628, 4979]
# Number of data points in this cluster: 11
#
# Cluster 542:
# Indices of data points: [53, 75, 110, 2707, 2927, 2986, 3757, 4494, 4506]
# Number of data points in this cluster: 9
#
# Cluster 194:
# Indices of data points: [54, 797, 1105, 1203, 1308, 1554, 1632, 2479, 3071, 3083, 3668]
# Number of data points in this cluster: 11
#
# Cluster 501:
# Indices of data points: [55, 389, 1455, 3029, 3533, 3643, 3647, 4604, 4836, 4857, 4873]
# Number of data points in this cluster: 11
#
# Cluster 357:
# Indices of data points: [56, 112, 125, 762, 772, 1007, 2652, 3076, 3494, 4207, 4688, 4896]
# Number of data points in this cluster: 12
#
# Cluster 229:
# Indices of data points: [57, 185, 612, 1085, 2089, 2576, 3052, 3426, 3594, 4160, 4297, 4482, 4782]
# Number of data points in this cluster: 13
#
# Cluster 273:
# Indices of data points: [58, 169, 370, 560, 859, 1180, 1442, 3040, 3169, 4343, 4654, 4988]
# Number of data points in this cluster: 12
#
# Cluster 62:
# Indices of data points: [59, 98, 295, 546, 963, 1322, 1504, 2028, 2441, 2449, 2451, 2618, 2813, 3542, 3710, 3732, 3938, 4886]
# Number of data points in this cluster: 18
#
# Cluster 36:
# Indices of data points: [61, 614, 828, 928, 939, 1231, 1282, 2620, 2741, 3304, 3805, 4037, 4626, 4750, 4878]
# Number of data points in this cluster: 15
#
# Cluster 666:
# Indices of data points: [62, 406, 823, 1109, 1362, 3947, 3966, 4257, 4305, 4468, 4676, 4951]
# Number of data points in this cluster: 12
#
# Cluster 228:
# Indices of data points: [63, 490, 1324, 1413, 1583, 1723, 2373, 2505, 2937, 2973, 3329, 3530, 3538, 3872, 4509, 4879, 5022]
# Number of data points in this cluster: 17
#
# Cluster 122:
# Indices of data points: [64, 664, 1234, 1826, 1828, 4413]
# Number of data points in this cluster: 6
#
# Cluster 53:
# Indices of data points: [65, 261, 891, 1011, 1566, 2477, 2626, 2933, 3144, 3775, 3806, 4124, 4687]
# Number of data points in this cluster: 13
#
# Cluster 424:
# Indices of data points: [66, 956, 1004, 2547, 2668, 3843, 4241, 4888]
# Number of data points in this cluster: 8
#
# Cluster 201:
# Indices of data points: [67, 470, 1680, 1934, 2714, 4855, 5013]
# Number of data points in this cluster: 7
#
# Cluster 60:
# Indices of data points: [68, 310, 674, 1061, 1228, 1602, 1721, 3357, 3846, 4227, 4231, 4579, 4671, 5039]
# Number of data points in this cluster: 14
#
# Cluster 18:
# Indices of data points: [69, 228, 849, 1300, 2539, 3199, 3211, 4335, 4444, 4599, 4630]
# Number of data points in this cluster: 11
#
# Cluster 560:
# Indices of data points: [70, 681, 791, 1245, 1302, 1348, 4374, 4705]
# Number of data points in this cluster: 8
#
# Cluster 30:
# Indices of data points: [71, 77, 659, 943, 1029, 1135, 1391, 1683, 2211, 3033, 3095, 3189, 4799]
# Number of data points in this cluster: 13
#
# Cluster 339:
# Indices of data points: [72, 205, 268, 1078, 1124, 1287, 1326, 3399]
# Number of data points in this cluster: 8
#
# Cluster 16:
# Indices of data points: [73, 714, 882, 1047, 1444, 1712, 1733, 1845, 2032, 2416, 2523, 3249, 3460, 3621, 3664, 4021, 4178, 4368, 4507, 4711, 4833]
# Number of data points in this cluster: 21
#
# Cluster 200:
# Indices of data points: [74, 2227, 2360, 2423, 2466, 2718, 3200, 3298, 3427, 3796, 4420, 4669]
# Number of data points in this cluster: 12
#
# Cluster 587:
# Indices of data points: [76, 2030, 3179, 3915, 4308]
# Number of data points in this cluster: 5
#
# Cluster 105:
# Indices of data points: [78, 99, 117, 1063, 1220, 1931, 2242, 2496, 2508, 2648, 2958, 3667, 3981, 4014, 4491, 4976]
# Number of data points in this cluster: 16
#
# Cluster 187:
# Indices of data points: [79, 257, 1630, 1767, 2112, 2145, 4125, 4500, 4537]
# Number of data points in this cluster: 9
#
# Cluster 381:
# Indices of data points: [80, 514, 703, 781, 1070, 1290, 1312, 1473, 2595, 2852, 3765, 3804, 4485]
# Number of data points in this cluster: 13
#
# Cluster 121:
# Indices of data points: [81, 1147, 2034, 2085, 3212, 3415, 3574, 4121, 4376, 4409, 4596, 4859, 5003, 5005]
# Number of data points in this cluster: 14
#
# Cluster 710:
# Indices of data points: [82, 1305, 1465, 2138, 2702, 2775, 3802, 5001]
# Number of data points in this cluster: 8
#
# Cluster 202:
# Indices of data points: [83, 766, 906, 1025, 2161, 2169, 2212, 2448, 2565, 2836, 3744, 4175, 4919, 5059]
# Number of data points in this cluster: 14
#
# Cluster 397:
# Indices of data points: [84, 1497, 2271, 2633, 3821, 4015, 4411]
# Number of data points in this cluster: 7
#
# Cluster 140:
# Indices of data points: [85, 148, 1268, 3489, 3869, 4157]
# Number of data points in this cluster: 6
#
# Cluster 110:
# Indices of data points: [86, 156, 603, 641, 1167, 1368, 1422, 2509, 3065, 4557]
# Number of data points in this cluster: 10
#
# Cluster 640:
# Indices of data points: [87, 1486, 2354, 2681, 4567]
# Number of data points in this cluster: 5
#
# Cluster 195:
# Indices of data points: [89, 126, 2117, 2844, 3340, 3734, 4432]
# Number of data points in this cluster: 7
#
# Cluster 234:
# Indices of data points: [90, 104, 528, 618, 808, 842, 1186, 1390, 3018, 3254, 3436, 3762, 4010, 4692, 4990]
# Number of data points in this cluster: 15
#
# Cluster 25:
# Indices of data points: [91, 522, 1887, 2672, 3114, 3623, 3844, 4556, 4610, 4668, 4714, 4765, 4795]
# Number of data points in this cluster: 13
#
# Cluster 549:
# Indices of data points: [92, 773, 981, 1276, 1684, 2710, 2717, 2850, 2942, 3852, 4251, 4645, 4856]
# Number of data points in this cluster: 13
#
# Cluster 308:
# Indices of data points: [93, 143, 933, 1507, 2497, 2795, 3680, 4119, 4504, 4591, 4812]
# Number of data points in this cluster: 11
#
# Cluster 434:
# Indices of data points: [94, 368, 1141, 2193, 2494, 2776, 2934, 3106, 3346, 3443, 3665, 3825, 4161]
# Number of data points in this cluster: 13
#
# Cluster 44:
# Indices of data points: [95, 405, 709, 742, 1017, 1020, 1030, 1144, 1197, 1997, 2185, 3038, 3417, 3508, 3534, 3646, 4798]
# Number of data points in this cluster: 17
#
# Cluster 163:
# Indices of data points: [96, 287, 1032, 2428, 2465, 2627, 2686, 3166, 3332, 3551, 3581, 3714, 4151, 4283, 4339, 4534, 4600]
# Number of data points in this cluster: 17
#
# Cluster 584:
# Indices of data points: [97, 338, 884, 1138, 2090, 2114, 2132, 2645, 2712]
# Number of data points in this cluster: 9
#
# Cluster 50:
# Indices of data points: [100, 208, 2062, 2221, 2247, 3174, 3408, 3412, 3707, 3960, 4337, 4535, 4576, 4741, 4821]
# Number of data points in this cluster: 15
#
# Cluster 294:
# Indices of data points: [101, 1545, 2519, 3635, 4698, 4889, 5045]
# Number of data points in this cluster: 7
#
# Cluster 416:
# Indices of data points: [102, 1947, 2135, 2501, 2569, 3192, 3218, 4193, 4716, 5007]
# Number of data points in this cluster: 10
#
# Cluster 642:
# Indices of data points: [103, 895, 4533, 4561, 4996]
# Number of data points in this cluster: 5
#
# Cluster 440:
# Indices of data points: [105, 1813, 3206, 3448, 4709, 4734]
# Number of data points in this cluster: 6
#
# Cluster 34:
# Indices of data points: [106, 662, 1033, 1387, 2210, 2644, 2662, 2884, 3424, 3769, 4204, 4310, 4618]
# Number of data points in this cluster: 13
#
# Cluster 104:
# Indices of data points: [107, 1185, 1316, 1332, 1371, 2231, 2709, 2950, 3167, 3550, 4678, 5036]
# Number of data points in this cluster: 12
#
# Cluster 650:
# Indices of data points: [108, 743, 1729, 1964]
# Number of data points in this cluster: 4
#
# Cluster 581:
# Indices of data points: [109, 1191, 1344, 2706, 3010]
# Number of data points in this cluster: 5
#
# Cluster 747:
# Indices of data points: [111, 527, 1417, 1624]
# Number of data points in this cluster: 4
#
# Cluster 739:
# Indices of data points: [113, 745, 1255, 1274, 1886, 5033]
# Number of data points in this cluster: 6
#
# Cluster 439:
# Indices of data points: [114, 1495, 2885, 3851]
# Number of data points in this cluster: 4
#
# Cluster 472:
# Indices of data points: [115, 177, 1969, 3591]
# Number of data points in this cluster: 4
#
# Cluster 621:
# Indices of data points: [116, 1601, 1700, 2881, 3299, 4214]
# Number of data points in this cluster: 6
#
# Cluster 1:
# Indices of data points: [118, 316, 407, 508, 517, 1126, 1357, 1392, 2684, 2755, 2785, 4644, 4651, 4865, 4876, 4920, 4957]
# Number of data points in this cluster: 17
#
# Cluster 462:
# Indices of data points: [119, 265, 464, 1002, 1060, 1435, 1513, 2605, 2787, 3069, 3177, 4152, 4565]
# Number of data points in this cluster: 13
#
# Cluster 553:
# Indices of data points: [120, 233, 622, 800, 994, 2962, 4658]
# Number of data points in this cluster: 7
#
# Cluster 320:
# Indices of data points: [122, 488, 1805, 4895, 4972]
# Number of data points in this cluster: 5
#
# Cluster 181:
# Indices of data points: [123, 979, 1067, 1210, 1971, 3181]
# Number of data points in this cluster: 6
#
# Cluster 534:
# Indices of data points: [124, 2304, 4064, 4233, 4473]
# Number of data points in this cluster: 5
#
# Cluster 182:
# Indices of data points: [127, 358, 938, 1037, 1123, 1254, 1854, 2199, 2656, 2862, 4255, 4574, 4700, 4925, 4973, 5069]
# Number of data points in this cluster: 16
#
# Cluster 644:
# Indices of data points: [128, 192, 414, 558, 835, 1042, 1280, 1424, 2218, 3045]
# Number of data points in this cluster: 10
#
# Cluster 388:
# Indices of data points: [129, 231, 597, 1252, 1626, 1987, 2002, 2101, 2157, 2189, 2194, 2263, 3515, 4306, 4550]
# Number of data points in this cluster: 15
#
# Cluster 288:
# Indices of data points: [131, 2827]
# Number of data points in this cluster: 2
#
# Cluster 571:
# Indices of data points: [132, 203, 477, 519, 581, 1031, 1319, 2462, 2782, 3228, 3728, 4909]
# Number of data points in this cluster: 12
#
# Cluster 49:
# Indices of data points: [133, 486, 2159, 2624, 2663, 2708, 2939, 3466, 3730, 3967, 4242, 4536, 4722, 4983]
# Number of data points in this cluster: 14
#
# Cluster 22:
# Indices of data points: [134, 282, 324, 402, 761, 789, 2623, 2727, 4431, 4502, 4552, 4706, 4773]
# Number of data points in this cluster: 13
#
# Cluster 693:
# Indices of data points: [135, 3880, 4030, 4235]
# Number of data points in this cluster: 4
#
# Cluster 130:
# Indices of data points: [136, 280, 419, 852, 883, 985, 1526, 1756, 3257, 3493, 3736, 3819, 4529, 4608, 4661]
# Number of data points in this cluster: 15
#
# Cluster 127:
# Indices of data points: [137, 1954, 2388, 2737, 3419, 3468, 4719]
# Number of data points in this cluster: 7
#
# Cluster 317:
# Indices of data points: [138, 1074, 2426, 2947, 3209, 4220, 4472, 4914, 4985]
# Number of data points in this cluster: 9
#
# Cluster 186:
# Indices of data points: [139, 1641, 2580, 3431, 3834, 4116, 4543, 4802, 4974]
# Number of data points in this cluster: 9
#
# Cluster 296:
# Indices of data points: [140, 589, 668, 1296, 1321, 1577, 2200, 3248]
# Number of data points in this cluster: 8
#
# Cluster 517:
# Indices of data points: [141, 163, 315, 1600, 2647, 2670, 3629, 3754, 4614, 4816]
# Number of data points in this cluster: 10
#
# Cluster 87:
# Indices of data points: [142, 2415, 2769, 2805, 4017, 4634, 4738]
# Number of data points in this cluster: 7
#
# Cluster 137:
# Indices of data points: [144, 288, 2337, 2882, 3618]
# Number of data points in this cluster: 5
#
# Cluster 0:
# Indices of data points: [145, 272, 1010, 2046, 2141, 2625, 2740, 3718, 4202, 4247, 4844, 4938]
# Number of data points in this cluster: 12
#
# Cluster 522:
# Indices of data points: [146, 566, 2929, 3205, 3388, 3813]
# Number of data points in this cluster: 6
#
# Cluster 114:
# Indices of data points: [147, 651, 857, 1744, 2694, 2829, 3176, 3477, 3770, 3856, 3908, 4108]
# Number of data points in this cluster: 12
#
# Cluster 315:
# Indices of data points: [149, 811, 1258, 1666, 2146, 2491, 3051, 3190]
# Number of data points in this cluster: 8
#
# Cluster 189:
# Indices of data points: [150, 194, 352, 1100, 1217, 1735, 2153, 2560, 2650, 3782]
# Number of data points in this cluster: 10
#
# Cluster 364:
# Indices of data points: [151, 444, 953, 3452, 3543, 4435]
# Number of data points in this cluster: 6
#
# Cluster 106:
# Indices of data points: [152, 722, 1541, 1817]
# Number of data points in this cluster: 4
#
# Cluster 465:
# Indices of data points: [154, 2068, 2807, 3884, 4496]
# Number of data points in this cluster: 5
#
# Cluster 414:
# Indices of data points: [157, 970, 1802, 1932, 2053, 2957, 3062, 4345]
# Number of data points in this cluster: 8
#
# Cluster 669:
# Indices of data points: [158, 1882, 2634]
# Number of data points in this cluster: 3
#
# Cluster 81:
# Indices of data points: [159, 283, 726, 2527, 3924, 5021]
# Number of data points in this cluster: 6
#
# Cluster 633:
# Indices of data points: [160, 1467, 4131]
# Number of data points in this cluster: 3
#
# Cluster 295:
# Indices of data points: [161, 881, 1080, 2789, 4718]
# Number of data points in this cluster: 5
#
# Cluster 154:
# Indices of data points: [162, 371, 555, 559, 705, 1406, 2531, 2820, 2924, 3793, 3888, 4761]
# Number of data points in this cluster: 12
#
# Cluster 611:
# Indices of data points: [164, 1778, 2335]
# Number of data points in this cluster: 3
#
# Cluster 600:
# Indices of data points: [165, 3657, 3863, 4102]
# Number of data points in this cluster: 4
#
# Cluster 678:
# Indices of data points: [166, 850, 1906, 2383, 2630, 2936, 4606]
# Number of data points in this cluster: 7
#
# Cluster 744:
# Indices of data points: [167, 251, 2109, 3936, 4336, 4460, 4924]
# Number of data points in this cluster: 7
#
# Cluster 222:
# Indices of data points: [168, 469, 499, 693, 1752, 2610, 3035, 3068, 3157, 3280, 3288, 3683, 3720, 4694, 4885]
# Number of data points in this cluster: 15
#
# Cluster 411:
# Indices of data points: [170, 396, 1536, 1629, 1885, 2371, 4271, 4916, 4956]
# Number of data points in this cluster: 9
#
# Cluster 259:
# Indices of data points: [171, 1333, 1480, 2331, 3365, 4012, 4115, 4763]
# Number of data points in this cluster: 8
#
# Cluster 299:
# Indices of data points: [172, 435, 683, 720, 1655, 2742, 2786, 3226, 3378, 3432, 4148, 4383, 4819, 4831]
# Number of data points in this cluster: 14
#
# Cluster 77:
# Indices of data points: [173, 388, 421, 831, 834, 910, 924, 1520, 2220, 2238, 3021, 3808, 4133, 4328, 4331, 4589, 4999]
# Number of data points in this cluster: 17
#
# Cluster 716:
# Indices of data points: [175, 4680]
# Number of data points in this cluster: 2
#
# Cluster 237:
# Indices of data points: [176, 269, 433, 971, 1647, 2249, 2935, 3048, 3229, 4564, 4686, 4788]
# Number of data points in this cluster: 12
#
# Cluster 20:
# Indices of data points: [178, 323, 431, 557, 768, 855, 1375, 2203, 2273, 2461, 2744, 3354, 4239, 4290, 4635, 5035]
# Number of data points in this cluster: 16
#
# Cluster 166:
# Indices of data points: [180, 1366, 2274, 2280, 3747, 4194, 4947]
# Number of data points in this cluster: 7
#
# Cluster 426:
# Indices of data points: [181, 347, 946, 954, 1177, 1898, 2364, 2407, 2943, 3422, 3743, 4735, 4747, 4764]
# Number of data points in this cluster: 14
#
# Cluster 119:
# Indices of data points: [182, 631, 1065, 1145, 1213, 2079, 2353, 3737, 3807]
# Number of data points in this cluster: 9
#
# Cluster 623:
# Indices of data points: [183, 1757, 2204, 2987, 3337, 4138]
# Number of data points in this cluster: 6
#
# Cluster 15:
# Indices of data points: [184, 301, 1929, 1940, 2262, 2464, 2549, 2784, 3952]
# Number of data points in this cluster: 9
#
# Cluster 29:
# Indices of data points: [186, 585, 599, 798, 1377, 1914, 2213, 3031, 3077, 3251, 3944, 4169, 4523, 4672]
# Number of data points in this cluster: 14
#
# Cluster 519:
# Indices of data points: [187, 616, 1021, 1548, 2288, 2372, 4704]
# Number of data points in this cluster: 7
#
# Cluster 393:
# Indices of data points: [188, 401, 437, 567, 2152, 3341, 4729, 4872]
# Number of data points in this cluster: 8
#
# Cluster 480:
# Indices of data points: [189, 1361, 1645, 1776, 2431, 2888, 2891]
# Number of data points in this cluster: 7
#
# Cluster 370:
# Indices of data points: [190, 378, 1257, 2566, 2574]
# Number of data points in this cluster: 5
#
# Cluster 743:
# Indices of data points: [191, 602, 1192, 1944, 1959, 2395, 3185, 4918]
# Number of data points in this cluster: 8
#
# Cluster 32:
# Indices of data points: [193, 327, 2044, 2082, 2500, 3722, 4172]
# Number of data points in this cluster: 7
#
# Cluster 737:
# Indices of data points: [195, 273, 676]
# Number of data points in this cluster: 3
#
# Cluster 335:
# Indices of data points: [196, 1613, 2701, 2982, 3143]
# Number of data points in this cluster: 5
#
# Cluster 95:
# Indices of data points: [197, 238, 845, 2086, 2195, 2558, 2711, 2713, 2767, 4282]
# Number of data points in this cluster: 10
#
# Cluster 33:
# Indices of data points: [198, 1580, 1771, 3486, 3487, 3892, 3897, 4289, 4325]
# Number of data points in this cluster: 9
#
# Cluster 559:
# Indices of data points: [199, 1221, 3861, 4414, 4461]
# Number of data points in this cluster: 5
#
# Cluster 12:
# Indices of data points: [200, 749, 2243, 2521, 3050, 3159]
# Number of data points in this cluster: 6
#
# Cluster 111:
# Indices of data points: [202, 3481, 4786, 4968]
# Number of data points in this cluster: 4
#
# Cluster 431:
# Indices of data points: [204, 889, 1528, 2054, 3759, 3764]
# Number of data points in this cluster: 6
#
# Cluster 28:
# Indices of data points: [206, 354, 1041, 1329, 1540, 1552, 1611, 2071, 2369, 3103, 3164, 3366, 3500, 4109, 4408, 4592]
# Number of data points in this cluster: 16
#
# Cluster 323:
# Indices of data points: [209, 361, 1153, 1190, 1810, 3510, 3935, 4252, 4524, 4870]
# Number of data points in this cluster: 10
#
# Cluster 156:
# Indices of data points: [211, 630, 1704, 1709, 1945, 2005, 2599, 3440, 3484, 4623]
# Number of data points in this cluster: 10
#
# Cluster 389:
# Indices of data points: [212, 1169, 1903, 4083]
# Number of data points in this cluster: 4
#
# Cluster 435:
# Indices of data points: [213, 380, 619, 1443, 1957, 2467, 2768, 2990, 3333, 4399]
# Number of data points in this cluster: 10
#
# Cluster 394:
# Indices of data points: [214, 1222, 2017, 2524]
# Number of data points in this cluster: 4
#
# Cluster 592:
# Indices of data points: [215, 337, 349, 1360, 1660]
# Number of data points in this cluster: 5
#
# Cluster 185:
# Indices of data points: [216, 1470, 2847, 4041, 4056, 4105]
# Number of data points in this cluster: 6
#
# Cluster 486:
# Indices of data points: [218, 256, 398, 482, 969, 1713, 2661, 2753, 2765, 3599]
# Number of data points in this cluster: 10
#
# Cluster 160:
# Indices of data points: [219, 1691, 1772, 2669, 2856, 2883]
# Number of data points in this cluster: 6
#
# Cluster 615:
# Indices of data points: [220, 502, 1292, 3207, 4171, 4319, 4609, 5060]
# Number of data points in this cluster: 8
#
# Cluster 647:
# Indices of data points: [221, 298, 3469]
# Number of data points in this cluster: 3
#
# Cluster 298:
# Indices of data points: [222, 678, 1247, 1884, 1928, 2012, 2432, 2788, 5029]
# Number of data points in this cluster: 9
#
# Cluster 84:
# Indices of data points: [223, 822, 1059, 1226, 1693, 1892, 1995, 2025, 2099, 2147, 2278, 2514, 2641, 3097, 3222, 4215]
# Number of data points in this cluster: 16
#
# Cluster 93:
# Indices of data points: [225, 314, 922, 1291, 2173, 2443, 4300, 4720]
# Number of data points in this cluster: 8
#
# Cluster 706:
# Indices of data points: [226, 1935]
# Number of data points in this cluster: 2
#
# Cluster 461:
# Indices of data points: [227, 395, 582, 1468, 1557, 1646, 2887, 3203, 3648, 4984]
# Number of data points in this cluster: 10
#
# Cluster 468:
# Indices of data points: [229, 652, 1157, 1165, 1727, 2926, 3086, 3286, 4216]
# Number of data points in this cluster: 9
#
# Cluster 564:
# Indices of data points: [230, 254, 2486, 3457]
# Number of data points in this cluster: 4
#
# Cluster 725:
# Indices of data points: [232, 553, 816, 1317, 2401, 2422, 2455, 3175, 3233, 4655]
# Number of data points in this cluster: 10
#
# Cluster 134:
# Indices of data points: [234, 837, 1419, 1665, 1909, 2255, 2660, 3523, 3928, 3932]
# Number of data points in this cluster: 10
#
# Cluster 662:
# Indices of data points: [236, 1434, 3007, 3598]
# Number of data points in this cluster: 4
#
# Cluster 144:
# Indices of data points: [237, 671, 2225, 2845, 4232, 4528]
# Number of data points in this cluster: 6
#
# Cluster 90:
# Indices of data points: [239, 1857, 2812, 2848, 3361, 3583, 3703, 4340]
# Number of data points in this cluster: 8
#
# Cluster 35:
# Indices of data points: [240, 532, 644, 701, 1334, 1739, 2992, 2998, 4662]
# Number of data points in this cluster: 9
#
# Cluster 684:
# Indices of data points: [241, 3749, 3964]
# Number of data points in this cluster: 3
#
# Cluster 382:
# Indices of data points: [242, 2057, 2164, 2452, 2908, 3225, 4272]
# Number of data points in this cluster: 7
#
# Cluster 443:
# Indices of data points: [243, 672, 717, 1057, 3335]
# Number of data points in this cluster: 5
#
# Cluster 438:
# Indices of data points: [244, 1879, 2760, 3492, 3937, 4453]
# Number of data points in this cluster: 6
#
# Cluster 757:
# Indices of data points: [245, 1012, 1346, 2446, 2640, 2826, 4142]
# Number of data points in this cluster: 7
#
# Cluster 690:
# Indices of data points: [246, 814, 1534, 1961, 2184, 2590, 3088]
# Number of data points in this cluster: 7
#
# Cluster 691:
# Indices of data points: [247, 2350, 2969]
# Number of data points in this cluster: 3
#
# Cluster 495:
# Indices of data points: [248, 379, 1148, 1241, 1908, 2007, 2105, 2290, 3091, 3277, 4580]
# Number of data points in this cluster: 11
#
# Cluster 177:
# Indices of data points: [249, 505, 802, 1363, 1788, 2526, 2606, 2955, 3227, 3729, 4481, 4733, 4874]
# Number of data points in this cluster: 13
#
# Cluster 494:
# Indices of data points: [250, 409, 880, 1229, 1410, 1530, 2182, 2732, 3235, 3697, 3814, 4338, 5051]
# Number of data points in this cluster: 13
#
# Cluster 520:
# Indices of data points: [252, 706, 1055, 1244, 1264, 1741, 2098, 2909, 4934, 5002]
# Number of data points in this cluster: 10
#
# Cluster 292:
# Indices of data points: [253, 1644, 1941, 2436, 2654, 3019, 4418, 4541, 4584]
# Number of data points in this cluster: 9
#
# Cluster 391:
# Indices of data points: [255, 1705, 2326, 2819, 2975, 3282]
# Number of data points in this cluster: 6
#
# Cluster 380:
# Indices of data points: [258, 2376, 4980]
# Number of data points in this cluster: 3
#
# Cluster 627:
# Indices of data points: [259, 929, 1087, 1303, 4237]
# Number of data points in this cluster: 5
#
# Cluster 418:
# Indices of data points: [260, 1505, 2328, 2734]
# Number of data points in this cluster: 4
#
# Cluster 537:
# Indices of data points: [262, 2860, 2951, 3565, 3726, 3773, 4727]
# Number of data points in this cluster: 7
#
# Cluster 379:
# Indices of data points: [264, 513, 2162, 2264, 2340, 3058, 4839]
# Number of data points in this cluster: 7
#
# Cluster 359:
# Indices of data points: [267, 1140, 1631, 3087, 4613]
# Number of data points in this cluster: 5
#
# Cluster 451:
# Indices of data points: [270, 609, 1339, 1933, 2392, 4586]
# Number of data points in this cluster: 6
#
# Cluster 510:
# Indices of data points: [271, 1564, 3374, 3569, 4791]
# Number of data points in this cluster: 5
#
# Cluster 572:
# Indices of data points: [275, 369, 1117, 1358, 2420, 2680, 3023, 3392, 4265]
# Number of data points in this cluster: 9
#
# Cluster 384:
# Indices of data points: [276, 466, 1936]
# Number of data points in this cluster: 3
#
# Cluster 349:
# Indices of data points: [277, 1440, 2313, 4150, 4532, 4862]
# Number of data points in this cluster: 6
#
# Cluster 492:
# Indices of data points: [278, 1132, 1249, 1365, 1396, 2027, 2339, 2487, 4416]
# Number of data points in this cluster: 9
#
# Cluster 755:
# Indices of data points: [279, 598, 1175, 2160, 2809, 2898, 3560, 4558]
# Number of data points in this cluster: 8
#
# Cluster 17:
# Indices of data points: [281, 408, 471, 832, 898, 997, 1088, 1240, 1278, 1650, 1658, 2000, 2084, 2123, 3584, 3755, 3842, 3886, 4495, 4745, 4749]
# Number of data points in this cluster: 21
#
# Cluster 37:
# Indices of data points: [285, 303, 386, 467, 539, 640, 819, 1013, 1980, 2437, 2485, 2800, 3586, 3620, 3631, 3777, 3792, 3817, 4755, 4846, 4986]
# Number of data points in this cluster: 21
#
# Cluster 204:
# Indices of data points: [286, 343, 376, 387, 756, 1572, 1865, 2043, 2110, 2222, 2397, 2919, 3349, 3450, 3567, 3785, 4679]
# Number of data points in this cluster: 17
#
# Cluster 582:
# Indices of data points: [289, 481, 636, 702, 790, 3017, 4281, 4465]
# Number of data points in this cluster: 8
#
# Cluster 162:
# Indices of data points: [290, 926, 2228, 4633, 4900]
# Number of data points in this cluster: 5
#
# Cluster 59:
# Indices of data points: [291, 787, 1189, 2048, 2059, 2268, 2613, 2638, 3034, 3089, 4907]
# Number of data points in this cluster: 11
#
# Cluster 733:
# Indices of data points: [292]
# Number of data points in this cluster: 1
#
# Cluster 183:
# Indices of data points: [293, 453, 1265, 1483, 2414, 3188]
# Number of data points in this cluster: 6
#
# Cluster 196:
# Indices of data points: [296, 637, 871, 961, 1327, 1669, 3439, 3548, 4725]
# Number of data points in this cluster: 9
#
# Cluster 39:
# Indices of data points: [297, 460, 1206, 1786, 2563, 4440, 4770]
# Number of data points in this cluster: 7
#
# Cluster 149:
# Indices of data points: [299, 646, 982, 1318, 2294, 2582, 2899, 3324, 3507, 3615, 4871, 4964, 4993]
# Number of data points in this cluster: 13
#
# Cluster 285:
# Indices of data points: [300, 363, 4126]
# Number of data points in this cluster: 3
#
# Cluster 487:
# Indices of data points: [302, 2322, 3605, 5016]
# Number of data points in this cluster: 4
#
# Cluster 565:
# Indices of data points: [304, 3996, 4047]
# Number of data points in this cluster: 3
#
# Cluster 447:
# Indices of data points: [305, 927, 1531, 1585, 1745, 4128, 4395, 4396, 4489]
# Number of data points in this cluster: 9
#
# Cluster 597:
# Indices of data points: [306, 4156]
# Number of data points in this cluster: 2
#
# Cluster 626:
# Indices of data points: [307, 775, 1952, 1975, 4573]
# Number of data points in this cluster: 5
#
# Cluster 407:
# Indices of data points: [308, 493, 572, 990, 1266, 1462, 1799, 1960, 2628, 3778, 4848]
# Number of data points in this cluster: 11
#
# Cluster 343:
# Indices of data points: [309, 2223, 2692, 3640]
# Number of data points in this cluster: 4
#
# Cluster 555:
# Indices of data points: [311, 595, 1897]
# Number of data points in this cluster: 3
#
# Cluster 415:
# Indices of data points: [312, 350, 531, 1427, 1575]
# Number of data points in this cluster: 5
#
# Cluster 705:
# Indices of data points: [313, 653, 1397, 2404, 3039, 3344, 4379, 5067]
# Number of data points in this cluster: 8
#
# Cluster 618:
# Indices of data points: [317, 334, 2440]
# Number of data points in this cluster: 3
#
# Cluster 505:
# Indices of data points: [318, 526, 1102, 1182, 1293, 1532, 1551, 1966, 2567, 2948, 3421, 3537, 3919]
# Number of data points in this cluster: 13
#
# Cluster 586:
# Indices of data points: [319, 442, 955, 1267, 2214, 2261, 4650, 4660]
# Number of data points in this cluster: 8
#
# Cluster 475:
# Indices of data points: [320, 2336, 3496, 4378, 4451]
# Number of data points in this cluster: 5
#
# Cluster 528:
# Indices of data points: [321, 342, 635, 3831, 5071]
# Number of data points in this cluster: 5
#
# Cluster 432:
# Indices of data points: [322, 381, 753, 903, 1682, 2745, 2822, 3184, 4295, 4309, 4713]
# Number of data points in this cluster: 11
#
# Cluster 136:
# Indices of data points: [326, 824, 1881, 2095, 2534, 2886, 3501, 3558, 3913, 4677]
# Number of data points in this cluster: 10
#
# Cluster 471:
# Indices of data points: [328, 2295]
# Number of data points in this cluster: 2
#
# Cluster 727:
# Indices of data points: [329, 345, 596, 1270, 2450, 3121, 4403, 4525]
# Number of data points in this cluster: 8
#
# Cluster 433:
# Indices of data points: [330, 778, 1883, 2093, 2946, 3094, 4447]
# Number of data points in this cluster: 7
#
# Cluster 455:
# Indices of data points: [331, 741, 836, 901, 975, 1235, 1335, 1429, 2092, 3170, 4144, 4170, 4681, 4818]
# Number of data points in this cluster: 14
#
# Cluster 404:
# Indices of data points: [332, 340, 2498, 2629, 2716]
# Number of data points in this cluster: 5
#
# Cluster 132:
# Indices of data points: [333, 1748, 2022, 3745, 3761, 4279]
# Number of data points in this cluster: 6
#
# Cluster 460:
# Indices of data points: [336, 1181, 1271, 1298, 1402, 2480, 4213, 4636]
# Number of data points in this cluster: 8
#
# Cluster 456:
# Indices of data points: [339, 2042, 2952, 3429, 3611, 4739]
# Number of data points in this cluster: 6
#
# Cluster 175:
# Indices of data points: [341, 690, 738, 1967, 2215, 2259, 2728, 2956, 3173, 3458, 4454]
# Number of data points in this cluster: 11
#
# Cluster 208:
# Indices of data points: [348, 769, 1309, 1389, 1612, 1652, 1921, 2094, 2857, 3418, 4004, 4642, 4772]
# Number of data points in this cluster: 13
#
# Cluster 395:
# Indices of data points: [351, 512, 810, 1001, 1200, 1761, 3004, 3411, 3650, 3800, 4324, 4464]
# Number of data points in this cluster: 12
#
# Cluster 10:
# Indices of data points: [353, 914, 1889, 2499, 2944, 3183, 3208, 3247, 4230, 4643, 4815, 4929]
# Number of data points in this cluster: 12
#
# Cluster 260:
# Indices of data points: [355, 713, 1853, 2174, 2703, 3343, 4147, 4936, 5064]
# Number of data points in this cluster: 9
#
# Cluster 469:
# Indices of data points: [357, 1556, 2541]
# Number of data points in this cluster: 3
#
# Cluster 312:
# Indices of data points: [359, 1299, 1718, 3006, 3624, 4577, 4911]
# Number of data points in this cluster: 7
#
# Cluster 329:
# Indices of data points: [360, 999, 1372, 4778]
# Number of data points in this cluster: 4
#
# Cluster 363:
# Indices of data points: [362, 2314, 4316, 4370]
# Number of data points in this cluster: 4
#
# Cluster 27:
# Indices of data points: [364, 658, 2039, 2096, 2667, 3124, 4463, 4998]
# Number of data points in this cluster: 8
#
# Cluster 429:
# Indices of data points: [365, 2921, 3342, 3917, 4208, 4486, 4632, 4690, 5042]
# Number of data points in this cluster: 9
#
# Cluster 146:
# Indices of data points: [366, 568, 1570, 1614, 1722, 1755, 1791, 2024, 3590, 4285, 4347, 4352, 4769, 4881]
# Number of data points in this cluster: 14
#
# Cluster 6:
# Indices of data points: [367, 707, 936, 1099, 1345, 1593, 1599, 2083, 2154, 2168, 2516, 2651, 2658, 2938, 3224, 3987, 4342, 4915, 5008]
# Number of data points in this cluster: 19
#
# Cluster 8:
# Indices of data points: [372, 1393, 1430, 2327, 2792, 4697, 5041]
# Number of data points in this cluster: 7
#
# Cluster 657:
# Indices of data points: [373, 451, 3950]
# Number of data points in this cluster: 3
#
# Cluster 58:
# Indices of data points: [374, 870, 980, 1436, 1461, 2009, 2319, 2377, 2594, 2616, 3416, 3517, 3610]
# Number of data points in this cluster: 13
#
# Cluster 718:
# Indices of data points: [375, 629, 920, 2457, 2678, 2783, 4942]
# Number of data points in this cluster: 7
#
# Cluster 352:
# Indices of data points: [382, 1183, 1199, 1209, 1558, 2281, 2664, 3193, 4243, 4353]
# Number of data points in this cluster: 10
#
# Cluster 385:
# Indices of data points: [384, 411, 934, 2188, 2676, 2752, 3445, 4381, 4475, 4717, 4958, 5049, 5074]
# Number of data points in this cluster: 13
#
# Cluster 48:
# Indices of data points: [385, 696, 1071, 1843, 2208, 2400, 2665, 3022, 3072, 3766, 3984]
# Number of data points in this cluster: 11
#
# Cluster 46:
# Indices of data points: [390, 393, 426, 620, 708, 1927, 2286, 2409, 2427, 3428, 3559, 3676, 3914, 4311, 4607, 4682]
# Number of data points in this cluster: 16
#
# Cluster 54:
# Indices of data points: [391, 392, 447, 510, 520, 571, 1066, 1493, 1578, 2080, 2556, 3182, 3283, 3441, 3522, 3865, 4637]
# Number of data points in this cluster: 17
#
# Cluster 347:
# Indices of data points: [394, 1416, 2612, 2700, 3244, 4843]
# Number of data points in this cluster: 6
#
# Cluster 7:
# Indices of data points: [397, 919, 2699, 3719, 3894, 3954, 4554, 4887, 4950]
# Number of data points in this cluster: 9
#
# Cluster 485:
# Indices of data points: [399, 436, 1006, 1323, 1820, 4122, 4263, 4743]
# Number of data points in this cluster: 8
#
# Cluster 550:
# Indices of data points: [400, 941, 1149, 1236, 2107, 2442, 2510, 3553, 3931, 4182, 4245, 4501]
# Number of data points in this cluster: 12
#
# Cluster 82:
# Indices of data points: [403, 544, 853, 1237, 2081, 2143, 2763, 3753, 3912, 4224, 4304, 4601, 4994]
# Number of data points in this cluster: 13
#
# Cluster 378:
# Indices of data points: [404, 684, 886, 2865, 4771]
# Number of data points in this cluster: 5
#
# Cluster 314:
# Indices of data points: [410, 452, 1550, 1946]
# Number of data points in this cluster: 4
#
# Cluster 484:
# Indices of data points: [412, 1625, 3529, 3818]
# Number of data points in this cluster: 4
#
# Cluster 614:
# Indices of data points: [413, 561, 1158, 1837, 2246, 2693, 2761, 3688, 4163, 4187, 4969]
# Number of data points in this cluster: 11
#
# Cluster 220:
# Indices of data points: [415, 1833, 3294, 3519, 4155, 4736, 4797]
# Number of data points in this cluster: 7
#
# Cluster 372:
# Indices of data points: [416, 1232, 1306, 1494, 1498, 2008, 4159, 4748]
# Number of data points in this cluster: 8
#
# Cluster 500:
# Indices of data points: [417, 848, 1294, 1866, 4130, 4995]
# Number of data points in this cluster: 6
#
# Cluster 700:
# Indices of data points: [418, 1295, 3081, 4358]
# Number of data points in this cluster: 4
#
# Cluster 230:
# Indices of data points: [420, 732, 1487, 1608, 1829, 2178, 2757, 3132]
# Number of data points in this cluster: 8
#
# Cluster 120:
# Indices of data points: [422, 757, 825, 2233, 2687, 3319, 3634, 4758, 4875]
# Number of data points in this cluster: 9
#
# Cluster 539:
# Indices of data points: [424, 680, 893, 1304, 3105]
# Number of data points in this cluster: 5
#
# Cluster 664:
# Indices of data points: [428, 632, 1051]
# Number of data points in this cluster: 3
#
# Cluster 51:
# Indices of data points: [429, 1501, 1661, 1780, 2568, 3330, 3651, 4441, 4602, 4787]
# Number of data points in this cluster: 10
#
# Cluster 26:
# Indices of data points: [430, 765, 2393, 2914, 3401, 3801, 3982]
# Number of data points in this cluster: 7
#
# Cluster 735:
# Indices of data points: [432, 1846, 3874]
# Number of data points in this cluster: 3
#
# Cluster 619:
# Indices of data points: [434, 3470]
# Number of data points in this cluster: 2
#
# Cluster 262:
# Indices of data points: [438, 468, 627, 689, 699, 1878, 2155, 2791, 2995, 3671, 4196]
# Number of data points in this cluster: 11
#
# Cluster 593:
# Indices of data points: [439, 1077, 1131, 2459, 2592, 2597, 2894, 3849]
# Number of data points in this cluster: 8
#
# Cluster 525:
# Indices of data points: [440, 474, 1056, 3577, 3702, 4005, 4211]
# Number of data points in this cluster: 7
#
# Cluster 523:
# Indices of data points: [441, 1115, 1894, 2374, 2965, 3075]
# Number of data points in this cluster: 6
#
# Cluster 524:
# Indices of data points: [443, 1511, 1695, 2299]
# Number of data points in this cluster: 4
#
# Cluster 732:
# Indices of data points: [445, 972, 1164, 2103, 2575]
# Number of data points in this cluster: 5
#
# Cluster 251:
# Indices of data points: [446, 475, 537, 1989, 2815, 3111, 3242, 4392, 4619, 4752, 4827]
# Number of data points in this cluster: 11
#
# Cluster 138:
# Indices of data points: [448, 1092, 1097, 4439, 4767]
# Number of data points in this cluster: 5
#
# Cluster 736:
# Indices of data points: [449, 1301, 3024, 4571]
# Number of data points in this cluster: 4
#
# Cluster 540:
# Indices of data points: [454, 801, 863, 3549, 4307, 4616]
# Number of data points in this cluster: 6
#
# Cluster 21:
# Indices of data points: [455, 507, 549, 611, 675, 1111, 1261, 1403, 2013, 3154, 4663, 4851, 5066]
# Number of data points in this cluster: 13
#
# Cluster 133:
# Indices of data points: [456, 767, 1835, 2418, 2429, 3552, 4492, 4807]
# Number of data points in this cluster: 8
#
# Cluster 452:
# Indices of data points: [457, 601, 638, 1307, 1852, 3512, 4189, 4547]
# Number of data points in this cluster: 8
#
# Cluster 125:
# Indices of data points: [458, 682, 1082, 1648, 2471, 3511, 3980]
# Number of data points in this cluster: 7
#
# Cluster 199:
# Indices of data points: [459, 497, 1514, 1710, 1904, 2603, 3066, 3353, 3933, 3945, 4067, 4114, 4382, 4503, 4622, 4826]
# Number of data points in this cluster: 16
#
# Cluster 448:
# Indices of data points: [461, 1711, 1890, 2036, 3435, 3699, 3781, 4415, 4455, 4549, 4578]
# Number of data points in this cluster: 11
#
# Cluster 307:
# Indices of data points: [462, 1445, 1567, 3272, 3488, 5004]
# Number of data points in this cluster: 6
#
# Cluster 291:
# Indices of data points: [463, 509, 1106, 1407, 2245, 3268, 3404, 3638, 3812, 4545, 4742]
# Number of data points in this cluster: 11
#
# Cluster 575:
# Indices of data points: [465, 947, 1653, 3413, 4894]
# Number of data points in this cluster: 5
#
# Cluster 241:
# Indices of data points: [473, 500, 548, 764, 973, 1038, 1314, 1418, 1543, 1703, 3223, 3786, 3975]
# Number of data points in this cluster: 13
#
# Cluster 107:
# Indices of data points: [476, 1336, 1610, 2257]
# Number of data points in this cluster: 4
#
# Cluster 638:
# Indices of data points: [478, 2896, 3789, 5020, 5028]
# Number of data points in this cluster: 5
#
# Cluster 246:
# Indices of data points: [479, 1874, 3104, 3270, 4512]
# Number of data points in this cluster: 5
#
# Cluster 302:
# Indices of data points: [480, 839, 932, 1463, 4145, 4327, 5014]
# Number of data points in this cluster: 7
#
# Cluster 383:
# Indices of data points: [483, 896, 1269, 1604, 1809, 2235, 4595]
# Number of data points in this cluster: 7
#
# Cluster 72:
# Indices of data points: [484, 1517, 1524, 2031, 2051, 2287, 3312, 4401, 4629, 4639, 5056]
# Number of data points in this cluster: 11
#
# Cluster 675:
# Indices of data points: [485, 727, 1193, 3467, 3735, 4740]
# Number of data points in this cluster: 6
#
# Cluster 344:
# Indices of data points: [487, 1113, 2518, 2621, 2876, 4249, 4286]
# Number of data points in this cluster: 7
#
# Cluster 115:
# Indices of data points: [489, 861, 1369, 2977, 3506, 3606, 3890, 4849, 5046]
# Number of data points in this cluster: 9
#
# Cluster 579:
# Indices of data points: [494, 912, 1736, 2006, 2470, 4813]
# Number of data points in this cluster: 6
#
# Cluster 174:
# Indices of data points: [495, 584, 1988, 3032]
# Number of data points in this cluster: 4
#
# Cluster 275:
# Indices of data points: [496, 925, 2239, 2433, 2984, 3391, 4858]
# Number of data points in this cluster: 7
#
# Cluster 326:
# Indices of data points: [501, 2291, 4710, 5070]
# Number of data points in this cluster: 4
#
# Cluster 631:
# Indices of data points: [503, 1281, 1993, 2100, 2482, 2743, 4400]
# Number of data points in this cluster: 7
#
# Cluster 108:
# Indices of data points: [504, 841, 1248, 1675, 1979, 2128, 2553, 2780, 2925, 2981, 3965, 4419, 4466, 4631, 4928]
# Number of data points in this cluster: 15
#
# Cluster 731:
# Indices of data points: [511, 796, 4424, 4449]
# Number of data points in this cluster: 4
#
# Cluster 300:
# Indices of data points: [515, 807, 1176, 1740, 1973, 2111, 3267, 3535, 3760, 3860, 3946]
# Number of data points in this cluster: 11
#
# Cluster 250:
# Indices of data points: [516, 788, 897, 1521, 2187, 4559]
# Number of data points in this cluster: 6
#
# Cluster 14:
# Indices of data points: [518, 1137, 1792, 2622, 2996, 4046, 4603, 5048]
# Number of data points in this cluster: 8
#
# Cluster 634:
# Indices of data points: [521, 3898, 4099]
# Number of data points in this cluster: 3
#
# Cluster 722:
# Indices of data points: [523, 1198, 1584, 1679, 4209, 5015]
# Number of data points in this cluster: 6
#
# Cluster 446:
# Indices of data points: [524, 535, 1128, 1754, 2473, 2619, 3275, 3442]
# Number of data points in this cluster: 8
#
# Cluster 596:
# Indices of data points: [525, 1766, 4538]
# Number of data points in this cluster: 3
#
# Cluster 720:
# Indices of data points: [529, 723, 965, 1122, 1340, 1356, 2190, 2536, 2953, 3555, 3661]
# Number of data points in this cluster: 11
#
# Cluster 694:
# Indices of data points: [530, 2779, 3102]
# Number of data points in this cluster: 3
#
# Cluster 75:
# Indices of data points: [538, 1576, 1635, 2073, 2841, 3305, 4877, 5018]
# Number of data points in this cluster: 8
#
# Cluster 52:
# Indices of data points: [540, 1388, 1597, 2777, 3776, 4158, 4691]
# Number of data points in this cluster: 7
#
# Cluster 454:
# Indices of data points: [541, 986, 1821, 2456, 3698, 4566, 4952]
# Number of data points in this cluster: 7
#
# Cluster 226:
# Indices of data points: [542, 657, 827, 2076, 2825, 3156, 3525, 4587, 4820, 5040]
# Number of data points in this cluster: 10
#
# Cluster 150:
# Indices of data points: [543, 2359, 2598, 2834, 4074, 4219, 4800]
# Number of data points in this cluster: 7
#
# Cluster 412:
# Indices of data points: [545, 1453, 1919, 2136, 3375, 3592, 4127]
# Number of data points in this cluster: 7
#
# Cluster 126:
# Indices of data points: [547, 1118, 1155, 1702, 1958, 2333, 2608, 2653, 2677, 3264]
# Number of data points in this cluster: 10
#
# Cluster 665:
# Indices of data points: [552, 1963, 2077, 2489, 2615, 3926, 4292, 4359]
# Number of data points in this cluster: 8
#
# Cluster 449:
# Indices of data points: [554, 1342, 2351, 2976, 3827, 3896]
# Number of data points in this cluster: 6
#
# Cluster 24:
# Indices of data points: [563, 864, 2550, 3303, 3571, 3596, 4106, 4811]
# Number of data points in this cluster: 8
#
# Cluster 330:
# Indices of data points: [564, 688, 1005, 2332, 4912]
# Number of data points in this cluster: 5
#
# Cluster 603:
# Indices of data points: [565, 2229, 3570, 4670]
# Number of data points in this cluster: 4
#
# Cluster 373:
# Indices of data points: [570, 1168, 1643, 1750, 3410, 3983]
# Number of data points in this cluster: 6
#
# Cluster 193:
# Indices of data points: [573, 991, 2065, 2643, 3274, 3733, 3855]
# Number of data points in this cluster: 7
#
# Cluster 238:
# Indices of data points: [574, 1049, 1101, 2253, 2764, 2930, 3074, 4430, 4484, 4867]
# Number of data points in this cluster: 10
#
# Cluster 696:
# Indices of data points: [576, 754, 2396, 2685, 3748, 4240, 4298, 4443, 4783]
# Number of data points in this cluster: 9
#
# Cluster 151:
# Indices of data points: [577, 1640, 4467]
# Number of data points in this cluster: 3
#
# Cluster 467:
# Indices of data points: [578, 710, 962, 1052, 1219, 1411, 1794, 1917, 1968, 3092, 3096, 4852]
# Number of data points in this cluster: 12
#
# Cluster 57:
# Indices of data points: [579, 1617, 1638, 1793, 1847, 2033, 2735, 3221, 3297, 4615]
# Number of data points in this cluster: 10
#
# Cluster 311:
# Indices of data points: [580, 1654, 2303, 3790, 4531, 4908]
# Number of data points in this cluster: 6
#
# Cluster 541:
# Indices of data points: [583, 813, 1154, 1405, 2343, 2408, 2916, 4412, 4902]
# Number of data points in this cluster: 9
#
# Cluster 340:
# Indices of data points: [586, 2234, 4287]
# Number of data points in this cluster: 3
#
# Cluster 168:
# Indices of data points: [587, 1925, 2236, 2490, 3145, 4077, 4569]
# Number of data points in this cluster: 7
#
# Cluster 243:
# Indices of data points: [588, 670, 784, 1133, 1275, 1876, 2285, 2875, 3053, 4417, 4459, 4937, 4954, 4975]
# Number of data points in this cluster: 14
#
# Cluster 64:
# Indices of data points: [590, 1830, 1985, 1998, 2023, 2772, 4796]
# Number of data points in this cluster: 7
#
# Cluster 216:
# ...
# Number of data points in this cluster: 5
#
# Cluster 332:
# Indices of data points: [1706, 3564]
# Number of data points in this cluster: 2
#
# Cluster 345:
# Indices of data points: [1715, 2398, 2900, 3133, 3706, 4366]
# Number of data points in this cluster: 6
#
# Cluster 99:
# Indices of data points: [1720, 3630, 3642, 4977]
# Number of data points in this cluster: 4
#
# Cluster 211:
# Indices of data points: [1724, 2614, 2980, 3968, 4753]
# Number of data points in this cluster: 5
#
# Cluster 342:
# Indices of data points: [1742, 1868, 2538, 3588, 3636, 3907, 3976]
# Number of data points in this cluster: 7
#
# Cluster 281:
# Indices of data points: [1747, 3368]
# Number of data points in this cluster: 2
#
# Cluster 165:
# Indices of data points: [1758, 2365, 2379, 3627]
# Number of data points in this cluster: 4
#
# Cluster 682:
# Indices of data points: [1762, 4146, 4360, 4762]
# Number of data points in this cluster: 4
#
# Cluster 628:
# Indices of data points: [1764, 4433]
# Number of data points in this cluster: 2
#
# Cluster 338:
# Indices of data points: [1773, 2562, 3136, 5044]
# Number of data points in this cluster: 4
#
# Cluster 483:
# Indices of data points: [1774, 2915, 3255, 3364, 3369, 3381]
# Number of data points in this cluster: 6
#
# Cluster 290:
# Indices of data points: [1775, 2572, 3850, 4085]
# Number of data points in this cluster: 4
#
# Cluster 319:
# Indices of data points: [1781, 2217, 2903, 3836, 4299]
# Number of data points in this cluster: 5
#
# Cluster 422:
# Indices of data points: [1782, 2293]
# Number of data points in this cluster: 2
#
# Cluster 153:
# Indices of data points: [1784, 2453, 2721, 4063, 4139, 4166, 4373]
# Number of data points in this cluster: 7
#
# Cluster 92:
# Indices of data points: [1785, 3328, 3711, 4040, 4137]
# Number of data points in this cluster: 5
#
# Cluster 711:
# Indices of data points: [1795, 1808, 2119, 3883]
# Number of data points in this cluster: 4
#
# Cluster 617:
# Indices of data points: [1796, 3000, 3670, 3994, 4112]
# Number of data points in this cluster: 5
#
# Cluster 450:
# Indices of data points: [1797, 1831, 2551, 3682, 3904]
# Number of data points in this cluster: 5
#
# Cluster 164:
# Indices of data points: [1798, 2381, 3779, 4035, 4045]
# Number of data points in this cluster: 5
#
# Cluster 536:
# Indices of data points: [1800, 1836, 3239]
# Number of data points in this cluster: 3
#
# Cluster 66:
# Indices of data points: [1806, 2901, 3318, 3373, 3396, 3826, 4070]
# Number of data points in this cluster: 7
#
# Cluster 616:
# Indices of data points: [1815, 2585, 4394]
# Number of data points in this cluster: 3
#
# Cluster 327:
# Indices of data points: [1816, 2475, 2522, 4480, 4568]
# Number of data points in this cluster: 5
#
# Cluster 112:
# Indices of data points: [1819, 2602, 3652, 4312]
# Number of data points in this cluster: 4
#
# Cluster 141:
# Indices of data points: [1822, 1938, 2838, 2954, 3461, 4162, 4997]
# Number of data points in this cluster: 7
#
# Cluster 334:
# Indices of data points: [1825, 3331, 3362, 3385, 4050]
# Number of data points in this cluster: 5
#
# Cluster 333:
# Indices of data points: [1832, 1877, 2967, 3386, 3601]
# Number of data points in this cluster: 5
#
# Cluster 184:
# Indices of data points: [1839, 1939, 2323, 3479, 3684, 4792, 4967]
# Number of data points in this cluster: 7
#
# Cluster 552:
# Indices of data points: [1840, 1872, 3258, 3694, 4333, 4518, 4861]
# Number of data points in this cluster: 7
#
# Cluster 242:
# Indices of data points: [1848, 2037, 2770, 4066, 4222, 4656, 5012]
# Number of data points in this cluster: 7
#
# Cluster 188:
# Indices of data points: [1849, 2056, 2368, 3116, 3891]
# Number of data points in this cluster: 5
#
# Cluster 583:
# Indices of data points: [1851, 2968, 5024]
# Number of data points in this cluster: 3
#
# Cluster 362:
# Indices of data points: [1860, 2506, 3557]
# Number of data points in this cluster: 3
#
# Cluster 143:
# Indices of data points: [1869, 1999, 2004, 4097, 4380, 4446]
# Number of data points in this cluster: 6
#
# Cluster 625:
# Indices of data points: [1871, 2730, 2877, 4321]
# Number of data points in this cluster: 4
#
# Cluster 396:
# Indices of data points: [1875, 2325, 2356, 2358, 2801]
# Number of data points in this cluster: 5
#
# Cluster 215:
# Indices of data points: [1891, 1905, 2282]
# Number of data points in this cluster: 3
#
# Cluster 401:
# Indices of data points: [1930, 4273]
# Number of data points in this cluster: 2
#
# Cluster 70:
# Indices of data points: [1949, 3497, 3901]
# Number of data points in this cluster: 3
#
# Cluster 94:
# Indices of data points: [1956, 2118, 2384, 2971]
# Number of data points in this cluster: 4
#
# Cluster 724:
# Indices of data points: [1990, 2312, 3291]
# Number of data points in this cluster: 3
#
# Cluster 513:
# Indices of data points: [1991, 2555, 2762, 3389]
# Number of data points in this cluster: 4
#
# Cluster 279:
# Indices of data points: [2001, 2144, 2537, 3099, 3232, 3837]
# Number of data points in this cluster: 6
#
# Cluster 667:
# Indices of data points: [2011, 2690, 2797]
# Number of data points in this cluster: 3
#
# Cluster 419:
# Indices of data points: [2016, 3213, 4315, 4562]
# Number of data points in this cluster: 4
#
# Cluster 42:
# Indices of data points: [2035, 2104, 2357, 3798, 4028]
# Number of data points in this cluster: 5
#
# Cluster 726:
# Indices of data points: [2038, 2122, 2251]
# Number of data points in this cluster: 3
#
# Cluster 529:
# Indices of data points: [2045, 2270]
# Number of data points in this cluster: 2
#
# Cluster 574:
# Indices of data points: [2047]
# Number of data points in this cluster: 1
#
# Cluster 350:
# Indices of data points: [2050, 3723, 4191]
# Number of data points in this cluster: 3
#
# Cluster 668:
# Indices of data points: [2052, 3009]
# Number of data points in this cluster: 2
#
# Cluster 45:
# Indices of data points: [2055, 3691, 3993, 4080, 4095, 4180]
# Number of data points in this cluster: 6
#
# Cluster 236:
# Indices of data points: [2060, 3002, 4840]
# Number of data points in this cluster: 3
#
# Cluster 604:
# Indices of data points: [2063]
# Number of data points in this cluster: 1
#
# Cluster 410:
# Indices of data points: [2074, 3949, 4708, 5037]
# Number of data points in this cluster: 4
#
# Cluster 689:
# Indices of data points: [2075, 3317, 3868]
# Number of data points in this cluster: 3
#
# Cluster 400:
# Indices of data points: [2087, 3119, 4038]
# Number of data points in this cluster: 3
#
# Cluster 740:
# Indices of data points: [2091, 3953, 4970, 4978]
# Number of data points in this cluster: 4
#
# Cluster 466:
# Indices of data points: [2097, 2691, 2831, 3654, 4218]
# Number of data points in this cluster: 5
#
# Cluster 399:
# Indices of data points: [2108, 2216, 2284, 2611]
# Number of data points in this cluster: 4
#
# Cluster 663:
# Indices of data points: [2113, 3725, 3841]
# Number of data points in this cluster: 3
#
# Cluster 538:
# Indices of data points: [2115, 3322, 4060]
# Number of data points in this cluster: 3
#
# Cluster 645:
# Indices of data points: [2116, 3603, 3613]
# Number of data points in this cluster: 3
#
# Cluster 253:
# Indices of data points: [2130, 2543, 2902, 3041]
# Number of data points in this cluster: 4
#
# Cluster 74:
# Indices of data points: [2134, 2345, 3079, 4551, 4575]
# Number of data points in this cluster: 5
#
# Cluster 717:
# Indices of data points: [2137, 3252]
# Number of data points in this cluster: 2
#
# Cluster 490:
# Indices of data points: [2140, 2302, 3278, 3301, 3832, 4052, 4427, 4665]
# Number of data points in this cluster: 8
#
# Cluster 276:
# Indices of data points: [2151, 3123, 4386]
# Number of data points in this cluster: 3
#
# Cluster 244:
# Indices of data points: [2166, 2405, 2474, 2988, 3784, 4348]
# Number of data points in this cluster: 6
#
# Cluster 758:
# Indices of data points: [2186, 2994]
# Number of data points in this cluster: 2
#
# Cluster 402:
# Indices of data points: [2192, 2833, 4261, 4423, 4825]
# Number of data points in this cluster: 5
#
# Cluster 358:
# Indices of data points: [2209, 3325, 3951, 4039, 4685]
# Number of data points in this cluster: 5
#
# Cluster 355:
# Indices of data points: [2237, 3626, 4923]
# Number of data points in this cluster: 3
#
# Cluster 376:
# Indices of data points: [2241, 2637, 4250, 4303, 4893]
# Number of data points in this cluster: 5
#
# Cluster 661:
# Indices of data points: [2272, 4164]
# Number of data points in this cluster: 2
#
# Cluster 496:
# Indices of data points: [2275, 2542, 2806, 3990]
# Number of data points in this cluster: 4
#
# Cluster 516:
# Indices of data points: [2277, 2843, 3359, 3360, 3791, 3902]
# Number of data points in this cluster: 6
#
# Cluster 660:
# Indices of data points: [2283, 4966, 5000]
# Number of data points in this cluster: 3
#
# Cluster 695:
# Indices of data points: [2296, 2997]
# Number of data points in this cluster: 2
#
# Cluster 554:
# Indices of data points: [2305, 3485, 4016]
# Number of data points in this cluster: 3
#
# Cluster 180:
# Indices of data points: [2307, 3316, 3367, 3398, 3696, 3768, 4091, 4318, 4505, 4511]
# Number of data points in this cluster: 10
#
# Cluster 464:
# Indices of data points: [2308, 2964, 4111]
# Number of data points in this cluster: 3
#
# Cluster 502:
# Indices of data points: [2315, 3600, 3815]
# Number of data points in this cluster: 3
#
# Cluster 235:
# Indices of data points: [2338, 3061, 3323, 4113]
# Number of data points in this cluster: 4
#
# Cluster 398:
# Indices of data points: [2342, 2904, 2913, 4003, 4356]
# Number of data points in this cluster: 5
#
# Cluster 348:
# Indices of data points: [2349, 3742, 4365, 4544]
# Number of data points in this cluster: 4
#
# Cluster 709:
# Indices of data points: [2361, 3989]
# Number of data points in this cluster: 2
#
# Cluster 321:
# Indices of data points: [2367, 2517, 2520, 4817]
# Number of data points in this cluster: 4
#
# Cluster 608:
# Indices of data points: [2370, 3310]
# Number of data points in this cluster: 2
#
# Cluster 580:
# Indices of data points: [2394, 3544, 3918]
# Number of data points in this cluster: 3
#
# Cluster 656:
# Indices of data points: [2403, 4244, 4730]
# Number of data points in this cluster: 3
#
# Cluster 566:
# Indices of data points: [2410, 3001, 4625]
# Number of data points in this cluster: 3
#
# Cluster 599:
# Indices of data points: [2444, 4185]
# Number of data points in this cluster: 2
#
# Cluster 699:
# Indices of data points: [2458]
# Number of data points in this cluster: 1
#
# Cluster 436:
# Indices of data points: [2478, 2910, 3563]
# Number of data points in this cluster: 3
#
# Cluster 588:
# Indices of data points: [2481, 3604, 3721]
# Number of data points in this cluster: 3
#
# Cluster 688:
# Indices of data points: [2530, 2830, 3290]
# Number of data points in this cluster: 3
#
# Cluster 313:
# Indices of data points: [2557, 3708]
# Number of data points in this cluster: 2
#
# Cluster 612:
# Indices of data points: [2564, 2828, 3130, 3580, 3934, 4090, 4723]
# Number of data points in this cluster: 7
#
# Cluster 470:
# Indices of data points: [2577, 4488]
# Number of data points in this cluster: 2
#
# Cluster 547:
# Indices of data points: [2596, 3541, 3593]
# Number of data points in this cluster: 3
#
# Cluster 219:
# Indices of data points: [2617, 2659, 3030, 3138, 3320, 3920, 4177, 4707, 4841, 4884]
# Number of data points in this cluster: 10
#
# Cluster 585:
# Indices of data points: [2655]
# Number of data points in this cluster: 1
#
# Cluster 171:
# Indices of data points: [2666, 3854, 4051]
# Number of data points in this cluster: 3
#
# Cluster 558:
# Indices of data points: [2719, 4780]
# Number of data points in this cluster: 2
#
# Cluster 570:
# Indices of data points: [2736, 3059]
# Number of data points in this cluster: 2
#
# Cluster 651:
# Indices of data points: [2749, 2945]
# Number of data points in this cluster: 2
#
# Cluster 274:
# Indices of data points: [2766, 3355, 3903, 4198, 4398]
# Number of data points in this cluster: 5
#
# Cluster 591:
# Indices of data points: [2794, 3112, 4346]
# Number of data points in this cluster: 3
#
# Cluster 148:
# Indices of data points: [2803, 4025, 4203]
# Number of data points in this cluster: 3
#
# Cluster 507:
# Indices of data points: [2810, 4434]
# Number of data points in this cluster: 2
#
# Cluster 498:
# Indices of data points: [2811, 2963, 4094]
# Number of data points in this cluster: 3
#
# Cluster 192:
# Indices of data points: [2840, 3025, 3478, 3693, 3740, 3853]
# Number of data points in this cluster: 6
#
# Cluster 209:
# Indices of data points: [2846, 3178, 3617, 4226, 4522, 4905]
# Number of data points in this cluster: 6
#
# Cluster 63:
# Indices of data points: [2851, 4280, 4570]
# Number of data points in this cluster: 3
#
# Cluster 692:
# Indices of data points: [2872, 3810, 4141]
# Number of data points in this cluster: 3
#
# Cluster 681:
# Indices of data points: [2893, 3273, 4275]
# Number of data points in this cluster: 3
#
# Cluster 526:
# Indices of data points: [2897, 3115, 4082]
# Number of data points in this cluster: 3
#
# Cluster 659:
# Indices of data points: [2912, 3140, 4055, 4344]
# Number of data points in this cluster: 4
#
# Cluster 489:
# Indices of data points: [2923]
# Number of data points in this cluster: 1
#
# Cluster 223:
# Indices of data points: [2989, 3476, 3659]
# Number of data points in this cluster: 3
#
# Cluster 458:
# Indices of data points: [3027, 3877]
# Number of data points in this cluster: 2
#
# Cluster 306:
# Indices of data points: [3049, 3930, 3948]
# Number of data points in this cluster: 3
#
# Cluster 632:
# Indices of data points: [3057, 3816, 4098]
# Number of data points in this cluster: 3
#
# Cluster 676:
# Indices of data points: [3125, 3356, 3645]
# Number of data points in this cluster: 3
#
# Cluster 629:
# Indices of data points: [3141, 3857, 4075]
# Number of data points in this cluster: 3
#
# Cluster 655:
# Indices of data points: [3149, 4153, 4278]
# Number of data points in this cluster: 3
#
# Cluster 746:
# Indices of data points: [3151, 4322, 4953]
# Number of data points in this cluster: 3
#
# Cluster 601:
# Indices of data points: [3152, 3879]
# Number of data points in this cluster: 2
#
# Cluster 170:
# Indices of data points: [3153, 3663, 3705]
# Number of data points in this cluster: 3
#
# Cluster 61:
# Indices of data points: [3285, 3572, 3939, 4013, 4653]
# Number of data points in this cluster: 5
#
# Cluster 649:
# Indices of data points: [3334, 3771, 4349]
# Number of data points in this cluster: 3
#
# Cluster 745:
# Indices of data points: [3406]
# Number of data points in this cluster: 1
#
# Cluster 672:
# Indices of data points: [3414, 4086]
# Number of data points in this cluster: 2
#
# Cluster 474:
# Indices of data points: [3472, 3503, 3681, 3923]
# Number of data points in this cluster: 4
#
# Cluster 715:
# Indices of data points: [3526, 3625, 4784]
# Number of data points in this cluster: 3
#
# Cluster 562:
# Indices of data points: [3573, 4744]
# Number of data points in this cluster: 2
#
# Cluster 545:
# Indices of data points: [3608, 4350, 4641]
# Number of data points in this cluster: 3
#
# Cluster 503:
# Indices of data points: [3612, 4341, 4931]
# Number of data points in this cluster: 3
#
# Cluster 624:
# Indices of data points: [3619, 3658, 3690, 4837]
# Number of data points in this cluster: 4
#
# Cluster 607:
# Indices of data points: [3653, 3689, 4001]
# Number of data points in this cluster: 3
#
# Cluster 277:
# Indices of data points: [3701, 4118, 4256]
# Number of data points in this cluster: 3
#
# Cluster 417:
# Indices of data points: [3704, 4450, 4471]
# Number of data points in this cluster: 3
#
# Cluster 702:
# Indices of data points: [3823, 3961]
# Number of data points in this cluster: 2
#
# Cluster 221:
# Indices of data points: [3847, 4022]
# Number of data points in this cluster: 2
#
# Cluster 708:
# Indices of data points: [3867, 4034, 4436]
# Number of data points in this cluster: 3
#
# Cluster 476:
# Indices of data points: [3971, 4031, 4183]
# Number of data points in this cluster: 3
#
# Cluster 437:
# Indices of data points: [4009, 4018]
# Number of data points in this cluster: 2
#
# Cluster 441:
# Indices of data points: [4073, 4448, 4526]
# Number of data points in this cluster: 3
#
# Cluster 671:
# Indices of data points: [4107, 4390]
# Number of data points in this cluster: 2
#
# Cluster 387:
# Indices of data points: [4110, 4200, 4724]
# Number of data points in this cluster: 3
#
# Cluster 227:
# Indices of data points: [4197, 5034]
# Number of data points in this cluster: 2
#
# Cluster 754:
# Indices of data points: [4253, 4301]
# Number of data points in this cluster: 2
#
# Cluster 759:
# Indices of data points: [4267, 4293]
# Number of data points in this cluster: 2
#
# Cluster 569:
# Indices of data points: [4362]
# Number of data points in this cluster: 1
#
# Cluster 499:
# Indices of data points: [4375]
# Number of data points in this cluster: 1

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Step 1: Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augcr\features_last_lstm.npy")

# Step 2: (Optional) Preprocess the data if needed
# For example, you might want to scale the features to ensure the clustering works well
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 3: Perform Agglomerative Clustering
# You can specify the number of clusters or other hyperparameters here
n_clusters = 761  # Example, set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model to the feature matrix
clustering_labels = clustering.fit_predict(features_scaled)

# Step 4: (Optional) Visualize the results if the features are 2D (or use dimensionality reduction)
if features_scaled.shape[1] == 2:  # If your features are 2D, you can visualize them
    plt.scatter(features_scaled[:, 0], features_scaled[:, 1], c=clustering_labels, cmap='viridis')
    plt.title("Agglomerative Clustering Results")
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# If you have higher-dimensional features, consider using PCA to reduce to 2D for visualization
# For example:
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# features_2d = pca.fit_transform(features_scaled)
# plt.scatter(features_2d[:, 0], features_2d[:, 1], c=clustering_labels, cmap='viridis')
# plt.show()

# Step 5: View the labels assigned to each data point
print("Cluster Labels:", clustering_labels)
# Out:
# Cluster Labels: [408 128 374 ... 741  97 385]

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augcr\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters =761  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Display the clusters in the desired format
for cluster_label, indices in cluster_dict.items():
    print(f"Cluster {cluster_label}:")
    print(f"Indices of data points: {indices}")
    print(f"Number of data points in this cluster: {len(indices)}\n")
# Out:
# Cluster 408:
# Indices of data points: [0, 14, 31, 551, 735, 1091, 1668, 1974, 2133, 2317, 2722, 3126, 4266, 4693]
# Number of data points in this cluster: 14
#
# Cluster 128:
# Indices of data points: [1, 533, 1036, 1214, 1273, 1591, 2167, 3377, 4530, 4581, 4611, 5010]
# Number of data points in this cluster: 12
#
# Cluster 374:
# Indices of data points: [2, 210, 498, 594, 948, 1212, 1408, 1559, 3561, 4498, 4945]
# Number of data points in this cluster: 11
#
# Cluster 207:
# Indices of data points: [3, 266, 1151, 1208, 1943, 2978, 3073, 3197, 3236, 3885, 4477, 4593, 4766, 4838, 5032]
# Number of data points in this cluster: 15
#
# Cluster 159:
# Indices of data points: [4, 550, 724, 858, 937, 1428, 2310, 2675, 3082, 3845, 4948, 4971, 5065]
# Number of data points in this cluster: 13
#
# Cluster 318:
# Indices of data points: [5, 38, 121, 562, 617, 988, 1315, 2201, 3204, 4790]
# Number of data points in this cluster: 10
#
# Cluster 375:
# Indices of data points: [6, 153, 201, 1114, 1922, 2688, 3026, 3135, 4330]
# Number of data points in this cluster: 9
#
# Cluster 493:
# Indices of data points: [7, 1350, 1834, 3909]
# Number of data points in this cluster: 4
#
# Cluster 97:
# Indices of data points: [8, 155, 633, 1633, 2121, 2347, 2607, 4673, 4789, 5073]
# Number of data points in this cluster: 10
#
# Cluster 173:
# Indices of data points: [9, 2269, 2402, 2447, 3380, 3516, 3556, 3685, 4032, 4149, 4553, 4696, 4721, 4922, 5057]
# Number of data points in this cluster: 15
#
# Cluster 78:
# Indices of data points: [10, 274, 491, 704, 1125, 1218, 2029, 2078, 2149, 2179, 2205, 3101, 3498, 3587, 4212, 4236, 4426]
# Number of data points in this cluster: 17
#
# Cluster 430:
# Indices of data points: [11, 506, 1850, 2683, 4210]
# Number of data points in this cluster: 5
#
# Cluster 129:
# Indices of data points: [12, 536, 1073, 1862, 3425, 3756, 4184]
# Number of data points in this cluster: 7
#
# Cluster 316:
# Indices of data points: [13, 774, 1749, 1977, 2126, 3809]
# Number of data points in this cluster: 6
#
# Cluster 721:
# Indices of data points: [15, 284, 1592, 3296]
# Number of data points in this cluster: 4
#
# Cluster 328:
# Indices of data points: [16, 224, 383, 1982, 2170, 2922, 3046, 3093, 4649, 5026, 5058]
# Number of data points in this cluster: 11
#
# Cluster 674:
# Indices of data points: [17, 815, 2581, 2941, 3338, 4389]
# Number of data points in this cluster: 6
#
# Cluster 322:
# Indices of data points: [18, 450, 960, 3455]
# Number of data points in this cluster: 4
#
# Cluster 336:
# Indices of data points: [19, 575, 1202, 1227, 3376, 4926]
# Number of data points in this cluster: 6
#
# Cluster 556:
# Indices of data points: [20, 1955, 3142, 3820, 4262]
# Number of data points in this cluster: 5
#
# Cluster 609:
# Indices of data points: [21, 1482, 2139, 4270]
# Number of data points in this cluster: 4
#
# Cluster 40:
# Indices of data points: [22, 900, 1120, 1696, 2355, 3271, 3660, 3687, 4103, 4354, 4897]
# Number of data points in this cluster: 11
#
# Cluster 683:
# Indices of data points: [23, 4422]
# Number of data points in this cluster: 2
#
# Cluster 212:
# Indices of data points: [24, 868, 1050, 1423, 1924, 2529, 2814, 3929, 4647, 5047]
# Number of data points in this cluster: 10
#
# Cluster 576:
# Indices of data points: [25, 556, 877, 2425, 2821, 3513]
# Number of data points in this cluster: 6
#
# Cluster 544:
# Indices of data points: [26, 179, 569, 1338, 1546]
# Number of data points in this cluster: 5
#
# Cluster 546:
# Indices of data points: [27, 534, 804, 977, 1751, 4965]
# Number of data points in this cluster: 6
#
# Cluster 19:
# Indices of data points: [28, 592, 694, 847, 909, 1044, 1086, 1380, 1765, 3028, 3943, 4582, 4657, 4703]
# Number of data points in this cluster: 14
#
# Cluster 506:
# Indices of data points: [29, 492, 740, 942, 1561, 1948, 2321, 3595, 3639, 3830, 4785]
# Number of data points in this cluster: 11
#
# Cluster 508:
# Indices of data points: [30, 642, 700, 1900, 2646, 2697, 2835, 3326, 4268, 4508, 5068]
# Number of data points in this cluster: 11
#
# Cluster 3:
# Indices of data points: [32, 294, 325, 983, 1238, 1262, 2472, 2631, 3128, 3187, 3217, 4313, 4421, 4814, 5054]
# Number of data points in this cluster: 15
#
# Cluster 68:
# Indices of data points: [33, 130, 715, 1768, 2318, 2344, 2696, 3795, 4254, 4323, 4402, 4666, 4805]
# Number of data points in this cluster: 13
#
# Cluster 271:
# Indices of data points: [34, 667, 1024, 1129, 1311, 1337, 3474, 4590]
# Number of data points in this cluster: 8
#
# Cluster 533:
# Indices of data points: [35, 472, 613, 894, 2196, 2949, 3423, 3451, 3739, 4675, 4944]
# Number of data points in this cluster: 11
#
# Cluster 605:
# Indices of data points: [36, 2363, 3986]
# Number of data points in this cluster: 3
#
# Cluster 392:
# Indices of data points: [37, 344, 945, 2015, 3020, 3446, 3554, 3602, 3679, 4190, 4223]
# Number of data points in this cluster: 11
#
# Cluster 527:
# Indices of data points: [39, 217, 356, 1382, 3962]
# Number of data points in this cluster: 5
#
# Cluster 214:
# Indices of data points: [40, 207, 346, 1279, 1381, 2061, 2546, 2704, 3168, 3231, 4061]
# Number of data points in this cluster: 11
#
# Cluster 55:
# Indices of data points: [41, 660, 843, 1000, 1171, 1996, 2010, 2156, 2380, 2778, 3171, 3350]
# Number of data points in this cluster: 12
#
# Cluster 43:
# Indices of data points: [42, 966, 1068, 1095, 1770, 3390, 4260, 4456, 4981]
# Number of data points in this cluster: 9
#
# Cluster 86:
# Indices of data points: [43, 423, 869, 1223, 1864, 2346, 2895, 4737]
# Number of data points in this cluster: 8
#
# Cluster 206:
# Indices of data points: [44, 2492, 2578, 2999, 3054, 3067, 3407, 3669, 3921, 3942, 4129, 4154, 4332, 4605]
# Number of data points in this cluster: 14
#
# Cluster 365:
# Indices of data points: [45, 335, 425, 656, 1019, 2172, 3109, 4962]
# Number of data points in this cluster: 8
#
# Cluster 637:
# Indices of data points: [46, 3279, 4695]
# Number of data points in this cluster: 3
#
# Cluster 289:
# Indices of data points: [47, 88, 1858, 2411, 2689, 3215, 3833, 4702, 4864]
# Number of data points in this cluster: 9
#
# Cluster 482:
# Indices of data points: [48, 876, 1136, 1260, 1477, 1926, 4062, 4173, 4910]
# Number of data points in this cluster: 9
#
# Cluster 310:
# Indices of data points: [49, 60, 174, 427, 2406, 2435, 2747, 2940, 3127, 4683, 4946]
# Number of data points in this cluster: 11
#
# Cluster 103:
# Indices of data points: [50, 235, 763, 1320, 1920, 2226, 4429, 4617, 4801]
# Number of data points in this cluster: 9
#
# Cluster 167:
# Indices of data points: [51, 263, 377, 625, 904, 1283, 1676, 1760, 1895, 2503, 3234, 3449, 4259, 4901]
# Number of data points in this cluster: 14
#
# Cluster 91:
# Indices of data points: [52, 669, 968, 1039, 1353, 1861, 3191, 3311, 3692, 4628, 4979]
# Number of data points in this cluster: 11
#
# Cluster 542:
# Indices of data points: [53, 75, 110, 2707, 2927, 2986, 3757, 4494, 4506]
# Number of data points in this cluster: 9
#
# Cluster 194:
# Indices of data points: [54, 797, 1105, 1203, 1308, 1554, 1632, 2479, 3071, 3083, 3668]
# Number of data points in this cluster: 11
#
# Cluster 501:
# Indices of data points: [55, 389, 1455, 3029, 3533, 3643, 3647, 4604, 4836, 4857, 4873]
# Number of data points in this cluster: 11
#
# Cluster 357:
# Indices of data points: [56, 112, 125, 762, 772, 1007, 2652, 3076, 3494, 4207, 4688, 4896]
# Number of data points in this cluster: 12
#
# Cluster 229:
# Indices of data points: [57, 185, 612, 1085, 2089, 2576, 3052, 3426, 3594, 4160, 4297, 4482, 4782]
# Number of data points in this cluster: 13
#
# Cluster 273:
# Indices of data points: [58, 169, 370, 560, 859, 1180, 1442, 3040, 3169, 4343, 4654, 4988]
# Number of data points in this cluster: 12
#
# Cluster 62:
# Indices of data points: [59, 98, 295, 546, 963, 1322, 1504, 2028, 2441, 2449, 2451, 2618, 2813, 3542, 3710, 3732, 3938, 4886]
# Number of data points in this cluster: 18
#
# Cluster 36:
# Indices of data points: [61, 614, 828, 928, 939, 1231, 1282, 2620, 2741, 3304, 3805, 4037, 4626, 4750, 4878]
# Number of data points in this cluster: 15
#
# Cluster 666:
# Indices of data points: [62, 406, 823, 1109, 1362, 3947, 3966, 4257, 4305, 4468, 4676, 4951]
# Number of data points in this cluster: 12
#
# Cluster 228:
# Indices of data points: [63, 490, 1324, 1413, 1583, 1723, 2373, 2505, 2937, 2973, 3329, 3530, 3538, 3872, 4509, 4879, 5022]
# Number of data points in this cluster: 17
#
# Cluster 122:
# Indices of data points: [64, 664, 1234, 1826, 1828, 4413]
# Number of data points in this cluster: 6
#
# Cluster 53:
# Indices of data points: [65, 261, 891, 1011, 1566, 2477, 2626, 2933, 3144, 3775, 3806, 4124, 4687]
# Number of data points in this cluster: 13
#
# Cluster 424:
# Indices of data points: [66, 956, 1004, 2547, 2668, 3843, 4241, 4888]
# Number of data points in this cluster: 8
#
# Cluster 201:
# Indices of data points: [67, 470, 1680, 1934, 2714, 4855, 5013]
# Number of data points in this cluster: 7
#
# Cluster 60:
# Indices of data points: [68, 310, 674, 1061, 1228, 1602, 1721, 3357, 3846, 4227, 4231, 4579, 4671, 5039]
# Number of data points in this cluster: 14
#
# Cluster 18:
# Indices of data points: [69, 228, 849, 1300, 2539, 3199, 3211, 4335, 4444, 4599, 4630]
# Number of data points in this cluster: 11
#
# Cluster 560:
# Indices of data points: [70, 681, 791, 1245, 1302, 1348, 4374, 4705]
# Number of data points in this cluster: 8
#
# Cluster 30:
# Indices of data points: [71, 77, 659, 943, 1029, 1135, 1391, 1683, 2211, 3033, 3095, 3189, 4799]
# Number of data points in this cluster: 13
#
# Cluster 339:
# Indices of data points: [72, 205, 268, 1078, 1124, 1287, 1326, 3399]
# Number of data points in this cluster: 8
#
# Cluster 16:
# Indices of data points: [73, 714, 882, 1047, 1444, 1712, 1733, 1845, 2032, 2416, 2523, 3249, 3460, 3621, 3664, 4021, 4178, 4368, 4507, 4711, 4833]
# Number of data points in this cluster: 21
#
# Cluster 200:
# Indices of data points: [74, 2227, 2360, 2423, 2466, 2718, 3200, 3298, 3427, 3796, 4420, 4669]
# Number of data points in this cluster: 12
#
# Cluster 587:
# Indices of data points: [76, 2030, 3179, 3915, 4308]
# Number of data points in this cluster: 5
#
# Cluster 105:
# Indices of data points: [78, 99, 117, 1063, 1220, 1931, 2242, 2496, 2508, 2648, 2958, 3667, 3981, 4014, 4491, 4976]
# Number of data points in this cluster: 16
#
# Cluster 187:
# Indices of data points: [79, 257, 1630, 1767, 2112, 2145, 4125, 4500, 4537]
# Number of data points in this cluster: 9
#
# Cluster 381:
# Indices of data points: [80, 514, 703, 781, 1070, 1290, 1312, 1473, 2595, 2852, 3765, 3804, 4485]
# Number of data points in this cluster: 13
#
# Cluster 121:
# Indices of data points: [81, 1147, 2034, 2085, 3212, 3415, 3574, 4121, 4376, 4409, 4596, 4859, 5003, 5005]
# Number of data points in this cluster: 14
#
# Cluster 710:
# Indices of data points: [82, 1305, 1465, 2138, 2702, 2775, 3802, 5001]
# Number of data points in this cluster: 8
#
# Cluster 202:
# Indices of data points: [83, 766, 906, 1025, 2161, 2169, 2212, 2448, 2565, 2836, 3744, 4175, 4919, 5059]
# Number of data points in this cluster: 14
#
# Cluster 397:
# Indices of data points: [84, 1497, 2271, 2633, 3821, 4015, 4411]
# Number of data points in this cluster: 7
#
# Cluster 140:
# Indices of data points: [85, 148, 1268, 3489, 3869, 4157]
# Number of data points in this cluster: 6
#
# Cluster 110:
# Indices of data points: [86, 156, 603, 641, 1167, 1368, 1422, 2509, 3065, 4557]
# Number of data points in this cluster: 10
#
# Cluster 640:
# Indices of data points: [87, 1486, 2354, 2681, 4567]
# Number of data points in this cluster: 5
#
# Cluster 195:
# Indices of data points: [89, 126, 2117, 2844, 3340, 3734, 4432]
# Number of data points in this cluster: 7
#
# Cluster 234:
# Indices of data points: [90, 104, 528, 618, 808, 842, 1186, 1390, 3018, 3254, 3436, 3762, 4010, 4692, 4990]
# Number of data points in this cluster: 15
#
# Cluster 25:
# Indices of data points: [91, 522, 1887, 2672, 3114, 3623, 3844, 4556, 4610, 4668, 4714, 4765, 4795]
# Number of data points in this cluster: 13
#
# Cluster 549:
# Indices of data points: [92, 773, 981, 1276, 1684, 2710, 2717, 2850, 2942, 3852, 4251, 4645, 4856]
# Number of data points in this cluster: 13
#
# Cluster 308:
# Indices of data points: [93, 143, 933, 1507, 2497, 2795, 3680, 4119, 4504, 4591, 4812]
# Number of data points in this cluster: 11
#
# Cluster 434:
# Indices of data points: [94, 368, 1141, 2193, 2494, 2776, 2934, 3106, 3346, 3443, 3665, 3825, 4161]
# Number of data points in this cluster: 13
#
# Cluster 44:
# Indices of data points: [95, 405, 709, 742, 1017, 1020, 1030, 1144, 1197, 1997, 2185, 3038, 3417, 3508, 3534, 3646, 4798]
# Number of data points in this cluster: 17
#
# Cluster 163:
# Indices of data points: [96, 287, 1032, 2428, 2465, 2627, 2686, 3166, 3332, 3551, 3581, 3714, 4151, 4283, 4339, 4534, 4600]
# Number of data points in this cluster: 17
#
# Cluster 584:
# Indices of data points: [97, 338, 884, 1138, 2090, 2114, 2132, 2645, 2712]
# Number of data points in this cluster: 9
#
# Cluster 50:
# Indices of data points: [100, 208, 2062, 2221, 2247, 3174, 3408, 3412, 3707, 3960, 4337, 4535, 4576, 4741, 4821]
# Number of data points in this cluster: 15
#
# Cluster 294:
# Indices of data points: [101, 1545, 2519, 3635, 4698, 4889, 5045]
# Number of data points in this cluster: 7
#
# Cluster 416:
# Indices of data points: [102, 1947, 2135, 2501, 2569, 3192, 3218, 4193, 4716, 5007]
# Number of data points in this cluster: 10
#
# Cluster 642:
# Indices of data points: [103, 895, 4533, 4561, 4996]
# Number of data points in this cluster: 5
#
# Cluster 440:
# Indices of data points: [105, 1813, 3206, 3448, 4709, 4734]
# Number of data points in this cluster: 6
#
# Cluster 34:
# Indices of data points: [106, 662, 1033, 1387, 2210, 2644, 2662, 2884, 3424, 3769, 4204, 4310, 4618]
# Number of data points in this cluster: 13
#
# Cluster 104:
# Indices of data points: [107, 1185, 1316, 1332, 1371, 2231, 2709, 2950, 3167, 3550, 4678, 5036]
# Number of data points in this cluster: 12
#
# Cluster 650:
# Indices of data points: [108, 743, 1729, 1964]
# Number of data points in this cluster: 4
#
# Cluster 581:
# Indices of data points: [109, 1191, 1344, 2706, 3010]
# Number of data points in this cluster: 5
#
# Cluster 747:
# Indices of data points: [111, 527, 1417, 1624]
# Number of data points in this cluster: 4
#
# Cluster 739:
# Indices of data points: [113, 745, 1255, 1274, 1886, 5033]
# Number of data points in this cluster: 6
#
# Cluster 439:
# Indices of data points: [114, 1495, 2885, 3851]
# Number of data points in this cluster: 4
#
# Cluster 472:
# Indices of data points: [115, 177, 1969, 3591]
# Number of data points in this cluster: 4
#
# Cluster 621:
# Indices of data points: [116, 1601, 1700, 2881, 3299, 4214]
# Number of data points in this cluster: 6
#
# Cluster 1:
# Indices of data points: [118, 316, 407, 508, 517, 1126, 1357, 1392, 2684, 2755, 2785, 4644, 4651, 4865, 4876, 4920, 4957]
# Number of data points in this cluster: 17
#
# Cluster 462:
# Indices of data points: [119, 265, 464, 1002, 1060, 1435, 1513, 2605, 2787, 3069, 3177, 4152, 4565]
# Number of data points in this cluster: 13
#
# Cluster 553:
# Indices of data points: [120, 233, 622, 800, 994, 2962, 4658]
# Number of data points in this cluster: 7
#
# Cluster 320:
# Indices of data points: [122, 488, 1805, 4895, 4972]
# Number of data points in this cluster: 5
#
# Cluster 181:
# Indices of data points: [123, 979, 1067, 1210, 1971, 3181]
# Number of data points in this cluster: 6
#
# Cluster 534:
# Indices of data points: [124, 2304, 4064, 4233, 4473]
# Number of data points in this cluster: 5
#
# Cluster 182:
# Indices of data points: [127, 358, 938, 1037, 1123, 1254, 1854, 2199, 2656, 2862, 4255, 4574, 4700, 4925, 4973, 5069]
# Number of data points in this cluster: 16
#
# Cluster 644:
# Indices of data points: [128, 192, 414, 558, 835, 1042, 1280, 1424, 2218, 3045]
# Number of data points in this cluster: 10
#
# Cluster 388:
# Indices of data points: [129, 231, 597, 1252, 1626, 1987, 2002, 2101, 2157, 2189, 2194, 2263, 3515, 4306, 4550]
# Number of data points in this cluster: 15
#
# Cluster 288:
# Indices of data points: [131, 2827]
# Number of data points in this cluster: 2
#
# Cluster 571:
# Indices of data points: [132, 203, 477, 519, 581, 1031, 1319, 2462, 2782, 3228, 3728, 4909]
# Number of data points in this cluster: 12
#
# Cluster 49:
# Indices of data points: [133, 486, 2159, 2624, 2663, 2708, 2939, 3466, 3730, 3967, 4242, 4536, 4722, 4983]
# Number of data points in this cluster: 14
#
# Cluster 22:
# Indices of data points: [134, 282, 324, 402, 761, 789, 2623, 2727, 4431, 4502, 4552, 4706, 4773]
# Number of data points in this cluster: 13
#
# Cluster 693:
# Indices of data points: [135, 3880, 4030, 4235]
# Number of data points in this cluster: 4
#
# Cluster 130:
# Indices of data points: [136, 280, 419, 852, 883, 985, 1526, 1756, 3257, 3493, 3736, 3819, 4529, 4608, 4661]
# Number of data points in this cluster: 15
#
# Cluster 127:
# Indices of data points: [137, 1954, 2388, 2737, 3419, 3468, 4719]
# Number of data points in this cluster: 7
#
# Cluster 317:
# Indices of data points: [138, 1074, 2426, 2947, 3209, 4220, 4472, 4914, 4985]
# Number of data points in this cluster: 9
#
# Cluster 186:
# Indices of data points: [139, 1641, 2580, 3431, 3834, 4116, 4543, 4802, 4974]
# Number of data points in this cluster: 9
#
# Cluster 296:
# Indices of data points: [140, 589, 668, 1296, 1321, 1577, 2200, 3248]
# Number of data points in this cluster: 8
#
# Cluster 517:
# Indices of data points: [141, 163, 315, 1600, 2647, 2670, 3629, 3754, 4614, 4816]
# Number of data points in this cluster: 10
#
# Cluster 87:
# Indices of data points: [142, 2415, 2769, 2805, 4017, 4634, 4738]
# Number of data points in this cluster: 7
#
# Cluster 137:
# Indices of data points: [144, 288, 2337, 2882, 3618]
# Number of data points in this cluster: 5
#
# Cluster 0:
# Indices of data points: [145, 272, 1010, 2046, 2141, 2625, 2740, 3718, 4202, 4247, 4844, 4938]
# Number of data points in this cluster: 12
#
# Cluster 522:
# Indices of data points: [146, 566, 2929, 3205, 3388, 3813]
# Number of data points in this cluster: 6
#
# Cluster 114:
# Indices of data points: [147, 651, 857, 1744, 2694, 2829, 3176, 3477, 3770, 3856, 3908, 4108]
# Number of data points in this cluster: 12
#
# Cluster 315:
# Indices of data points: [149, 811, 1258, 1666, 2146, 2491, 3051, 3190]
# Number of data points in this cluster: 8
#
# Cluster 189:
# Indices of data points: [150, 194, 352, 1100, 1217, 1735, 2153, 2560, 2650, 3782]
# Number of data points in this cluster: 10
#
# Cluster 364:
# Indices of data points: [151, 444, 953, 3452, 3543, 4435]
# Number of data points in this cluster: 6
#
# Cluster 106:
# Indices of data points: [152, 722, 1541, 1817]
# Number of data points in this cluster: 4
#
# Cluster 465:
# Indices of data points: [154, 2068, 2807, 3884, 4496]
# Number of data points in this cluster: 5
#
# Cluster 414:
# Indices of data points: [157, 970, 1802, 1932, 2053, 2957, 3062, 4345]
# Number of data points in this cluster: 8
#
# Cluster 669:
# Indices of data points: [158, 1882, 2634]
# Number of data points in this cluster: 3
#
# Cluster 81:
# Indices of data points: [159, 283, 726, 2527, 3924, 5021]
# Number of data points in this cluster: 6
#
# Cluster 633:
# Indices of data points: [160, 1467, 4131]
# Number of data points in this cluster: 3
#
# Cluster 295:
# Indices of data points: [161, 881, 1080, 2789, 4718]
# Number of data points in this cluster: 5
#
# Cluster 154:
# Indices of data points: [162, 371, 555, 559, 705, 1406, 2531, 2820, 2924, 3793, 3888, 4761]
# Number of data points in this cluster: 12
#
# Cluster 611:
# Indices of data points: [164, 1778, 2335]
# Number of data points in this cluster: 3
#
# Cluster 600:
# Indices of data points: [165, 3657, 3863, 4102]
# Number of data points in this cluster: 4
#
# Cluster 678:
# Indices of data points: [166, 850, 1906, 2383, 2630, 2936, 4606]
# Number of data points in this cluster: 7
#
# Cluster 744:
# Indices of data points: [167, 251, 2109, 3936, 4336, 4460, 4924]
# Number of data points in this cluster: 7
#
# Cluster 222:
# Indices of data points: [168, 469, 499, 693, 1752, 2610, 3035, 3068, 3157, 3280, 3288, 3683, 3720, 4694, 4885]
# Number of data points in this cluster: 15
#
# Cluster 411:
# Indices of data points: [170, 396, 1536, 1629, 1885, 2371, 4271, 4916, 4956]
# Number of data points in this cluster: 9
#
# Cluster 259:
# Indices of data points: [171, 1333, 1480, 2331, 3365, 4012, 4115, 4763]
# Number of data points in this cluster: 8
#
# Cluster 299:
# Indices of data points: [172, 435, 683, 720, 1655, 2742, 2786, 3226, 3378, 3432, 4148, 4383, 4819, 4831]
# Number of data points in this cluster: 14
#
# Cluster 77:
# Indices of data points: [173, 388, 421, 831, 834, 910, 924, 1520, 2220, 2238, 3021, 3808, 4133, 4328, 4331, 4589, 4999]
# Number of data points in this cluster: 17
#
# Cluster 716:
# Indices of data points: [175, 4680]
# Number of data points in this cluster: 2
#
# Cluster 237:
# Indices of data points: [176, 269, 433, 971, 1647, 2249, 2935, 3048, 3229, 4564, 4686, 4788]
# Number of data points in this cluster: 12
#
# Cluster 20:
# Indices of data points: [178, 323, 431, 557, 768, 855, 1375, 2203, 2273, 2461, 2744, 3354, 4239, 4290, 4635, 5035]
# Number of data points in this cluster: 16
#
# Cluster 166:
# Indices of data points: [180, 1366, 2274, 2280, 3747, 4194, 4947]
# Number of data points in this cluster: 7
#
# Cluster 426:
# Indices of data points: [181, 347, 946, 954, 1177, 1898, 2364, 2407, 2943, 3422, 3743, 4735, 4747, 4764]
# Number of data points in this cluster: 14
#
# Cluster 119:
# Indices of data points: [182, 631, 1065, 1145, 1213, 2079, 2353, 3737, 3807]
# Number of data points in this cluster: 9
#
# Cluster 623:
# Indices of data points: [183, 1757, 2204, 2987, 3337, 4138]
# Number of data points in this cluster: 6
#
# Cluster 15:
# Indices of data points: [184, 301, 1929, 1940, 2262, 2464, 2549, 2784, 3952]
# Number of data points in this cluster: 9
#
# Cluster 29:
# Indices of data points: [186, 585, 599, 798, 1377, 1914, 2213, 3031, 3077, 3251, 3944, 4169, 4523, 4672]
# Number of data points in this cluster: 14
#
# Cluster 519:
# Indices of data points: [187, 616, 1021, 1548, 2288, 2372, 4704]
# Number of data points in this cluster: 7
#
# Cluster 393:
# Indices of data points: [188, 401, 437, 567, 2152, 3341, 4729, 4872]
# Number of data points in this cluster: 8
#
# Cluster 480:
# Indices of data points: [189, 1361, 1645, 1776, 2431, 2888, 2891]
# Number of data points in this cluster: 7
#
# Cluster 370:
# Indices of data points: [190, 378, 1257, 2566, 2574]
# Number of data points in this cluster: 5
#
# Cluster 743:
# Indices of data points: [191, 602, 1192, 1944, 1959, 2395, 3185, 4918]
# Number of data points in this cluster: 8
#
# Cluster 32:
# Indices of data points: [193, 327, 2044, 2082, 2500, 3722, 4172]
# Number of data points in this cluster: 7
#
# Cluster 737:
# Indices of data points: [195, 273, 676]
# Number of data points in this cluster: 3
#
# Cluster 335:
# Indices of data points: [196, 1613, 2701, 2982, 3143]
# Number of data points in this cluster: 5
#
# Cluster 95:
# Indices of data points: [197, 238, 845, 2086, 2195, 2558, 2711, 2713, 2767, 4282]
# Number of data points in this cluster: 10
#
# Cluster 33:
# Indices of data points: [198, 1580, 1771, 3486, 3487, 3892, 3897, 4289, 4325]
# Number of data points in this cluster: 9
#
# Cluster 559:
# Indices of data points: [199, 1221, 3861, 4414, 4461]
# Number of data points in this cluster: 5
#
# Cluster 12:
# Indices of data points: [200, 749, 2243, 2521, 3050, 3159]
# Number of data points in this cluster: 6
#
# Cluster 111:
# Indices of data points: [202, 3481, 4786, 4968]
# Number of data points in this cluster: 4
#
# Cluster 431:
# Indices of data points: [204, 889, 1528, 2054, 3759, 3764]
# Number of data points in this cluster: 6
#
# Cluster 28:
# Indices of data points: [206, 354, 1041, 1329, 1540, 1552, 1611, 2071, 2369, 3103, 3164, 3366, 3500, 4109, 4408, 4592]
# Number of data points in this cluster: 16
#
# Cluster 323:
# Indices of data points: [209, 361, 1153, 1190, 1810, 3510, 3935, 4252, 4524, 4870]
# Number of data points in this cluster: 10
#
# Cluster 156:
# Indices of data points: [211, 630, 1704, 1709, 1945, 2005, 2599, 3440, 3484, 4623]
# Number of data points in this cluster: 10
#
# Cluster 389:
# Indices of data points: [212, 1169, 1903, 4083]
# Number of data points in this cluster: 4
#
# Cluster 435:
# Indices of data points: [213, 380, 619, 1443, 1957, 2467, 2768, 2990, 3333, 4399]
# Number of data points in this cluster: 10
#
# Cluster 394:
# Indices of data points: [214, 1222, 2017, 2524]
# Number of data points in this cluster: 4
#
# Cluster 592:
# Indices of data points: [215, 337, 349, 1360, 1660]
# Number of data points in this cluster: 5
#
# Cluster 185:
# Indices of data points: [216, 1470, 2847, 4041, 4056, 4105]
# Number of data points in this cluster: 6
#
# Cluster 486:
# Indices of data points: [218, 256, 398, 482, 969, 1713, 2661, 2753, 2765, 3599]
# Number of data points in this cluster: 10
#
# Cluster 160:
# Indices of data points: [219, 1691, 1772, 2669, 2856, 2883]
# Number of data points in this cluster: 6
#
# Cluster 615:
# Indices of data points: [220, 502, 1292, 3207, 4171, 4319, 4609, 5060]
# Number of data points in this cluster: 8
#
# Cluster 647:
# Indices of data points: [221, 298, 3469]
# Number of data points in this cluster: 3
#
# Cluster 298:
# Indices of data points: [222, 678, 1247, 1884, 1928, 2012, 2432, 2788, 5029]
# Number of data points in this cluster: 9
#
# Cluster 84:
# Indices of data points: [223, 822, 1059, 1226, 1693, 1892, 1995, 2025, 2099, 2147, 2278, 2514, 2641, 3097, 3222, 4215]
# Number of data points in this cluster: 16
#
# Cluster 93:
# Indices of data points: [225, 314, 922, 1291, 2173, 2443, 4300, 4720]
# Number of data points in this cluster: 8
#
# Cluster 706:
# Indices of data points: [226, 1935]
# Number of data points in this cluster: 2
#
# Cluster 461:
# Indices of data points: [227, 395, 582, 1468, 1557, 1646, 2887, 3203, 3648, 4984]
# Number of data points in this cluster: 10
#
# Cluster 468:
# Indices of data points: [229, 652, 1157, 1165, 1727, 2926, 3086, 3286, 4216]
# Number of data points in this cluster: 9
#
# Cluster 564:
# Indices of data points: [230, 254, 2486, 3457]
# Number of data points in this cluster: 4
#
# Cluster 725:
# Indices of data points: [232, 553, 816, 1317, 2401, 2422, 2455, 3175, 3233, 4655]
# Number of data points in this cluster: 10
#
# Cluster 134:
# Indices of data points: [234, 837, 1419, 1665, 1909, 2255, 2660, 3523, 3928, 3932]
# Number of data points in this cluster: 10
#
# Cluster 662:
# Indices of data points: [236, 1434, 3007, 3598]
# Number of data points in this cluster: 4
#
# Cluster 144:
# Indices of data points: [237, 671, 2225, 2845, 4232, 4528]
# Number of data points in this cluster: 6
#
# Cluster 90:
# Indices of data points: [239, 1857, 2812, 2848, 3361, 3583, 3703, 4340]
# Number of data points in this cluster: 8
#
# Cluster 35:
# Indices of data points: [240, 532, 644, 701, 1334, 1739, 2992, 2998, 4662]
# Number of data points in this cluster: 9
#
# Cluster 684:
# Indices of data points: [241, 3749, 3964]
# Number of data points in this cluster: 3
#
# Cluster 382:
# Indices of data points: [242, 2057, 2164, 2452, 2908, 3225, 4272]
# Number of data points in this cluster: 7
#
# Cluster 443:
# Indices of data points: [243, 672, 717, 1057, 3335]
# Number of data points in this cluster: 5
#
# Cluster 438:
# Indices of data points: [244, 1879, 2760, 3492, 3937, 4453]
# Number of data points in this cluster: 6
#
# Cluster 757:
# Indices of data points: [245, 1012, 1346, 2446, 2640, 2826, 4142]
# Number of data points in this cluster: 7
#
# Cluster 690:
# Indices of data points: [246, 814, 1534, 1961, 2184, 2590, 3088]
# Number of data points in this cluster: 7
#
# Cluster 691:
# Indices of data points: [247, 2350, 2969]
# Number of data points in this cluster: 3
#
# Cluster 495:
# Indices of data points: [248, 379, 1148, 1241, 1908, 2007, 2105, 2290, 3091, 3277, 4580]
# Number of data points in this cluster: 11
#
# Cluster 177:
# Indices of data points: [249, 505, 802, 1363, 1788, 2526, 2606, 2955, 3227, 3729, 4481, 4733, 4874]
# Number of data points in this cluster: 13
#
# Cluster 494:
# Indices of data points: [250, 409, 880, 1229, 1410, 1530, 2182, 2732, 3235, 3697, 3814, 4338, 5051]
# Number of data points in this cluster: 13
#
# Cluster 520:
# Indices of data points: [252, 706, 1055, 1244, 1264, 1741, 2098, 2909, 4934, 5002]
# Number of data points in this cluster: 10
#
# Cluster 292:
# Indices of data points: [253, 1644, 1941, 2436, 2654, 3019, 4418, 4541, 4584]
# Number of data points in this cluster: 9
#
# Cluster 391:
# Indices of data points: [255, 1705, 2326, 2819, 2975, 3282]
# Number of data points in this cluster: 6
#
# Cluster 380:
# Indices of data points: [258, 2376, 4980]
# Number of data points in this cluster: 3
#
# Cluster 627:
# Indices of data points: [259, 929, 1087, 1303, 4237]
# Number of data points in this cluster: 5
#
# Cluster 418:
# Indices of data points: [260, 1505, 2328, 2734]
# Number of data points in this cluster: 4
#
# Cluster 537:
# Indices of data points: [262, 2860, 2951, 3565, 3726, 3773, 4727]
# Number of data points in this cluster: 7
#
# Cluster 379:
# Indices of data points: [264, 513, 2162, 2264, 2340, 3058, 4839]
# Number of data points in this cluster: 7
#
# Cluster 359:
# Indices of data points: [267, 1140, 1631, 3087, 4613]
# Number of data points in this cluster: 5
#
# Cluster 451:
# Indices of data points: [270, 609, 1339, 1933, 2392, 4586]
# Number of data points in this cluster: 6
#
# Cluster 510:
# Indices of data points: [271, 1564, 3374, 3569, 4791]
# Number of data points in this cluster: 5
#
# Cluster 572:
# Indices of data points: [275, 369, 1117, 1358, 2420, 2680, 3023, 3392, 4265]
# Number of data points in this cluster: 9
#
# Cluster 384:
# Indices of data points: [276, 466, 1936]
# Number of data points in this cluster: 3
#
# Cluster 349:
# Indices of data points: [277, 1440, 2313, 4150, 4532, 4862]
# Number of data points in this cluster: 6
#
# Cluster 492:
# Indices of data points: [278, 1132, 1249, 1365, 1396, 2027, 2339, 2487, 4416]
# Number of data points in this cluster: 9
#
# Cluster 755:
# Indices of data points: [279, 598, 1175, 2160, 2809, 2898, 3560, 4558]
# Number of data points in this cluster: 8
#
# Cluster 17:
# Indices of data points: [281, 408, 471, 832, 898, 997, 1088, 1240, 1278, 1650, 1658, 2000, 2084, 2123, 3584, 3755, 3842, 3886, 4495, 4745, 4749]
# Number of data points in this cluster: 21
#
# Cluster 37:
# Indices of data points: [285, 303, 386, 467, 539, 640, 819, 1013, 1980, 2437, 2485, 2800, 3586, 3620, 3631, 3777, 3792, 3817, 4755, 4846, 4986]
# Number of data points in this cluster: 21
#
# Cluster 204:
# Indices of data points: [286, 343, 376, 387, 756, 1572, 1865, 2043, 2110, 2222, 2397, 2919, 3349, 3450, 3567, 3785, 4679]
# Number of data points in this cluster: 17
#
# Cluster 582:
# Indices of data points: [289, 481, 636, 702, 790, 3017, 4281, 4465]
# Number of data points in this cluster: 8
#
# Cluster 162:
# Indices of data points: [290, 926, 2228, 4633, 4900]
# Number of data points in this cluster: 5
#
# Cluster 59:
# Indices of data points: [291, 787, 1189, 2048, 2059, 2268, 2613, 2638, 3034, 3089, 4907]
# Number of data points in this cluster: 11
#
# Cluster 733:
# Indices of data points: [292]
# Number of data points in this cluster: 1
#
# Cluster 183:
# Indices of data points: [293, 453, 1265, 1483, 2414, 3188]
# Number of data points in this cluster: 6
#
# Cluster 196:
# Indices of data points: [296, 637, 871, 961, 1327, 1669, 3439, 3548, 4725]
# Number of data points in this cluster: 9
#
# Cluster 39:
# Indices of data points: [297, 460, 1206, 1786, 2563, 4440, 4770]
# Number of data points in this cluster: 7
#
# Cluster 149:
# Indices of data points: [299, 646, 982, 1318, 2294, 2582, 2899, 3324, 3507, 3615, 4871, 4964, 4993]
# Number of data points in this cluster: 13
#
# Cluster 285:
# Indices of data points: [300, 363, 4126]
# Number of data points in this cluster: 3
#
# Cluster 487:
# Indices of data points: [302, 2322, 3605, 5016]
# Number of data points in this cluster: 4
#
# Cluster 565:
# Indices of data points: [304, 3996, 4047]
# Number of data points in this cluster: 3
#
# Cluster 447:
# Indices of data points: [305, 927, 1531, 1585, 1745, 4128, 4395, 4396, 4489]
# Number of data points in this cluster: 9
#
# Cluster 597:
# Indices of data points: [306, 4156]
# Number of data points in this cluster: 2
#
# Cluster 626:
# Indices of data points: [307, 775, 1952, 1975, 4573]
# Number of data points in this cluster: 5
#
# Cluster 407:
# Indices of data points: [308, 493, 572, 990, 1266, 1462, 1799, 1960, 2628, 3778, 4848]
# Number of data points in this cluster: 11
#
# Cluster 343:
# Indices of data points: [309, 2223, 2692, 3640]
# Number of data points in this cluster: 4
#
# Cluster 555:
# Indices of data points: [311, 595, 1897]
# Number of data points in this cluster: 3
#
# Cluster 415:
# Indices of data points: [312, 350, 531, 1427, 1575]
# Number of data points in this cluster: 5
#
# Cluster 705:
# Indices of data points: [313, 653, 1397, 2404, 3039, 3344, 4379, 5067]
# Number of data points in this cluster: 8
#
# Cluster 618:
# Indices of data points: [317, 334, 2440]
# Number of data points in this cluster: 3
#
# Cluster 505:
# Indices of data points: [318, 526, 1102, 1182, 1293, 1532, 1551, 1966, 2567, 2948, 3421, 3537, 3919]
# Number of data points in this cluster: 13
#
# Cluster 586:
# Indices of data points: [319, 442, 955, 1267, 2214, 2261, 4650, 4660]
# Number of data points in this cluster: 8
#
# Cluster 475:
# Indices of data points: [320, 2336, 3496, 4378, 4451]
# Number of data points in this cluster: 5
#
# Cluster 528:
# Indices of data points: [321, 342, 635, 3831, 5071]
# Number of data points in this cluster: 5
#
# Cluster 432:
# Indices of data points: [322, 381, 753, 903, 1682, 2745, 2822, 3184, 4295, 4309, 4713]
# Number of data points in this cluster: 11
#
# Cluster 136:
# Indices of data points: [326, 824, 1881, 2095, 2534, 2886, 3501, 3558, 3913, 4677]
# Number of data points in this cluster: 10
#
# Cluster 471:
# Indices of data points: [328, 2295]
# Number of data points in this cluster: 2
#
# Cluster 727:
# Indices of data points: [329, 345, 596, 1270, 2450, 3121, 4403, 4525]
# Number of data points in this cluster: 8
#
# Cluster 433:
# Indices of data points: [330, 778, 1883, 2093, 2946, 3094, 4447]
# Number of data points in this cluster: 7
#
# Cluster 455:
# Indices of data points: [331, 741, 836, 901, 975, 1235, 1335, 1429, 2092, 3170, 4144, 4170, 4681, 4818]
# Number of data points in this cluster: 14
#
# Cluster 404:
# Indices of data points: [332, 340, 2498, 2629, 2716]
# Number of data points in this cluster: 5
#
# Cluster 132:
# Indices of data points: [333, 1748, 2022, 3745, 3761, 4279]
# Number of data points in this cluster: 6
#
# Cluster 460:
# Indices of data points: [336, 1181, 1271, 1298, 1402, 2480, 4213, 4636]
# Number of data points in this cluster: 8
#
# Cluster 456:
# Indices of data points: [339, 2042, 2952, 3429, 3611, 4739]
# Number of data points in this cluster: 6
#
# Cluster 175:
# Indices of data points: [341, 690, 738, 1967, 2215, 2259, 2728, 2956, 3173, 3458, 4454]
# Number of data points in this cluster: 11
#
# Cluster 208:
# Indices of data points: [348, 769, 1309, 1389, 1612, 1652, 1921, 2094, 2857, 3418, 4004, 4642, 4772]
# Number of data points in this cluster: 13
#
# Cluster 395:
# Indices of data points: [351, 512, 810, 1001, 1200, 1761, 3004, 3411, 3650, 3800, 4324, 4464]
# Number of data points in this cluster: 12
#
# Cluster 10:
# Indices of data points: [353, 914, 1889, 2499, 2944, 3183, 3208, 3247, 4230, 4643, 4815, 4929]
# Number of data points in this cluster: 12
#
# Cluster 260:
# Indices of data points: [355, 713, 1853, 2174, 2703, 3343, 4147, 4936, 5064]
# Number of data points in this cluster: 9
#
# Cluster 469:
# Indices of data points: [357, 1556, 2541]
# Number of data points in this cluster: 3
#
# Cluster 312:
# Indices of data points: [359, 1299, 1718, 3006, 3624, 4577, 4911]
# Number of data points in this cluster: 7
#
# Cluster 329:
# Indices of data points: [360, 999, 1372, 4778]
# Number of data points in this cluster: 4
#
# Cluster 363:
# Indices of data points: [362, 2314, 4316, 4370]
# Number of data points in this cluster: 4
#
# Cluster 27:
# Indices of data points: [364, 658, 2039, 2096, 2667, 3124, 4463, 4998]
# Number of data points in this cluster: 8
#
# Cluster 429:
# Indices of data points: [365, 2921, 3342, 3917, 4208, 4486, 4632, 4690, 5042]
# Number of data points in this cluster: 9
#
# Cluster 146:
# Indices of data points: [366, 568, 1570, 1614, 1722, 1755, 1791, 2024, 3590, 4285, 4347, 4352, 4769, 4881]
# Number of data points in this cluster: 14
#
# Cluster 6:
# Indices of data points: [367, 707, 936, 1099, 1345, 1593, 1599, 2083, 2154, 2168, 2516, 2651, 2658, 2938, 3224, 3987, 4342, 4915, 5008]
# Number of data points in this cluster: 19
#
# Cluster 8:
# Indices of data points: [372, 1393, 1430, 2327, 2792, 4697, 5041]
# Number of data points in this cluster: 7
#
# Cluster 657:
# Indices of data points: [373, 451, 3950]
# Number of data points in this cluster: 3
#
# Cluster 58:
# Indices of data points: [374, 870, 980, 1436, 1461, 2009, 2319, 2377, 2594, 2616, 3416, 3517, 3610]
# Number of data points in this cluster: 13
#
# Cluster 718:
# Indices of data points: [375, 629, 920, 2457, 2678, 2783, 4942]
# Number of data points in this cluster: 7
#
# Cluster 352:
# Indices of data points: [382, 1183, 1199, 1209, 1558, 2281, 2664, 3193, 4243, 4353]
# Number of data points in this cluster: 10
#
# Cluster 385:
# Indices of data points: [384, 411, 934, 2188, 2676, 2752, 3445, 4381, 4475, 4717, 4958, 5049, 5074]
# Number of data points in this cluster: 13
#
# Cluster 48:
# Indices of data points: [385, 696, 1071, 1843, 2208, 2400, 2665, 3022, 3072, 3766, 3984]
# Number of data points in this cluster: 11
#
# Cluster 46:
# Indices of data points: [390, 393, 426, 620, 708, 1927, 2286, 2409, 2427, 3428, 3559, 3676, 3914, 4311, 4607, 4682]
# Number of data points in this cluster: 16
#
# Cluster 54:
# Indices of data points: [391, 392, 447, 510, 520, 571, 1066, 1493, 1578, 2080, 2556, 3182, 3283, 3441, 3522, 3865, 4637]
# Number of data points in this cluster: 17
#
# Cluster 347:
# Indices of data points: [394, 1416, 2612, 2700, 3244, 4843]
# Number of data points in this cluster: 6
#
# Cluster 7:
# Indices of data points: [397, 919, 2699, 3719, 3894, 3954, 4554, 4887, 4950]
# Number of data points in this cluster: 9
#
# Cluster 485:
# Indices of data points: [399, 436, 1006, 1323, 1820, 4122, 4263, 4743]
# Number of data points in this cluster: 8
#
# Cluster 550:
# Indices of data points: [400, 941, 1149, 1236, 2107, 2442, 2510, 3553, 3931, 4182, 4245, 4501]
# Number of data points in this cluster: 12
#
# Cluster 82:
# Indices of data points: [403, 544, 853, 1237, 2081, 2143, 2763, 3753, 3912, 4224, 4304, 4601, 4994]
# Number of data points in this cluster: 13
#
# Cluster 378:
# Indices of data points: [404, 684, 886, 2865, 4771]
# Number of data points in this cluster: 5
#
# Cluster 314:
# Indices of data points: [410, 452, 1550, 1946]
# Number of data points in this cluster: 4
#
# Cluster 484:
# Indices of data points: [412, 1625, 3529, 3818]
# Number of data points in this cluster: 4
#
# Cluster 614:
# Indices of data points: [413, 561, 1158, 1837, 2246, 2693, 2761, 3688, 4163, 4187, 4969]
# Number of data points in this cluster: 11
#
# Cluster 220:
# Indices of data points: [415, 1833, 3294, 3519, 4155, 4736, 4797]
# Number of data points in this cluster: 7
#
# Cluster 372:
# Indices of data points: [416, 1232, 1306, 1494, 1498, 2008, 4159, 4748]
# Number of data points in this cluster: 8
#
# Cluster 500:
# Indices of data points: [417, 848, 1294, 1866, 4130, 4995]
# Number of data points in this cluster: 6
#
# Cluster 700:
# Indices of data points: [418, 1295, 3081, 4358]
# Number of data points in this cluster: 4
#
# Cluster 230:
# Indices of data points: [420, 732, 1487, 1608, 1829, 2178, 2757, 3132]
# Number of data points in this cluster: 8
#
# Cluster 120:
# Indices of data points: [422, 757, 825, 2233, 2687, 3319, 3634, 4758, 4875]
# Number of data points in this cluster: 9
#
# Cluster 539:
# Indices of data points: [424, 680, 893, 1304, 3105]
# Number of data points in this cluster: 5
#
# Cluster 664:
# Indices of data points: [428, 632, 1051]
# Number of data points in this cluster: 3
#
# Cluster 51:
# Indices of data points: [429, 1501, 1661, 1780, 2568, 3330, 3651, 4441, 4602, 4787]
# Number of data points in this cluster: 10
#
# Cluster 26:
# Indices of data points: [430, 765, 2393, 2914, 3401, 3801, 3982]
# Number of data points in this cluster: 7
#
# Cluster 735:
# Indices of data points: [432, 1846, 3874]
# Number of data points in this cluster: 3
#
# Cluster 619:
# Indices of data points: [434, 3470]
# Number of data points in this cluster: 2
#
# Cluster 262:
# Indices of data points: [438, 468, 627, 689, 699, 1878, 2155, 2791, 2995, 3671, 4196]
# Number of data points in this cluster: 11
#
# Cluster 593:
# Indices of data points: [439, 1077, 1131, 2459, 2592, 2597, 2894, 3849]
# Number of data points in this cluster: 8
#
# Cluster 525:
# Indices of data points: [440, 474, 1056, 3577, 3702, 4005, 4211]
# Number of data points in this cluster: 7
#
# Cluster 523:
# Indices of data points: [441, 1115, 1894, 2374, 2965, 3075]
# Number of data points in this cluster: 6
#
# Cluster 524:
# Indices of data points: [443, 1511, 1695, 2299]
# Number of data points in this cluster: 4
#
# Cluster 732:
# Indices of data points: [445, 972, 1164, 2103, 2575]
# Number of data points in this cluster: 5
#
# Cluster 251:
# Indices of data points: [446, 475, 537, 1989, 2815, 3111, 3242, 4392, 4619, 4752, 4827]
# Number of data points in this cluster: 11
#
# Cluster 138:
# Indices of data points: [448, 1092, 1097, 4439, 4767]
# Number of data points in this cluster: 5
#
# Cluster 736:
# Indices of data points: [449, 1301, 3024, 4571]
# Number of data points in this cluster: 4
#
# Cluster 540:
# Indices of data points: [454, 801, 863, 3549, 4307, 4616]
# Number of data points in this cluster: 6
#
# Cluster 21:
# Indices of data points: [455, 507, 549, 611, 675, 1111, 1261, 1403, 2013, 3154, 4663, 4851, 5066]
# Number of data points in this cluster: 13
#
# Cluster 133:
# Indices of data points: [456, 767, 1835, 2418, 2429, 3552, 4492, 4807]
# Number of data points in this cluster: 8
#
# Cluster 452:
# Indices of data points: [457, 601, 638, 1307, 1852, 3512, 4189, 4547]
# Number of data points in this cluster: 8
#
# Cluster 125:
# Indices of data points: [458, 682, 1082, 1648, 2471, 3511, 3980]
# Number of data points in this cluster: 7
#
# Cluster 199:
# Indices of data points: [459, 497, 1514, 1710, 1904, 2603, 3066, 3353, 3933, 3945, 4067, 4114, 4382, 4503, 4622, 4826]
# Number of data points in this cluster: 16
#
# Cluster 448:
# Indices of data points: [461, 1711, 1890, 2036, 3435, 3699, 3781, 4415, 4455, 4549, 4578]
# Number of data points in this cluster: 11
#
# Cluster 307:
# Indices of data points: [462, 1445, 1567, 3272, 3488, 5004]
# Number of data points in this cluster: 6
#
# Cluster 291:
# Indices of data points: [463, 509, 1106, 1407, 2245, 3268, 3404, 3638, 3812, 4545, 4742]
# Number of data points in this cluster: 11
#
# Cluster 575:
# Indices of data points: [465, 947, 1653, 3413, 4894]
# Number of data points in this cluster: 5
#
# Cluster 241:
# Indices of data points: [473, 500, 548, 764, 973, 1038, 1314, 1418, 1543, 1703, 3223, 3786, 3975]
# Number of data points in this cluster: 13
#
# Cluster 107:
# Indices of data points: [476, 1336, 1610, 2257]
# Number of data points in this cluster: 4
#
# Cluster 638:
# Indices of data points: [478, 2896, 3789, 5020, 5028]
# Number of data points in this cluster: 5
#
# Cluster 246:
# Indices of data points: [479, 1874, 3104, 3270, 4512]
# Number of data points in this cluster: 5
#
# Cluster 302:
# Indices of data points: [480, 839, 932, 1463, 4145, 4327, 5014]
# Number of data points in this cluster: 7
#
# Cluster 383:
# Indices of data points: [483, 896, 1269, 1604, 1809, 2235, 4595]
# Number of data points in this cluster: 7
#
# Cluster 72:
# Indices of data points: [484, 1517, 1524, 2031, 2051, 2287, 3312, 4401, 4629, 4639, 5056]
# Number of data points in this cluster: 11
#
# Cluster 675:
# Indices of data points: [485, 727, 1193, 3467, 3735, 4740]
# Number of data points in this cluster: 6
#
# Cluster 344:
# Indices of data points: [487, 1113, 2518, 2621, 2876, 4249, 4286]
# Number of data points in this cluster: 7
#
# Cluster 115:
# Indices of data points: [489, 861, 1369, 2977, 3506, 3606, 3890, 4849, 5046]
# Number of data points in this cluster: 9
#
# Cluster 579:
# Indices of data points: [494, 912, 1736, 2006, 2470, 4813]
# Number of data points in this cluster: 6
#
# Cluster 174:
# Indices of data points: [495, 584, 1988, 3032]
# Number of data points in this cluster: 4
#
# Cluster 275:
# Indices of data points: [496, 925, 2239, 2433, 2984, 3391, 4858]
# Number of data points in this cluster: 7
#
# Cluster 326:
# Indices of data points: [501, 2291, 4710, 5070]
# Number of data points in this cluster: 4
#
# Cluster 631:
# Indices of data points: [503, 1281, 1993, 2100, 2482, 2743, 4400]
# Number of data points in this cluster: 7
#
# Cluster 108:
# Indices of data points: [504, 841, 1248, 1675, 1979, 2128, 2553, 2780, 2925, 2981, 3965, 4419, 4466, 4631, 4928]
# Number of data points in this cluster: 15
#
# Cluster 731:
# Indices of data points: [511, 796, 4424, 4449]
# Number of data points in this cluster: 4
#
# Cluster 300:
# Indices of data points: [515, 807, 1176, 1740, 1973, 2111, 3267, 3535, 3760, 3860, 3946]
# Number of data points in this cluster: 11
#
# Cluster 250:
# Indices of data points: [516, 788, 897, 1521, 2187, 4559]
# Number of data points in this cluster: 6
#
# Cluster 14:
# Indices of data points: [518, 1137, 1792, 2622, 2996, 4046, 4603, 5048]
# Number of data points in this cluster: 8
#
# Cluster 634:
# Indices of data points: [521, 3898, 4099]
# Number of data points in this cluster: 3
#
# Cluster 722:
# Indices of data points: [523, 1198, 1584, 1679, 4209, 5015]
# Number of data points in this cluster: 6
#
# Cluster 446:
# Indices of data points: [524, 535, 1128, 1754, 2473, 2619, 3275, 3442]
# Number of data points in this cluster: 8
#
# Cluster 596:
# Indices of data points: [525, 1766, 4538]
# Number of data points in this cluster: 3
#
# Cluster 720:
# Indices of data points: [529, 723, 965, 1122, 1340, 1356, 2190, 2536, 2953, 3555, 3661]
# Number of data points in this cluster: 11
#
# Cluster 694:
# Indices of data points: [530, 2779, 3102]
# Number of data points in this cluster: 3
#
# Cluster 75:
# Indices of data points: [538, 1576, 1635, 2073, 2841, 3305, 4877, 5018]
# Number of data points in this cluster: 8
#
# Cluster 52:
# Indices of data points: [540, 1388, 1597, 2777, 3776, 4158, 4691]
# Number of data points in this cluster: 7
#
# Cluster 454:
# Indices of data points: [541, 986, 1821, 2456, 3698, 4566, 4952]
# Number of data points in this cluster: 7
#
# Cluster 226:
# Indices of data points: [542, 657, 827, 2076, 2825, 3156, 3525, 4587, 4820, 5040]
# Number of data points in this cluster: 10
#
# Cluster 150:
# Indices of data points: [543, 2359, 2598, 2834, 4074, 4219, 4800]
# Number of data points in this cluster: 7
#
# Cluster 412:
# Indices of data points: [545, 1453, 1919, 2136, 3375, 3592, 4127]
# Number of data points in this cluster: 7
#
# Cluster 126:
# Indices of data points: [547, 1118, 1155, 1702, 1958, 2333, 2608, 2653, 2677, 3264]
# Number of data points in this cluster: 10
#
# Cluster 665:
# Indices of data points: [552, 1963, 2077, 2489, 2615, 3926, 4292, 4359]
# Number of data points in this cluster: 8
#
# Cluster 449:
# Indices of data points: [554, 1342, 2351, 2976, 3827, 3896]
# Number of data points in this cluster: 6
#
# Cluster 24:
# Indices of data points: [563, 864, 2550, 3303, 3571, 3596, 4106, 4811]
# Number of data points in this cluster: 8
#
# Cluster 330:
# Indices of data points: [564, 688, 1005, 2332, 4912]
# Number of data points in this cluster: 5
#
# Cluster 603:
# Indices of data points: [565, 2229, 3570, 4670]
# Number of data points in this cluster: 4
#
# Cluster 373:
# Indices of data points: [570, 1168, 1643, 1750, 3410, 3983]
# Number of data points in this cluster: 6
#
# Cluster 193:
# Indices of data points: [573, 991, 2065, 2643, 3274, 3733, 3855]
# Number of data points in this cluster: 7
#
# Cluster 238:
# Indices of data points: [574, 1049, 1101, 2253, 2764, 2930, 3074, 4430, 4484, 4867]
# Number of data points in this cluster: 10
#
# Cluster 696:
# Indices of data points: [576, 754, 2396, 2685, 3748, 4240, 4298, 4443, 4783]
# Number of data points in this cluster: 9
#
# Cluster 151:
# Indices of data points: [577, 1640, 4467]
# Number of data points in this cluster: 3
#
# Cluster 467:
# Indices of data points: [578, 710, 962, 1052, 1219, 1411, 1794, 1917, 1968, 3092, 3096, 4852]
# Number of data points in this cluster: 12
#
# Cluster 57:
# Indices of data points: [579, 1617, 1638, 1793, 1847, 2033, 2735, 3221, 3297, 4615]
# Number of data points in this cluster: 10
#
# Cluster 311:
# Indices of data points: [580, 1654, 2303, 3790, 4531, 4908]
# Number of data points in this cluster: 6
#
# Cluster 541:
# Indices of data points: [583, 813, 1154, 1405, 2343, 2408, 2916, 4412, 4902]
# Number of data points in this cluster: 9
#
# Cluster 340:
# Indices of data points: [586, 2234, 4287]
# Number of data points in this cluster: 3
#
# Cluster 168:
# Indices of data points: [587, 1925, 2236, 2490, 3145, 4077, 4569]
# Number of data points in this cluster: 7
#
# Cluster 243:
# Indices of data points: [588, 670, 784, 1133, 1275, 1876, 2285, 2875, 3053, 4417, 4459, 4937, 4954, 4975]
# Number of data points in this cluster: 14
#
# Cluster 64:
# Indices of data points: [590, 1830, 1985, 1998, 2023, 2772, 4796]
# Number of data points in this cluster: 7
#
# Cluster 216:
# ...
# Number of data points in this cluster: 5
#
# Cluster 332:
# Indices of data points: [1706, 3564]
# Number of data points in this cluster: 2
#
# Cluster 345:
# Indices of data points: [1715, 2398, 2900, 3133, 3706, 4366]
# Number of data points in this cluster: 6
#
# Cluster 99:
# Indices of data points: [1720, 3630, 3642, 4977]
# Number of data points in this cluster: 4
#
# Cluster 211:
# Indices of data points: [1724, 2614, 2980, 3968, 4753]
# Number of data points in this cluster: 5
#
# Cluster 342:
# Indices of data points: [1742, 1868, 2538, 3588, 3636, 3907, 3976]
# Number of data points in this cluster: 7
#
# Cluster 281:
# Indices of data points: [1747, 3368]
# Number of data points in this cluster: 2
#
# Cluster 165:
# Indices of data points: [1758, 2365, 2379, 3627]
# Number of data points in this cluster: 4
#
# Cluster 682:
# Indices of data points: [1762, 4146, 4360, 4762]
# Number of data points in this cluster: 4
#
# Cluster 628:
# Indices of data points: [1764, 4433]
# Number of data points in this cluster: 2
#
# Cluster 338:
# Indices of data points: [1773, 2562, 3136, 5044]
# Number of data points in this cluster: 4
#
# Cluster 483:
# Indices of data points: [1774, 2915, 3255, 3364, 3369, 3381]
# Number of data points in this cluster: 6
#
# Cluster 290:
# Indices of data points: [1775, 2572, 3850, 4085]
# Number of data points in this cluster: 4
#
# Cluster 319:
# Indices of data points: [1781, 2217, 2903, 3836, 4299]
# Number of data points in this cluster: 5
#
# Cluster 422:
# Indices of data points: [1782, 2293]
# Number of data points in this cluster: 2
#
# Cluster 153:
# Indices of data points: [1784, 2453, 2721, 4063, 4139, 4166, 4373]
# Number of data points in this cluster: 7
#
# Cluster 92:
# Indices of data points: [1785, 3328, 3711, 4040, 4137]
# Number of data points in this cluster: 5
#
# Cluster 711:
# Indices of data points: [1795, 1808, 2119, 3883]
# Number of data points in this cluster: 4
#
# Cluster 617:
# Indices of data points: [1796, 3000, 3670, 3994, 4112]
# Number of data points in this cluster: 5
#
# Cluster 450:
# Indices of data points: [1797, 1831, 2551, 3682, 3904]
# Number of data points in this cluster: 5
#
# Cluster 164:
# Indices of data points: [1798, 2381, 3779, 4035, 4045]
# Number of data points in this cluster: 5
#
# Cluster 536:
# Indices of data points: [1800, 1836, 3239]
# Number of data points in this cluster: 3
#
# Cluster 66:
# Indices of data points: [1806, 2901, 3318, 3373, 3396, 3826, 4070]
# Number of data points in this cluster: 7
#
# Cluster 616:
# Indices of data points: [1815, 2585, 4394]
# Number of data points in this cluster: 3
#
# Cluster 327:
# Indices of data points: [1816, 2475, 2522, 4480, 4568]
# Number of data points in this cluster: 5
#
# Cluster 112:
# Indices of data points: [1819, 2602, 3652, 4312]
# Number of data points in this cluster: 4
#
# Cluster 141:
# Indices of data points: [1822, 1938, 2838, 2954, 3461, 4162, 4997]
# Number of data points in this cluster: 7
#
# Cluster 334:
# Indices of data points: [1825, 3331, 3362, 3385, 4050]
# Number of data points in this cluster: 5
#
# Cluster 333:
# Indices of data points: [1832, 1877, 2967, 3386, 3601]
# Number of data points in this cluster: 5
#
# Cluster 184:
# Indices of data points: [1839, 1939, 2323, 3479, 3684, 4792, 4967]
# Number of data points in this cluster: 7
#
# Cluster 552:
# Indices of data points: [1840, 1872, 3258, 3694, 4333, 4518, 4861]
# Number of data points in this cluster: 7
#
# Cluster 242:
# Indices of data points: [1848, 2037, 2770, 4066, 4222, 4656, 5012]
# Number of data points in this cluster: 7
#
# Cluster 188:
# Indices of data points: [1849, 2056, 2368, 3116, 3891]
# Number of data points in this cluster: 5
#
# Cluster 583:
# Indices of data points: [1851, 2968, 5024]
# Number of data points in this cluster: 3
#
# Cluster 362:
# Indices of data points: [1860, 2506, 3557]
# Number of data points in this cluster: 3
#
# Cluster 143:
# Indices of data points: [1869, 1999, 2004, 4097, 4380, 4446]
# Number of data points in this cluster: 6
#
# Cluster 625:
# Indices of data points: [1871, 2730, 2877, 4321]
# Number of data points in this cluster: 4
#
# Cluster 396:
# Indices of data points: [1875, 2325, 2356, 2358, 2801]
# Number of data points in this cluster: 5
#
# Cluster 215:
# Indices of data points: [1891, 1905, 2282]
# Number of data points in this cluster: 3
#
# Cluster 401:
# Indices of data points: [1930, 4273]
# Number of data points in this cluster: 2
#
# Cluster 70:
# Indices of data points: [1949, 3497, 3901]
# Number of data points in this cluster: 3
#
# Cluster 94:
# Indices of data points: [1956, 2118, 2384, 2971]
# Number of data points in this cluster: 4
#
# Cluster 724:
# Indices of data points: [1990, 2312, 3291]
# Number of data points in this cluster: 3
#
# Cluster 513:
# Indices of data points: [1991, 2555, 2762, 3389]
# Number of data points in this cluster: 4
#
# Cluster 279:
# Indices of data points: [2001, 2144, 2537, 3099, 3232, 3837]
# Number of data points in this cluster: 6
#
# Cluster 667:
# Indices of data points: [2011, 2690, 2797]
# Number of data points in this cluster: 3
#
# Cluster 419:
# Indices of data points: [2016, 3213, 4315, 4562]
# Number of data points in this cluster: 4
#
# Cluster 42:
# Indices of data points: [2035, 2104, 2357, 3798, 4028]
# Number of data points in this cluster: 5
#
# Cluster 726:
# Indices of data points: [2038, 2122, 2251]
# Number of data points in this cluster: 3
#
# Cluster 529:
# Indices of data points: [2045, 2270]
# Number of data points in this cluster: 2
#
# Cluster 574:
# Indices of data points: [2047]
# Number of data points in this cluster: 1
#
# Cluster 350:
# Indices of data points: [2050, 3723, 4191]
# Number of data points in this cluster: 3
#
# Cluster 668:
# Indices of data points: [2052, 3009]
# Number of data points in this cluster: 2
#
# Cluster 45:
# Indices of data points: [2055, 3691, 3993, 4080, 4095, 4180]
# Number of data points in this cluster: 6
#
# Cluster 236:
# Indices of data points: [2060, 3002, 4840]
# Number of data points in this cluster: 3
#
# Cluster 604:
# Indices of data points: [2063]
# Number of data points in this cluster: 1
#
# Cluster 410:
# Indices of data points: [2074, 3949, 4708, 5037]
# Number of data points in this cluster: 4
#
# Cluster 689:
# Indices of data points: [2075, 3317, 3868]
# Number of data points in this cluster: 3
#
# Cluster 400:
# Indices of data points: [2087, 3119, 4038]
# Number of data points in this cluster: 3
#
# Cluster 740:
# Indices of data points: [2091, 3953, 4970, 4978]
# Number of data points in this cluster: 4
#
# Cluster 466:
# Indices of data points: [2097, 2691, 2831, 3654, 4218]
# Number of data points in this cluster: 5
#
# Cluster 399:
# Indices of data points: [2108, 2216, 2284, 2611]
# Number of data points in this cluster: 4
#
# Cluster 663:
# Indices of data points: [2113, 3725, 3841]
# Number of data points in this cluster: 3
#
# Cluster 538:
# Indices of data points: [2115, 3322, 4060]
# Number of data points in this cluster: 3
#
# Cluster 645:
# Indices of data points: [2116, 3603, 3613]
# Number of data points in this cluster: 3
#
# Cluster 253:
# Indices of data points: [2130, 2543, 2902, 3041]
# Number of data points in this cluster: 4
#
# Cluster 74:
# Indices of data points: [2134, 2345, 3079, 4551, 4575]
# Number of data points in this cluster: 5
#
# Cluster 717:
# Indices of data points: [2137, 3252]
# Number of data points in this cluster: 2
#
# Cluster 490:
# Indices of data points: [2140, 2302, 3278, 3301, 3832, 4052, 4427, 4665]
# Number of data points in this cluster: 8
#
# Cluster 276:
# Indices of data points: [2151, 3123, 4386]
# Number of data points in this cluster: 3
#
# Cluster 244:
# Indices of data points: [2166, 2405, 2474, 2988, 3784, 4348]
# Number of data points in this cluster: 6
#
# Cluster 758:
# Indices of data points: [2186, 2994]
# Number of data points in this cluster: 2
#
# Cluster 402:
# Indices of data points: [2192, 2833, 4261, 4423, 4825]
# Number of data points in this cluster: 5
#
# Cluster 358:
# Indices of data points: [2209, 3325, 3951, 4039, 4685]
# Number of data points in this cluster: 5
#
# Cluster 355:
# Indices of data points: [2237, 3626, 4923]
# Number of data points in this cluster: 3
#
# Cluster 376:
# Indices of data points: [2241, 2637, 4250, 4303, 4893]
# Number of data points in this cluster: 5
#
# Cluster 661:
# Indices of data points: [2272, 4164]
# Number of data points in this cluster: 2
#
# Cluster 496:
# Indices of data points: [2275, 2542, 2806, 3990]
# Number of data points in this cluster: 4
#
# Cluster 516:
# Indices of data points: [2277, 2843, 3359, 3360, 3791, 3902]
# Number of data points in this cluster: 6
#
# Cluster 660:
# Indices of data points: [2283, 4966, 5000]
# Number of data points in this cluster: 3
#
# Cluster 695:
# Indices of data points: [2296, 2997]
# Number of data points in this cluster: 2
#
# Cluster 554:
# Indices of data points: [2305, 3485, 4016]
# Number of data points in this cluster: 3
#
# Cluster 180:
# Indices of data points: [2307, 3316, 3367, 3398, 3696, 3768, 4091, 4318, 4505, 4511]
# Number of data points in this cluster: 10
#
# Cluster 464:
# Indices of data points: [2308, 2964, 4111]
# Number of data points in this cluster: 3
#
# Cluster 502:
# Indices of data points: [2315, 3600, 3815]
# Number of data points in this cluster: 3
#
# Cluster 235:
# Indices of data points: [2338, 3061, 3323, 4113]
# Number of data points in this cluster: 4
#
# Cluster 398:
# Indices of data points: [2342, 2904, 2913, 4003, 4356]
# Number of data points in this cluster: 5
#
# Cluster 348:
# Indices of data points: [2349, 3742, 4365, 4544]
# Number of data points in this cluster: 4
#
# Cluster 709:
# Indices of data points: [2361, 3989]
# Number of data points in this cluster: 2
#
# Cluster 321:
# Indices of data points: [2367, 2517, 2520, 4817]
# Number of data points in this cluster: 4
#
# Cluster 608:
# Indices of data points: [2370, 3310]
# Number of data points in this cluster: 2
#
# Cluster 580:
# Indices of data points: [2394, 3544, 3918]
# Number of data points in this cluster: 3
#
# Cluster 656:
# Indices of data points: [2403, 4244, 4730]
# Number of data points in this cluster: 3
#
# Cluster 566:
# Indices of data points: [2410, 3001, 4625]
# Number of data points in this cluster: 3
#
# Cluster 599:
# Indices of data points: [2444, 4185]
# Number of data points in this cluster: 2
#
# Cluster 699:
# Indices of data points: [2458]
# Number of data points in this cluster: 1
#
# Cluster 436:
# Indices of data points: [2478, 2910, 3563]
# Number of data points in this cluster: 3
#
# Cluster 588:
# Indices of data points: [2481, 3604, 3721]
# Number of data points in this cluster: 3
#
# Cluster 688:
# Indices of data points: [2530, 2830, 3290]
# Number of data points in this cluster: 3
#
# Cluster 313:
# Indices of data points: [2557, 3708]
# Number of data points in this cluster: 2
#
# Cluster 612:
# Indices of data points: [2564, 2828, 3130, 3580, 3934, 4090, 4723]
# Number of data points in this cluster: 7
#
# Cluster 470:
# Indices of data points: [2577, 4488]
# Number of data points in this cluster: 2
#
# Cluster 547:
# Indices of data points: [2596, 3541, 3593]
# Number of data points in this cluster: 3
#
# Cluster 219:
# Indices of data points: [2617, 2659, 3030, 3138, 3320, 3920, 4177, 4707, 4841, 4884]
# Number of data points in this cluster: 10
#
# Cluster 585:
# Indices of data points: [2655]
# Number of data points in this cluster: 1
#
# Cluster 171:
# Indices of data points: [2666, 3854, 4051]
# Number of data points in this cluster: 3
#
# Cluster 558:
# Indices of data points: [2719, 4780]
# Number of data points in this cluster: 2
#
# Cluster 570:
# Indices of data points: [2736, 3059]
# Number of data points in this cluster: 2
#
# Cluster 651:
# Indices of data points: [2749, 2945]
# Number of data points in this cluster: 2
#
# Cluster 274:
# Indices of data points: [2766, 3355, 3903, 4198, 4398]
# Number of data points in this cluster: 5
#
# Cluster 591:
# Indices of data points: [2794, 3112, 4346]
# Number of data points in this cluster: 3
#
# Cluster 148:
# Indices of data points: [2803, 4025, 4203]
# Number of data points in this cluster: 3
#
# Cluster 507:
# Indices of data points: [2810, 4434]
# Number of data points in this cluster: 2
#
# Cluster 498:
# Indices of data points: [2811, 2963, 4094]
# Number of data points in this cluster: 3
#
# Cluster 192:
# Indices of data points: [2840, 3025, 3478, 3693, 3740, 3853]
# Number of data points in this cluster: 6
#
# Cluster 209:
# Indices of data points: [2846, 3178, 3617, 4226, 4522, 4905]
# Number of data points in this cluster: 6
#
# Cluster 63:
# Indices of data points: [2851, 4280, 4570]
# Number of data points in this cluster: 3
#
# Cluster 692:
# Indices of data points: [2872, 3810, 4141]
# Number of data points in this cluster: 3
#
# Cluster 681:
# Indices of data points: [2893, 3273, 4275]
# Number of data points in this cluster: 3
#
# Cluster 526:
# Indices of data points: [2897, 3115, 4082]
# Number of data points in this cluster: 3
#
# Cluster 659:
# Indices of data points: [2912, 3140, 4055, 4344]
# Number of data points in this cluster: 4
#
# Cluster 489:
# Indices of data points: [2923]
# Number of data points in this cluster: 1
#
# Cluster 223:
# Indices of data points: [2989, 3476, 3659]
# Number of data points in this cluster: 3
#
# Cluster 458:
# Indices of data points: [3027, 3877]
# Number of data points in this cluster: 2
#
# Cluster 306:
# Indices of data points: [3049, 3930, 3948]
# Number of data points in this cluster: 3
#
# Cluster 632:
# Indices of data points: [3057, 3816, 4098]
# Number of data points in this cluster: 3
#
# Cluster 676:
# Indices of data points: [3125, 3356, 3645]
# Number of data points in this cluster: 3
#
# Cluster 629:
# Indices of data points: [3141, 3857, 4075]
# Number of data points in this cluster: 3
#
# Cluster 655:
# Indices of data points: [3149, 4153, 4278]
# Number of data points in this cluster: 3
#
# Cluster 746:
# Indices of data points: [3151, 4322, 4953]
# Number of data points in this cluster: 3
#
# Cluster 601:
# Indices of data points: [3152, 3879]
# Number of data points in this cluster: 2
#
# Cluster 170:
# Indices of data points: [3153, 3663, 3705]
# Number of data points in this cluster: 3
#
# Cluster 61:
# Indices of data points: [3285, 3572, 3939, 4013, 4653]
# Number of data points in this cluster: 5
#
# Cluster 649:
# Indices of data points: [3334, 3771, 4349]
# Number of data points in this cluster: 3
#
# Cluster 745:
# Indices of data points: [3406]
# Number of data points in this cluster: 1
#
# Cluster 672:
# Indices of data points: [3414, 4086]
# Number of data points in this cluster: 2
#
# Cluster 474:
# Indices of data points: [3472, 3503, 3681, 3923]
# Number of data points in this cluster: 4
#
# Cluster 715:
# Indices of data points: [3526, 3625, 4784]
# Number of data points in this cluster: 3
#
# Cluster 562:
# Indices of data points: [3573, 4744]
# Number of data points in this cluster: 2
#
# Cluster 545:
# Indices of data points: [3608, 4350, 4641]
# Number of data points in this cluster: 3
#
# Cluster 503:
# Indices of data points: [3612, 4341, 4931]
# Number of data points in this cluster: 3
#
# Cluster 624:
# Indices of data points: [3619, 3658, 3690, 4837]
# Number of data points in this cluster: 4
#
# Cluster 607:
# Indices of data points: [3653, 3689, 4001]
# Number of data points in this cluster: 3
#
# Cluster 277:
# Indices of data points: [3701, 4118, 4256]
# Number of data points in this cluster: 3
#
# Cluster 417:
# Indices of data points: [3704, 4450, 4471]
# Number of data points in this cluster: 3
#
# Cluster 702:
# Indices of data points: [3823, 3961]
# Number of data points in this cluster: 2
#
# Cluster 221:
# Indices of data points: [3847, 4022]
# Number of data points in this cluster: 2
#
# Cluster 708:
# Indices of data points: [3867, 4034, 4436]
# Number of data points in this cluster: 3
#
# Cluster 476:
# Indices of data points: [3971, 4031, 4183]
# Number of data points in this cluster: 3
#
# Cluster 437:
# Indices of data points: [4009, 4018]
# Number of data points in this cluster: 2
#
# Cluster 441:
# Indices of data points: [4073, 4448, 4526]
# Number of data points in this cluster: 3
#
# Cluster 671:
# Indices of data points: [4107, 4390]
# Number of data points in this cluster: 2
#
# Cluster 387:
# Indices of data points: [4110, 4200, 4724]
# Number of data points in this cluster: 3
#
# Cluster 227:
# Indices of data points: [4197, 5034]
# Number of data points in this cluster: 2
#
# Cluster 754:
# Indices of data points: [4253, 4301]
# Number of data points in this cluster: 2
#
# Cluster 759:
# Indices of data points: [4267, 4293]
# Number of data points in this cluster: 2
#
# Cluster 569:
# Indices of data points: [4362]
# Number of data points in this cluster: 1
#
# Cluster 499:
# Indices of data points: [4375]
# Number of data points in this cluster: 1

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist

# Load the feature matrix from the .npy file
features = np.load(r"C:\SumMe\Augmentation\Augcr\features_last_lstm.npy")

# Optional: Preprocess the data by scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform Agglomerative Clustering
n_clusters = 761  # Set the desired number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)

# Fit the model and predict the labels
clustering_labels = clustering.fit_predict(features_scaled)

# Group the indices by cluster labels
cluster_dict = {}

for idx, label in enumerate(clustering_labels):
    if label not in cluster_dict:
        cluster_dict[label] = []
    cluster_dict[label].append(idx)

# Function to get the keyframe index (centroid-based approach)
def get_keyframe_for_cluster(cluster_indices):
    # Extract the features for the current cluster
    cluster_features = features_scaled[cluster_indices]
    
    # Compute the centroid of the cluster (mean of the features)
    centroid = np.mean(cluster_features, axis=0)
    
    # Calculate the distance from each point to the centroid
    distances = cdist([centroid], cluster_features)
    
    # Get the index of the point closest to the centroid
    keyframe_index = cluster_indices[np.argmin(distances)]
    return keyframe_index

# Generate and display the sequence of keyframe indices for each cluster
keyframe_sequence = []

for cluster_label, indices in cluster_dict.items():
    keyframe_index = get_keyframe_for_cluster(indices)
    keyframe_sequence.append((cluster_label, keyframe_index))

# Print the sequence of keyframes in the desired format
for cluster_label, keyframe_index in keyframe_sequence:
    print(f"Cluster {cluster_label}: Keyframe index: {keyframe_index}")
# Out:
# Cluster 408: Keyframe index: 2722
# Cluster 128: Keyframe index: 1591
# Cluster 374: Keyframe index: 594
# Cluster 207: Keyframe index: 5032
# Cluster 159: Keyframe index: 5065
# Cluster 318: Keyframe index: 121
# Cluster 375: Keyframe index: 6
# Cluster 474: Keyframe index: 3503
# Cluster 715: Keyframe index: 4784
# Cluster 562: Keyframe index: 4744
# Cluster 545: Keyframe index: 4641
# Cluster 503: Keyframe index: 4341
# Cluster 624: Keyframe index: 3619
# Cluster 607: Keyframe index: 4001
# Cluster 277: Keyframe index: 4118
# Cluster 417: Keyframe index: 3704
# Cluster 702: Keyframe index: 3823
# Cluster 221: Keyframe index: 3847
# Cluster 708: Keyframe index: 4034
# Cluster 476: Keyframe index: 3971
# Cluster 437: Keyframe index: 4018
# Cluster 441: Keyframe index: 4073
# Cluster 671: Keyframe index: 4107
# Cluster 387: Keyframe index: 4724
# Cluster 227: Keyframe index: 5034
# Cluster 754: Keyframe index: 4253
# Cluster 759: Keyframe index: 4267
# Cluster 569: Keyframe index: 4362
# Cluster 499: Keyframe index: 4375

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist
from scipy.io import savemat  # Import savemat to save in .mat format
import pandas as pd  # Import pandas for CSV file export

# Load the LSTM features from the .npy file
lstm_features = np.load(r"C:\SumMe\Augmentation\AugBus\features_last_lstm.npy")

# Flatten LSTM features for clustering (if necessary)
n_samples = lstm_features.shape[0]  # Define the number of samples
n_clusters = 761  # Set the number of clusters
lstm_features_flattened = lstm_features.reshape(n_samples, -1)

# Standardizing the data before clustering
scaler = StandardScaler()
lstm_features_scaled = scaler.fit_transform(lstm_features_flattened)

# Apply Agglomerative Clustering with 'ward' linkage (no need to specify affinity)
agg_clustering = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
labels = agg_clustering.fit_predict(lstm_features_scaled)

# Group data points by cluster
clustered_data = {}

for idx, label in enumerate(labels):
    if label not in clustered_data:
        clustered_data[label] = []
    clustered_data[label].append(idx)

# Find keyframe for each cluster
keyframes = {}

for cluster_id, indices in clustered_data.items():
    # Get the feature vectors for the data points in this cluster
    cluster_features = lstm_features_scaled[indices]
    
    # Compute the centroid of the cluster (average of all feature vectors in the cluster)
    centroid = np.mean(cluster_features, axis=0)
    
    # Compute the Euclidean distance from each data point to the centroid
    distances = cdist(cluster_features, [centroid], metric='euclidean')
    
    # Find the index of the closest data point (keyframe)
    keyframe_idx = indices[np.argmin(distances)]
    
    # Store the keyframe index for the cluster
    keyframes[cluster_id] = keyframe_idx

# Create a binary matrix of shape (n_samples, n_clusters)
keyframe_matrix = np.zeros((n_samples, n_clusters), dtype=int)

# Mark the keyframes (set the corresponding index to 1)
for cluster_id, keyframe_idx in keyframes.items():
    keyframe_matrix[keyframe_idx, cluster_id] = 1

# Save the keyframe binary matrix as a .mat file
keyframe_data = {'keyframe_matrix': keyframe_matrix}  # Create a dictionary to save in .mat format
savemat(r'C:\SumMe\Augmentation\Augcr\features_last_lstm1.mat', keyframe_data)

# Print confirmation for .mat file
print(f"Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.mat")
print(f"Dimensions of the keyframe binary matrix: {keyframe_matrix.shape}")

# Save the keyframe binary matrix as a .csv file
keyframe_matrix_df = pd.DataFrame(keyframe_matrix)  # Convert matrix to DataFrame
keyframe_matrix_df.to_csv(r'C:\SumMe\Augmentation\Augcr\features_last_lstm1.csv', index=False)

# Print confirmation for .csv file
print(f"Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.csv")

# Print the sequence of keyframe indices in order of cluster numbers (Cluster 0, Cluster 1, ..., Cluster n)
print("\nKeyframe indices for each cluster:")
for cluster_id in range(n_clusters):
    if cluster_id in keyframes:
        print(f"Cluster {cluster_id}: Keyframe Index {keyframes[cluster_id]}")
    else:
        print(f"Cluster {cluster_id}: No keyframe found")
# Out:
# Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.mat
# Dimensions of the keyframe binary matrix: (5131, 761)
# Keyframe binary matrix saved to C:/SumMe/Spectral/AugJ/features_last_lstm1.csv
#
# Keyframe indices for each cluster:
# Cluster 0: Keyframe Index 3672
# Cluster 1: Keyframe Index 2349
# Cluster 2: Keyframe Index 5064
# Cluster 3: Keyframe Index 3508
# Cluster 4: Keyframe Index 3496
# Cluster 5: Keyframe Index 2685
# Cluster 6: Keyframe Index 70
# Cluster 7: Keyframe Index 807
# Cluster 8: Keyframe Index 972
# Cluster 9: Keyframe Index 4185
# Cluster 10: Keyframe Index 2967
# Cluster 11: Keyframe Index 2846
# Cluster 12: Keyframe Index 3438
# Cluster 13: Keyframe Index 1642
# Cluster 14: Keyframe Index 4767
# Cluster 15: Keyframe Index 3154
# Cluster 16: Keyframe Index 1882
# Cluster 17: Keyframe Index 1374
# Cluster 18: Keyframe Index 2380
# Cluster 19: Keyframe Index 1956
# Cluster 20: Keyframe Index 645
# Cluster 21: Keyframe Index 4875
# Cluster 22: Keyframe Index 2764
# Cluster 23: Keyframe Index 3359
# Cluster 24: Keyframe Index 2814
# Cluster 25: Keyframe Index 1283
# Cluster 26: Keyframe Index 2859
# Cluster 27: Keyframe Index 2690
# Cluster 28: Keyframe Index 771
# Cluster 29: Keyframe Index 3139
# Cluster 30: Keyframe Index 3813
# Cluster 31: Keyframe Index 2209
# Cluster 32: Keyframe Index 1539
# Cluster 33: Keyframe Index 2039
# Cluster 34: Keyframe Index 1002
# Cluster 35: Keyframe Index 2938
# Cluster 36: Keyframe Index 1263
# Cluster 37: Keyframe Index 1766
# Cluster 38: Keyframe Index 4023
# Cluster 39: Keyframe Index 864
# Cluster 40: Keyframe Index 696
# Cluster 41: Keyframe Index 3131
# Cluster 42: Keyframe Index 3578
# Cluster 43: Keyframe Index 398
# Cluster 44: Keyframe Index 2978
# Cluster 45: Keyframe Index 2186
# Cluster 46: Keyframe Index 4520
# Cluster 47: Keyframe Index 2220
# Cluster 48: Keyframe Index 1284
# Cluster 49: Keyframe Index 7
# Cluster 50: Keyframe Index 1484
# Cluster 51: Keyframe Index 3901
# Cluster 52: Keyframe Index 2097
# Cluster 53: Keyframe Index 35
# Cluster 54: Keyframe Index 2440
# Cluster 55: Keyframe Index 1237
# Cluster 56: Keyframe Index 3933
# Cluster 57: Keyframe Index 812
# Cluster 58: Keyframe Index 2886
# Cluster 709: Keyframe Index 473
# Cluster 710: Keyframe Index 563
# Cluster 711: Keyframe Index 744
# Cluster 712: Keyframe Index 4383
# Cluster 713: Keyframe Index 3389
# Cluster 714: Keyframe Index 4431
# Cluster 715: Keyframe Index 2562
# Cluster 716: Keyframe Index 3650
# Cluster 717: Keyframe Index 4082
# Cluster 718: Keyframe Index 2416
# Cluster 719: Keyframe Index 2456
# Cluster 720: Keyframe Index 1086
# Cluster 721: Keyframe Index 5095
# Cluster 722: Keyframe Index 2139
# Cluster 723: Keyframe Index 5104
# Cluster 724: Keyframe Index 980
# Cluster 725: Keyframe Index 5125
# Cluster 726: Keyframe Index 4556
# Cluster 727: Keyframe Index 1243
# Cluster 728: Keyframe Index 3775
# Cluster 729: Keyframe Index 4435
# Cluster 730: Keyframe Index 3456
# Cluster 731: Keyframe Index 1948
# Cluster 732: Keyframe Index 3852
# Cluster 733: Keyframe Index 2228
# Cluster 734: Keyframe Index 1153
# Cluster 735: Keyframe Index 615
# Cluster 736: Keyframe Index 2087
# Cluster 737: Keyframe Index 2487
# Cluster 738: Keyframe Index 2784
# Cluster 739: Keyframe Index 4477
# Cluster 740: Keyframe Index 1739
# Cluster 741: Keyframe Index 1327
# Cluster 742: Keyframe Index 3972
# Cluster 743: Keyframe Index 74
# Cluster 744: Keyframe Index 3047
# Cluster 745: Keyframe Index 1108
# Cluster 746: Keyframe Index 3344
# Cluster 747: Keyframe Index 1616
# Cluster 748: Keyframe Index 435
# Cluster 749: Keyframe Index 4473
# Cluster 750: Keyframe Index 837
# Cluster 751: Keyframe Index 3026
# Cluster 752: Keyframe Index 16
# Cluster 753: Keyframe Index 9
# Cluster 754: Keyframe Index 2082
# Cluster 755: Keyframe Index 799
# Cluster 756: Keyframe Index 1454
# Cluster 757: Keyframe Index 2181
# Cluster 758: Keyframe Index 4936
# Cluster 759: Keyframe Index 1465
# Cluster 760: Keyframe Index 2964

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import scipy.io

# Step 1: Load the annotator labels from the .mat file
annotator_path = r"C:\SumMe\GT\Car_railcrossing.mat" # Path to the .mat file
mat_data = scipy.io.loadmat(annotator_path)

# Check the keys in the .mat file
print("Keys in the .mat file:", mat_data.keys())


user_scores = mat_data['user_score']  
print(f"Shape of user_score: {user_scores.shape}")

# Step 2: Load our model's predictions from the .csv file
our_path = r"C:\SumMe\Augmentation\Augcr\features_last_lstm1.csv" # Path to the CSV file
u1 = pd.read_csv(our_path, header=None).values.flatten()  # Our model's predictions (binary array)


print(f"Shape of model's predictions (u1): {u1.shape}")

# Ensure that the length of u1 matches the number of rows in user_scores
if u1.shape[0] != user_scores.shape[0]:
    print(f"Warning: Mismatched lengths. Adjusting the data...")
    u1 = u1[:user_scores.shape[0]]  # Truncate u1 to match the number of rows in user_scores

# Step 3: Ensure both u1 and user_scores are binary (logical values, 0 or 1)
u1 = u1.astype(bool)

# Step 4: Compute the F1-Score for each of the 15 datasets (columns in user_scores)
f1_scores = []  # List to store F1 scores for each dataset

for i in range(user_scores.shape[1]):  # Loop through the 15 columns
    u2 = user_scores[:, i]  # Extract the i-th column (ground truth labels for the i-th dataset)
    
    # Ensure u2 is a boolean array
    u2 = u2.astype(bool)
    
    # Step 5: Compute the confusion matrix
    cm = confusion_matrix(u2, u1)
    
    # Extract the confusion matrix components
    tn, fp, fn, tp = cm.ravel()  # Unpack the confusion matrix
    
    # Debugging step: Print confusion matrix for the 4th column
    if i == 3:  # Checking the 4th column
        print(f"Confusion Matrix for user_score column {i+1} (4th column):")
        print(f"TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")
    
    # Check for zero denominators and calculate Precision, Recall, and F1-Score safely
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    
    # F1 Score is calculated if both precision and recall are non-zero, otherwise it's 0 or nan
    if precision + recall > 0:
        fscore = 2 * (precision * recall) / (precision + recall)
    else:
        fscore = 0.0  # F1 score is 0 if either precision or recall is zero
    
    f1_scores.append(fscore)  # Append F1 score for this dataset
    
    # Print the F1 Score for this dataset
    print(f"\nF1-Score for user_score column {i+1}: {fscore:.4f}")

# Step 6: Output all the F1 scores for the 15 datasets
print("\nAll F1 Scores:")
for i, score in enumerate(f1_scores, 1):
    print(f"F1 Score for user_score column {i}: {score:.4f}")
# Out:
# Keys in the .mat file: dict_keys(['__header__', '__version__', '__globals__', 'all_userIDs', 'segments', 'nFrames', 'video_duration', 'FPS', 'gt_score', 'user_score'])
# Shape of user_score: (5075, 16)
# Shape of model's predictions (u1): (3905452,)
# Warning: Mismatched lengths. Adjusting the data...
#
# F1-Score for user_score column 1: 0.4962
#
# F1-Score for user_score column 2: 0.3265
#
# F1-Score for user_score column 3: 0.2589
# Confusion Matrix for user_score column 4 (4th column):
# TN: 4052, FP: 304, FN: 262, TP: 457
#
# F1-Score for user_score column 4: 0.6176
#
# F1-Score for user_score column 5: 0.5352
#
# F1-Score for user_score column 6: 0.1983
#
# F1-Score for user_score column 7: 0.3380
#
# F1-Score for user_score column 8: 0.2029
#
# F1-Score for user_score column 9: 0.2070
#
# F1-Score for user_score column 10: 0.4147
#
# F1-Score for user_score column 11: 0.4290
#
# F1-Score for user_score column 12: 0.4493
#
# F1-Score for user_score column 13: 0.5868
#
# F1-Score for user_score column 14: 0.3307
#
# F1-Score for user_score column 15: 0.5073
#
# F1-Score for user_score column 16: 0.2847
#
# All F1 Scores:
# F1 Score for user_score column 1: 0.4962
# F1 Score for user_score column 2: 0.3265
# F1 Score for user_score column 3: 0.2589
# F1 Score for user_score column 4: 0.6176
# F1 Score for user_score column 5: 0.5352
# F1 Score for user_score column 6: 0.1983
# F1 Score for user_score column 7: 0.3380
# F1 Score for user_score column 8: 0.2029
# F1 Score for user_score column 9: 0.2070
# F1 Score for user_score column 10: 0.4147
# F1 Score for user_score column 11: 0.4290
# F1 Score for user_score column 12: 0.4493
# F1 Score for user_score column 13: 0.5868
# F1 Score for user_score column 14: 0.3307
# F1 Score for user_score column 15: 0.5073
# F1 Score for user_score column 16: 0.2847
